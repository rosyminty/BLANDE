# %%
import pandas as pd
import numpy as np

# %%
V_SL = pd.read_csv('./data/Vogue_SaintLaurent_ccc.csv' , sep='|', encoding='utf-8')
V_SL
# Out:
#                                   title        date  \
# 0                   생 로랑 2020 가을 로제 캠페인  2020.07.24
# 1    입생로랑 뷰티만의 인텐스 누드와 대체 불가 현아의 짜릿한 만남  2020.06.26
# 2                  입생로랑 틴트 혁명 NEW 벨벳 틴트  2020.04.23
# 3         한예슬의 선택, 입생로랑 뷰티 ‘더 슬림 쉬어 마뜨’  2019.08.30
# 4                  쿠션의 완결판, 입생로랑 올아워 쿠션  2019.07.26
# ..                                  ...         ...
# 292         패션의 발원지인 파리, 뉴욕, 도쿄, 서울의 클럽  2016.04.27
# 293                    어깨를 드러내는 것이 유행이다  2016.04.26
# 294      CNI 럭셔리 컨퍼런스 2일차 – 디지털로 간 도나텔라  2016.04.21
# 295                #시선강탈자 #Nicola Peltz  2016.04.20
# 296                             힙색이 대세!  2016.04.15
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/07/24/%ed%94%84%eb...            1      0
# 1    http://www.vogue.co.kr/2020/06/26/%ec%9e%85%ec...            1      2
# 2    http://www.vogue.co.kr/2020/04/23/%ec%9e%85%ec...            1      2
# ...

# %%
# magazine column 추가
V_SL['magazine'] = 'V'
V_SL
# Out:
#                                   title        date  \
# 0                   생 로랑 2020 가을 로제 캠페인  2020.07.24
# 1    입생로랑 뷰티만의 인텐스 누드와 대체 불가 현아의 짜릿한 만남  2020.06.26
# 2                  입생로랑 틴트 혁명 NEW 벨벳 틴트  2020.04.23
# 3         한예슬의 선택, 입생로랑 뷰티 ‘더 슬림 쉬어 마뜨’  2019.08.30
# 4                  쿠션의 완결판, 입생로랑 올아워 쿠션  2019.07.26
# ..                                  ...         ...
# 292         패션의 발원지인 파리, 뉴욕, 도쿄, 서울의 클럽  2016.04.27
# 293                    어깨를 드러내는 것이 유행이다  2016.04.26
# 294      CNI 럭셔리 컨퍼런스 2일차 – 디지털로 간 도나텔라  2016.04.21
# 295                #시선강탈자 #Nicola Peltz  2016.04.20
# 296                             힙색이 대세!  2016.04.15
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/07/24/%ed%94%84%eb...            1      0
# 1    http://www.vogue.co.kr/2020/06/26/%ec%9e%85%ec...            1      2
# 2    http://www.vogue.co.kr/2020/04/23/%ec%9e%85%ec...            1      2
# ...

# %%
# Brand -> brand
V_SL = V_SL.rename({'Brand' : 'brand'}, axis='columns')
V_SL
# Out:
#                                   title        date  \
# 0                   생 로랑 2020 가을 로제 캠페인  2020.07.24
# 1    입생로랑 뷰티만의 인텐스 누드와 대체 불가 현아의 짜릿한 만남  2020.06.26
# 2                  입생로랑 틴트 혁명 NEW 벨벳 틴트  2020.04.23
# 3         한예슬의 선택, 입생로랑 뷰티 ‘더 슬림 쉬어 마뜨’  2019.08.30
# 4                  쿠션의 완결판, 입생로랑 올아워 쿠션  2019.07.26
# ..                                  ...         ...
# 292         패션의 발원지인 파리, 뉴욕, 도쿄, 서울의 클럽  2016.04.27
# 293                    어깨를 드러내는 것이 유행이다  2016.04.26
# 294      CNI 럭셔리 컨퍼런스 2일차 – 디지털로 간 도나텔라  2016.04.21
# 295                #시선강탈자 #Nicola Peltz  2016.04.20
# 296                             힙색이 대세!  2016.04.15
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/07/24/%ed%94%84%eb...            1      0
# 1    http://www.vogue.co.kr/2020/06/26/%ec%9e%85%ec...            1      2
# 2    http://www.vogue.co.kr/2020/04/23/%ec%9e%85%ec...            1      2
# ...

# %%
# column 순서
V_SL = V_SL[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
V_SL
# Out:
#     magazine brand category                               title  \
# 0          V    SL    Video                 생 로랑 2020 가을 로제 캠페인
# 1          V    SL   Beauty  입생로랑 뷰티만의 인텐스 누드와 대체 불가 현아의 짜릿한 만남
# 2          V    SL   Beauty                입생로랑 틴트 혁명 NEW 벨벳 틴트
# 3          V    SL   Beauty       한예슬의 선택, 입생로랑 뷰티 ‘더 슬림 쉬어 마뜨’
# 4          V    SL    Video                쿠션의 완결판, 입생로랑 올아워 쿠션
# ..       ...   ...      ...                                 ...
# 292        V    SL  Fashion         패션의 발원지인 파리, 뉴욕, 도쿄, 서울의 클럽
# 293        V    SL  Fashion                    어깨를 드러내는 것이 유행이다
# 294        V    SL  Fashion      CNI 럭셔리 컨퍼런스 2일차 – 디지털로 간 도나텔라
# 295        V    SL  Fashion                #시선강탈자 #Nicola Peltz
# 296        V    SL  Fashion                             힙색이 대세!
#
#                                                   link        date  \
# 0    http://www.vogue.co.kr/2020/07/24/%ed%94%84%eb...  2020.07.24
# ...

# %%
V_SL.to_csv('./data/Vogue_SaintLaurent.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
V_SL = pd.read_csv('./data/Vogue_SaintLaurent.csv' , sep='|', encoding='utf-8')
V_SL
# Out:
#     magazine brand category                               title  \
# 0          V    SL    Video                 생 로랑 2020 가을 로제 캠페인
# 1          V    SL   Beauty  입생로랑 뷰티만의 인텐스 누드와 대체 불가 현아의 짜릿한 만남
# 2          V    SL   Beauty                입생로랑 틴트 혁명 NEW 벨벳 틴트
# 3          V    SL   Beauty       한예슬의 선택, 입생로랑 뷰티 ‘더 슬림 쉬어 마뜨’
# 4          V    SL    Video                쿠션의 완결판, 입생로랑 올아워 쿠션
# ..       ...   ...      ...                                 ...
# 292        V    SL  Fashion         패션의 발원지인 파리, 뉴욕, 도쿄, 서울의 클럽
# 293        V    SL  Fashion                    어깨를 드러내는 것이 유행이다
# 294        V    SL  Fashion      CNI 럭셔리 컨퍼런스 2일차 – 디지털로 간 도나텔라
# 295        V    SL  Fashion                #시선강탈자 #Nicola Peltz
# 296        V    SL  Fashion                             힙색이 대세!
#
#                                                   link        date  \
# 0    http://www.vogue.co.kr/2020/07/24/%ed%94%84%eb...  2020.07.24
# ...
