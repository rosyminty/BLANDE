# %%
import pandas as pd
import numpy as np

# %%
a_r = pd.read_csv('./data/bp/Allure_R.csv' , sep='|', encoding='utf-8')
b_r = pd.read_csv('./data/bp/Bazaar_R.csv' , sep='|', encoding='utf-8')
c_r = pd.read_csv('./data/bp/cosmo_R.csv' , sep='|', encoding='utf-8')
e_r = pd.read_csv('./data/bp/elle_R.csv' , sep='|', encoding='utf-8')
fn_r = pd.read_csv('./data/bp/fashionn_R.csv' , sep='|', encoding='utf-8')
m_r = pd.read_csv('./data/bp/marie_R.csv' , sep='|', encoding='utf-8')
v_r = pd.read_csv('./data/bp/V_R.csv' , sep='|', encoding='utf-8')
w_r = pd.read_csv('./data/bp/w_R.csv' , sep='|', encoding='utf-8')

# %% [markdown]
# ## Allure

# %%
a_r
# Out:
#   magazine brand category                                          title  \
# 0   Allure     R   BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
#
#                                                 link         date  \
# 0  http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
#
#                                             contents  title_brand
# 0  ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...            0

# %%
a_r['word_rose'] = a_r['contents']

# %%
a_r
# Out:
#   magazine brand category                                          title  \
# 0   Allure     R   BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
#
#                                                 link         date  \
# 0  http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
#
#                                             contents  title_brand  \
# 0  ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...            0
#
#                                            word_rose
# 0  ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...

# %% [markdown]
# ## Bazaar

# %%
b_r
# Out:
#   magazine brand   category                      title  \
# 0        B     R    FASHION            잘 고른 여름 원피스 한 벌
# 1        B     R  CELEBRITY        난리 난 블랙핑크의 네일아트, 왜?
# 2        B     R    FASHION  방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 3        B     R    FASHION        무더위엔 원피스 한 벌이면 충분해!
# 4        B     R    FASHION      휴양지에서 셀럽들이 인생샷 남기는 비법
#
#                                             link        date  \
# 0  https://www.harpersbazaar.co.kr/article/47843  2020.07.24
# 1  https://www.harpersbazaar.co.kr/article/47719  2020.07.17
# 2  https://www.harpersbazaar.co.kr/article/41976  2019.09.04
# 3  https://www.harpersbazaar.co.kr/article/40532  2019.08.09
# 4  https://www.harpersbazaar.co.kr/article/40355  2019.07.30
#
#                                             contents  title_brand  \
# 0  ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...            0
# 1  ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...            0
# ...

# %%
b_r.rename({'word_jenny':'word_rose'}, axis=1, inplace=True)

# %%
b_r
# Out:
#   magazine brand   category                      title  \
# 0        B     R    FASHION            잘 고른 여름 원피스 한 벌
# 1        B     R  CELEBRITY        난리 난 블랙핑크의 네일아트, 왜?
# 2        B     R    FASHION  방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 3        B     R    FASHION        무더위엔 원피스 한 벌이면 충분해!
# 4        B     R    FASHION      휴양지에서 셀럽들이 인생샷 남기는 비법
#
#                                             link        date  \
# 0  https://www.harpersbazaar.co.kr/article/47843  2020.07.24
# 1  https://www.harpersbazaar.co.kr/article/47719  2020.07.17
# 2  https://www.harpersbazaar.co.kr/article/41976  2019.09.04
# 3  https://www.harpersbazaar.co.kr/article/40532  2019.08.09
# 4  https://www.harpersbazaar.co.kr/article/40355  2019.07.30
#
#                                             contents  title_brand  \
# 0  ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...            0
# 1  ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...            0
# ...

# %% [markdown]
# ## Cosmopolitan

# %%
c_r
# Out:
#    magazine brand category                       title  \
# 0         C     R     LIFE  블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C     R   CELEBS        블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C     R   CELEBS          외국인이었어? 아이돌 의외의 국적
# 3         C     R  FASHION      카디건 센스 있게 입는 셀럽들의 노하우!
# 4         C     R     LIFE        무대를 씹어드셨다! 우먼 아티스트 5
# 5         C     R   CELEBS                  아이돌 한복 대결!
# 6         C     R  FASHION            사회 초년생 첫 명품 백 추천
# 7         C     R   CELEBS            FW20 컬렉션을 찾은 스타들
# 8         C     R   CELEBS             겨울 속 여름 즐기는 언니들
# 9         C     R   BEAUTY    블핑부터 트와이스까지 금발 박제 각 여돌 6
# 10        C     R   CELEBS                판타스틱 4, 블랙핑크
#
#                                            link  \
# 0   http://v.media.daum.net/v/20201015145934137
# 1   http://v.media.daum.net/v/20201014184113530
# 2   http://v.media.daum.net/v/20201005111743409
# 3   http://v.media.daum.net/v/20200918164045849
# 4   http://v.media.daum.net/v/20200713144300007
# ...

# %%
c_r.drop('cosmo_link', axis=1, inplace=True)

# %%
c_r
# Out:
#    magazine brand category                       title  \
# 0         C     R     LIFE  블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C     R   CELEBS        블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C     R   CELEBS          외국인이었어? 아이돌 의외의 국적
# 3         C     R  FASHION      카디건 센스 있게 입는 셀럽들의 노하우!
# 4         C     R     LIFE        무대를 씹어드셨다! 우먼 아티스트 5
# 5         C     R   CELEBS                  아이돌 한복 대결!
# 6         C     R  FASHION            사회 초년생 첫 명품 백 추천
# 7         C     R   CELEBS            FW20 컬렉션을 찾은 스타들
# 8         C     R   CELEBS             겨울 속 여름 즐기는 언니들
# 9         C     R   BEAUTY    블핑부터 트와이스까지 금발 박제 각 여돌 6
# 10        C     R   CELEBS                판타스틱 4, 블랙핑크
#
#                                            link        date  \
# 0   http://v.media.daum.net/v/20201015145934137  2020.10.15
# 1   http://v.media.daum.net/v/20201014184113530  2020.10.14
# 2   http://v.media.daum.net/v/20201005111743409  2020.10.05
# ...

# %%
c_r.drop('check', axis=1, inplace=True)

# %%
c_r
# Out:
#    magazine brand category                       title  \
# 0         C     R     LIFE  블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C     R   CELEBS        블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C     R   CELEBS          외국인이었어? 아이돌 의외의 국적
# 3         C     R  FASHION      카디건 센스 있게 입는 셀럽들의 노하우!
# 4         C     R     LIFE        무대를 씹어드셨다! 우먼 아티스트 5
# 5         C     R   CELEBS                  아이돌 한복 대결!
# 6         C     R  FASHION            사회 초년생 첫 명품 백 추천
# 7         C     R   CELEBS            FW20 컬렉션을 찾은 스타들
# 8         C     R   CELEBS             겨울 속 여름 즐기는 언니들
# 9         C     R   BEAUTY    블핑부터 트와이스까지 금발 박제 각 여돌 6
# 10        C     R   CELEBS                판타스틱 4, 블랙핑크
#
#                                            link        date  \
# 0   http://v.media.daum.net/v/20201015145934137  2020.10.15
# 1   http://v.media.daum.net/v/20201014184113530  2020.10.14
# 2   http://v.media.daum.net/v/20201005111743409  2020.10.05
# ...

# %% [markdown]
# ## Elle

# %%
e_r
# Out:
#    magazine brand category                               title  \
# 0         E     R  FASHION                  유행은 돌아오는 거야! #어그슈즈
# 1         E     R  FASHION                    '베레모'하나면 드레스업 끝!
# 2         E     R   BEAUTY               로제처럼 귀엽게? 사랑스러운 핑크 헤어
# 3         E     R  FASHION                   여름과 가을 사이, 니트 베스트
# 4         E     R  FASHION                     로제만이 존재한 몰입의 순간
# 5         E     R     STAR                리사부터 선미까지 스타들의 블랙 홀릭
# 6         E     R     STAR   아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 7         E     R     STAR                제니, 걸그룹 브랜드 평판 1위 등극
# 8         E     R     STAR      스타들이 픽한 여름 헤어 스타일링! 상큼 발랄 포니테일
# 9         E     R     STAR                         로제, 우먼 인 블랙
# 10        E     R     STAR                블랙핑크가 쓰는 K-pop의 새 역사
# 11        E     R     STAR                            돌아온 블랙핑크
# 12        E     R     STAR                           로제에게 경배를!
# 13        E     R     STAR                        스타들의 #덕분에챌린지
# ...

# %%
e_r.drop('elle_link', axis=1, inplace=True)

# %%
e_r
# Out:
#    magazine brand category                               title  \
# 0         E     R  FASHION                  유행은 돌아오는 거야! #어그슈즈
# 1         E     R  FASHION                    '베레모'하나면 드레스업 끝!
# 2         E     R   BEAUTY               로제처럼 귀엽게? 사랑스러운 핑크 헤어
# 3         E     R  FASHION                   여름과 가을 사이, 니트 베스트
# 4         E     R  FASHION                     로제만이 존재한 몰입의 순간
# 5         E     R     STAR                리사부터 선미까지 스타들의 블랙 홀릭
# 6         E     R     STAR   아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 7         E     R     STAR                제니, 걸그룹 브랜드 평판 1위 등극
# 8         E     R     STAR      스타들이 픽한 여름 헤어 스타일링! 상큼 발랄 포니테일
# 9         E     R     STAR                         로제, 우먼 인 블랙
# 10        E     R     STAR                블랙핑크가 쓰는 K-pop의 새 역사
# 11        E     R     STAR                            돌아온 블랙핑크
# 12        E     R     STAR                           로제에게 경배를!
# 13        E     R     STAR                        스타들의 #덕분에챌린지
# ...

# %%
e_r.drop('check', axis=1, inplace=True)

# %%
e_r
# Out:
#    magazine brand category                               title  \
# 0         E     R  FASHION                  유행은 돌아오는 거야! #어그슈즈
# 1         E     R  FASHION                    '베레모'하나면 드레스업 끝!
# 2         E     R   BEAUTY               로제처럼 귀엽게? 사랑스러운 핑크 헤어
# 3         E     R  FASHION                   여름과 가을 사이, 니트 베스트
# 4         E     R  FASHION                     로제만이 존재한 몰입의 순간
# 5         E     R     STAR                리사부터 선미까지 스타들의 블랙 홀릭
# 6         E     R     STAR   아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 7         E     R     STAR                제니, 걸그룹 브랜드 평판 1위 등극
# 8         E     R     STAR      스타들이 픽한 여름 헤어 스타일링! 상큼 발랄 포니테일
# 9         E     R     STAR                         로제, 우먼 인 블랙
# 10        E     R     STAR                블랙핑크가 쓰는 K-pop의 새 역사
# 11        E     R     STAR                            돌아온 블랙핑크
# 12        E     R     STAR                           로제에게 경배를!
# 13        E     R     STAR                        스타들의 #덕분에챌린지
# ...

# %% [markdown]
# ## FashionN

# %%
fn_r
# Out:
#    brand category                                          title        date  \
# 0      R     인스타일      [그 옷 어디꺼] 블랙핑크 로제, 사랑스러워! 빛나는 시퀸 원피스 어디꺼?  2020-11-26
# 1      R     스타패션            로제, 생로랑 홍보대사!블랙핑크 멤버 모두 럭셔리 브랜드 싹쓸이  2020-07-01
# 2      R     스타패션          [패션엔 포토] 블랙핑크 로제, 크롭탑으로 뽐낸 흩날리는 코트자락!  2019-11-10
# 3      R     패션필름  [패션엔 TV] 블랙핑크 제니·리사·로제, 크롭탑과 점프슈트 톡톡 튀는 애슬레저룩  2019-07-15
# 4      R     스타패션     [패션엔 포토] 블랙핑크 리사·지수·로제, 자체발광 여신들 위트있는 캐주얼룩  2018-09-09
# 5      R     패션뉴스           노나곤, 한정판 '블랙 후디' 블랙핑크·위너·아이콘 셀피로 화제!  2018-09-07
# 6      R     패션뉴스            블랙핑크 지수·리사·로제, 톡톡튀는 '아디다스 오리지널스' 화보  2018-08-17
# 7      R     스타패션         블랙핑크, 반전의 청순미! 클로즈업에도 굴욕없는 비주얼 '시선 강탈'  2017-07-06
# 8      R     패션뉴스                  블랙핑크의 성숙한 반전! 오피스 핸드백 스타일링 화보  2017-05-16
# 9      R     패션뉴스                 리복 클래식, 블랙핑크와 함께한 ‘클럽 C’ 영상 공개  2016-11-18
# 10     R     패션뉴스              블랙핑크, 휘파람이 절로 나는 ‘신비+유니크’ 걸크러쉬 매력  2016-09-12
# ...

# %%
fn_r['magazine'] = 'FN'

# %%
fn_r = fn_r[['magazine', 'brand', 'category', 'title','link','date','contents','title_brand']]
fn_r
# Out:
#    magazine brand category                                          title  \
# 0        FN     R     인스타일      [그 옷 어디꺼] 블랙핑크 로제, 사랑스러워! 빛나는 시퀸 원피스 어디꺼?
# 1        FN     R     스타패션            로제, 생로랑 홍보대사!블랙핑크 멤버 모두 럭셔리 브랜드 싹쓸이
# 2        FN     R     스타패션          [패션엔 포토] 블랙핑크 로제, 크롭탑으로 뽐낸 흩날리는 코트자락!
# 3        FN     R     패션필름  [패션엔 TV] 블랙핑크 제니·리사·로제, 크롭탑과 점프슈트 톡톡 튀는 애슬레저룩
# 4        FN     R     스타패션     [패션엔 포토] 블랙핑크 리사·지수·로제, 자체발광 여신들 위트있는 캐주얼룩
# 5        FN     R     패션뉴스           노나곤, 한정판 '블랙 후디' 블랙핑크·위너·아이콘 셀피로 화제!
# 6        FN     R     패션뉴스            블랙핑크 지수·리사·로제, 톡톡튀는 '아디다스 오리지널스' 화보
# 7        FN     R     스타패션         블랙핑크, 반전의 청순미! 클로즈업에도 굴욕없는 비주얼 '시선 강탈'
# 8        FN     R     패션뉴스                  블랙핑크의 성숙한 반전! 오피스 핸드백 스타일링 화보
# 9        FN     R     패션뉴스                 리복 클래식, 블랙핑크와 함께한 ‘클럽 C’ 영상 공개
# 10       FN     R     패션뉴스              블랙핑크, 휘파람이 절로 나는 ‘신비+유니크’ 걸크러쉬 매력
# 11       FN     R     패션뉴스                  세인트코스트, YG신예 걸그룹 '블랙핑크' 모델 발탁
#
# ...

# %%
fn_r['word_rose'] = fn_r['contents']
# Out:
# <ipython-input-64-62b3d7045306>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fn_r['word_rose'] = fn_r['contents']

# %%
fn_r
# Out:
#    magazine brand category                                          title  \
# 0        FN     R     인스타일      [그 옷 어디꺼] 블랙핑크 로제, 사랑스러워! 빛나는 시퀸 원피스 어디꺼?
# 1        FN     R     스타패션            로제, 생로랑 홍보대사!블랙핑크 멤버 모두 럭셔리 브랜드 싹쓸이
# 2        FN     R     스타패션          [패션엔 포토] 블랙핑크 로제, 크롭탑으로 뽐낸 흩날리는 코트자락!
# 3        FN     R     패션필름  [패션엔 TV] 블랙핑크 제니·리사·로제, 크롭탑과 점프슈트 톡톡 튀는 애슬레저룩
# 4        FN     R     스타패션     [패션엔 포토] 블랙핑크 리사·지수·로제, 자체발광 여신들 위트있는 캐주얼룩
# 5        FN     R     패션뉴스           노나곤, 한정판 '블랙 후디' 블랙핑크·위너·아이콘 셀피로 화제!
# 6        FN     R     패션뉴스            블랙핑크 지수·리사·로제, 톡톡튀는 '아디다스 오리지널스' 화보
# 7        FN     R     스타패션         블랙핑크, 반전의 청순미! 클로즈업에도 굴욕없는 비주얼 '시선 강탈'
# 8        FN     R     패션뉴스                  블랙핑크의 성숙한 반전! 오피스 핸드백 스타일링 화보
# 9        FN     R     패션뉴스                 리복 클래식, 블랙핑크와 함께한 ‘클럽 C’ 영상 공개
# 10       FN     R     패션뉴스              블랙핑크, 휘파람이 절로 나는 ‘신비+유니크’ 걸크러쉬 매력
# 11       FN     R     패션뉴스                  세인트코스트, YG신예 걸그룹 '블랙핑크' 모델 발탁
#
# ...

# %% [markdown]
# ## Marie Claire

# %%
m_r
# Out:
#   magazine brand   category                    title  \
# 0        M     R    fashion  패셔니스타들이 레오퍼드 스커트를 입는 방법
# 1        M     R    fashion         그들이 입은 여름, 슬리브리스
# 2        M     R  celebrity           Blooming Scene
# 3        M     R  lifestyle           붐바야, 소녀들이 출격했다
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/fashion/2020/0...  2020-08
# 1  http://www.marieclairekorea.com/fashion/2020/0...  2020-07
# 2  http://www.marieclairekorea.com/celebrity/2018...  2018-02
# 3  http://www.marieclairekorea.com/lifestyle/2016...  2016-08
#
#                                             contents  title_brand  check  \
# 0  ['레오퍼드 패턴이라 하면 ‘센’ 이미지가 강했는데,\n그랬던 ‘레오퍼드’가\n어느...            0      0
# 1  ['여름이 되면\n한 번쯤 입고 싶어지는 슬리브리스.', '어떤 스타일을 어떻게 입...            0      0
# 2  ['', '', '', '데뷔한 지 1년 반이 지났어요. 5년의 연습 기간까지 합하...            0      0
# 3  ['YG가 2NE1 이후 7년만에 걸그룹 출격 소식을 전했다. 혹독하기로 소문난 Y...            0      0
#
# ...

# %%
m_r.drop('check', axis=1, inplace=True)

# %%
m_r
# Out:
#   magazine brand   category                    title  \
# 0        M     R    fashion  패셔니스타들이 레오퍼드 스커트를 입는 방법
# 1        M     R    fashion         그들이 입은 여름, 슬리브리스
# 2        M     R  celebrity           Blooming Scene
# 3        M     R  lifestyle           붐바야, 소녀들이 출격했다
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/fashion/2020/0...  2020-08
# 1  http://www.marieclairekorea.com/fashion/2020/0...  2020-07
# 2  http://www.marieclairekorea.com/celebrity/2018...  2018-02
# 3  http://www.marieclairekorea.com/lifestyle/2016...  2016-08
#
#                                             contents  title_brand  \
# 0  ['레오퍼드 패턴이라 하면 ‘센’ 이미지가 강했는데,\n그랬던 ‘레오퍼드’가\n어느...            0
# 1  ['여름이 되면\n한 번쯤 입고 싶어지는 슬리브리스.', '어떤 스타일을 어떻게 입...            0
# 2  ['', '', '', '데뷔한 지 1년 반이 지났어요. 5년의 연습 기간까지 합하...            0
# 3  ['YG가 2NE1 이후 7년만에 걸그룹 출격 소식을 전했다. 혹독하기로 소문난 Y...            0
#
# ...

# %% [markdown]
# ## Vogue

# %%
v_r
# Out:
#    magazine brand     category  \
# 0         V     R      Fashion
# 1         V     R        Video
# 2         V     R      Fashion
# 3         V     R       People
# 4         V     R      Fashion
# 5         V     R      Fashion
# 6         V     R      Fashion
# 7         V     R      Fashion
# 8         V     R  daily issue
# 9         V     R      Fashion
# 10        V     R  daily issue
# 11        V     R  daily issue
# 12        V     R  daily issue
# 13        V     R      Fashion
# 14        V     R       Beauty
#
#                                                 title  \
# 0                             블랙핑크 로제 & 리사의 카디건 활용법은?
# 1                                 생 로랑 2020 가을 로제 캠페인
# 2                       블핑 제니, 로제가 ‘애정하는’ 10만원대 ‘패션템’
# 3                            멀버리 행사장에 등장한 블랙핑크 리사-로제!
# 4                             가을 룩의 화룡점정, 헤어 액세서리 활용법
# 5                         지금 여자 아이돌들이 빠져 있는 #하이틴패션 탐구
# 6                                                 몽중몽
# ...

# %%
v_r.drop('check', axis=1, inplace=True)

# %%
v_r
# Out:
#    magazine brand     category  \
# 0         V     R      Fashion
# 1         V     R        Video
# 2         V     R      Fashion
# 3         V     R       People
# 4         V     R      Fashion
# 5         V     R      Fashion
# 6         V     R      Fashion
# 7         V     R      Fashion
# 8         V     R  daily issue
# 9         V     R      Fashion
# 10        V     R  daily issue
# 11        V     R  daily issue
# 12        V     R  daily issue
# 13        V     R      Fashion
# 14        V     R       Beauty
#
#                                                 title  \
# 0                             블랙핑크 로제 & 리사의 카디건 활용법은?
# 1                                 생 로랑 2020 가을 로제 캠페인
# 2                       블핑 제니, 로제가 ‘애정하는’ 10만원대 ‘패션템’
# 3                            멀버리 행사장에 등장한 블랙핑크 리사-로제!
# 4                             가을 룩의 화룡점정, 헤어 액세서리 활용법
# 5                         지금 여자 아이돌들이 빠져 있는 #하이틴패션 탐구
# 6                                                 몽중몽
# ...

# %% [markdown]
# ## W

# %%
w_r
# Out:
#   brand magazine                  category                        title  \
# 0     R        W  FASHION, FEATURE, 피플, 화보        You Go High (블랙핑크 로제)
# 1     R        W                      W TV                 블랙핑크 로제의 모먼트
# 2     R        W               FASHION, 화보  All The Good Times(블랙핑크 로제)
# 3     R        W               W HOT ISSUE     블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 4     R        W               FASHION, 화보     Je taime ROSE (로제) vol.2
# 5     R        W               FASHION, 화보    Je t’aime ROSE (로제) Vol.1
# 6     R        W               W HOT ISSUE     블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 7     R        W               W HOT ISSUE      블랙핑크가 아이스크림 셀카를 올린 이유는?
# 8     R        W               FASHION, 뉴스         블랙핑크 컴백! 남다른 패션 스타일링
# 9     R        W               W HOT ISSUE        K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#          date                                               link  title_brand  \
# 0  2020-09-22  http://www.wkorea.com/2020/09/22/you-go-high-%...            1
# ...

# %%
w_r = w_r[['magazine', 'brand', 'category', 'title','link','date','contents','title_brand']]
w_r
# Out:
#   magazine brand                  category                        title  \
# 0        W     R  FASHION, FEATURE, 피플, 화보        You Go High (블랙핑크 로제)
# 1        W     R                      W TV                 블랙핑크 로제의 모먼트
# 2        W     R               FASHION, 화보  All The Good Times(블랙핑크 로제)
# 3        W     R               W HOT ISSUE     블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 4        W     R               FASHION, 화보     Je taime ROSE (로제) vol.2
# 5        W     R               FASHION, 화보    Je t’aime ROSE (로제) Vol.1
# 6        W     R               W HOT ISSUE     블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 7        W     R               W HOT ISSUE      블랙핑크가 아이스크림 셀카를 올린 이유는?
# 8        W     R               FASHION, 뉴스         블랙핑크 컴백! 남다른 패션 스타일링
# 9        W     R               W HOT ISSUE        K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                                 link        date  \
# 0  http://www.wkorea.com/2020/09/22/you-go-high-%...  2020-09-22
# ...

# %%
w_r['word_rose'] = w_r['contents']
# Out:
# <ipython-input-74-fe3d544c2960>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w_r['word_rose'] = w_r['contents']

# %%
w_r
# Out:
#   magazine brand                  category                        title  \
# 0        W     R  FASHION, FEATURE, 피플, 화보        You Go High (블랙핑크 로제)
# 1        W     R                      W TV                 블랙핑크 로제의 모먼트
# 2        W     R               FASHION, 화보  All The Good Times(블랙핑크 로제)
# 3        W     R               W HOT ISSUE     블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 4        W     R               FASHION, 화보     Je taime ROSE (로제) vol.2
# 5        W     R               FASHION, 화보    Je t’aime ROSE (로제) Vol.1
# 6        W     R               W HOT ISSUE     블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 7        W     R               W HOT ISSUE      블랙핑크가 아이스크림 셀카를 올린 이유는?
# 8        W     R               FASHION, 뉴스         블랙핑크 컴백! 남다른 패션 스타일링
# 9        W     R               W HOT ISSUE        K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                                 link        date  \
# 0  http://www.wkorea.com/2020/09/22/you-go-high-%...  2020-09-22
# ...

# %%
magazine_r = pd.concat([a_r, b_r, c_r, e_r, fn_r, m_r, v_r, w_r])

# %%
magazine_r
# Out:
#    magazine brand     category                                          title  \
# 0    Allure     R       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 0         B     R      FASHION                                잘 고른 여름 원피스 한 벌
# 1         B     R    CELEBRITY                            난리 난 블랙핑크의 네일아트, 왜?
# 2         B     R      FASHION                      방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 3         B     R      FASHION                            무더위엔 원피스 한 벌이면 충분해!
# ..      ...   ...          ...                                            ...
# 5         W     R  FASHION, 화보                      Je t’aime ROSE (로제) Vol.1
# 6         W     R  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 7         W     R  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 8         W     R  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
# 9         W     R  W HOT ISSUE                          K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
# ...

# %%
magazine_r.to_csv('./data/bp/magazine_r.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_r = pd.read_csv('./data/bp/magazine_r.csv' , sep='|', encoding='utf-8')
magazine_r
# Out:
#    magazine brand     category                                          title  \
# 0    Allure     R       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 1         B     R      FASHION                                잘 고른 여름 원피스 한 벌
# 2         B     R    CELEBRITY                            난리 난 블랙핑크의 네일아트, 왜?
# 3         B     R      FASHION                      방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 4         B     R      FASHION                            무더위엔 원피스 한 벌이면 충분해!
# ..      ...   ...          ...                                            ...
# 83        W     R  FASHION, 화보                      Je t’aime ROSE (로제) Vol.1
# 84        W     R  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 85        W     R  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 86        W     R  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
# 87        W     R  W HOT ISSUE                          K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
# ...
