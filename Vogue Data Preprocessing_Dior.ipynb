# %%
import pandas as pd
import numpy as np

# %%
V_D = pd.read_csv('./data/Vogue_Dior_ccc.csv' , sep='|', encoding='utf-8')
V_D
# Out:
#                        title        date  \
# 0             보물 창고 같은 빈티지 숍  2020.11.09
# 1              패션계 F4를 소개합니다  2020.10.28
# 2                     패션, 아멘  2020.10.21
# 3           송경아처럼 예쁜 집 꾸미는 법  2020.10.15
# 4          스트레이 키즈의 후회 없는 순간  2020.10.02
# ..                       ...         ...
# 490               상하이의 디올 전시  2013.11.20
# 491       ‘미스 디올’로 변신한 전지현 2  2013.09.03
# 492       ‘미스 디올’로 변신한 전지현 1  2013.09.02
# 493  디올 드레스 입은 스타들의 부산 파티 현장  2011.11.03
# 494           미스 디올, 나탈리 포트만  2011.04.05
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      2
# 1    http://www.vogue.co.kr/2020/10/28/%ed%8c%a8%ec...            0      3
# 2    http://www.vogue.co.kr/2020/10/21/%ed%8c%a8%ec...            0      2
# 3    http://www.vogue.co.kr/2020/10/15/%ec%86%a1%ea...            0      2
# 4    http://www.vogue.co.kr/2020/10/02/%ec%8a%a4%ed...            0      2
# ...

# %%
# magazine column 추가
V_D['magazine'] = 'V'
V_D
# Out:
#                        title        date  \
# 0             보물 창고 같은 빈티지 숍  2020.11.09
# 1              패션계 F4를 소개합니다  2020.10.28
# 2                     패션, 아멘  2020.10.21
# 3           송경아처럼 예쁜 집 꾸미는 법  2020.10.15
# 4          스트레이 키즈의 후회 없는 순간  2020.10.02
# ..                       ...         ...
# 490               상하이의 디올 전시  2013.11.20
# 491       ‘미스 디올’로 변신한 전지현 2  2013.09.03
# 492       ‘미스 디올’로 변신한 전지현 1  2013.09.02
# 493  디올 드레스 입은 스타들의 부산 파티 현장  2011.11.03
# 494           미스 디올, 나탈리 포트만  2011.04.05
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      2
# 1    http://www.vogue.co.kr/2020/10/28/%ed%8c%a8%ec...            0      3
# 2    http://www.vogue.co.kr/2020/10/21/%ed%8c%a8%ec...            0      2
# 3    http://www.vogue.co.kr/2020/10/15/%ec%86%a1%ea...            0      2
# 4    http://www.vogue.co.kr/2020/10/02/%ec%8a%a4%ed...            0      2
# ...

# %%
# Brand -> brand
V_D = V_D.rename({'Brand' : 'brand'}, axis='columns')
V_D
# Out:
#                        title        date  \
# 0             보물 창고 같은 빈티지 숍  2020.11.09
# 1              패션계 F4를 소개합니다  2020.10.28
# 2                     패션, 아멘  2020.10.21
# 3           송경아처럼 예쁜 집 꾸미는 법  2020.10.15
# 4          스트레이 키즈의 후회 없는 순간  2020.10.02
# ..                       ...         ...
# 490               상하이의 디올 전시  2013.11.20
# 491       ‘미스 디올’로 변신한 전지현 2  2013.09.03
# 492       ‘미스 디올’로 변신한 전지현 1  2013.09.02
# 493  디올 드레스 입은 스타들의 부산 파티 현장  2011.11.03
# 494           미스 디올, 나탈리 포트만  2011.04.05
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      2
# 1    http://www.vogue.co.kr/2020/10/28/%ed%8c%a8%ec...            0      3
# 2    http://www.vogue.co.kr/2020/10/21/%ed%8c%a8%ec...            0      2
# 3    http://www.vogue.co.kr/2020/10/15/%ec%86%a1%ea...            0      2
# 4    http://www.vogue.co.kr/2020/10/02/%ec%8a%a4%ed...            0      2
# ...

# %%
# column 순서
V_D = V_D[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
V_D
# Out:
#     magazine brand     category  \
# 0          V     D      Fashion
# 1          V     D      Fashion
# 2          V     D  daily issue
# 3          V     D       Living
# 4          V     D      Fashion
# ..       ...   ...          ...
# 474        V     D      Fashion
# 475        V     D      Fashion
# 476        V     D       Beauty
# 477        V     D       People
# 478        V     D      Fashion
#
#                                                  title  \
# 0                                       보물 창고 같은 빈티지 숍
# 1                                        패션계 F4를 소개합니다
# 2                                               패션, 아멘
# 3                                     송경아처럼 예쁜 집 꾸미는 법
# 4                                    스트레이 키즈의 후회 없는 순간
# ..                                                 ...
# 474                         #RESORT – Dior Cruise 2017
# 475                                 아시아 최초의 디올 온라인 부티크
# 476                          디올 ‘샤또 드 라 콜 누와르’의 새로운 탄생
# ...

# %%
V_D.to_csv('./data/Vogue_Dior.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
V_D = pd.read_csv('./data/Vogue_Dior.csv' , sep='|', encoding='utf-8')
V_D
# Out:
#     magazine brand     category  \
# 0          V     D      Fashion
# 1          V     D      Fashion
# 2          V     D  daily issue
# 3          V     D       Living
# 4          V     D      Fashion
# ..       ...   ...          ...
# 474        V     D      Fashion
# 475        V     D      Fashion
# 476        V     D       Beauty
# 477        V     D       People
# 478        V     D      Fashion
#
#                                                  title  \
# 0                                       보물 창고 같은 빈티지 숍
# 1                                        패션계 F4를 소개합니다
# 2                                               패션, 아멘
# 3                                     송경아처럼 예쁜 집 꾸미는 법
# 4                                    스트레이 키즈의 후회 없는 순간
# ..                                                 ...
# 474                         #RESORT – Dior Cruise 2017
# 475                                 아시아 최초의 디올 온라인 부티크
# 476                          디올 ‘샤또 드 라 콜 누와르’의 새로운 탄생
# ...

# %%
# 날짜 지난 거 빼기
d = list(range(479,495))
d
# Out:
# [479,
#  480,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486,
#  487,
#  488,
#  489,
#  490,
#  491,
#  492,
#  493,
#  494]

# %%
V_D.drop(d, inplace=True)
V_D
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-a70f15fc6ce9> in <module>
# ----> 1 V_D.drop(d, inplace=True)
#       2 V_D
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
V_D.to_csv('./data/Vogue_Dior.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
V_D = pd.read_csv('./data/Vogue_Dior.csv' , sep='|', encoding='utf-8')
V_D
# Out:
#     magazine brand     category  \
# 0          V     D      Fashion
# 1          V     D      Fashion
# 2          V     D  daily issue
# 3          V     D       Living
# 4          V     D      Fashion
# ..       ...   ...          ...
# 474        V     D      Fashion
# 475        V     D      Fashion
# 476        V     D       Beauty
# 477        V     D       People
# 478        V     D      Fashion
#
#                                                  title  \
# 0                                       보물 창고 같은 빈티지 숍
# 1                                        패션계 F4를 소개합니다
# 2                                               패션, 아멘
# 3                                     송경아처럼 예쁜 집 꾸미는 법
# 4                                    스트레이 키즈의 후회 없는 순간
# ..                                                 ...
# 474                         #RESORT – Dior Cruise 2017
# 475                                 아시아 최초의 디올 온라인 부티크
# 476                          디올 ‘샤또 드 라 콜 누와르’의 새로운 탄생
# ...
