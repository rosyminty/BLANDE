# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Genesis

# %%
hmgj_g = pd.read_csv('./data/genesis/hmgj_g.csv' , sep='|', encoding='utf-8')
hmgj_g
# Out:
#      magazine type                                  title  \
# 0        HMGJ   PR    현대자동차, 4대 미래사업 전략 및 수정 <2025 전략> 공개
# 1        HMGJ   PR                 ‘제네시스 GV70’ 전 세계 동시 공개
# 2        HMGJ   PR         현대자동차, 2020년 11월 37만 6,704대 판매
# 3        HMGJ   PR  제네시스, 생체 인식 기술로 편의·안전성 높인 지능형 자동차 나온다
# 4        HMGJ   PR                      ‘제네시스 스튜디오 안성’ 개관
# ...       ...  ...                                    ...
# 1133     HMGJ    B    다이캐스트 자동차의 어제 그리고 오늘 ① 장난감 그 이상의 가치
# 1134     HMGJ    B       2014부산국제모터쇼, 부산 벡스코에서 화려한 막을 올리다
# 1135     HMGJ    B               기원전부터 시작된 탈것의 발전 자동차의 역사
# 1136     HMGJ    B        세계적인 디자인상을 수상한 현대자동차그룹의 다양한 제품들
# 1137     HMGJ    B       장인과 장인이 만나 명품을 만들다 현대자동차 모던 프리미엄
#
#                                                    link                  date  \
# 0     https://news.hmgjournal.com/MediaCenter/News/P...     2020/12/10  현대자동차
# 1     https://news.hmgjournal.com/MediaCenter/News/P...      2020/12/08  제네시스
# ...

# %%
hmgj_g['word_top100'][0]
# Out:
# "['GENESIS', '브랜드', '경우', '전용', '모델', '국내', '미국', '시장', '확대', '브랜드', '모델', '럭셔리', '차', '이미지', '계획', '차', '경우', '글로벌', '세대', 'GENESIS', '브랜드', '글로벌']"

# %%
n_g = pd.read_csv('./data/genesis/n_g.csv' , sep='|', encoding='utf-8')
n_g
# Out:
#      magazine                               title  \
# 0           N     제네시스 GV70 12월 출시...싼타페 실내보다 클까?
# 1           N      제네시스 'GV70' 곧 출시… 8일 온라인 공개 행사
# 2           N          현대차 수출 단가 대당 2만달러 시대 '초읽기'
# 3           N           제네시스 GV70, 오는 8일 디지털 공개행사
# 4           N                   국산차 수출 단가 2만달러 육박
# ...       ...                                 ...
# 1538        N       현대차 제네시스 사업부장에 해외통 이용우 부사장 선임
# 1539        N      3년 만에 실적 반등 현대차 "美 가속페달 더 밟는다"
# 1540        N     현대·기아차 신형 엔진 공개… ‘GV80’ 첫 장착 유력
# 1541        N  "이노션, 제네시스 풀 라인업 확보…마케팅 활발해질 것"-NH
# 1542        N         엔비디아-현대기아차, 차량용 인포테인먼트 ‘맞손’
#
#                                                    link        date  \
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-04
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-03
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-11-29
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-02
# ...

# %%
a_g = pd.concat([hmgj_g , n_g])
a_g
# Out:
#      magazine type                                  title  \
# 0        HMGJ   PR    현대자동차, 4대 미래사업 전략 및 수정 <2025 전략> 공개
# 1        HMGJ   PR                 ‘제네시스 GV70’ 전 세계 동시 공개
# 2        HMGJ   PR         현대자동차, 2020년 11월 37만 6,704대 판매
# 3        HMGJ   PR  제네시스, 생체 인식 기술로 편의·안전성 높인 지능형 자동차 나온다
# 4        HMGJ   PR                      ‘제네시스 스튜디오 안성’ 개관
# ...       ...  ...                                    ...
# 1538        N  NaN          현대차 제네시스 사업부장에 해외통 이용우 부사장 선임
# 1539        N  NaN         3년 만에 실적 반등 현대차 "美 가속페달 더 밟는다"
# 1540        N  NaN        현대·기아차 신형 엔진 공개… ‘GV80’ 첫 장착 유력
# 1541        N  NaN     "이노션, 제네시스 풀 라인업 확보…마케팅 활발해질 것"-NH
# 1542        N  NaN            엔비디아-현대기아차, 차량용 인포테인먼트 ‘맞손’
#
#                                                    link               date  \
# 0     https://news.hmgjournal.com/MediaCenter/News/P...  2020/12/10  현대자동차
# 1     https://news.hmgjournal.com/MediaCenter/News/P...   2020/12/08  제네시스
# ...

# %%
len(a_g)
# Out:
# 2681

# %%
a_g.reset_index(drop=True, inplace=True)

# %%
a_g.sort_values('date', ascending=False, inplace=True)

# %%
a_g
# Out:
#      magazine   type                                              title  \
# 752      HMGJ      B  미국 소비자 기관이 주목하다. 현대차그룹 켈리블루북 '2021 베스트 바이 어워드' 석권
# 0        HMGJ     PR                현대자동차, 4대 미래사업 전략 및 수정 <2025 전략> 공개
# 543      HMGJ  VIDEO                                 제네시스, GV70 전 세계 공개
# 544      HMGJ  VIDEO                        제네시스 GV70 - 도심을 가르는 역동적 디자인
# 1        HMGJ     PR                             ‘제네시스 GV70’ 전 세계 동시 공개
# ...       ...    ...                                                ...
# 453      HMGJ     PR                     현대차 최초의 브랜드 체험공간 ‘현대모터스튜디오’ 개관
# 1136     HMGJ      B                    세계적인 디자인상을 수상한 현대자동차그룹의 다양한 제품들
# 1137     HMGJ      B                   장인과 장인이 만나 명품을 만들다 현대자동차 모던 프리미엄
# 625      HMGJ  VIDEO                                    제네시스 미 충돌테스트 만점
# 711      HMGJ  VIDEO                                        중국 기자단 시승행사
#
#                                                    link                  date  \
# ...

# %%
a_g.reset_index(drop=True, inplace=True)
a_g
# Out:
#      magazine   type                                              title  \
# 0        HMGJ      B  미국 소비자 기관이 주목하다. 현대차그룹 켈리블루북 '2021 베스트 바이 어워드' 석권
# 1        HMGJ     PR                현대자동차, 4대 미래사업 전략 및 수정 <2025 전략> 공개
# 2        HMGJ  VIDEO                                 제네시스, GV70 전 세계 공개
# 3        HMGJ  VIDEO                        제네시스 GV70 - 도심을 가르는 역동적 디자인
# 4        HMGJ     PR                             ‘제네시스 GV70’ 전 세계 동시 공개
# ...       ...    ...                                                ...
# 2676     HMGJ     PR                     현대차 최초의 브랜드 체험공간 ‘현대모터스튜디오’ 개관
# 2677     HMGJ      B                    세계적인 디자인상을 수상한 현대자동차그룹의 다양한 제품들
# 2678     HMGJ      B                   장인과 장인이 만나 명품을 만들다 현대자동차 모던 프리미엄
# 2679     HMGJ  VIDEO                                    제네시스 미 충돌테스트 만점
# 2680     HMGJ  VIDEO                                        중국 기자단 시승행사
#
#                                                    link                  date  \
# ...

# %%
# 2018년부터의 기사만 갖고오기
# jist_2020 = []
for idx in range(len(a_g)) :
    if not a_g.loc[idx, 'date'][0:4] in ['2018', '2019', '2020'] :
        a_g.drop(idx, inplace=True)

# %%
a_g
# Out:
#      magazine   type                                              title  \
# 0        HMGJ      B  미국 소비자 기관이 주목하다. 현대차그룹 켈리블루북 '2021 베스트 바이 어워드' 석권
# 1        HMGJ     PR                현대자동차, 4대 미래사업 전략 및 수정 <2025 전략> 공개
# 2        HMGJ  VIDEO                                 제네시스, GV70 전 세계 공개
# 3        HMGJ  VIDEO                        제네시스 GV70 - 도심을 가르는 역동적 디자인
# 4        HMGJ     PR                             ‘제네시스 GV70’ 전 세계 동시 공개
# ...       ...    ...                                                ...
# 2171     HMGJ      B                                        '제네시스답다'는 것
# 2172     HMGJ  VIDEO                 제네시스 최초의 독립형 전용 전시 공간 제네시스 강남 미리보기
# 2173     HMGJ     PR                              국내 최초 선택형 보증제도 서비스 실시
# 2174     HMGJ     PR                                     2017년 12월 판매실적
# 2175     HMGJ      B                                두 워커홀릭의 에너지 재충전 체험기
#
#                                                    link                 date  \
# ...

# %%
len(a_g)
# Out:
# 2176

# %%
2176/158
# Out:
# 13.772151898734178

# %%
thirteen = []
for idx in range(len(a_g)) :
    if idx % 13 == 0 :
        thirteen.append(idx)
thirteen
# Out:
# [0,
#  13,
#  26,
#  39,
#  52,
#  65,
#  78,
#  91,
#  104,
#  117,
#  130,
#  143,
#  156,
#  169,
#  182,
#  195,
#  208,
#  221,
#  234,
#  247,
#  260,
#  273,
#  286,
#  299,
#  312,
#  325,
#  338,
#  351,
#  364,
#  377,
#  390,
#  403,
#  416,
#  429,
#  442,
#  455,
#  468,
#  481,
#  494,
#  507,
#  520,
#  533,
#  546,
#  559,
#  572,
#  585,
#  598,
#  611,
#  624,
#  637,
#  650,
#  663,
#  676,
#  689,
#  702,
#  715,
#  728,
#  741,
#  754,
#  767,
#  780,
#  793,
#  806,
#  819,
#  832,
#  845,
#  858,
#  871,
#  884,
#  897,
#  910,
#  923,
#  936,
#  949,
#  962,
#  975,
#  988,
#  1001,
#  1014,
#  1027,
#  1040,
#  1053,
#  1066,
#  1079,
#  1092,
#  1105,
#  1118,
#  1131,
#  1144,
#  1157,
#  1170,
#  1183,
#  1196,
#  1209,
#  1222,
#  1235,
#  1248,
#  1261,
#  1274,
#  1287,
#  1300,
#  1313,
#  1326,
#  1339,
#  1352,
#  1365,
#  1378,
#  1391,
#  1404,
#  1417,
#  1430,
#  1443,
#  1456,
#  1469,
#  1482,
#  1495,
#  1508,
#  1521,
#  1534,
#  1547,
# ...

# %%
a_g_13 = a_g.iloc[thirteen]
a_g_13.reset_index(drop=True, inplace=True)
a_g_13
# Out:
#     magazine   type                                              title  \
# 0       HMGJ      B  미국 소비자 기관이 주목하다. 현대차그룹 켈리블루북 '2021 베스트 바이 어워드' 석권
# 1       HMGJ     PR                     현대자동차, 2020년 11월 37만 6,704대 판매
# 2       HMGJ     PR                        현대자동차그룹, 제3회 중국 국제 수입박람회 참가
# 3       HMGJ      B                   제네시스의 가장 역동적인 스포츠 세단, 더 뉴 G70 출시
# 4       HMGJ  VIDEO                      현대자동차그룹, 2020 IDEA 디자인 어워드 수상
# ..       ...    ...                                                ...
# 163     HMGJ     PR                            ‘2018 제네시스 챔피언십’ 24일 개막
# 164     HMGJ  VIDEO                                    제네시스 버틀러 서비스 론칭
# 165     HMGJ     PR             제네시스 브랜드 후원 미 PGA 투어 ‘2018 제네시스 오픈’ 개막
# 166     HMGJ  VIDEO                                    제네시스, G80 디젤 출시
# 167     HMGJ      B                                        '제네시스답다'는 것
#
#                                                   link                 date  \
# ...

# %% [markdown]
# ### Jisoo

# %%
ji = pd.read_csv('./data/bp/tot_jisu_adfn_2.csv' , sep='|', encoding='utf-8')
ji
# Out:
#     magazine brand                                              title  \
# 0     Allure    Ji                         화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1     Allure    Ji      3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2     Allure    Ji                                   #얼루어_커버걸 블랙핑크 지수
# 3     Allure    Ji                                         LOOK AT ME
# 4     Allure    Ji                    얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..       ...   ...                                                ...
# 153  YOUTUBE    Ji  블랙핑크 지수 실력없다고 왜이래~ 나 블랙핑크야~ 제대로 보여줄게! [All Abo...
# 154  YOUTUBE    Ji  사랑스러움지수 한도초과! 🧡지수🖤 모음 3탄! [예능맛ZIP 맛남의 광장_Delic...
# 155  YOUTUBE    Ji  지수 MBTI는 'CUTE'가 분명해 🧡지수🖤 모음 5탄! [예능맛ZIP 맛남의 광...
# 156  YOUTUBE    Ji  지수가 먹지 지수 먹방 영상😎 _ BLACKPINK JISOO_korean_comm...
# 157  YOUTUBE    Ji  ＂안 돼＂ 진심으로 섭외하는 김영철(kim young chul)에 칼차단하는 지수(...
#
#                                               contents  \
# 0    ["['블랙핑크 지수도, 레드벨벳 아이린도, 이효리도, 선미도 했다! 앞머리 두가닥...
# ...

# %%
ji['ADFN_3'] = ji['ADFN_3'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')

# %%
ji['ADFN_3']
# Out:
# 0      [BLACKPINK, 지수, 레드, 벨벳, 이효리, 가닥, 길게, 내놓은, 일명, ...
# 1      [뷰, 돌파, BLACKPINK, How, like, that, 숨겨진, 메이크업,...
# 2      [얼루어, 호, 주인공, BLACKPINK, 지수, 온스타일, 퍼펙트, 브러시, 파...
# 3      [얼루어, 코리아, 모델, BLACKPINK, 지수, 특별한, 섰다, 퍼펙트, 브러...
# 4      [걸그룹, BLACKPINK, 지수, 얼루어, 코리아, 호, 장식, 온스타일, 겟잇...
#                              ...
# 153    [지수, 볼수록, 좋아짐, 성격, 예쁘다, 노래, 노력, 실력, 시킴, 기획사, 마...
# 154    [지수, 웃긴, 캐릭터, 이상한, 캐릭터, 라서, 웃김, BLACKPINK, 하든,...
# 155    [지수, 멘트, 재밌어서, 보고있는, 행복함, 지수, 폭발, ☆, 나와, 줬으면, ...
# 156    [저녁, 도레미, 마켓, 지수, BLACKPINK, 예전, 소통, 하려구, v, 앱...
# 157    [감도, 쩌, BLACKPINK, 참도, 글코, 드라마, 주인공, 지수, 패널, 지...
# Name: ADFN_3, Length: 158, dtype: object

# %%
sw_df = pd.read_csv('./stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각',
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어',
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '↑', '이자', '대해' ,
        '진짜', '존나', '보고', '그냥', '❤️', '없는','놀토', '런닝맨', '아는', '형님', '경우', '아니야', '넷플릭스', 
         '정말'  '❤', '♥', '있고', '저렇게', '같았음', '코첼라', 'BLINK', '걸']
for w in add_0:
    stop_words.append(w)

# %%
# '', ',', '너무', '.', '...', '..'

# %%
add_1 = ['BLACKPINK', '로제', '리사', '제니']
for w in add_1:
    stop_words.append(w)

# %%
len(stop_words)
# Out:
# 846

# %%
noun_adj_jist = []
for i in range(len(ji)):
    for word in ji.loc[i, 'ADFN_3']:
        if word not in stop_words:
            noun_adj_jist.append(word)

# %%
from collections import Counter

# %%
word = Counter(noun_adj_jist)
print(word.most_common(100))
# Out:
# [('지수', 4231), ('예쁘다', 1889), ('귀엽다', 723), ('얼굴', 516), ('사랑', 429), ('노래', 389), ('DIOR', 257), ('매력', 255), ('음악', 235), ('목소리', 234), ('춤', 165), ('아이돌', 162), ('처음', 158), ('실력', 148), ('스타일', 143), ('라이브', 129), ('성격', 125), ('음색', 124), ('누나', 119), ('최고', 107), ('여신', 105), ('외모', 101), ('배우', 98), ('여자', 97), ('메이크업', 96), ('VISUAL', 94), ('분위기', 74), ('패션', 72), ('핑크', 70), ('솔로', 68), ('헤어', 67), ('세계', 67), ('레전드', 66), ('걸그룹', 64), ('사랑스럽다', 61), ('시작', 59), ('매치', 59), ('완성', 58), ('패턴', 57), ('노력', 57), ('가족', 56), ('입덕', 56), ('드라마', 55), ('가수', 54), ('디자인', 54), ('이미지', 54), ('카디건', 53), ('보컬', 53), ('친구', 52), ('라인', 51), ('레드', 50), ('웃음', 50), ('팬츠', 50), ('스타', 49), ('반전', 49), ('연예인', 48), ('톱', 47), ('달곰', 47), ('천재', 47), ('자연', 46), ('찰떡', 46), ('봄', 46), ('인기', 45), ('인형', 45), ('연기', 44), ('천사', 43), ('빛', 42), ('모델', 42), ('화보', 42), ('새로운', 42), ('브랜드', 42), ('입술', 41), ('드레스', 41), ('멋있다', 41), ('립', 40), ('도전', 40), ('코디', 39), ('데님', 39), ('소녀', 39), (
# ...

# %%
# 리스트로 만들기
top100 = word.most_common(100)
top100_word = []
for w, t in top100 :
    top100_word.append(w)
print(len(top100_word))
print(top100_word)
# Out:
# 100
# ['지수', '예쁘다', '귀엽다', '얼굴', '사랑', '노래', 'DIOR', '매력', '음악', '목소리', '춤', '아이돌', '처음', '실력', '스타일', '라이브', '성격', '음색', '누나', '최고', '여신', '외모', '배우', '여자', '메이크업', 'VISUAL', '분위기', '패션', '핑크', '솔로', '헤어', '세계', '레전드', '걸그룹', '사랑스럽다', '시작', '매치', '완성', '패턴', '노력', '가족', '입덕', '드라마', '가수', '디자인', '이미지', '카디건', '보컬', '친구', '라인', '레드', '웃음', '팬츠', '스타', '반전', '연예인', '톱', '달곰', '천재', '자연', '찰떡', '봄', '인기', '인형', '연기', '천사', '빛', '모델', '화보', '새로운', '브랜드', '입술', '드레스', '멋있다', '립', '도전', '코디', '데님', '소녀', '재킷', '미소', '말투', '뷰티', '존재', '실물', '시크', 'ELEGANCE', '티셔츠', '프로', '볼살', '않는', '늘', '', '셔츠', '캐', '아티스트', '그대로', '고급', '사랑스러운', '피부']

# %%
word_top100 = []
for idx in range(len(ji)) :
    ADFNT = []
    for w in ji.loc[idx, 'ADFN_2'] :
#         print(idx)
#         print(w)
        if w in top100_word:
#             print(w)
            ADFNT.append(w)
    word_top100.append(ADFNT)
print(len(word_top100)) 
# print(word_top100[0])
# Out:
# 158

# %%
ji['word_top100'] = word_top100
ji
# Out:
#     magazine brand                                              title  \
# 0     Allure    Ji                         화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1     Allure    Ji      3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2     Allure    Ji                                   #얼루어_커버걸 블랙핑크 지수
# 3     Allure    Ji                                         LOOK AT ME
# 4     Allure    Ji                    얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..       ...   ...                                                ...
# 153  YOUTUBE    Ji  블랙핑크 지수 실력없다고 왜이래~ 나 블랙핑크야~ 제대로 보여줄게! [All Abo...
# 154  YOUTUBE    Ji  사랑스러움지수 한도초과! 🧡지수🖤 모음 3탄! [예능맛ZIP 맛남의 광장_Delic...
# 155  YOUTUBE    Ji  지수 MBTI는 'CUTE'가 분명해 🧡지수🖤 모음 5탄! [예능맛ZIP 맛남의 광...
# 156  YOUTUBE    Ji  지수가 먹지 지수 먹방 영상😎 _ BLACKPINK JISOO_korean_comm...
# 157  YOUTUBE    Ji  ＂안 돼＂ 진심으로 섭외하는 김영철(kim young chul)에 칼차단하는 지수(...
#
#                                               contents  \
# 0    ["['블랙핑크 지수도, 레드벨벳 아이린도, 이효리도, 선미도 했다! 앞머리 두가닥...
# ...

# %%
ji.to_csv('./data/bp/ji_top100.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
ji = pd.read_csv('./data/bp/ji_top100.csv' , sep='|', encoding='utf-8')
ji
# Out:
#     magazine brand                                              title  \
# 0     Allure    Ji                         화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1     Allure    Ji      3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2     Allure    Ji                                   #얼루어_커버걸 블랙핑크 지수
# 3     Allure    Ji                                         LOOK AT ME
# 4     Allure    Ji                    얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..       ...   ...                                                ...
# 153  YOUTUBE    Ji  블랙핑크 지수 실력없다고 왜이래~ 나 블랙핑크야~ 제대로 보여줄게! [All Abo...
# 154  YOUTUBE    Ji  사랑스러움지수 한도초과! 🧡지수🖤 모음 3탄! [예능맛ZIP 맛남의 광장_Delic...
# 155  YOUTUBE    Ji  지수 MBTI는 'CUTE'가 분명해 🧡지수🖤 모음 5탄! [예능맛ZIP 맛남의 광...
# 156  YOUTUBE    Ji  지수가 먹지 지수 먹방 영상😎 _ BLACKPINK JISOO_korean_comm...
# 157  YOUTUBE    Ji  ＂안 돼＂ 진심으로 섭외하는 김영철(kim young chul)에 칼차단하는 지수(...
#
#                                               contents  \
# 0    ["['블랙핑크 지수도, 레드벨벳 아이린도, 이효리도, 선미도 했다! 앞머리 두가닥...
# ...

# %%
len(ji)
# Out:
# 158

# %% [markdown]
# ### merging

# %%
geji = pd.concat([a_g_13 , ji])
geji
# Out:
#     magazine   type                                              title  \
# 0       HMGJ      B  미국 소비자 기관이 주목하다. 현대차그룹 켈리블루북 '2021 베스트 바이 어워드' 석권
# 1       HMGJ     PR                     현대자동차, 2020년 11월 37만 6,704대 판매
# 2       HMGJ     PR                        현대자동차그룹, 제3회 중국 국제 수입박람회 참가
# 3       HMGJ      B                   제네시스의 가장 역동적인 스포츠 세단, 더 뉴 G70 출시
# 4       HMGJ  VIDEO                      현대자동차그룹, 2020 IDEA 디자인 어워드 수상
# ..       ...    ...                                                ...
# 153  YOUTUBE    NaN  블랙핑크 지수 실력없다고 왜이래~ 나 블랙핑크야~ 제대로 보여줄게! [All Abo...
# 154  YOUTUBE    NaN  사랑스러움지수 한도초과! 🧡지수🖤 모음 3탄! [예능맛ZIP 맛남의 광장_Delic...
# 155  YOUTUBE    NaN  지수 MBTI는 'CUTE'가 분명해 🧡지수🖤 모음 5탄! [예능맛ZIP 맛남의 광...
# 156  YOUTUBE    NaN  지수가 먹지 지수 먹방 영상😎 _ BLACKPINK JISOO_korean_comm...
# 157  YOUTUBE    NaN  ＂안 돼＂ 진심으로 섭외하는 김영철(kim young chul)에 칼차단하는 지수(...
#
#                                                   link                 date  \
# ...

# %%
geji.reset_index(drop=True, inplace=True)

# %%
geji
# Out:
#     magazine   type                                              title  \
# 0       HMGJ      B  미국 소비자 기관이 주목하다. 현대차그룹 켈리블루북 '2021 베스트 바이 어워드' 석권
# 1       HMGJ     PR                     현대자동차, 2020년 11월 37만 6,704대 판매
# 2       HMGJ     PR                        현대자동차그룹, 제3회 중국 국제 수입박람회 참가
# 3       HMGJ      B                   제네시스의 가장 역동적인 스포츠 세단, 더 뉴 G70 출시
# 4       HMGJ  VIDEO                      현대자동차그룹, 2020 IDEA 디자인 어워드 수상
# ..       ...    ...                                                ...
# 321  YOUTUBE    NaN  블랙핑크 지수 실력없다고 왜이래~ 나 블랙핑크야~ 제대로 보여줄게! [All Abo...
# 322  YOUTUBE    NaN  사랑스러움지수 한도초과! 🧡지수🖤 모음 3탄! [예능맛ZIP 맛남의 광장_Delic...
# 323  YOUTUBE    NaN  지수 MBTI는 'CUTE'가 분명해 🧡지수🖤 모음 5탄! [예능맛ZIP 맛남의 광...
# 324  YOUTUBE    NaN  지수가 먹지 지수 먹방 영상😎 _ BLACKPINK JISOO_korean_comm...
# 325  YOUTUBE    NaN  ＂안 돼＂ 진심으로 섭외하는 김영철(kim young chul)에 칼차단하는 지수(...
#
#                                                   link                 date  \
# ...

# %% [markdown]
# ## Netword Analysis

# %%
import re

# %%
def cleanText(readData):
    text = re.sub('[-=+#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', readData)
    return text

# %%
# type(geje.loc[704, 'word_top100'])

# %%
ADFN = []
for i in range(len(geji)) :
    string = geji.loc[i, 'word_top100']
    text = cleanText(string)
    ADFN.append(text)

# %%
len(ADFN)
# Out:
# 326

# %%
print(ADFN[0])
print(type(ADFN[0]))
# Out:
# 미국, 차, 품질, 주행, 성능, 평가, SUV, SUV, 차, SUV, SUV, 대형, SUV, 럭셔리, 차, 럭셔리, SUV, 럭셔리, SUV, 럭셔리, SUV, 대형, 가치, 모델, 모델, 가치, 차, 최고, 차로, 수상, 평가, 차, 차, SUV, 타, SUV, 차, SUV, 럭셔리, SUV, GENESIS, 차, 차, SUV, 최고, 차, 모델, 차, 최고, 차, 차, 차, GENESIS, 브랜드, 모델, 세계, 차, 차, 차, 브랜드, 수상, 차, 다양, 모델, 차, SUV, 모델, 차, 모델, 수상, GENESIS, 수준, ELEGANCE, 엔진, 다양, GENESIS, 럭셔리, SUV, 모델, 가치, GENESIS, 럭셔리, SUV, 최고, 럭셔리, SUV, 모델, 수준, ELEGANCE, 엔진, 다양, 주행, 성능, 최고, 수준, 품질, 첨단, 안전, 사양, 다양, 기능, 차, 차, 시장, 조사, 평가, 차, 차, 미국, 시장, 조사, 파워, 진행, 차, 조사, 차, 품질, 조사, GENESIS, 차, 차, 차, 모델, 차종, 수상, 수상, SUV, 미국, 시장, 북미, 최고, 차, 차, 평가, 글로벌, 시장, 차, 브랜드, 이미지, 차
# <class 'str'>

# %%
ADFN[0].split(", ")
# Out:
# ['미국',
#  '차',
#  '품질',
#  '주행',
#  '성능',
#  '평가',
#  'SUV',
#  'SUV',
#  '차',
#  'SUV',
#  'SUV',
#  '대형',
#  'SUV',
#  '럭셔리',
#  '차',
#  '럭셔리',
#  'SUV',
#  '럭셔리',
#  'SUV',
#  '럭셔리',
#  'SUV',
#  '대형',
#  '가치',
#  '모델',
#  '모델',
#  '가치',
#  '차',
#  '최고',
#  '차로',
#  '수상',
#  '평가',
#  '차',
#  '차',
#  'SUV',
#  '타',
#  'SUV',
#  '차',
#  'SUV',
#  '럭셔리',
#  'SUV',
#  'GENESIS',
#  '차',
#  '차',
#  'SUV',
#  '최고',
#  '차',
#  '모델',
#  '차',
#  '최고',
#  '차',
#  '차',
#  '차',
#  'GENESIS',
#  '브랜드',
#  '모델',
#  '세계',
#  '차',
#  '차',
#  '차',
#  '브랜드',
#  '수상',
#  '차',
#  '다양',
#  '모델',
#  '차',
#  'SUV',
#  '모델',
#  '차',
#  '모델',
#  '수상',
#  'GENESIS',
#  '수준',
#  'ELEGANCE',
#  '엔진',
#  '다양',
#  'GENESIS',
#  '럭셔리',
#  'SUV',
#  '모델',
#  '가치',
#  'GENESIS',
#  '럭셔리',
#  'SUV',
#  '최고',
#  '럭셔리',
#  'SUV',
#  '모델',
#  '수준',
#  'ELEGANCE',
#  '엔진',
#  '다양',
#  '주행',
#  '성능',
#  '최고',
#  '수준',
#  '품질',
#  '첨단',
#  '안전',
#  '사양',
#  '다양',
#  '기능',
#  '차',
#  '차',
#  '시장',
#  '조사',
#  '평가',
# ...

# %%
for i in range(len(ADFN)) :
    ADFN[i] = ADFN[i].split(", ")
    print(ADFN[i])
# Out:
# ['미국', '차', '품질', '주행', '성능', '평가', 'SUV', 'SUV', '차', 'SUV', 'SUV', '대형', 'SUV', '럭셔리', '차', '럭셔리', 'SUV', '럭셔리', 'SUV', '럭셔리', 'SUV', '대형', '가치', '모델', '모델', '가치', '차', '최고', '차로', '수상', '평가', '차', '차', 'SUV', '타', 'SUV', '차', 'SUV', '럭셔리', 'SUV', 'GENESIS', '차', '차', 'SUV', '최고', '차', '모델', '차', '최고', '차', '차', '차', 'GENESIS', '브랜드', '모델', '세계', '차', '차', '차', '브랜드', '수상', '차', '다양', '모델', '차', 'SUV', '모델', '차', '모델', '수상', 'GENESIS', '수준', 'ELEGANCE', '엔진', '다양', 'GENESIS', '럭셔리', 'SUV', '모델', '가치', 'GENESIS', '럭셔리', 'SUV', '최고', '럭셔리', 'SUV', '모델', '수준', 'ELEGANCE', '엔진', '다양', '주행', '성능', '최고', '수준', '품질', '첨단', '안전', '사양', '다양', '기능', '차', '차', '시장', '조사', '평가', '차', '차', '미국', '시장', '조사', '파워', '진행', '차', '조사', '차', '품질', '조사', 'GENESIS', '차', '차', '차', '모델', '차종', '수상', '수상', 'SUV', '미국', '시장', '북미', '최고', '차', '차', '평가', '글로벌', '시장', '차', '브랜드', '이미지', '차']
# ['프리미엄', '브랜드', 'GENESIS']
# ...

# %%
print(ADFN[0])
print(type(ADFN[0]))
# Out:
# ['미국', '차', '품질', '주행', '성능', '평가', 'SUV', 'SUV', '차', 'SUV', 'SUV', '대형', 'SUV', '럭셔리', '차', '럭셔리', 'SUV', '럭셔리', 'SUV', '럭셔리', 'SUV', '대형', '가치', '모델', '모델', '가치', '차', '최고', '차로', '수상', '평가', '차', '차', 'SUV', '타', 'SUV', '차', 'SUV', '럭셔리', 'SUV', 'GENESIS', '차', '차', 'SUV', '최고', '차', '모델', '차', '최고', '차', '차', '차', 'GENESIS', '브랜드', '모델', '세계', '차', '차', '차', '브랜드', '수상', '차', '다양', '모델', '차', 'SUV', '모델', '차', '모델', '수상', 'GENESIS', '수준', 'ELEGANCE', '엔진', '다양', 'GENESIS', '럭셔리', 'SUV', '모델', '가치', 'GENESIS', '럭셔리', 'SUV', '최고', '럭셔리', 'SUV', '모델', '수준', 'ELEGANCE', '엔진', '다양', '주행', '성능', '최고', '수준', '품질', '첨단', '안전', '사양', '다양', '기능', '차', '차', '시장', '조사', '평가', '차', '차', '미국', '시장', '조사', '파워', '진행', '차', '조사', '차', '품질', '조사', 'GENESIS', '차', '차', '차', '모델', '차종', '수상', '수상', 'SUV', '미국', '시장', '북미', '최고', '차', '차', '평가', '글로벌', '시장', '차', '브랜드', '이미지', '차']
# <class 'list'>

# %%
type(ADFN)
# Out:
# list

# %%
dataset = ADFN

# %% [markdown]
# # 장바구니 분석

# %%
# 한글 폰트 문제 해결
import platform
from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
# Out:
# Unknown system... sorry~~~~

# %%
# http://blog.daum.net/geoscience/1408

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# pip install apyori

# %%
from apyori import apriori
# 지지도(support): P(A 공통 B)
result = (list(apriori(dataset, min_support=0.05)))

# %%
df = pd.DataFrame(result)
df['length'] = df['items'].apply(lambda x: len(x))
df = df[(df['length'] == 2 ) & 
                   (df['support'] >= 0.06)].sort_values(by='support', ascending=False) 
df
# Out:
#               items   support  \
# 243    (GENESIS, 차)  0.453988
# 218  (브랜드, GENESIS)  0.315951
# 723        (브랜드, 차)  0.300613
# 192  (SUV, GENESIS)  0.276074
# 302        (SUV, 차)  0.263804
# ..              ...       ...
# 535       (센터, 디자인)  0.061350
# 541      (역동적, 디자인)  0.061350
# 542       (완성, 디자인)  0.061350
# 548       (처음, 디자인)  0.061350
# 911       (지수, 연예인)  0.061350
#
#                                     ordered_statistics  length
# 243  [((), (GENESIS, 차), 0.4539877300613497, 1.0), ...       2
# 218  [((), (브랜드, GENESIS), 0.3159509202453988, 1.0)...       2
# 723  [((), (브랜드, 차), 0.3006134969325153, 1.0), ((브랜...       2
# 192  [((), (SUV, GENESIS), 0.27607361963190186, 1.0...       2
# 302  [((), (SUV, 차), 0.26380368098159507, 1.0), ((S...       2
# ..                                                 ...     ...
# 535  [((), (센터, 디자인), 0.06134969325153374, 1.0), ((...       2
# 541  [((), (역동적, 디자인), 0.06134969325153374, 1.0), (...       2
# ...

# %%
# networkx 그래프 정의
G = nx.Graph()
ar = (df['items']); G.add_edges_from(ar)

# %%
# 페이지랭크
pr = nx.pagerank(G)
nsize = np.array([v for v in pr.values()])
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

# %%
# 레이아웃
# pos = nx.planar_layout(G)
# pos = nx.rescale_layout(G)
# pos = nx.fruchterman_reingold_layout(G)
# pos = nx.spectral_layout(G)
# pos = nx.random_layout(G)

pos = nx.spring_layout(G)

# %%
# 네트워크 그래프
plt.figure(figsize=(16,12))
plt.axis('off')
nx.draw_networkx(G, font_family='Malgun Gothic', font_color = 'white' , font_size=14 , font_weight = 'bold',  pos=pos, 
                node_color=list(pr.values()), node_size=nsize,  
                alpha = 0.8, edge_color='darkgray', cmap=plt.cm.twilight_shifted)
