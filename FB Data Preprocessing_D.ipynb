# %%
import pandas as pd
import numpy as np

# %%
FB_D = pd.read_csv('./data/FashionBiz_Dior_contents.csv' , sep='|', encoding='utf-8')
FB_D
# Out:
#                                                title        date  \
# 0                       셀렉온 코스메틱 핫딜, ‘디올 립스틱 2만 원대…’  2020/11/11
# 1                     아디다스 X 프라다, 뉴 '슈퍼스타' 8일 전세계 발매  2020/09/01
# 2   6조5000억 시장, 디비전 · 디지털이 KEY\n불패신화! 2020 럭셔리 마켓 나우  2020/08/10
# 3                      디올, 온라인 라이브 스트리밍으로 크루즈 컬렉션 공개  2020/07/27
# 4                        디올뷰티 ‘디올 립 글로우’ 듀오 세트 한정 출시  2020/06/30
# 5                       [포토] 젠더리스 트렌드에 남성들도 '미니백' 든다  2020/04/17
# 6                          디올, 롯데백화점 부산본점 부티크 리뉴얼 오픈  2020/04/02
# 7                      2030 영 & 리치맨 ... 명품 조닝 큰 손으로!  2020/02/17
# 8                      롯데월드몰, 더일마 디올뷰티 등 신규 브랜드 '속속'  2020/02/04
# 9                          갤러리아·신세계강남 등 남성 명품숍 속속 등장  2020/02/03
# 10                      [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장  2020/01/23
# 11                     디올, 11人11色으로 재탄생한 '레이디 디올' 선봬  2020/01/10
# 12                    갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# ...

# %%
# magazine column 추가
FB_D['magazine'] = 'FB'
FB_D
# Out:
#                                                title        date  \
# 0                       셀렉온 코스메틱 핫딜, ‘디올 립스틱 2만 원대…’  2020/11/11
# 1                     아디다스 X 프라다, 뉴 '슈퍼스타' 8일 전세계 발매  2020/09/01
# 2   6조5000억 시장, 디비전 · 디지털이 KEY\n불패신화! 2020 럭셔리 마켓 나우  2020/08/10
# 3                      디올, 온라인 라이브 스트리밍으로 크루즈 컬렉션 공개  2020/07/27
# 4                        디올뷰티 ‘디올 립 글로우’ 듀오 세트 한정 출시  2020/06/30
# 5                       [포토] 젠더리스 트렌드에 남성들도 '미니백' 든다  2020/04/17
# 6                          디올, 롯데백화점 부산본점 부티크 리뉴얼 오픈  2020/04/02
# 7                      2030 영 & 리치맨 ... 명품 조닝 큰 손으로!  2020/02/17
# 8                      롯데월드몰, 더일마 디올뷰티 등 신규 브랜드 '속속'  2020/02/04
# 9                          갤러리아·신세계강남 등 남성 명품숍 속속 등장  2020/02/03
# 10                      [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장  2020/01/23
# 11                     디올, 11人11色으로 재탄생한 '레이디 디올' 선봬  2020/01/10
# 12                    갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# ...

# %%
# brand column 추가
FB_D['brand'] = 'D'
FB_D
# Out:
#                                                title        date  \
# 0                       셀렉온 코스메틱 핫딜, ‘디올 립스틱 2만 원대…’  2020/11/11
# 1                     아디다스 X 프라다, 뉴 '슈퍼스타' 8일 전세계 발매  2020/09/01
# 2   6조5000억 시장, 디비전 · 디지털이 KEY\n불패신화! 2020 럭셔리 마켓 나우  2020/08/10
# 3                      디올, 온라인 라이브 스트리밍으로 크루즈 컬렉션 공개  2020/07/27
# 4                        디올뷰티 ‘디올 립 글로우’ 듀오 세트 한정 출시  2020/06/30
# 5                       [포토] 젠더리스 트렌드에 남성들도 '미니백' 든다  2020/04/17
# 6                          디올, 롯데백화점 부산본점 부티크 리뉴얼 오픈  2020/04/02
# 7                      2030 영 & 리치맨 ... 명품 조닝 큰 손으로!  2020/02/17
# 8                      롯데월드몰, 더일마 디올뷰티 등 신규 브랜드 '속속'  2020/02/04
# 9                          갤러리아·신세계강남 등 남성 명품숍 속속 등장  2020/02/03
# 10                      [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장  2020/01/23
# 11                     디올, 11人11色으로 재탄생한 '레이디 디올' 선봬  2020/01/10
# 12                    갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# ...

# %%
# column 순서
FB_D = FB_D[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
FB_D
# Out:
#    magazine brand        category  \
# 0        FB     D  Life & Culture
# 1        FB     D    Today's News
# 2        FB     D  Premium Report
# 3        FB     D    Today's News
# 4        FB     D    Today's News
# 5        FB     D    Today's News
# 6        FB     D    Today's News
# 7        FB     D  Fashion Report
# 8        FB     D    Today's News
# 9        FB     D    Today's News
# 10       FB     D    Today's News
# 11       FB     D    Today's News
# 12       FB     D    Today's News
# 13       FB     D    Today's News
# 14       FB     D    Today's News
# 15       FB     D    Today's News
# 16       FB     D    Today's News
# 17       FB     D    Today's News
# 18       FB     D    Today's News
# 19       FB     D    Today's News
# 20       FB     D    Today's News
# 21       FB     D    Today's News
# 22       FB     D    Today's News
# 23       FB     D      World Wide
# 24       FB     D    Today's News
# 25       FB     D    Today's News
# ...

# %%
FB_D.to_csv('./data/FB_Dior.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
FB_D = pd.read_csv('./data/FB_Dior.csv' , sep='|', encoding='utf-8')
FB_D
# Out:
#    magazine brand        category  \
# 0        FB     D  Life & Culture
# 1        FB     D    Today's News
# 2        FB     D  Premium Report
# 3        FB     D    Today's News
# 4        FB     D    Today's News
# 5        FB     D    Today's News
# 6        FB     D    Today's News
# 7        FB     D  Fashion Report
# 8        FB     D    Today's News
# 9        FB     D    Today's News
# 10       FB     D    Today's News
# 11       FB     D    Today's News
# 12       FB     D    Today's News
# 13       FB     D    Today's News
# 14       FB     D    Today's News
# 15       FB     D    Today's News
# 16       FB     D    Today's News
# 17       FB     D    Today's News
# 18       FB     D    Today's News
# 19       FB     D    Today's News
# 20       FB     D    Today's News
# 21       FB     D    Today's News
# 22       FB     D    Today's News
# 23       FB     D      World Wide
# 24       FB     D    Today's News
# 25       FB     D    Today's News
# ...
