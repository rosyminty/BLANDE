# %%
import pandas as pd
import numpy as np

# %%
n_g = pd.read_csv('./data/genesis/N_genesis_adfn_3.csv' , sep='|', encoding='utf-8')
n_g
# Out:
#      magazine                               title  \
# 0           N     제네시스 GV70 12월 출시...싼타페 실내보다 클까?
# 1           N      제네시스 'GV70' 곧 출시… 8일 온라인 공개 행사
# 2           N          현대차 수출 단가 대당 2만달러 시대 '초읽기'
# 3           N           제네시스 GV70, 오는 8일 디지털 공개행사
# 4           N                   국산차 수출 단가 2만달러 육박
# ...       ...                                 ...
# 1538        N       현대차 제네시스 사업부장에 해외통 이용우 부사장 선임
# 1539        N      3년 만에 실적 반등 현대차 "美 가속페달 더 밟는다"
# 1540        N     현대·기아차 신형 엔진 공개… ‘GV80’ 첫 장착 유력
# 1541        N  "이노션, 제네시스 풀 라인업 확보…마케팅 활발해질 것"-NH
# 1542        N         엔비디아-현대기아차, 차량용 인포테인먼트 ‘맞손’
#
#                                                    link        date  \
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-04
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-03
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-11-29
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-02
# ...

# %%
FN = []
for idx in range(len(n_g)) :
    if '제네시스' in n_g.iloc[idx, 8] :
        n_g.iloc[idx, 8] = n_g.iloc[idx, 8].replace('제네시스' , 'GENESIS')
        FN.append(idx)
#         print(idx, n_g.iloc[idx, 8])
print(len(FN))
# Out:
# 1 ['현대', '강조', '램프', '차', '출시', '운전', 'SUV', '현대차', '전면', '계획', '결제', '디젤', '대비', '내비게이션', '운전자', '디자인', 'GENESIS', '중형', '라인업', '브랜드', '가솔린', '터보', '탑재', '글로벌', '고급', '라인', '그릴', '쿼드램프', '통해', '엔진', '럭셔리', '역동적', '기술', '이미지']
# 2 ['GENESIS', '확대', '전망', '판매', '고급', '개선', '미국', '차', '대형', '브랜드', 'SUV', '현대차', '때문']
# 3 ['강조', '차', '출시', 'SUV', '공개', '현대차', '업계', '처음', '결제', '디젤', '편의', 'GENESIS', '중형', '최초', '브랜드', '가솔린', '터보', '탑재', '계약', '판매', '고급', '통해', '럭셔리', '역동적', '기술', '이미지']
# 4 ['GENESIS', '판매', '미국', '대형', '브랜드', '세단', 'SUV', '현대차']
# 5 ['설명', '차', '성능', '출시', '부분', 'SUV', '공개', '관계자', '현대차', '수준', '업계', '대형', '기능', '세단', '운전자', '디자인', 'GENESIS', '전망', '세계', '중형', '최초', '브랜드', '공간', '탑재', '프리미엄']
# 6 ['차', '성능', '출시', '소음', 'SUV', '공개', '관계자', '현대차', '수준', '업계', '미국', '대형', '업체', '세단', '한국', '디자인', 'GENESIS', '평가', '전망', '라인업', '브랜드', '경쟁', '실내', '판매량', '터보', '발생', '계약', '판매', '고급', '엔진', '럭셔리', '최고', '국내']
# ...

# %%
FN = []
for idx in range(len(n_g)) :
    if '커넥티드' in n_g.iloc[idx, 4] :
#         n_g.iloc[idx, 8] = n_g.iloc[idx, 8].replace('커넥티드' , 'CONNECTED')
        FN.append(idx)
#         print(idx, n_g.iloc[idx, 8])
print(len(FN))
# Out:
# 66
