# %%
import pandas as pd
import numpy as np

# %%
magazine_ji = pd.read_csv('./data/bp/magazine_ji.csv' , sep='|', encoding='utf-8')
magazine_ji
# Out:
#     magazine brand     category  \
# 0     Allure    Ji       BEAUTY
# 1     Allure    Ji       BEAUTY
# 2     Allure    Ji       BEAUTY
# 3     Allure    Ji       BEAUTY
# 4     Allure    Ji       BEAUTY
# ..       ...   ...          ...
# 103        W    Ji  W HOT ISSUE
# 104        W    Ji  W HOT ISSUE
# 105        W    Ji  W HOT ISSUE
# 106        W    Ji  W HOT ISSUE
# 107        W    Ji  FASHION, 뉴스
#
#                                              title  \
# 0                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2                                 #얼루어_커버걸 블랙핑크 지수
# 3                                       LOOK AT ME
# 4                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..                                             ...
# 103                         블랙핑크, 4년 만의 첫 정규 앨범 발매
# 104                   배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 105                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 106                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# ...

# %% [markdown]
# ## Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
jiji = []
for line in magazine_ji['word_jisoo']:
    jiji.append(line)

# %%
type(jiji)
# Out:
# list

# %% [markdown]
# ### 외국어 안잘리게 영어로

# %%
FN = []
for idx in range(len(jiji)) :
    if '마리아 그라치아 치우리' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('마리아 그라치아 치우리' , 'Maria Grazia Chiuri')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 1

# %%
FN = []
for idx in range(len(jiji)) :
    if '블랙핑크' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('블랙핑크' , 'BLACKPINK')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 65

# %%
FN = []
for idx in range(len(jiji)) :
    if '디올' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('디올' , 'DIOR')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 17

# %%
FN = []
for idx in range(len(jiji)) :
    if '리사' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('리사' , 'LISA')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 31

# %%
FN = []
for idx in range(len(jiji)) :
    if '엘르' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('엘르' , 'ELLE')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 7

# %%
FN = []
for idx in range(len(jiji)) :
    if '아이코닉' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('아이코닉' , 'ICONIC')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 6

# %%
FN = []
for idx in range(len(jiji)) :
    if '파샤 드 까르띠에' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('파샤 드 까르띠에' , 'Pasha de Cartier')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(jiji)) :
    if '레오퍼드' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('레오퍼드' , 'Leopard')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(jiji)) :
    if '스틸레토' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('스틸레토' , 'Stiletto')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 1

# %%
FN = []
for idx in range(len(jiji)) :
    if '레전드' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('레전드' , 'LEGEND')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 1

# %%
FN = []
for idx in range(len(jiji)) :
    if '까르띠에' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('까르띠에' , 'Cartier')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 4

# %%
FN = []
for idx in range(len(jiji)) :
    if '엔도르핀' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('엔도르핀' , 'Endorphins')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(jiji)) :
    if '셀레나' in jiji[idx] :
        jiji[idx] = jiji[idx].replace('셀레나' , 'Selena')
        FN.append(idx)
#         print(idx, jiji[idx])
print(len(FN))
# Out:
# 4

# %% [markdown]
# ### 영문 다 대문자로 변환

# %%
for idx in range(len(jiji)) :
    jiji[idx] = jiji[idx].upper()
#     print(slsl[idx])

# %% [markdown]
# ### 각 문장별로 형태소 구분하기

# %%
sentences_tag = []
for i in range(len(jiji)) :
# for sentence in didi:
#     print(i)
    morph = kkma.pos(jiji[i])
    sentences_tag.append(morph)
#     print(morph)
#     print('-'*30)

# %% [markdown]
# ### 형태소 구분 검토용으로 일부 진행

# %%
len(jiji)
# Out:
# 108

# %%
# TEST
# 각 문장별로 형태소 구분하기
sentences_tagT = []
for i in range(108) :
# for sentence in didi:
    print(i)
    morph = kkma.pos(jiji[i])
    sentences_tagT.append(morph)
    print(morph)
    print('-'*30)
# Out:
# 0
# ...

# %%
jiji[31]
# Out:
# '["[[], [\'과도한 업무, 복잡한 인간관계, 마르고 닳도록 일해도 메마른 통장. 도대체 내 인생은 언제 행복해지느냐고? 당신을 지금 당장\', \'행복하게 만들 수 있는 12가지 트릭을 준비했다.\', \'\', \' 행복 호르몬  행복을 관장하는 호르몬들. 이 호르몬이 분비되면 당신은 행복해질 수 있다. \', \'아드레날린 흔히 “아드레날린이 솟구친다”라는 표현을 쓰는 건 이유가 있다. 아드레날린은 우리를 들뜨게 만들고 살아 있다는 느낌이 들게 한다. 이 호르몬은 우리가 긴장감 혹은 두려움을 느낄 때도 분비되는데, 예를 들면 지각 2분 전 로비에서 엘리베이터를 기다리는 상황 같은 때 말이다. \', \'도파민 ‘보상 분자’라고 불리는 신경전달물질로 새롭거나 놀라운 경험을 할 때 그 수치가 높아진다. \', \'ENDORPHINS  이 신경 화학물질은 우리 몸에서 만들어지는 천연 진통제다. 격렬한 운동을 하면서 쾌감을 느낀 적이 있나? 그게 다 ENDORPHINS 때문이다. \', \'감마아미노낙산 몸에서 분비되는 천연 신경안정제 정도로 생각하면 된다. 우리 뇌 속 분자들이 활발해지는 걸 막아 마음을 편안한 상태로 유지시킨다. \', \'옥시토신 신뢰감과 충성심을 느끼거나 친밀한 누군가를 만났을 때 분비되는 호르몬. \', \'세로토닌 자신감에 차 있거나 기분이 좋을 때 분비되는 신경전달물질이다. \', \' 행복 처방전 당신을 당장 행복하게 해줄 행동 12가지. 시시껄렁해 보여도 과학적으로 호르몬을 조절하는 방법에 기반한 트릭이니 믿고 따라 해볼 것. \', \'반려동물과 놀기 털이 복슬복슬한 것은 늘 옳다. 강아지나 고양이 등의 동물과 놀거나 그것들의 귀여운 사진을 보는 것만으로도 우리의 뇌는 자극을 받는다. \', \'명상하기 10분, 그것도 안 되면 단 1분만이라도 명상을 하자. 명상은 불안한 감정을 차분하게 가라앉히는 데 큰 도움이 된다. \', \'몸 움직이기 퇴근 후 집에 오면 가만히 누워 있고만 싶다고? 제자리에서 점프라도 해라. 우
# ...

# %%
# 명사 혹은 형용사인 품사만 선별해 리스트에 담기
noun_adj_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
            noun_adj_list.append(word)

# %% [markdown]
# ## Stopwords

# %%
stpwds = pd.read_csv('./stopwords.csv' , sep=',', encoding='utf-8', header=None)
stpwds
# Out:
#        0
# 0      아
# 1      휴
# 2    아이구
# 3    아이쿠
# 4    아이고
# ..   ...
# 670   일곱
# 671   여덟
# 672   아홉
# 673    령
# 674    영
#
# [675 rows x 1 columns]

# %%
# 리스트로 변환
stpwds_l = stpwds[0].tolist()

# %%
# stpwds_l = []
add = ['위하', '선보이', '가격', '가격 미정', '미정', '지금', 'BY', 'N', '있', '없', '보', '같', '되', '좋', '입', '모습', 
       '보이', '많', '주', '듣', '크', '통하', '전', '받', '공개', '더하', '따르', '선택', '어떻', '알', '맞', '사진', 
       '만들', '연출', '멤버', '르', 
      'BLACKPINK']
for words in add :
    stpwds_l.append(words)
# stpwds_l

# %% [markdown]
# ### 불용어는 형태소분석 결과에서도 빼주기

# %%
from collections import Counter

# %%
# 불용어 제외 리스트
noun_adj_list_stp= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if word not in stpwds_l:
            if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
                noun_adj_list_stp.append(word)

# %%
# 블용어 제외 순위
counts_stp = Counter(noun_adj_list_stp)
print(counts_stp.most_common(100))
# Out:
# [('지수', 269), ('DIOR', 139), ('LISA', 84), ('컬러', 83), ('로제', 68), ('생각', 52), ('블랙', 49), ('메이크업', 47), ('사람', 47), ('무대', 47), ('스타일', 46), ('룩', 44), ('포인트', 42), ('립', 40), ('매력', 40), ('패션', 38), ('팬츠', 35), ('패턴', 35), ('CARTIER', 35), ('마음', 34), ('팬', 34), ('매치', 34), ('완성', 33), ('촬영', 33), ('도전', 33), ('느낌', 32), ('뷰티', 32), ('디자인', 32), ('스타', 32), ('톱', 31), ('좋아하', 30), ('즐기', 30), ('헤어', 29), ('배우', 29), ('화보', 29), ('활동', 29), ('행복', 29), ('모델', 28), ('분위기', 28), ('브랜드', 28), ('스타일링', 27), ('제품', 27), ('데님', 27), ('백', 27), ('벨트', 27), ('피', 27), ('머리', 26), ('사랑', 26), ('라', 26), ('다르', 26), ('셔츠', 26), ('PASHA', 26), ('DE', 26), ('얼굴', 25), ('라인', 25), ('핑크', 25), ('데뷔', 25), ('딕트', 25), ('늘', 25), ('걸', 24), ('속', 24), ('커버', 24), ('그룹', 24), ('카디건', 24), ('즐겁', 24), ('포', 24), ('요즘', 23), ('입술', 23), ('디', 23), ('보여주', 23), ('후', 23), ('글로우', 23), ('이미지', 23), ('훈', 23), ('ELLE', 23), ('리', 22), ('대하', 22), ('웃음', 22), ('재킷', 22), ('민', 22), ('오버', 22), ('손', 22), 
# ...

# %% [markdown]
# ## WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = ' '.join(noun_adj_list)
# text

# %%
# wordcloud = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text)
wordcloud = WordCloud(font_path='ows/Fonts/malgun.ttf', background_color='white', stopwords = stpwds_l).generate(text)

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %% [markdown]
# ### top100 wordcloud before deleting other brands

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top100 = counts_stp.most_common(100)
top100_word = []
for word, tag in top100 :
    top100_word.append(word)

# %%
text_b = ' '.join(top100_word)
text_b
# Out:
# '지수 DIOR LISA 컬러 로제 생각 블랙 메이크업 사람 무대 스타일 룩 포인트 립 매력 패션 팬츠 패턴 CARTIER 마음 팬 매치 완성 촬영 도전 느낌 뷰티 디자인 스타 톱 좋아하 즐기 헤어 배우 화보 활동 행복 모델 분위기 브랜드 스타일링 제품 데님 백 벨트 피 머리 사랑 라 다르 셔츠 PASHA DE 얼굴 라인 핑크 데뷔 딕트 늘 걸 속 커버 그룹 카디건 즐겁 포 요즘 입술 디 보여주 후 글로우 이미지 훈 ELLE 리 대하 웃음 재킷 민 오버 손 쇼 레드 비 티 가지 말하 코 링 앨범 스텔라 길 점 영상 색 에버 말 음악 사실'

# %%
# wordcloud100 = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text_b)
# plt.figure(figsize=(22,22)) #이미지 사이즈 지정
# plt.imshow(wordcloud100, interpolation='lanczos') #이미지의 부드럽기 정도
# plt.axis('off') #x y 축 숫자 제거
# plt.show() 
# # plt.savefig()

# %% [markdown]
# ### top100 wordcloud after deleting other brands

# %%
stpwds_b = stpwds_l
brands = ['LISA', '로제']
for words in brands :
    stpwds_b.append(words)
# stpwds_b

# %%
# 불용어 제외 리스트
noun_adj_list_stp= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if word not in stpwds_b:
            if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
                noun_adj_list_stp.append(word)

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top100 = counts_stp.most_common(100)
top100_word = []
for word, tag in top100 :
    top100_word.append(word)

# %%
text_a = ' '.join(top100_word)
text_a
# Out:
# '지수 DIOR 컬러 생각 블랙 메이크업 사람 무대 스타일 룩 포인트 립 매력 패션 팬츠 패턴 CARTIER 마음 팬 매치 완성 촬영 도전 느낌 뷰티 디자인 스타 톱 좋아하 즐기 헤어 배우 화보 활동 행복 모델 분위기 브랜드 스타일링 제품 데님 백 벨트 피 머리 사랑 라 다르 셔츠 PASHA DE 얼굴 라인 핑크 데뷔 딕트 늘 걸 속 커버 그룹 카디건 즐겁 포 요즘 입술 디 보여주 후 글로우 이미지 훈 ELLE 리 대하 웃음 재킷 민 오버 손 쇼 레드 비 티 가지 말하 코 링 앨범 스텔라 길 점 영상 색 에버 말 음악 사실 넣 재미있'

# %%
wordcloud100 = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text_a)
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud100, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %% [markdown]
# ### TOP50 따로 추출

# %%
common = ['패션', '컬렉션', '시즌', '사진', '연출', '모습', '매치',
          '시작', '룩', '다양', '브랜드', '쇼', '모델', '장식', '드레스', '파리', '여성', '스타일', '컬러', '디자이너', '블랙', '재킷',
          '아이템', '옷', '디렉터', '팬츠']

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top50 = counts_stp.most_common(50)
top50_word = []
for word, tag in top50 :
    if not word in common :
        if not word in brands :
            top50_word.append(word)

# %%
top50_word
# Out:
# ['지수',
#  'DIOR',
#  '생각',
#  '메이크업',
#  '사람',
#  '무대',
#  '포인트',
#  '립',
#  '매력',
#  '패턴',
#  '마음',
#  '팬',
#  '완성',
#  '촬영',
#  '도전',
#  '느낌',
#  '뷰티',
#  '디자인',
#  '스타',
#  '톱',
#  '좋아하',
#  '즐기',
#  '헤어',
#  '배우',
#  '화보',
#  '활동',
#  '행복',
#  '분위기',
#  '스타일링',
#  '제품',
#  '데님',
#  '백',
#  '벨트',
#  '피',
#  'CARTIER',
#  '머리',
#  '사랑',
#  '라',
#  '다르',
#  '셔츠',
#  '레']

# %% [markdown]
# ### magazine_di에 tag 컬럼 생성하기

# %%
len(sentences_tag)
# Out:
# 108

# %%
print(magazine_ji['word_jisoo'][0])
print(sentences_tag[0])
# Out:
# ["['블랙핑크 지수도, 레드벨벳 아이린도, 이효리도, 선미도 했다! 앞머리 두가닥을 길게 내놓은 일명 ‘더듬이 머리’ 대체 왜 하는 걸까? 그 시절 ‘찐’ SES의 헤어를 담당하던 이희 원장과 선미의 헤어를 담당하는 정샘물 인스피레이션 다빈 팀장에게 그때VS요즘 더듬이 헤어에 대해 물어봤습니다.", '광고', '    그때 그 시절 HOT, SES, 엄정화, 박지윤, 이정현, Y2K, 투야 등 수 많은 가수와 배우의 헤어/메이크업을 담당했던 이희 헤어앤메이크업 대표원장 이희 헤어 디자이너', '선미의 헤어를 담당하고 있는 정샘물 인스피레이션 이스트점의 다빈 헤어 디자이너. 이 두사람에게 그때와 요즘 더듬이 헤어에 대해 물어본 결과는?', 'Q. 선미의 ‘보라빛 밤’ 더듬이 헤어는 어떻게 탄생하게 되었나요?', '‘보라빛 밤’은 사랑스러운 여자 친구, 옛 기억 속 첫사랑 같은 컨셉이어서 거기에 맞춰 머리를 사랑스럽게 묶으려 했었어요. 선미씨가 머리를 하나로만 묶지 말고 앞머리를 좀 내려보는 건 어떨지 먼저 제안을 줘서 더듬이를 내리게 된 거예요. 딱히 어떤 시안이 있어서 그걸 따라한 건 아니지만 기억 속의 누군가라는 컨셉과 복고풍의 패션이 더듬이 헤어를 더 복고스럽게 보이도록 한 것 같아요.', 'Q. 더듬이 헤어는 언제부터 하셨나요?', '제가 머리를 한 지는 34년이 되었어요. 문희 선생님부터 300여명이 넘는 셀럽들이 저희 샵을 다녔었는데요, 그 중엔 HOT, SES, Y2K, 박지윤, 엄정화 등의 많은 가수도 있었죠. 특히 이소라씨는 제가 슈퍼모델 대회 시절부터 헤어를 담당했었는데 아마 그때 부터 조금씩 머리를 내리기 시작한 것 같아요.', '정확하게 더듬이 머리를 의도해서 그렇게 된 건 아니고 어쩌다가 그렇게 된 거예요. 사실 더듬이 머리의 대표로 꼽히는 SES 바다씨 머리는 제가 샵에서 그렇게 만져주지는 않았어요. 현장에 나가있던 코디분이 조금 더 만져서 그렇게 탄생하게 된 것 같아요. 그 시절에는 현장에 나가는 스텝이 그리 많지 않았거든요.',
# ...

# %%
# 불용어 제외 리스트
ADFN= []
for sentence1 in sentences_tag:
    ADFNT = [] 
    for word, tag in sentence1:
        
        if word in top100_word:
           
            if tag in ['NNG','NNP','VA', 'VV', 'OL']:
                ADFNT.append(word)
    ADFN.append(ADFNT)

# %%
len(ADFN)
# Out:
# 108

# %%
len(sentences_tag)
# Out:
# 108

# %%
magazine_ji['sentences_tag'] = sentences_tag
magazine_ji
# Out:
#     magazine brand     category  \
# 0     Allure    Ji       BEAUTY
# 1     Allure    Ji       BEAUTY
# 2     Allure    Ji       BEAUTY
# 3     Allure    Ji       BEAUTY
# 4     Allure    Ji       BEAUTY
# ..       ...   ...          ...
# 103        W    Ji  W HOT ISSUE
# 104        W    Ji  W HOT ISSUE
# 105        W    Ji  W HOT ISSUE
# 106        W    Ji  W HOT ISSUE
# 107        W    Ji  FASHION, 뉴스
#
#                                              title  \
# 0                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2                                 #얼루어_커버걸 블랙핑크 지수
# 3                                       LOOK AT ME
# 4                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..                                             ...
# 103                         블랙핑크, 4년 만의 첫 정규 앨범 발매
# 104                   배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 105                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 106                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# ...

# %%
magazine_ji['ADFN'] = ADFN
magazine_ji
# Out:
#     magazine brand     category  \
# 0     Allure    Ji       BEAUTY
# 1     Allure    Ji       BEAUTY
# 2     Allure    Ji       BEAUTY
# 3     Allure    Ji       BEAUTY
# 4     Allure    Ji       BEAUTY
# ..       ...   ...          ...
# 103        W    Ji  W HOT ISSUE
# 104        W    Ji  W HOT ISSUE
# 105        W    Ji  W HOT ISSUE
# 106        W    Ji  W HOT ISSUE
# 107        W    Ji  FASHION, 뉴스
#
#                                              title  \
# 0                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2                                 #얼루어_커버걸 블랙핑크 지수
# 3                                       LOOK AT ME
# 4                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..                                             ...
# 103                         블랙핑크, 4년 만의 첫 정규 앨범 발매
# 104                   배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 105                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 106                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# ...

# %%
magazine_ji.to_csv('./data/bp/magazine_ji.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_ji = pd.read_csv('./data/bp/magazine_ji.csv' , sep='|', encoding='utf-8')
magazine_ji
# Out:
#     magazine brand     category  \
# 0     Allure    Ji       BEAUTY
# 1     Allure    Ji       BEAUTY
# 2     Allure    Ji       BEAUTY
# 3     Allure    Ji       BEAUTY
# 4     Allure    Ji       BEAUTY
# ..       ...   ...          ...
# 103        W    Ji  W HOT ISSUE
# 104        W    Ji  W HOT ISSUE
# 105        W    Ji  W HOT ISSUE
# 106        W    Ji  W HOT ISSUE
# 107        W    Ji  FASHION, 뉴스
#
#                                              title  \
# 0                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2                                 #얼루어_커버걸 블랙핑크 지수
# 3                                       LOOK AT ME
# 4                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..                                             ...
# 103                         블랙핑크, 4년 만의 첫 정규 앨범 발매
# 104                   배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 105                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 106                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# ...
