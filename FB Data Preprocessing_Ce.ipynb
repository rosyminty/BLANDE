# %%
import pandas as pd
import numpy as np

# %%
FB_Ce = pd.read_csv('./data/FashionBiz_Celine_contents.csv' , sep='|', encoding='utf-8')
FB_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
# magazine column 추가
FB_Ce['magazine'] = 'FB'
FB_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
# Brand -> brand
FB_Ce = FB_Ce.rename({'Brand' : 'brand'}, axis='columns')
FB_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
# column 순서
FB_Ce = FB_Ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
FB_Ce
# Out:
#    magazine brand        category                                title  \
# 0        FB    Ce    Today's News            셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁
# 1        FB    Ce    Today's News      여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트
# 2        FB    Ce    Today's News       갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대
# 3        FB    Ce    Today's News              [월드] 셀린느, 남성복 패션쇼 잠정 중단
# 4        FB    Ce    Today's News          [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?
# 5        FB    Ce    Today's News        갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화
# 6        FB    Ce      World Wide               아동복 패션 하우스, ‘마이크로 타깃팅’
# 7        FB    Ce    Today's News     [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선
# 8        FB    Ce    Today's News        셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개
# 9        FB    Ce    Today's News       [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선
# 10       FB    Ce    Today's News      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)
# 11       FB    Ce    Today's News           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이
# ...

# %%
FB_Ce.to_csv('./data/FB_Celine.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
FB_Ce = pd.read_csv('./data/FB_Celine.csv' , sep='|', encoding='utf-8')
FB_Ce
# Out:
#    magazine brand        category                                title  \
# 0        FB    Ce    Today's News            셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁
# 1        FB    Ce    Today's News      여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트
# 2        FB    Ce    Today's News       갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대
# 3        FB    Ce    Today's News              [월드] 셀린느, 남성복 패션쇼 잠정 중단
# 4        FB    Ce    Today's News          [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?
# 5        FB    Ce    Today's News        갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화
# 6        FB    Ce      World Wide               아동복 패션 하우스, ‘마이크로 타깃팅’
# 7        FB    Ce    Today's News     [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선
# 8        FB    Ce    Today's News        셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개
# 9        FB    Ce    Today's News       [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선
# 10       FB    Ce    Today's News      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)
# 11       FB    Ce    Today's News           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이
# ...
