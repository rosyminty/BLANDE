# %%
import pandas as pd
import numpy as np

# %%
a_ji = pd.read_csv('./data/bp/Allure_Ji.csv' , sep='|', encoding='utf-8')
b_ji = pd.read_csv('./data/bp/Bazaar_Ji.csv' , sep='|', encoding='utf-8')
c_ji = pd.read_csv('./data/bp/cosmo_Ji.csv' , sep='|', encoding='utf-8')
e_ji = pd.read_csv('./data/bp/elle_Ji.csv' , sep='|', encoding='utf-8')
fn_ji = pd.read_csv('./data/bp/fashionn_Ji.csv' , sep='|', encoding='utf-8')
m_ji = pd.read_csv('./data/bp/marie_Ji.csv' , sep='|', encoding='utf-8')
v_ji = pd.read_csv('./data/bp/V_Ji.csv' , sep='|', encoding='utf-8')
w_ji = pd.read_csv('./data/bp/w_Ji.csv' , sep='|', encoding='utf-8')

# %% [markdown]
# ## Allure

# %%
a_ji
# Out:
#   magazine brand category                                            title  \
# 0   Allure    Ji   BEAUTY                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1   Allure    Ji   BEAUTY    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2   Allure    Ji   BEAUTY                                 #얼루어_커버걸 블랙핑크 지수
# 3   Allure    Ji   BEAUTY                                       LOOK AT ME
# 4   Allure    Ji   BEAUTY                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# 5   Allure    Ji   BEAUTY                        얼루어 2월호 화보, 퍼펙트 브러시 촬영 현장
# 6   Allure    Ji  FASHION                   지수 VS 한예슬? 편해서 더 예쁜 셀럽표 애슬레저 룩
# 7   Allure    Ji  FASHION     제니의 크롭트 카디건부터 효민의 롱 카디건까지. 셀럽들이 선택한 카디건은 무엇?
# 8   Allure    Ji  FASHION  한겨울에 더욱 눈이 가는 포근한 시어링 아우터. 지수, 조이가 선택한 것은 어디 거?
#
#                                                 link         date  \
# 0  http://www.allurekorea.com/2020/09/27/%ed%99%9...  2020/09/27/
# 1  http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
# ...

# %%
a_ji['word_jisoo'] = a_ji['contents']

# %%
a_ji
# Out:
#   magazine brand category                                            title  \
# 0   Allure    Ji   BEAUTY                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1   Allure    Ji   BEAUTY    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2   Allure    Ji   BEAUTY                                 #얼루어_커버걸 블랙핑크 지수
# 3   Allure    Ji   BEAUTY                                       LOOK AT ME
# 4   Allure    Ji   BEAUTY                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# 5   Allure    Ji   BEAUTY                        얼루어 2월호 화보, 퍼펙트 브러시 촬영 현장
# 6   Allure    Ji  FASHION                   지수 VS 한예슬? 편해서 더 예쁜 셀럽표 애슬레저 룩
# 7   Allure    Ji  FASHION     제니의 크롭트 카디건부터 효민의 롱 카디건까지. 셀럽들이 선택한 카디건은 무엇?
# 8   Allure    Ji  FASHION  한겨울에 더욱 눈이 가는 포근한 시어링 아우터. 지수, 조이가 선택한 것은 어디 거?
#
#                                                 link         date  \
# 0  http://www.allurekorea.com/2020/09/27/%ed%99%9...  2020/09/27/
# 1  http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
# ...

# %% [markdown]
# ## Bazaar

# %%
b_ji
# Out:
#   magazine brand     category                              title  \
# 0        B    Ji    CELEBRITY           하퍼스 바자 2020년 첫 커버 주인공 지수
# 1        B    Ji    CELEBRITY  오직 <바자>에서만 볼 수 있는 지수의 인터뷰와 비하인드 컷
# 2        B    Ji  ART&CULTURE                        블랙핑크 지수의 봄날
# 3        B    Ji    CELEBRITY                난리 난 블랙핑크의 네일아트, 왜?
# 4        B    Ji    CELEBRITY                     블랙핑크 지수의 색다른 날
# 5        B    Ji      FASHION                     돌고 도는 #탑골공원 패션
# 6        B    Ji       BEAUTY                    하반기 뷰티 트렌드가 궁금해
# 7        B    Ji       BEAUTY                    이젠 #말린살구 컬러가 대세
#
#                                             link        date  \
# 0  https://www.harpersbazaar.co.kr/article/43747  2019.12.18
# 1  https://www.harpersbazaar.co.kr/article/43987  2020.01.03
# 2  https://www.harpersbazaar.co.kr/article/40188  2019.06.10
# 3  https://www.harpersbazaar.co.kr/article/47719  2020.07.17
# 4  https://www.harpersbazaar.co.kr/article/40148  2019.05.27
# ...

# %%
b_ji.rename({'word_jenny':'word_jisoo'}, axis=1, inplace=True)

# %%
b_ji
# Out:
#   magazine brand     category                              title  \
# 0        B    Ji    CELEBRITY           하퍼스 바자 2020년 첫 커버 주인공 지수
# 1        B    Ji    CELEBRITY  오직 <바자>에서만 볼 수 있는 지수의 인터뷰와 비하인드 컷
# 2        B    Ji  ART&CULTURE                        블랙핑크 지수의 봄날
# 3        B    Ji    CELEBRITY                난리 난 블랙핑크의 네일아트, 왜?
# 4        B    Ji    CELEBRITY                     블랙핑크 지수의 색다른 날
# 5        B    Ji      FASHION                     돌고 도는 #탑골공원 패션
# 6        B    Ji       BEAUTY                    하반기 뷰티 트렌드가 궁금해
# 7        B    Ji       BEAUTY                    이젠 #말린살구 컬러가 대세
#
#                                             link        date  \
# 0  https://www.harpersbazaar.co.kr/article/43747  2019.12.18
# 1  https://www.harpersbazaar.co.kr/article/43987  2020.01.03
# 2  https://www.harpersbazaar.co.kr/article/40188  2019.06.10
# 3  https://www.harpersbazaar.co.kr/article/47719  2020.07.17
# 4  https://www.harpersbazaar.co.kr/article/40148  2019.05.27
# ...

# %% [markdown]
# ## Cosmopolitan

# %%
c_ji
# Out:
#    magazine brand category                          title  \
# 0         C    Ji     LIFE     블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C    Ji   CELEBS           블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C    Ji     LIFE                   가을 광고계는 아이돌판
# 3         C    Ji   BEAUTY                    더듬이 앞머리의 변신
# 4         C    Ji  FASHION    파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         C    Ji  FASHION         카디건 센스 있게 입는 셀럽들의 노하우!
# 6         C    Ji     LIFE           무대를 씹어드셨다! 우먼 아티스트 5
# 7         C    Ji  FASHION            스트리트 룩 보고 '쿨' 지수 업!
# 8         C    Ji   BEAUTY  봄웜? 겨쿨? 내 최애 아이돌의 퍼스널 컬러는 무엇?
# 9         C    Ji  FASHION                     신상 말고, 빈티지
# 10        C    Ji   BEAUTY                  멍뭉상 vs 냥이상 스타
# 11        C    Ji  FASHION                오프숄더 베스트 스타일링 5
# 12        C    Ji   CELEBS                   판타스틱 4, 블랙핑크
# 13        C    Ji  FASHION               운동 지수 업! 컬러풀 운동복
# 14        C    Ji   BEAUTY             행복 지수 올리는 12가지 노하우
# ...

# %%
c_ji.drop('cosmo_link', axis=1, inplace=True)

# %%
c_ji
# Out:
#    magazine brand category                          title  \
# 0         C    Ji     LIFE     블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C    Ji   CELEBS           블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C    Ji     LIFE                   가을 광고계는 아이돌판
# 3         C    Ji   BEAUTY                    더듬이 앞머리의 변신
# 4         C    Ji  FASHION    파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         C    Ji  FASHION         카디건 센스 있게 입는 셀럽들의 노하우!
# 6         C    Ji     LIFE           무대를 씹어드셨다! 우먼 아티스트 5
# 7         C    Ji  FASHION            스트리트 룩 보고 '쿨' 지수 업!
# 8         C    Ji   BEAUTY  봄웜? 겨쿨? 내 최애 아이돌의 퍼스널 컬러는 무엇?
# 9         C    Ji  FASHION                     신상 말고, 빈티지
# 10        C    Ji   BEAUTY                  멍뭉상 vs 냥이상 스타
# 11        C    Ji  FASHION                오프숄더 베스트 스타일링 5
# 12        C    Ji   CELEBS                   판타스틱 4, 블랙핑크
# 13        C    Ji  FASHION               운동 지수 업! 컬러풀 운동복
# 14        C    Ji   BEAUTY             행복 지수 올리는 12가지 노하우
# ...

# %%
c_ji.drop('check', axis=1, inplace=True)

# %%
c_ji
# Out:
#    magazine brand category                          title  \
# 0         C    Ji     LIFE     블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C    Ji   CELEBS           블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C    Ji     LIFE                   가을 광고계는 아이돌판
# 3         C    Ji   BEAUTY                    더듬이 앞머리의 변신
# 4         C    Ji  FASHION    파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         C    Ji  FASHION         카디건 센스 있게 입는 셀럽들의 노하우!
# 6         C    Ji     LIFE           무대를 씹어드셨다! 우먼 아티스트 5
# 7         C    Ji  FASHION            스트리트 룩 보고 '쿨' 지수 업!
# 8         C    Ji   BEAUTY  봄웜? 겨쿨? 내 최애 아이돌의 퍼스널 컬러는 무엇?
# 9         C    Ji  FASHION                     신상 말고, 빈티지
# 10        C    Ji   BEAUTY                  멍뭉상 vs 냥이상 스타
# 11        C    Ji  FASHION                오프숄더 베스트 스타일링 5
# 12        C    Ji   CELEBS                   판타스틱 4, 블랙핑크
# 13        C    Ji  FASHION               운동 지수 업! 컬러풀 운동복
# 14        C    Ji   BEAUTY             행복 지수 올리는 12가지 노하우
# ...

# %%
c_ji.rename({'word_jisu':'word_jisoo'}, axis=1, inplace=True)
c_ji
# Out:
#    magazine brand category                          title  \
# 0         C    Ji     LIFE     블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         C    Ji   CELEBS           블랙핑크 멤버들의 실제 성격을 밝혀라
# 2         C    Ji     LIFE                   가을 광고계는 아이돌판
# 3         C    Ji   BEAUTY                    더듬이 앞머리의 변신
# 4         C    Ji  FASHION    파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         C    Ji  FASHION         카디건 센스 있게 입는 셀럽들의 노하우!
# 6         C    Ji     LIFE           무대를 씹어드셨다! 우먼 아티스트 5
# 7         C    Ji  FASHION            스트리트 룩 보고 '쿨' 지수 업!
# 8         C    Ji   BEAUTY  봄웜? 겨쿨? 내 최애 아이돌의 퍼스널 컬러는 무엇?
# 9         C    Ji  FASHION                     신상 말고, 빈티지
# 10        C    Ji   BEAUTY                  멍뭉상 vs 냥이상 스타
# 11        C    Ji  FASHION                오프숄더 베스트 스타일링 5
# 12        C    Ji   CELEBS                   판타스틱 4, 블랙핑크
# 13        C    Ji  FASHION               운동 지수 업! 컬러풀 운동복
# 14        C    Ji   BEAUTY             행복 지수 올리는 12가지 노하우
# ...

# %% [markdown]
# ## Elle

# %%
e_ji
# Out:
#    magazine brand category                                title  \
# 0         E    Ji  FASHION            김나영부터 지수까지! 진주 주얼리를 한 스타들
# 1         E    Ji  FASHION             공효진부터 제니까지! 스타들의 #니트 활용법
# 2         E    Ji  FASHION             스타일 지수 올려주는 비장의 액세서리, 벨트
# 3         E    Ji  FASHION  환불 원정대 제시부터 블핑 지수까지! 셉럽들의 레오퍼드 패션 7
# 4         E    Ji  FASHION          파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         E    Ji  FASHION              가방에 쏙! 간절기 BEST 스카프 활용법
# 6         E    Ji  FASHION  블핑 지수부터 손나은까지 스타들의 필수템 #화이트셔츠 돌려 입기
# 7         E    Ji     STAR    아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 8         E    Ji     STAR    블랙핑크 지수, 드라마 '설강화' 주연 발탁!_#ELLE뉴스
# 9         E    Ji  FASHION                             여름에도 카디건
# 10        E    Ji   BEAUTY                         형형색색 아이 메이크업
# 11        E    Ji     STAR                 제니, 걸그룹 브랜드 평판 1위 등극
# 12        E    Ji   BEAUTY                디올의 뮤즈 지수, 청량한 여름을 닮은
# 13        E    Ji  FASHION           스타일링 지수 높여주는 마법의 액세서리 '벨트'
# ...

# %%
e_ji.drop('elle_link', axis=1, inplace=True)

# %%
e_ji
# Out:
#    magazine brand category                                title  \
# 0         E    Ji  FASHION            김나영부터 지수까지! 진주 주얼리를 한 스타들
# 1         E    Ji  FASHION             공효진부터 제니까지! 스타들의 #니트 활용법
# 2         E    Ji  FASHION             스타일 지수 올려주는 비장의 액세서리, 벨트
# 3         E    Ji  FASHION  환불 원정대 제시부터 블핑 지수까지! 셉럽들의 레오퍼드 패션 7
# 4         E    Ji  FASHION          파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         E    Ji  FASHION              가방에 쏙! 간절기 BEST 스카프 활용법
# 6         E    Ji  FASHION  블핑 지수부터 손나은까지 스타들의 필수템 #화이트셔츠 돌려 입기
# 7         E    Ji     STAR    아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 8         E    Ji     STAR    블랙핑크 지수, 드라마 '설강화' 주연 발탁!_#ELLE뉴스
# 9         E    Ji  FASHION                             여름에도 카디건
# 10        E    Ji   BEAUTY                         형형색색 아이 메이크업
# 11        E    Ji     STAR                 제니, 걸그룹 브랜드 평판 1위 등극
# 12        E    Ji   BEAUTY                디올의 뮤즈 지수, 청량한 여름을 닮은
# 13        E    Ji  FASHION           스타일링 지수 높여주는 마법의 액세서리 '벨트'
# ...

# %%
e_ji.drop('check', axis=1, inplace=True)

# %%
e_ji
# Out:
#    magazine brand category                                title  \
# 0         E    Ji  FASHION            김나영부터 지수까지! 진주 주얼리를 한 스타들
# 1         E    Ji  FASHION             공효진부터 제니까지! 스타들의 #니트 활용법
# 2         E    Ji  FASHION             스타일 지수 올려주는 비장의 액세서리, 벨트
# 3         E    Ji  FASHION  환불 원정대 제시부터 블핑 지수까지! 셉럽들의 레오퍼드 패션 7
# 4         E    Ji  FASHION          파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5         E    Ji  FASHION              가방에 쏙! 간절기 BEST 스카프 활용법
# 6         E    Ji  FASHION  블핑 지수부터 손나은까지 스타들의 필수템 #화이트셔츠 돌려 입기
# 7         E    Ji     STAR    아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 8         E    Ji     STAR    블랙핑크 지수, 드라마 '설강화' 주연 발탁!_#ELLE뉴스
# 9         E    Ji  FASHION                             여름에도 카디건
# 10        E    Ji   BEAUTY                         형형색색 아이 메이크업
# 11        E    Ji     STAR                 제니, 걸그룹 브랜드 평판 1위 등극
# 12        E    Ji   BEAUTY                디올의 뮤즈 지수, 청량한 여름을 닮은
# 13        E    Ji  FASHION           스타일링 지수 높여주는 마법의 액세서리 '벨트'
# ...

# %% [markdown]
# ## FashionN

# %%
fn_ji
# Out:
#   brand category                                       title        date  \
# 0    Ji     인스타일     블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩  2020-10-09
# 1    Ji     인스타일     [그 옷 어디꺼] 블랙핑크 지수, 상큼 발랄 오버롤 데님 팬츠 어디꺼?  2020-07-29
# 2    Ji     스타패션  [패션엔 포토] 블랙핑크 리사·지수·로제, 자체발광 여신들 위트있는 캐주얼룩  2018-09-09
# 3    Ji     패션뉴스        노나곤, 한정판 '블랙 후디' 블랙핑크·위너·아이콘 셀피로 화제!  2018-09-07
# 4    Ji     패션뉴스         블랙핑크 지수·리사·로제, 톡톡튀는 '아디다스 오리지널스' 화보  2018-08-17
# 5    Ji     패션뉴스              리복 클래식, 블랙핑크와 함께한 ‘클럽 C’ 영상 공개  2016-11-18
# 6    Ji     패션뉴스           블랙핑크, 휘파람이 절로 나는 ‘신비+유니크’ 걸크러쉬 매력  2016-09-12
# 7    Ji     패션뉴스               세인트코스트, YG신예 걸그룹 '블랙핑크' 모델 발탁  2016-09-07
#
#                                                 link  title_brand  \
# 0  https://www.fashionn.com/board/read_new.php?ta...            1
# 1  https://www.fashionn.com/board/read_new.php?ta...            1
# 2  https://www.fashionn.com/board/read_new.php?ta...            1
# ...

# %%
fn_ji['magazine'] = 'FN'

# %%
fn_ji = fn_ji[['magazine', 'brand', 'category', 'title','link','date','contents','title_brand']]
fn_ji
# Out:
#   magazine brand category                                       title  \
# 0       FN    Ji     인스타일     블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩
# 1       FN    Ji     인스타일     [그 옷 어디꺼] 블랙핑크 지수, 상큼 발랄 오버롤 데님 팬츠 어디꺼?
# 2       FN    Ji     스타패션  [패션엔 포토] 블랙핑크 리사·지수·로제, 자체발광 여신들 위트있는 캐주얼룩
# 3       FN    Ji     패션뉴스        노나곤, 한정판 '블랙 후디' 블랙핑크·위너·아이콘 셀피로 화제!
# 4       FN    Ji     패션뉴스         블랙핑크 지수·리사·로제, 톡톡튀는 '아디다스 오리지널스' 화보
# 5       FN    Ji     패션뉴스              리복 클래식, 블랙핑크와 함께한 ‘클럽 C’ 영상 공개
# 6       FN    Ji     패션뉴스           블랙핑크, 휘파람이 절로 나는 ‘신비+유니크’ 걸크러쉬 매력
# 7       FN    Ji     패션뉴스               세인트코스트, YG신예 걸그룹 '블랙핑크' 모델 발탁
#
#                                                 link        date  \
# 0  https://www.fashionn.com/board/read_new.php?ta...  2020-10-09
# 1  https://www.fashionn.com/board/read_new.php?ta...  2020-07-29
# 2  https://www.fashionn.com/board/read_new.php?ta...  2018-09-09
# 3  https://www.fashionn.com/board/read_new.php?ta...  2018-09-07
# ...

# %%
fn_ji['word_jisoo'] = fn_ji['contents']
# Out:
# <ipython-input-35-b3a38826509e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fn_ji['word_jisoo'] = fn_ji['contents']

# %%
fn_ji
# Out:
#   magazine brand category                                       title  \
# 0       FN    Ji     인스타일     블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩
# 1       FN    Ji     인스타일     [그 옷 어디꺼] 블랙핑크 지수, 상큼 발랄 오버롤 데님 팬츠 어디꺼?
# 2       FN    Ji     스타패션  [패션엔 포토] 블랙핑크 리사·지수·로제, 자체발광 여신들 위트있는 캐주얼룩
# 3       FN    Ji     패션뉴스        노나곤, 한정판 '블랙 후디' 블랙핑크·위너·아이콘 셀피로 화제!
# 4       FN    Ji     패션뉴스         블랙핑크 지수·리사·로제, 톡톡튀는 '아디다스 오리지널스' 화보
# 5       FN    Ji     패션뉴스              리복 클래식, 블랙핑크와 함께한 ‘클럽 C’ 영상 공개
# 6       FN    Ji     패션뉴스           블랙핑크, 휘파람이 절로 나는 ‘신비+유니크’ 걸크러쉬 매력
# 7       FN    Ji     패션뉴스               세인트코스트, YG신예 걸그룹 '블랙핑크' 모델 발탁
#
#                                                 link        date  \
# 0  https://www.fashionn.com/board/read_new.php?ta...  2020-10-09
# 1  https://www.fashionn.com/board/read_new.php?ta...  2020-07-29
# 2  https://www.fashionn.com/board/read_new.php?ta...  2018-09-09
# 3  https://www.fashionn.com/board/read_new.php?ta...  2018-09-07
# ...

# %% [markdown]
# ## Marie Claire

# %%
m_ji
# Out:
#   magazine brand   category           title  \
# 0        M    Ji     beauty       점만 잘 찍어도!
# 1        M    Ji  celebrity         지수다운 순간
# 2        M    Ji     beauty     앞머리 내릴까 말까?
# 3        M    Ji  celebrity  Blooming Scene
# 4        M    Ji     beauty  실패 없는 아이돌 포니테일
# 5        M    Ji  lifestyle  붐바야, 소녀들이 출격했다
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/beauty/2020/09...  2020-09
# 1  http://www.marieclairekorea.com/celebrity/2020...  2020-08
# 2  http://www.marieclairekorea.com/beauty/2018/02...  2018-02
# 3  http://www.marieclairekorea.com/celebrity/2018...  2018-02
# 4  http://www.marieclairekorea.com/beauty/2018/01...  2018-01
# 5  http://www.marieclairekorea.com/lifestyle/2016...  2016-08
#
#                                             contents  title_brand  check  \
# 0  [' ', '잡티 하나 없는 백옥같은 피부가 대세이던 시절, 얼굴에 있는 점을 컨실...            0      0
# ...

# %%
m_ji.drop('check', axis=1, inplace=True)

# %%
m_ji
# Out:
#   magazine brand   category           title  \
# 0        M    Ji     beauty       점만 잘 찍어도!
# 1        M    Ji  celebrity         지수다운 순간
# 2        M    Ji     beauty     앞머리 내릴까 말까?
# 3        M    Ji  celebrity  Blooming Scene
# 4        M    Ji     beauty  실패 없는 아이돌 포니테일
# 5        M    Ji  lifestyle  붐바야, 소녀들이 출격했다
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/beauty/2020/09...  2020-09
# 1  http://www.marieclairekorea.com/celebrity/2020...  2020-08
# 2  http://www.marieclairekorea.com/beauty/2018/02...  2018-02
# 3  http://www.marieclairekorea.com/celebrity/2018...  2018-02
# 4  http://www.marieclairekorea.com/beauty/2018/01...  2018-01
# 5  http://www.marieclairekorea.com/lifestyle/2016...  2016-08
#
#                                             contents  title_brand  \
# 0  [' ', '잡티 하나 없는 백옥같은 피부가 대세이던 시절, 얼굴에 있는 점을 컨실...            0
# 1  ['오늘 촬영은 어땠어요? 시간이 생각보다 빨리 지나갔네요. 재미있었어요.(웃음)'...            1
# ...

# %%
m_ji.rename({'word_jisu':'word_jisoo'}, axis=1, inplace=True)
m_ji
# Out:
#   magazine brand   category           title  \
# 0        M    Ji     beauty       점만 잘 찍어도!
# 1        M    Ji  celebrity         지수다운 순간
# 2        M    Ji     beauty     앞머리 내릴까 말까?
# 3        M    Ji  celebrity  Blooming Scene
# 4        M    Ji     beauty  실패 없는 아이돌 포니테일
# 5        M    Ji  lifestyle  붐바야, 소녀들이 출격했다
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/beauty/2020/09...  2020-09
# 1  http://www.marieclairekorea.com/celebrity/2020...  2020-08
# 2  http://www.marieclairekorea.com/beauty/2018/02...  2018-02
# 3  http://www.marieclairekorea.com/celebrity/2018...  2018-02
# 4  http://www.marieclairekorea.com/beauty/2018/01...  2018-01
# 5  http://www.marieclairekorea.com/lifestyle/2016...  2016-08
#
#                                             contents  title_brand  \
# 0  [' ', '잡티 하나 없는 백옥같은 피부가 대세이던 시절, 얼굴에 있는 점을 컨실...            0
# 1  ['오늘 촬영은 어땠어요? 시간이 생각보다 빨리 지나갔네요. 재미있었어요.(웃음)'...            1
# ...

# %% [markdown]
# ## Vogue

# %%
v_ji
# Out:
#    magazine brand     category                              title  \
# 0         V    Ji  daily issue                  블랙핑크 지수, 드라마 첫 주연
# 1         V    Ji      Fashion  블랙핑크 리사, 레드벨벳 아이린이 즐겨 입는 여름 티셔츠는?
# 2         V    Ji       Beauty                             지수의 입술
# 3         V    Ji       Beauty                Dior Beauty & Jisoo
# 4         V    Ji       Beauty                           디올 뷰티x지수
# 5         V    Ji      Fashion                                몽중몽
# 6         V    Ji       Beauty                          En Etoile
# 7         V    Ji  daily issue               ‘텀블러’가 뽑은 올해의 인기 아이돌
# 8         V    Ji       Beauty                         앞머리 대신 잔머리
# 9         V    Ji  daily issue                        스타들의 체크 활용법
# 10        V    Ji  daily issue                   필름 카메라에 푹 빠진 스타들
# 11        V    Ji       Living                    그들만의 언어, ‘돌민정음’
# 12        V    Ji      Fashion                              핑크 펑크
# ...

# %%
v_ji.drop('check', axis=1, inplace=True)

# %%
v_ji
# Out:
#    magazine brand     category                              title  \
# 0         V    Ji  daily issue                  블랙핑크 지수, 드라마 첫 주연
# 1         V    Ji      Fashion  블랙핑크 리사, 레드벨벳 아이린이 즐겨 입는 여름 티셔츠는?
# 2         V    Ji       Beauty                             지수의 입술
# 3         V    Ji       Beauty                Dior Beauty & Jisoo
# 4         V    Ji       Beauty                           디올 뷰티x지수
# 5         V    Ji      Fashion                                몽중몽
# 6         V    Ji       Beauty                          En Etoile
# 7         V    Ji  daily issue               ‘텀블러’가 뽑은 올해의 인기 아이돌
# 8         V    Ji       Beauty                         앞머리 대신 잔머리
# 9         V    Ji  daily issue                        스타들의 체크 활용법
# 10        V    Ji  daily issue                   필름 카메라에 푹 빠진 스타들
# 11        V    Ji       Living                    그들만의 언어, ‘돌민정음’
# 12        V    Ji      Fashion                              핑크 펑크
# ...

# %% [markdown]
# ## W

# %%
w_ji
# Out:
#   brand magazine     category                         title        date  \
# 0    Ji        W   BEAUTY, 화보       블랙핑크 지수의 촉촉하고 생기 넘치는 순간  2020-12-04
# 1    Ji        W  W HOT ISSUE          블랙핑크 지수, ‘설강화’ 주연 발탁  2020-08-18
# 2    Ji        W  W HOT ISSUE      블랙핑크 로제, 리사, 지수 솔로곡 공개한다  2020-06-01
# 3    Ji        W  W HOT ISSUE        블랙핑크, 4년 만의 첫 정규 앨범 발매  2020-10-02
# 4    Ji        W  W HOT ISSUE  배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑  2020-09-18
# 5    Ji        W  W HOT ISSUE      블랙핑크X세레나 고메즈 영상통화, 협업 티징  2020-08-24
# 6    Ji        W  W HOT ISSUE       블랙핑크가 아이스크림 셀카를 올린 이유는?  2020-07-20
# 7    Ji        W  FASHION, 뉴스          블랙핑크 컴백! 남다른 패션 스타일링  2020-06-26
#
#                                                 link  title_brand  \
# 0  http://www.wkorea.com/2020/12/04/%eb%b8%94%eb%...            1
# 1  http://www.wkorea.com/2020/08/18/%eb%b8%94%eb%...            1
# 2  http://www.wkorea.com/2020/06/01/%eb%b8%94%eb%...            1
# ...

# %%
w_ji = w_ji[['magazine', 'brand', 'category', 'title','link','date','contents','title_brand']]
w_ji
# Out:
#   magazine brand     category                         title  \
# 0        W    Ji   BEAUTY, 화보       블랙핑크 지수의 촉촉하고 생기 넘치는 순간
# 1        W    Ji  W HOT ISSUE          블랙핑크 지수, ‘설강화’ 주연 발탁
# 2        W    Ji  W HOT ISSUE      블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 3        W    Ji  W HOT ISSUE        블랙핑크, 4년 만의 첫 정규 앨범 발매
# 4        W    Ji  W HOT ISSUE  배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 5        W    Ji  W HOT ISSUE      블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 6        W    Ji  W HOT ISSUE       블랙핑크가 아이스크림 셀카를 올린 이유는?
# 7        W    Ji  FASHION, 뉴스          블랙핑크 컴백! 남다른 패션 스타일링
#
#                                                 link        date  \
# 0  http://www.wkorea.com/2020/12/04/%eb%b8%94%eb%...  2020-12-04
# 1  http://www.wkorea.com/2020/08/18/%eb%b8%94%eb%...  2020-08-18
# 2  http://www.wkorea.com/2020/06/01/%eb%b8%94%eb%...  2020-06-01
# 3  http://www.wkorea.com/2020/10/02/%eb%b8%94%eb%...  2020-10-02
# 4  http://www.wkorea.com/2020/09/18/%eb%b0%b0%ed%...  2020-09-18
# ...

# %%
w_ji['word_jisoo'] = w_ji['contents']
# Out:
# <ipython-input-46-188e9deb4988>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w_ji['word_jisoo'] = w_ji['contents']

# %%
w_ji
# Out:
#   magazine brand     category                         title  \
# 0        W    Ji   BEAUTY, 화보       블랙핑크 지수의 촉촉하고 생기 넘치는 순간
# 1        W    Ji  W HOT ISSUE          블랙핑크 지수, ‘설강화’ 주연 발탁
# 2        W    Ji  W HOT ISSUE      블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 3        W    Ji  W HOT ISSUE        블랙핑크, 4년 만의 첫 정규 앨범 발매
# 4        W    Ji  W HOT ISSUE  배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 5        W    Ji  W HOT ISSUE      블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 6        W    Ji  W HOT ISSUE       블랙핑크가 아이스크림 셀카를 올린 이유는?
# 7        W    Ji  FASHION, 뉴스          블랙핑크 컴백! 남다른 패션 스타일링
#
#                                                 link        date  \
# 0  http://www.wkorea.com/2020/12/04/%eb%b8%94%eb%...  2020-12-04
# 1  http://www.wkorea.com/2020/08/18/%eb%b8%94%eb%...  2020-08-18
# 2  http://www.wkorea.com/2020/06/01/%eb%b8%94%eb%...  2020-06-01
# 3  http://www.wkorea.com/2020/10/02/%eb%b8%94%eb%...  2020-10-02
# 4  http://www.wkorea.com/2020/09/18/%eb%b0%b0%ed%...  2020-09-18
# ...

# %%
magazine_ji = pd.concat([a_ji, b_ji, c_ji, e_ji, fn_ji, m_ji, v_ji, w_ji])

# %%
magazine_ji
# Out:
#    magazine brand     category                                          title  \
# 0    Allure    Ji       BEAUTY                     화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1    Allure    Ji       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2    Allure    Ji       BEAUTY                               #얼루어_커버걸 블랙핑크 지수
# 3    Allure    Ji       BEAUTY                                     LOOK AT ME
# 4    Allure    Ji       BEAUTY                얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..      ...   ...          ...                                            ...
# 3         W    Ji  W HOT ISSUE                         블랙핑크, 4년 만의 첫 정규 앨범 발매
# 4         W    Ji  W HOT ISSUE                   배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 5         W    Ji  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 6         W    Ji  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 7         W    Ji  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
#
# ...

# %%
magazine_ji.to_csv('./data/bp/magazine_ji.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_ji = pd.read_csv('./data/bp/magazine_ji.csv' , sep='|', encoding='utf-8')
magazine_ji
# Out:
#     magazine brand     category  \
# 0     Allure    Ji       BEAUTY
# 1     Allure    Ji       BEAUTY
# 2     Allure    Ji       BEAUTY
# 3     Allure    Ji       BEAUTY
# 4     Allure    Ji       BEAUTY
# ..       ...   ...          ...
# 103        W    Ji  W HOT ISSUE
# 104        W    Ji  W HOT ISSUE
# 105        W    Ji  W HOT ISSUE
# 106        W    Ji  W HOT ISSUE
# 107        W    Ji  FASHION, 뉴스
#
#                                              title  \
# 0                       화제의 더듬이 머리, 지금과 옛날의 다른 점은?
# 1    3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 2                                 #얼루어_커버걸 블랙핑크 지수
# 3                                       LOOK AT ME
# 4                  얼루어 2018년 2월호 커버 (블랙핑크 지수, 민스코)
# ..                                             ...
# 103                         블랙핑크, 4년 만의 첫 정규 앨범 발매
# 104                   배틀 그라운드 X 블랙핑크, 게임업계도 접수한 블핑
# 105                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 106                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# ...
