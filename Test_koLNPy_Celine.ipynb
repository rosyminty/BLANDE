# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %% [markdown]
# ## 데이터 전처리하면서 모을 준비

# %% [markdown]
# ### Allure

# %%
a_ce = pd.read_csv('./data/Ce/Allure_Celine.csv' , sep='|', encoding='utf-8')
a_ce
# Out:
#      Unnamed: 0 magazine brand   category                title  \
# 0             0        A    Ce    FASHION                코트 체크
# 1             1        A    Ce    FASHION            데님이여 영원하라
# 2             2        A    Ce    FASHION        남자 백’까지 갖고 싶어
# 3             3        A    Ce  CELEBRITY                예림-예리
# 4             4        A    Ce  CELEBRITY        GOOD TIME, 헨리
# ..          ...      ...   ...        ...                  ...
# 123         124        A    Ce     BEAUTY           탐나는 아기 화장품
# 124         125        A    Ce     BEAUTY  다시 돌아온 인조 속눈썹과 마스카라
# 125         126        A    Ce     BEAUTY       접속! 파워 유투버 <2>
# 126         131        A    Ce     BEAUTY               면세점 쇼핑
# 127         136        A    Ce     BEAUTY          비디비치가 달라졌어요
#
#                                                   link        date  \
# 0    http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# 1    http://www.allurekorea.com/2020/11/06/%eb%8d%b...  2020-10-26
# ...

# %%
d = list(range(110,127))
a_ce.iloc[d]
# Out:
#      Unnamed: 0 magazine brand category                  title  \
# 110         111        A    Ce   BEAUTY     윤종신 PICK! 민서 입덕 화보
# 111         112        A    Ce   BEAUTY  에디터가 꼽은 예쁜 틴티드 립밤 8가지
# 112         113        A    Ce  FEATURE         미니 보습 크림 성분 사전
# 113         114        A    Ce   BEAUTY          SHINE A LIGHT
# 114         115        A    Ce  FASHION        SOCK-LIKE BOOTS
# 115         116        A    Ce   BEAUTY        할리우드 뷰티의 새로운 정의
# 116         117        A    Ce   BEAUTY                뷰티풀 모먼트
# 117         118        A    Ce   BEAUTY  건조한 입술을 위한 특급 관리법 <2>
# 118         119        A    Ce   BEAUTY  건조한 입술을 위한 특급 관리법 <1>
# 119         120        A    Ce   BEAUTY          피부, 겨울 나기 <1>
# 120         121        A    Ce   BEAUTY               특급 입술 관리
# 121         122        A    Ce   BEAUTY            보디 메이크업 노하우
# 122         123        A    Ce   BEAUTY              선이 고와야 미인
# 123         124        A    Ce   BEAUTY             탐나는 아기 화장품
# ...

# %%
# column name 추출
list(a_ce)
# Out:
# ['Unnamed: 0',
#  'magazine',
#  'brand',
#  'category',
#  'title',
#  'link',
#  'date',
#  'contents',
#  'title_brand',
#  'check',
#  'why']

# %%
a_ce.drop('Unnamed: 0', axis=1, inplace=True)
a_ce
# Out:
#     magazine brand   category                title  \
# 0          A    Ce    FASHION                코트 체크
# 1          A    Ce    FASHION            데님이여 영원하라
# 2          A    Ce    FASHION        남자 백’까지 갖고 싶어
# 3          A    Ce  CELEBRITY                예림-예리
# 4          A    Ce  CELEBRITY        GOOD TIME, 헨리
# ..       ...   ...        ...                  ...
# 123        A    Ce     BEAUTY           탐나는 아기 화장품
# 124        A    Ce     BEAUTY  다시 돌아온 인조 속눈썹과 마스카라
# 125        A    Ce     BEAUTY       접속! 파워 유투버 <2>
# 126        A    Ce     BEAUTY               면세점 쇼핑
# 127        A    Ce     BEAUTY          비디비치가 달라졌어요
#
#                                                   link        date  \
# 0    http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# 1    http://www.allurekorea.com/2020/11/06/%eb%8d%b...  2020-10-26
# 2    http://www.allurekorea.com/2020/11/04/%eb%82%a...  2020-10-25
# 3    http://www.allurekorea.com/2020/11/03/%ec%98%8...  2020-10-25
# ...

# %%
a_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
a_ce
# Out:
#     magazine brand   category                           title  \
# 0          A    Ce    FASHION                           코트 체크
# 1          A    Ce    FASHION                       데님이여 영원하라
# 2          A    Ce    FASHION                   남자 백’까지 갖고 싶어
# 3          A    Ce  CELEBRITY                           예림-예리
# 89         A    Ce     BEAUTY       11월의 뷰티 신상 파헤치기 #잇츠온세일 #립
# ..       ...   ...        ...                             ...
# 62         A    Ce    FASHION                패션하우스에서 또 무슨 일이?
# 61         A    Ce    FASHION                      HIGH LIGHT
# 60         A    Ce    FASHION               THE BASIC JACKETS
# 127        A    Ce     BEAUTY                     비디비치가 달라졌어요
# 59         A    Ce    FEATURE  내가 뭘 본거지? 눈을 의심하게 하는 인스타 아티스트4
#
#                                                   link        date  \
# 0    http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# 1    http://www.allurekorea.com/2020/11/06/%eb%8d%b...  2020-10-26
# ...

# %%
a_ce.to_csv('./data/Ce/a_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### Cosmopolitan

# %%
c_ce = pd.read_csv('./data/Ce/cos_ce.csv' , sep='|', encoding='utf-8')
c_ce
# Out:
#     magazine brand category                  title  \
# 0          C    Ce  FASHION   이보다 시크할 순 없다! 케이프 코트
# 1          C    Ce  FASHION       올겨울 하의 트렌드 완벽 정리
# 2          C    Ce  FASHION     카디건 이렇게도 입을 수 있어요!
# 3          C    Ce  FASHION         가을 여자라면 역시 체크지
# 4          C    Ce   CELEBS                모두의 클래식
# ..       ...   ...      ...                    ...
# 121        C    Ce  FASHION  새로 나온 백을 가장 빨리 든 스타는?
# 122        C    Ce  FASHION          스타들의 런웨이 오피스룩
# 123        C    Ce  FASHION   품절대란! SNS에서 핫한 아이템은?
# 124        C    Ce     LIFE        사랑이 고플 땐, 이 영화!
# 125        C    Ce   CELEBS              몬스타엑스의 비밀
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201121000132646  2020.11.21
# 1    http://v.media.daum.net/v/20201112001113982  2020.11.12
# 2    http://v.media.daum.net/v/20201108000047639  2020.11.08
# 3    http://v.media.daum.net/v/20201109000132851  2020.11.09
# ...

# %%
c_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
c_ce
# Out:
#     magazine brand category                                 title  \
# 0          C    Ce  FASHION                  이보다 시크할 순 없다! 케이프 코트
# 1          C    Ce  FASHION                      올겨울 하의 트렌드 완벽 정리
# 3          C    Ce  FASHION                        가을 여자라면 역시 체크지
# 2          C    Ce  FASHION                    카디건 이렇게도 입을 수 있어요!
# 4          C    Ce   CELEBS                               모두의 클래식
# ..       ...   ...      ...                                   ...
# 93         C    Ce   BEAUTY              8명의 모델이 이야기하는 아름다운 몸 이야기
# 79         C    Ce  FASHION  트렌치, 데님재킷, 롱 카디건! 올 봄 당신이 사야할 아우터 2탄
# 125        C    Ce   CELEBS                             몬스타엑스의 비밀
# 100        C    Ce  FASHION               액세서리 맞아? 조각 작품 같은 액세서리들
# 105        C    Ce  FASHION                 자유를 만끽하는 소녀의 어느 오후 #2
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201121000132646  2020.11.21
# ...

# %%
c_ce.to_csv('./data/Ce/c_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### Daum BAZAAR

# %%
b_ce = pd.read_csv('./data/Ce/Daum_BAZAAR_Celine.csv' , sep='|', encoding='utf-8')
b_ce
# Out:
#     Unnamed: 0 magazine brand     category                      title  \
# 0            0        B    Ce      Fashion               오버사이즈로 압도하라!
# 1            1        B    Ce      FASHION     코로나 시대에 '귀족룩'이 트렌드인 이유
# 2            2        B    Ce    CELEBRITY           뒷광고 말고, 셀럽들의 앞광고
# 3            3        B    Ce      FASHION    변덕스러운 날씨에 탁월한 서머 샌들 연출법
# 4            4        B    Ce      FASHION  연휴에 정주행하면 좋을 에디슬리먼의 #집콕영화
# 5            5        B    Ce      FASHION       이번 시즌 런웨이에서 뽑은 베스트 룩
# 6            6        B    Ce      FASHION     스타일링이 어려운 베스트, 이렇게 입어!
# 7            7        B    Ce    CELEBRITY        영화 시상식에 참석한 배우들의 외침
# 8            8        B    Ce      FASHION          2020 S/S 컬렉션의 핫스팟
# 9            9        B    Ce  ART&CULTURE                 사랑과 연대의 기록
# 10          10        B    Ce      FASHION                  루시아 피카의 집
# 11          11        B    Ce      FASHION       2019 F/W '이것'만 알면 끝!
# ...

# %%
b_ce.drop('Unnamed: 0', axis=1, inplace=True)
b_ce
# Out:
#    magazine brand     category                      title  \
# 0         B    Ce      Fashion               오버사이즈로 압도하라!
# 1         B    Ce      FASHION     코로나 시대에 '귀족룩'이 트렌드인 이유
# 2         B    Ce    CELEBRITY           뒷광고 말고, 셀럽들의 앞광고
# 3         B    Ce      FASHION    변덕스러운 날씨에 탁월한 서머 샌들 연출법
# 4         B    Ce      FASHION  연휴에 정주행하면 좋을 에디슬리먼의 #집콕영화
# 5         B    Ce      FASHION       이번 시즌 런웨이에서 뽑은 베스트 룩
# 6         B    Ce      FASHION     스타일링이 어려운 베스트, 이렇게 입어!
# 7         B    Ce    CELEBRITY        영화 시상식에 참석한 배우들의 외침
# 8         B    Ce      FASHION          2020 S/S 컬렉션의 핫스팟
# 9         B    Ce  ART&CULTURE                 사랑과 연대의 기록
# 10        B    Ce      FASHION                  루시아 피카의 집
# 11        B    Ce      FASHION       2019 F/W '이것'만 알면 끝!
# 12        B    Ce    LIFESTYLE                모델 이혜승의 사진집
# 13        B    Ce      FASHION           올 가을, 겨울 트렌드 총집합
# 14        B    Ce      FASHION           2019 F/W 런웨이 리포트
# ...

# %%
b_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
b_ce
# Out:
#    magazine brand     category                      title  \
# 1         B    Ce      FASHION     코로나 시대에 '귀족룩'이 트렌드인 이유
# 2         B    Ce    CELEBRITY           뒷광고 말고, 셀럽들의 앞광고
# 3         B    Ce      FASHION    변덕스러운 날씨에 탁월한 서머 샌들 연출법
# 4         B    Ce      FASHION  연휴에 정주행하면 좋을 에디슬리먼의 #집콕영화
# 5         B    Ce      FASHION       이번 시즌 런웨이에서 뽑은 베스트 룩
# 6         B    Ce      FASHION     스타일링이 어려운 베스트, 이렇게 입어!
# 7         B    Ce    CELEBRITY        영화 시상식에 참석한 배우들의 외침
# 8         B    Ce      FASHION          2020 S/S 컬렉션의 핫스팟
# 9         B    Ce  ART&CULTURE                 사랑과 연대의 기록
# 10        B    Ce      FASHION                  루시아 피카의 집
# 11        B    Ce      FASHION       2019 F/W '이것'만 알면 끝!
# 12        B    Ce    LIFESTYLE                모델 이혜승의 사진집
# 13        B    Ce      FASHION           올 가을, 겨울 트렌드 총집합
# 14        B    Ce      FASHION           2019 F/W 런웨이 리포트
# 15        B    Ce      FASHION           톱 모델 강소영의 사적인 취향
# ...

# %%
b_ce.to_csv('./data/Ce/b_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### Elle

# %%
e_ce = pd.read_csv('./data/Ce/elle_ce.csv' , sep='|', encoding='utf-8')
e_ce
# Out:
#     magazine brand category                                     title  \
# 0          E    Ce  FASHION     내일 뭐 입지? 스타들이 픽한 아우터는 바로 '이것' #옷잘입는언니
# 1          E    Ce  FASHION  예쁜 애 옆에 예쁜 애! '손민수' 하고 싶은 무스가드 자매의 트위...
# 2          E    Ce  FASHION                      단 하나의 셀린느_요주의 물건 #49
# 3          E    Ce        0                          데일리한 니트 원피스 스타일링
# 4          E    Ce        0              어디에나 잘 어울리는 트렌디한 블랙 아이템 코디법!
# ..       ...   ...      ...                                       ...
# 147        E    Ce  FASHION                              조니 코카의 건축학개론
# 148        E    Ce  FASHION                                  아, 옛날이여!
# 149        E    Ce  FASHION                                 도전! 팬츠 수트
# 150        E    Ce  FASHION                      '스웨그' 만드는 스타일링 법칙 10
# 151        E    Ce   BEAUTY                               작은 향수병 속 런던
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201121070041038  2020.11.21
# ...

# %%
e_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
e_ce
# Out:
#     magazine brand category                                     title  \
# 0          E    Ce  FASHION     내일 뭐 입지? 스타들이 픽한 아우터는 바로 '이것' #옷잘입는언니
# 1          E    Ce  FASHION  예쁜 애 옆에 예쁜 애! '손민수' 하고 싶은 무스가드 자매의 트위...
# 2          E    Ce  FASHION                      단 하나의 셀린느_요주의 물건 #49
# 3          E    Ce        0                          데일리한 니트 원피스 스타일링
# 4          E    Ce        0              어디에나 잘 어울리는 트렌디한 블랙 아이템 코디법!
# ..       ...   ...      ...                                       ...
# 147        E    Ce  FASHION                              조니 코카의 건축학개론
# 148        E    Ce  FASHION                                  아, 옛날이여!
# 149        E    Ce  FASHION                                 도전! 팬츠 수트
# 150        E    Ce  FASHION                      '스웨그' 만드는 스타일링 법칙 10
# 151        E    Ce   BEAUTY                               작은 향수병 속 런던
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201121070041038  2020.11.21
# ...

# %%
e_ce.to_csv('./data/Ce/e_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### FashionN

# %%
fn_ce = pd.read_csv('./data/Ce/fashionn_Ce.csv' , sep='|', encoding='utf-8')
fn_ce
# Out:
#     brand category                                    title        date  \
# 0      Ce      라이프      굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1      Ce       리뷰           [리뷰] 파리지엔 걸, 2021 봄/여름 셀린느 컬렉션  2020-10-27
# 2      Ce     패션뉴스   롯데백화점, 프리미엄 멘즈셀렉트샵 ‘스말트(SMALT)’ 1호점 오픈  2020-10-23
# 3      Ce     인스타일  블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩  2020-10-09
# 4      Ce     인스타일         블랙핑크 리사, 셀린느 디자이너가 포착한 시크한 파리지엔룩  2020-09-22
# ..    ...      ...                                      ...         ...
# 172    Ce      라이프          [스타일n] 올 겨울 유행을 주도하는 9가지 코트 스타일  2016-11-14
# 173    Ce       리뷰        [리뷰] 2017 봄/여름 파리 패션위크 트렌드 키워드 10  2016-10-10
# 174    Ce     패션칼럼            버버리의 실험적인 '현장 직구' 도전은 현재 순항중?  2016-09-22
# 175    Ce     패션칼럼                 기본으로 돌아간 트렌치의 '이유 있는 유혹'  2016-09-08
# 176    Ce     월드패션        요절한 천재 디자이너 '알렉산더 맥퀸' 패션전기 영화로 제작  2016-09-01
#
#                                                   link  title_brand  check  \
# ...

# %%
fn_ce['magazine'] = 'FN'
fn_ce
# Out:
#     brand category                                    title        date  \
# 0      Ce      라이프      굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1      Ce       리뷰           [리뷰] 파리지엔 걸, 2021 봄/여름 셀린느 컬렉션  2020-10-27
# 2      Ce     패션뉴스   롯데백화점, 프리미엄 멘즈셀렉트샵 ‘스말트(SMALT)’ 1호점 오픈  2020-10-23
# 3      Ce     인스타일  블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩  2020-10-09
# 4      Ce     인스타일         블랙핑크 리사, 셀린느 디자이너가 포착한 시크한 파리지엔룩  2020-09-22
# ..    ...      ...                                      ...         ...
# 172    Ce      라이프          [스타일n] 올 겨울 유행을 주도하는 9가지 코트 스타일  2016-11-14
# 173    Ce       리뷰        [리뷰] 2017 봄/여름 파리 패션위크 트렌드 키워드 10  2016-10-10
# 174    Ce     패션칼럼            버버리의 실험적인 '현장 직구' 도전은 현재 순항중?  2016-09-22
# 175    Ce     패션칼럼                 기본으로 돌아간 트렌치의 '이유 있는 유혹'  2016-09-08
# 176    Ce     월드패션        요절한 천재 디자이너 '알렉산더 맥퀸' 패션전기 영화로 제작  2016-09-01
#
#                                                   link  title_brand  check  \
# ...

# %%
# content -> contents
fn_ce = fn_ce.rename({'content' : 'contents'}, axis='columns')
fn_ce
# Out:
#     brand category                                    title        date  \
# 0      Ce      라이프      굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1      Ce       리뷰           [리뷰] 파리지엔 걸, 2021 봄/여름 셀린느 컬렉션  2020-10-27
# 2      Ce     패션뉴스   롯데백화점, 프리미엄 멘즈셀렉트샵 ‘스말트(SMALT)’ 1호점 오픈  2020-10-23
# 3      Ce     인스타일  블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩  2020-10-09
# 4      Ce     인스타일         블랙핑크 리사, 셀린느 디자이너가 포착한 시크한 파리지엔룩  2020-09-22
# ..    ...      ...                                      ...         ...
# 172    Ce      라이프          [스타일n] 올 겨울 유행을 주도하는 9가지 코트 스타일  2016-11-14
# 173    Ce       리뷰        [리뷰] 2017 봄/여름 파리 패션위크 트렌드 키워드 10  2016-10-10
# 174    Ce     패션칼럼            버버리의 실험적인 '현장 직구' 도전은 현재 순항중?  2016-09-22
# 175    Ce     패션칼럼                 기본으로 돌아간 트렌치의 '이유 있는 유혹'  2016-09-08
# 176    Ce     월드패션        요절한 천재 디자이너 '알렉산더 맥퀸' 패션전기 영화로 제작  2016-09-01
#
#                                                   link  title_brand  check  \
# ...

# %%
fn_ce = fn_ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
fn_ce
# Out:
#     magazine brand category                                    title  \
# 0         FN    Ce      라이프      굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN    Ce       리뷰           [리뷰] 파리지엔 걸, 2021 봄/여름 셀린느 컬렉션
# 2         FN    Ce     패션뉴스   롯데백화점, 프리미엄 멘즈셀렉트샵 ‘스말트(SMALT)’ 1호점 오픈
# 3         FN    Ce     인스타일  블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩
# 4         FN    Ce     인스타일         블랙핑크 리사, 셀린느 디자이너가 포착한 시크한 파리지엔룩
# ..       ...   ...      ...                                      ...
# 172       FN    Ce      라이프          [스타일n] 올 겨울 유행을 주도하는 9가지 코트 스타일
# 173       FN    Ce       리뷰        [리뷰] 2017 봄/여름 파리 패션위크 트렌드 키워드 10
# 174       FN    Ce     패션칼럼            버버리의 실험적인 '현장 직구' 도전은 현재 순항중?
# 175       FN    Ce     패션칼럼                 기본으로 돌아간 트렌치의 '이유 있는 유혹'
# 176       FN    Ce     월드패션        요절한 천재 디자이너 '알렉산더 맥퀸' 패션전기 영화로 제작
#
#                                                   link        date  \
# 0    https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
# ...

# %%
fn_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
fn_ce
# Out:
#     magazine brand category                                    title  \
# 0         FN    Ce      라이프      굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN    Ce       리뷰           [리뷰] 파리지엔 걸, 2021 봄/여름 셀린느 컬렉션
# 2         FN    Ce     패션뉴스   롯데백화점, 프리미엄 멘즈셀렉트샵 ‘스말트(SMALT)’ 1호점 오픈
# 3         FN    Ce     인스타일  블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩
# 4         FN    Ce     인스타일         블랙핑크 리사, 셀린느 디자이너가 포착한 시크한 파리지엔룩
# ..       ...   ...      ...                                      ...
# 172       FN    Ce      라이프          [스타일n] 올 겨울 유행을 주도하는 9가지 코트 스타일
# 173       FN    Ce       리뷰        [리뷰] 2017 봄/여름 파리 패션위크 트렌드 키워드 10
# 174       FN    Ce     패션칼럼            버버리의 실험적인 '현장 직구' 도전은 현재 순항중?
# 175       FN    Ce     패션칼럼                 기본으로 돌아간 트렌치의 '이유 있는 유혹'
# 176       FN    Ce     월드패션        요절한 천재 디자이너 '알렉산더 맥퀸' 패션전기 영화로 제작
#
#                                                   link        date  \
# 0    https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
# ...

# %%
fn_ce.to_csv('./data/Ce/fn_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### Fashion Biz

# %%
fb_ce = pd.read_csv('./data/Ce/FB_Celine.csv' , sep='|', encoding='utf-8')
fb_ce
# Out:
#    magazine brand        category                                title  \
# 0        FB    Ce    Today's News            셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁
# 1        FB    Ce    Today's News      여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트
# 2        FB    Ce    Today's News       갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대
# 3        FB    Ce    Today's News              [월드] 셀린느, 남성복 패션쇼 잠정 중단
# 4        FB    Ce    Today's News          [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?
# 5        FB    Ce    Today's News        갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화
# 6        FB    Ce      World Wide               아동복 패션 하우스, ‘마이크로 타깃팅’
# 7        FB    Ce    Today's News     [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선
# 8        FB    Ce    Today's News        셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개
# 9        FB    Ce    Today's News       [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선
# 10       FB    Ce    Today's News      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)
# 11       FB    Ce    Today's News           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이
# ...

# %%
fb_ce.to_csv('./data/Ce/fb_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### Marie Claire

# %%
m_ce = pd.read_csv('./data/Ce/marie_ce.csv' , sep='|', encoding='utf-8')
m_ce
# Out:
#     magazine brand   category                               title  \
# 0          M    Ce  celebrity                             Look At
# 1          M    Ce  lifestyle             10월 넷째주, 11월 첫째주 #신작 추천
# 2          M    Ce  lifestyle                         오직, 여자의 이야기
# 3          M    Ce    fashion                     MASCULINE SCENE
# 4          M    Ce     beauty  2020 F/W BEAUTY TREND FORECAST – 2
# ..       ...   ...        ...                                 ...
# 208        M    Ce     beauty                     과일처럼 상큼발랄한 뷰티 신
# 209        M    Ce    fashion                       Woman In Gold
# 210        M    Ce    fashion                        디자이너들의 리얼 룩!
# 211        M    Ce  celebrity                              유정의 여정
# 212        M    Ce    fashion               가늘고 길게, 새로운 감성의 미니멀 룩
#
#                                                   link     date  \
# 0    http://www.marieclairekorea.com/celebrity/2020...  2020-11
# ...

# %%
m_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
m_ce
# Out:
#     magazine brand   category                               title  \
# 0          M    Ce  celebrity                             Look At
# 2          M    Ce  lifestyle                         오직, 여자의 이야기
# 1          M    Ce  lifestyle             10월 넷째주, 11월 첫째주 #신작 추천
# 3          M    Ce    fashion                     MASCULINE SCENE
# 4          M    Ce     beauty  2020 F/W BEAUTY TREND FORECAST – 2
# ..       ...   ...        ...                                 ...
# 208        M    Ce     beauty                     과일처럼 상큼발랄한 뷰티 신
# 209        M    Ce    fashion                       Woman In Gold
# 210        M    Ce    fashion                        디자이너들의 리얼 룩!
# 211        M    Ce  celebrity                              유정의 여정
# 212        M    Ce    fashion               가늘고 길게, 새로운 감성의 미니멀 룩
#
#                                                   link     date  \
# 0    http://www.marieclairekorea.com/celebrity/2020...  2020-11
# ...

# %%
d = [211,212]
m_ce.drop(d, inplace=True)
m_ce
# Out:
#     magazine brand   category                               title  \
# 0          M    Ce  celebrity                             Look At
# 2          M    Ce  lifestyle                         오직, 여자의 이야기
# 1          M    Ce  lifestyle             10월 넷째주, 11월 첫째주 #신작 추천
# 3          M    Ce    fashion                     MASCULINE SCENE
# 4          M    Ce     beauty  2020 F/W BEAUTY TREND FORECAST – 2
# ..       ...   ...        ...                                 ...
# 206        M    Ce    fashion                      SHOW YOUR BAGS
# 207        M    Ce    fashion                            요즘 뭐 드니?
# 208        M    Ce     beauty                     과일처럼 상큼발랄한 뷰티 신
# 209        M    Ce    fashion                       Woman In Gold
# 210        M    Ce    fashion                        디자이너들의 리얼 룩!
#
#                                                   link     date  \
# 0    http://www.marieclairekorea.com/celebrity/2020...  2020-11
# ...

# %%
m_ce.to_csv('./data/Ce/m_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### Vogue

# %%
v_ce = pd.read_csv('./data/Ce/Vogue_Celine.csv' , sep='|', encoding='utf-8')
v_ce
# Out:
#   magazine brand     category  \
# 0        V    Ce      Fashion
# 1        V    Ce  ADVERTORIAL
# 2        V    Ce       Beauty
# 3        V    Ce      Fashion
# 4        V    Ce      Fashion
# 5        V    Ce      Fashion
# 6        V    Ce      Fashion
# 7        V    Ce      Fashion
# 8        V    Ce       Beauty
#
#                                                title  \
# 0                           셀린느 글로벌 앰배서더가 된 블랙핑크 리사!
# 1                    인 더 백 : Burberry’s DK88 메이킹 스토리
# 2                                         삭발에 빠진 여자들
# 3                                  오뜨 꾸뛰르 쇼에서 만난 스타들
# 4                                 2017 S/S Trends 11
# 5                     2017 S/S 밀란 패션위크 – Day 3, 4, 5
# 6  수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 셀린느: 현대 여성을 위한 ...
# 7      수지 멘키스가 품평한 2016 F/W 뉴욕 패션위크 프로엔자 스쿨러: 통제와 해방
# 8                                  촛불을 켠 듯 환한 피부의 비밀
#
#                                                 link        date  \
# ...

# %%
v_ce.to_csv('./data/Ce/v_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ### W

# %%
w_ce = pd.read_csv('./data/Ce/w_Ce.csv' , sep='|', encoding='utf-8')
w_ce
# Out:
#     brand                  category                       title        date  \
# 0      Ce                WHAT'S NEW     셀린느 글로벌 엠버서더가 된 블랙핑크 리사  2020-09-22
# 1      Ce                WHAT'S NEW              셀린느 트리옹프 캔버스 백  2020-04-16
# 2      Ce               FASHION, 뉴스  셀린느(Celine) 청담 플래그십 스토어 오픈  2017-04-03
# 3      Ce              FASHION, 트렌드               We Love Vol.1  2020-11-24
# 4      Ce           FASHION, 쇼핑, 화보                         띵동!  2020-11-08
# ..    ...                       ...                         ...         ...
# 210    Ce  FASHION, FEATURE, 피플, 화보             Thief of hearts  2016-09-27
# 211    Ce          FASHION, 쇼핑, 트렌드                     사고 말겠어!  2016-09-21
# 212    Ce                   쇼핑, 트렌드                         가을로  2016-09-12
# 213    Ce              FASHION, 트렌드                        남다르게  2016-09-08
# 214    Ce              FASHION, 트렌드                   너도 나도 베트멍  2016-09-01
#
# ...

# %%
w_ce.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
w_ce
# Out:
#     brand                  category            title        date  \
# 3      Ce              FASHION, 트렌드    We Love Vol.1  2020-11-24
# 4      Ce           FASHION, 쇼핑, 화보              띵동!  2020-11-08
# 5      Ce          FASHION, 쇼핑, 트렌드            말 달리자  2020-11-07
# 6      Ce          FASHION, 쇼핑, 트렌드            버블 버블  2020-11-06
# 7      Ce          FASHION, 트렌드, 화보            가을 따라  2020-11-02
# ..    ...                       ...              ...         ...
# 210    Ce  FASHION, FEATURE, 피플, 화보  Thief of hearts  2016-09-27
# 211    Ce          FASHION, 쇼핑, 트렌드          사고 말겠어!  2016-09-21
# 212    Ce                   쇼핑, 트렌드              가을로  2016-09-12
# 213    Ce              FASHION, 트렌드             남다르게  2016-09-08
# 214    Ce              FASHION, 트렌드        너도 나도 베트멍  2016-09-01
#
#                                                   link  title_brand  check  \
# 3      http://www.wkorea.com/2020/11/24/we-love-vol-1/            0      0
# ...

# %%
w_ce['magazine'] = 'W'
w_ce
# Out:
#     brand                  category            title        date  \
# 3      Ce              FASHION, 트렌드    We Love Vol.1  2020-11-24
# 4      Ce           FASHION, 쇼핑, 화보              띵동!  2020-11-08
# 5      Ce          FASHION, 쇼핑, 트렌드            말 달리자  2020-11-07
# 6      Ce          FASHION, 쇼핑, 트렌드            버블 버블  2020-11-06
# 7      Ce          FASHION, 트렌드, 화보            가을 따라  2020-11-02
# ..    ...                       ...              ...         ...
# 210    Ce  FASHION, FEATURE, 피플, 화보  Thief of hearts  2016-09-27
# 211    Ce          FASHION, 쇼핑, 트렌드          사고 말겠어!  2016-09-21
# 212    Ce                   쇼핑, 트렌드              가을로  2016-09-12
# 213    Ce              FASHION, 트렌드             남다르게  2016-09-08
# 214    Ce              FASHION, 트렌드        너도 나도 베트멍  2016-09-01
#
#                                                   link  title_brand  check  \
# 3      http://www.wkorea.com/2020/11/24/we-love-vol-1/            0      0
# ...

# %%
# content -> contents
w_ce = w_ce.rename({'content' : 'contents'}, axis='columns')
w_ce
# Out:
#     brand                  category            title        date  \
# 3      Ce              FASHION, 트렌드    We Love Vol.1  2020-11-24
# 4      Ce           FASHION, 쇼핑, 화보              띵동!  2020-11-08
# 5      Ce          FASHION, 쇼핑, 트렌드            말 달리자  2020-11-07
# 6      Ce          FASHION, 쇼핑, 트렌드            버블 버블  2020-11-06
# 7      Ce          FASHION, 트렌드, 화보            가을 따라  2020-11-02
# ..    ...                       ...              ...         ...
# 210    Ce  FASHION, FEATURE, 피플, 화보  Thief of hearts  2016-09-27
# 211    Ce          FASHION, 쇼핑, 트렌드          사고 말겠어!  2016-09-21
# 212    Ce                   쇼핑, 트렌드              가을로  2016-09-12
# 213    Ce              FASHION, 트렌드             남다르게  2016-09-08
# 214    Ce              FASHION, 트렌드        너도 나도 베트멍  2016-09-01
#
#                                                   link  title_brand  check  \
# 3      http://www.wkorea.com/2020/11/24/we-love-vol-1/            0      0
# ...

# %%
w_ce = w_ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
w_ce
# Out:
#     magazine brand                  category            title  \
# 3          W    Ce              FASHION, 트렌드    We Love Vol.1
# 4          W    Ce           FASHION, 쇼핑, 화보              띵동!
# 5          W    Ce          FASHION, 쇼핑, 트렌드            말 달리자
# 6          W    Ce          FASHION, 쇼핑, 트렌드            버블 버블
# 7          W    Ce          FASHION, 트렌드, 화보            가을 따라
# ..       ...   ...                       ...              ...
# 210        W    Ce  FASHION, FEATURE, 피플, 화보  Thief of hearts
# 211        W    Ce          FASHION, 쇼핑, 트렌드          사고 말겠어!
# 212        W    Ce                   쇼핑, 트렌드              가을로
# 213        W    Ce              FASHION, 트렌드             남다르게
# 214        W    Ce              FASHION, 트렌드        너도 나도 베트멍
#
#                                                   link        date  \
# 3      http://www.wkorea.com/2020/11/24/we-love-vol-1/  2020-11-24
# 4    http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...  2020-11-08
# ...

# %%
w_ce.to_csv('./data/Ce/w_ce.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %% [markdown]
# ## contents 합치기

# %%
contents = []

# %%
type(a_ce['contents'])
# Out:
# pandas.core.series.Series

# %%
contents.append(a_ce['contents'])

# %%
contents.append(b_ce['contents'])

# %%
contents.append(c_ce['contents'])

# %%
contents.append(e_ce['contents'])

# %%
contents.append(fb_ce['contents'])

# %%
contents.append(fn_ce['contents'])

# %%
contents.append(m_ce['contents'])

# %%
contents.append(v_ce['contents'])

# %%
contents.append(w_ce['contents'])

# %%
print(type(contents))
print(contents)
# Out:
# <class 'list'>
# [0      ['겨울이 오기 전 기억해야 할 코트의 면면.', '90’S STANDARD', '...
# 1      ['데님 팬츠를 선택할 때 가장 중요한 것은 자신의 체형에 맞는 핏을 고르는 것이다...
# 2      ['때로는 단정하게, 때로는 위트 있게 제 할 일을 다 하는. 그래서 더 넘보게 되...
# 3      ['어디에도 휘둘리지 않은 채 영향 바깥에서 명랑하게 씩 웃고 마는 하나뿐인 나, ...
# 89     ['뷰티 업계는 이제 겨울 준비를 시작했다. 피부에 진한 영양감을 넣어줄 앰플과 정...
#                              ...
# 62     ['변화하지 않으면 도태되기 쉬운 패션하우스. 오늘은 또 무슨 일이 일어나고 있나?...
# 61     ['지난 시즌의 쇼핑 리스트는 잠시 잊을 것. 여기 2019 봄/여름 시즌을 수놓을...
# 60     ['색도, 패턴도, 디자인도 새로운 것을 골라 다르게 입어보자. 포멀부터 캐주얼까지...
# 127    ['론칭 10주년을 맞아 새롭게 변신한 비디비치를 만나보자.\n1\n/\n1\n1 ...
# 59     ['컴퓨터 툴을 브러시로, 인스타그램을 캔버스로 활용하는 아티스트들이 있다. 인스타...
# Name: contents, Length: 128, dtype: object, 1     [' "코로나 시대에 \'귀족룩\'이 트렌드인 이유", \'여유로움과 낭만이 희미해...
# 2     [" '뒷광고 말고, 셀럽들의 앞광고", " '‘제품협찬’, ‘광고’는 이렇게!",...
# 3     [" '변덕스러운 날씨에 탁월한 서머 샌들 연출법", " '아리아나 그란데도 신는 ...
# 4     [" '연휴에 정주행하면 좋을 에디슬리먼의 #집콕영화", " '셀린의 크리에이티브 ...
# 5     [" '이번 시즌 런웨이에서 뽑은 베스트 룩", " '재해석한 클래식부터 사파리에서...
# ...

# %%
celine = []
for line in contents:
    celine.append(line)

# %%
celine
# Out:
# [0      ['겨울이 오기 전 기억해야 할 코트의 면면.', '90’S STANDARD', '...
#  1      ['데님 팬츠를 선택할 때 가장 중요한 것은 자신의 체형에 맞는 핏을 고르는 것이다...
#  2      ['때로는 단정하게, 때로는 위트 있게 제 할 일을 다 하는. 그래서 더 넘보게 되...
#  3      ['어디에도 휘둘리지 않은 채 영향 바깥에서 명랑하게 씩 웃고 마는 하나뿐인 나, ...
#  89     ['뷰티 업계는 이제 겨울 준비를 시작했다. 피부에 진한 영양감을 넣어줄 앰플과 정...
#                               ...
#  62     ['변화하지 않으면 도태되기 쉬운 패션하우스. 오늘은 또 무슨 일이 일어나고 있나?...
#  61     ['지난 시즌의 쇼핑 리스트는 잠시 잊을 것. 여기 2019 봄/여름 시즌을 수놓을...
#  60     ['색도, 패턴도, 디자인도 새로운 것을 골라 다르게 입어보자. 포멀부터 캐주얼까지...
#  127    ['론칭 10주년을 맞아 새롭게 변신한 비디비치를 만나보자.\n1\n/\n1\n1 ...
#  59     ['컴퓨터 툴을 브러시로, 인스타그램을 캔버스로 활용하는 아티스트들이 있다. 인스타...
#  Name: contents, Length: 128, dtype: object,
#  1     [' "코로나 시대에 \'귀족룩\'이 트렌드인 이유", \'여유로움과 낭만이 희미해...
#  2     [" '뒷광고 말고, 셀럽들의 앞광고", " '‘제품협찬’, ‘광고’는 이렇게!",...
#  3     [" '변덕스러운 날씨에 탁월한 서머 샌들 연출법", " '아리아나 그란데도 신는 ...
#  4     [" '연휴에 정주행하면 좋을 에디슬리먼의 #집콕영화", " '셀린의 크리에이티브 ...
#  5     [" '이번 시즌 런웨이에서 뽑은 베스트 룩", " '재해석한 클래식부터 사파리에서...
# ...

# %%
for line in a_ce['contents']:
    print(line)
# Out:
# ['겨울이 오기 전 기억해야 할 코트의 면면.', '90’S STANDARD', '1990년대의 모던한 느낌은 올겨울의 코트 스타일에서도 엿볼 수 있다. 유행을 타지 않는 군더더기 없는 스탠더드 핏의 코트는 그때의 감성은 물론 지금의 멋스러움까지 소화해낼 테니 기억할 것.', '간결한 실루엣의 코트는 5백78만원, 질 샌더(Jil Sander). 블랙 터틀넥은 8만9천원, 코스(Cos). 후프형의 실버 귀고리는 가격미정, 에르메스(Hermes). 멜란지 그레이 컬러의 와이드핏 슬랙스는 가격미정, 마그다 부트림 바이 무이(Magda Butrym by Mue). 레트로 무드의 스니커즈는 14만9천원, 아식스 스포츠스타일(Asics Sportstyle).', '클래식한 캐멀 컬러 코트는 1백78만원, 우영미(Wooyoungmi). 버건디 컬러 나파 가죽 셔츠는 3백85만원, 살바토레 페라가모(Salvatore Ferragamo). 슬릿 디테일 롱 스커트는 2백8만원, 질 샌더. 화이트 컬러 펌프스는 1백만원, 토즈(Tod’s). 금장 로고 사첼백은 3백85만원, 생 로랑 바이 안토니 바카렐로(Saint Laurent by Anthony Vaccarello).', '허리 라인에 슬릿이 있는 롱 코트는 2백60만원, 오프화이트(Off-White). 가죽 소재 재킷과 팬츠는 가격미정, YCH. 굵은 체인 네크리스는 1백62만5천원, 생 로랑 바이 안토니 바카렐로. 볼드한 빅 로고 장식 클러치백은 3백74만원, 발렌티노 가라바니(Valentino Garavani).', '  OVERSIZED SHAPE', '넉넉한 오버사이즈 코트는 여러 가지 아이템 간의 레이어드가 필요한 겨울에 더욱 요긴한 아이템. 쓱 걸치기만 해도 멋스러운 케이프나 부드럽게 몸을 감싸는 낙낙한 코트 등으로 다양한 스타일을 즐겨보자.', '골드 잠금 장식으로 포인트를 준 케이프 체크 코트는 1백9만원, 산드로(Sandro). 데님 팬츠는 가격미정, 리바이스(Levi’s). 그레이 컬러 니트 톱은 13
# ...

# %%
contents = []

# %%
for line in a_ce['contents'] :
