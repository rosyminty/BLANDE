# %%
import pandas as pd
import numpy as np

# %%
a_sl_dw = pd.read_csv('./data/SL/a_sl_dw.csv' , sep='|', encoding='utf-8')
c_sl_dw = pd.read_csv('./data/SL/c_sl_dw.csv' , sep='|', encoding='utf-8')
b_sl_dw = pd.read_csv('./data/SL/b_sl_dw.csv' , sep='|', encoding='utf-8')
e_sl_dw = pd.read_csv('./data/SL/e_sl_dw.csv' , sep='|', encoding='utf-8')
fb_sl_dw = pd.read_csv('./data/SL/fb_sl_dw.csv' , sep='|', encoding='utf-8')
fn_sl_dw = pd.read_csv('./data/SL/fn_sl_dw.csv' , sep='|', encoding='utf-8')
m_sl_dw = pd.read_csv('./data/SL/m_sl_dw.csv' , sep='|', encoding='utf-8')
v_sl_dw = pd.read_csv('./data/SL/v_sl_dw.csv' , sep='|', encoding='utf-8')
w_sl_dw = pd.read_csv('./data/SL/w_sl_dw.csv' , sep='|', encoding='utf-8')

# %%
magazine_sl = pd.concat([a_sl_dw, b_sl_dw, c_sl_dw, e_sl_dw, fb_sl_dw, fn_sl_dw, m_sl_dw, v_sl_dw, w_sl_dw])
magazine_sl
# Out:
#     magazine brand      category                    title  \
# 0          A   YSL     CELEBRITY         깊게 뿌리내리기 위하여, 수영
# 1          A   YSL       FASHION                    코트 체크
# 2          A   YSL       FASHION                데님이여 영원하라
# 3          A   YSL       FASHION                 안경 하세요?!
# 4          A   YSL       FASHION  가을의 정석, 트렌치 코트 입는 법 8가지
# ..       ...   ...           ...                      ...
# 242        W   YSL  FASHION, 트렌드                   어깨로말해요
# 243        W   YSL   FASHION, 뉴스                    W해시태그
# 244        W   YSL   FASHION, 화보                  따로 또 같이
# 245        W   YSL  FASHION, 트렌드                두려움 없는 반란
# 246        W   YSL  FASHION, 트렌드                너도 나도 베트멍
#
#                                                   link        date  \
# 0    http://www.allurekorea.com/2020/11/20/%ea%b9%8...  2020-11-20
# 1    http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# ...

# %%
magazine_sl.to_csv('./data/SL/magazine_sl.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_sl = pd.read_csv('./data/SL/magazine_sl.csv' , sep='|', encoding='utf-8')

# %%
magazine_sl
# Out:
#      magazine brand      category                    title  \
# 0           A   YSL     CELEBRITY         깊게 뿌리내리기 위하여, 수영
# 1           A   YSL       FASHION                    코트 체크
# 2           A   YSL       FASHION                데님이여 영원하라
# 3           A   YSL       FASHION                 안경 하세요?!
# 4           A   YSL       FASHION  가을의 정석, 트렌치 코트 입는 법 8가지
# ...       ...   ...           ...                      ...
# 1269        W   YSL  FASHION, 트렌드                   어깨로말해요
# 1270        W   YSL   FASHION, 뉴스                    W해시태그
# 1271        W   YSL   FASHION, 화보                  따로 또 같이
# 1272        W   YSL  FASHION, 트렌드                두려움 없는 반란
# 1273        W   YSL  FASHION, 트렌드                너도 나도 베트멍
#
#                                                    link        date  \
# 0     http://www.allurekorea.com/2020/11/20/%ea%b9%8...  2020-11-20
# 1     http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# ...

# %%
magazine_sl.iloc[873]
# Out:
# magazine                                                        M
# brand                                                         YSL
# category                                                  fashion
# title                                          아티스트 손에서 탄생한 커플 워치
# link            http://www.marieclairekorea.com/fashion/2016/0...
# date                                                      2016-09
# contents        ['', '포토그래퍼이자 아트 디렉터인 플로랑 타네와 작업한 부쉐론의 이번 시즌 리...
# title_brand                                                     0
# check                                                           0
# why                                                           NaN
# word_laurent    ['포토그래퍼이자 아트 디렉터인 플로랑 타네와 작업한 부쉐론의 이번 시즌 리플레 이...
# Name: 873, dtype: object
