# %%
import pandas as pd
import numpy as np

# %%
from selenium import webdriver
import time

# %%
F_Ce = pd.read_csv('./data/FashionBiz_Celine_df.csv' , sep='|', encoding='utf-8')
F_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
F_Ce = F_Ce.rename({'셀린':'title_brand'}, axis='columns')
F_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
F_Ce['check'] = 0
F_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
F_Ce['why'] = ''
F_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %% [markdown]
# ## contents crawling

# %%
path = './driver/chromedriver.exe'

# %%
driver_Ce = webdriver.Chrome(path)     # 크롬 브라우저 제어할 수 있는 객체, 웹브라우저 실행
driver_Ce
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="a2647b825ea9045114f687e4aee04e18")>

# %%
contents = []
for i in range(len(F_Ce)) :
    cUrl = F_Ce['link'][i]
#     print(cUrl)
    driver_Ce.get(cUrl)
    time.sleep(0.5)
    pghs = driver_Ce.find_elements_by_css_selector('div.view_cont')
    if len(pghs) > 0 :
        content = pghs[0].text
        contents.append(content)
    else :
        content = ''
        contents.append(content)
    print('[',i,']' , content)
    print('-'*100)
# Out:
# [ 0 ] 신세계인터내셔날(대표 장재영)에서 국내 수입·유통하는 셀린느가 블랙핑크 멤버 리사를 글로벌 앰배서더로 발탁했다.
#
# 리사는 지속적으로 셀린느와 깊은 유대 관계를 형성해온 셀러브리티로 셀린느의 크리에이티브 디렉터 에디 슬리먼의 뮤즈로 활동해왔다. 지난해 열린 셀린느 2020 S/S 컬렉션 쇼에 참석하기도 했으며 미국 패션 매거진 '엘르' 커버 화보에서도 이 브랜드의의 아이보리 블라우스와 조끼, 가죽 팬츠를 입었다.
#
# 한편 리사는 명품 주얼리 불가리의 글로벌 앰배서더로도 활약하고 있어 현재 하이패션씬에서 가장 핫한 인물임을 다시금 입증했다. [패션비즈=정효신 기자]
#
#
#
# ＜저작권자 ⓒ Fashionbiz , 무단전재 및 재배포 금지＞
# 기사목록
# 이전
# ----------------------------------------------------------------------------------------------------
# [ 1 ] 여성 쇼핑 앱 브랜디(대표 서정민)가 봄을 맞아 고객 감사 할인 프로모션인 ‘브랜디 페스타’를 개최한다. 브랜디는 3월 20일부터 26일까지 진행되는 이번 페스타에서 쇼핑몰, 블로그 마켓, 브랜드, 뷰티 상품을 최대 90% 할인가로 판매한다.
#
#
#
#
#
# 페스타 기간에 진행하는 특별 기획 이벤트에서는 추첨을 통해 여성들이 좋아하는 브랜드인 구찌와 셀린느 지갑을 천 원에 구매할 수 있다. 브랜디 회원이라면 모바일 앱을 통해 누구나 이벤트 참여가 가능하다.
#
# 이번 페스타에서 주목할 기획전으로는 봄맞이 창고 대방출 90% 할인 기획전이 있다. 패션 이커머스 업계에서 최초로 도입한 ‘오늘출발’ 상품을 판매하며, 오후 2시 이전에 결제를 완료하면 택배가 당일 발송되어 다음날 받아볼 수 있다. 또한 오늘출발 상품 2개 이상 구매 시 추가 적립금도 지급된다.
#
# ...

# %%
len(contents)
# Out:
# 30

# %%
len(F_Ce)
# Out:
# 30

# %%
if len(F_Ce) == len(contents) :
    F_Ce['contents'] = contents

# %%
F_Ce['Brand'] = 'Ce'
F_Ce
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...

# %%
F_Ce.to_csv('./data/FashionBiz_Celine_contents.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
F_Ce_c = pd.read_csv('./data/FashionBiz_Celine_contents.csv' , sep='|', encoding='utf-8')
F_Ce_c
# Out:
#                                   title        date  \
# 0             셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁  2020/09/23
# 1       여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트  2020/03/20
# 2        갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대  2020/01/02
# 3               [월드] 셀린느, 남성복 패션쇼 잠정 중단  2019/12/06
# 4           [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?  2019/09/03
# 5         갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화  2019/08/13
# 6                아동복 패션 하우스, ‘마이크로 타깃팅’  2019/05/01
# 7      [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선  2019/02/27
# 8         셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개  2019/02/25
# 9        [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선  2018/11/29
# 10      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)  2018/10/12
# 11           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이  2018/09/17
# 12       [월드] 리카르도 티시 영입한 '버버리' 새로운 룩은?  2018/06/08
# 13       [월드] 「셀린느」 새 디렉터 에디 슬리먼 야심찬 행보  2018/04/11
# 14         [월드] 「셀린느」 떠나는 피비 필로 어디로 갈까?  2018/01/09
# 15    2018 S/S Women’s Collection Trend  2017/12/29
# 16                    럭셔리 「셀린느」 플래그십스토어  2017/04/01
# ...
