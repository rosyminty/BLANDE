# %%
import pandas as pd
import numpy as np

# %%
magazine_sl = pd.read_csv('./data/SL/magazine_sl.csv' , sep='|', encoding='utf-8')

# %%
magazine_sl
# Out:
#      magazine brand      category                    title  \
# 0           A   YSL     CELEBRITY         깊게 뿌리내리기 위하여, 수영
# 1           A   YSL       FASHION                    코트 체크
# 2           A   YSL       FASHION                데님이여 영원하라
# 3           A   YSL       FASHION                 안경 하세요?!
# 4           A   YSL       FASHION  가을의 정석, 트렌치 코트 입는 법 8가지
# ...       ...   ...           ...                      ...
# 1269        W   YSL  FASHION, 트렌드                   어깨로말해요
# 1270        W   YSL   FASHION, 뉴스                    W해시태그
# 1271        W   YSL   FASHION, 화보                  따로 또 같이
# 1272        W   YSL  FASHION, 트렌드                두려움 없는 반란
# 1273        W   YSL  FASHION, 트렌드                너도 나도 베트멍
#
#                                                    link        date  \
# 0     http://www.allurekorea.com/2020/11/20/%ea%b9%8...  2020-11-20
# 1     http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# 2     http://www.allurekorea.com/2020/11/06/%eb%8d%b...  2020-10-26
# 3     http://www.allurekorea.com/2020/10/29/%ec%95%8...  2020-10-23
# 4     http://www.allurekorea.com/2020/10/11/%ea%b0%8...  2020-09-27
# ...                                                 ...         ...
# 1269  http://www.wkorea.com/2016/09/05/%ec%96%b4%ea%...  2016-09-05
# 1270  http://www.wkorea.com/2016/09/02/w%ed%95%b4%ec...  2016-09-02
# 1271  http://www.wkorea.com/2016/09/02/%eb%94%b0%eb%...  2016-09-02
# 1272  http://www.wkorea.com/2016/09/01/%eb%91%90%eb%...  2016-09-01
# 1273  http://www.wkorea.com/2016/09/01/%eb%84%88%eb%...  2016-09-01
#
#                                                contents  title_brand  check  \
# 0     ['누구보다 본인에게 엄격하지만 수용할 줄 아는 너른 마음도 지녔다. 오늘도 부단히...            0      0
# 1     ['겨울이 오기 전 기억해야 할 코트의 면면.', '90’S STANDARD', '...            0      0
# 2     ['데님 팬츠를 선택할 때 가장 중요한 것은 자신의 체형에 맞는 핏을 고르는 것이다...            0      0
# 3     ['모든 게 익고 마는 금빛 가을에는 탐스러운 금테 안경을. 전체 메탈로 장식한 다...            0      0
# 4     ['정직하고 말끔하게, 혹은 자유롭고 분방하게. 변화무쌍한 계절처럼 다양한 모습을 ...            0      0
# ...                                                 ...          ...    ...
# 1269  '어깨 좀 쓴다 하는 여인들이 모두 모였다. 이 현상은 특히 젊은 디자이너들의 의상...            0      0
# 1270  '패션&뷰티 아이템, 핫 스폿, 영화, 전시 등 더블유 에디터의 날카롭고 감각적인 ...            0      0
# 1271  '새로운 시즌을 맞아 더 모호하고 더 자유로운 방식으로 진화하고 있는 젠더 블렌딩 ...            0      0
# 1272  '오늘날 패션엔 경계가 사라졌다. 패션계에 하이와 로 패션의 캐주얼한 조우가 무르익...            0      0
# 1273  '패션계에서 노바운더리 시대의 전후를 가르는 존재가 된 베트멍. 그 대표 아이템은 ...            0      0
#
#                                            word_laurent  \
# 0     ['빨간 더블 브레스티드 코트, 타이츠, 라텍스 소재 보디슈트와 사이하이 부츠는 모...
# 1     ['클래식한 캐멀 컬러 코트는 1백78만원, 우영미(Wooyoungmi). 버건디 ...
# 2     ['  짙은 그레이 컬러의 데님 팬츠는 95만5천원, 생로랑 바이 안토니 바카렐로(...
# 3     ['  YSL 모노그램을 새긴 블랙 에나멜 안경다리의 둥근 금테 안경은 40만원대,...
# 4     ['컬러블록 트렌치코트는 가격미정, 르쥬(Leje). 컵케이크 프린트 티셔츠는 27...
# ...                                                 ...
# 1269  ["'어깨 좀 쓴다 하는 여인들이 모두 모였다. 이 현상은 특히 젊은 디자이너들의 ...
# 1270  ['#W뷰티콕  (뷰티 디렉터 송시은)\\n조회 2,023회\\n너무나 뜨거운 여름...
# 1271  ['중성적인 스타일링을 위해선 실루엣을 활용하는 방법에 주목해야 한다. 생로랑 남성...
# 1272  ['이러한 맥락은 오늘날 브랜드의 모델 캐스팅에도 그대로 적용된다. 일례로 유명한 ...
# 1273  ['셀린 디옹\\n나이 만48세\\n직업 세계적인 디바\\n평소 스타일 얼마 전까진...
#
#                                           sentences_tag  \
# 0     [('[', 'SS'), ("'", 'SS'), ('빨갛', 'VA'), ('ㄴ',...
# 1     [('[', 'SS'), ("'", 'SS'), ('클래식', 'NNG'), ('하...
# 2     [('[', 'SS'), ("'", 'SS'), ('짙', 'VV'), ('은', ...
# 3     [('[', 'SS'), ("'", 'SS'), ('YSL', 'OL'), ('모노...
# 4     [('[', 'SS'), ("'", 'SS'), ('컬러', 'NNG'), ('블록...
# ...                                                 ...
# 1269  [('[', 'SS'), ('"', 'SS'), ("'", 'SS'), ('어깨',...
# 1270  [('[', 'SS'), ("'", 'SS'), ('#', 'SW'), ('W', ...
# 1271  [('[', 'SS'), ("'", 'SS'), ('중', 'NNG'), ('성적'...
# 1272  [('[', 'SS'), ("'", 'SS'), ('이러', 'XR'), ('하',...
# 1273  [('[', 'SS'), ("'", 'SS'), ('세', 'VA'), ('ㄹ', ...
#
#                                                    ADFN
# 0     ['코트', '소재', '슈트', '하이', '부츠', 'LAURENT', 'ANT...
# 1     ['클래식', '컬러', '코트', '컬러', '가죽', '셔츠', '스커트', '...
# 2     ['컬러', '데님', '팬츠', 'LAURENT', 'ANTHONY', 'LAUR...
# 3                          ['블랙', 'LAURENT', 'LAURENT']
# 4     ['컬러', '코트', '프린트', '데님', '팬츠', '슈즈', '선글라스', ...
# ...                                                 ...
# 1269  ['어깨', '디자이너', '의상', '어깨', '어깨', 'DESIGN', '데뷔...
# 1270  ['뷰티', '뷰티', '디렉터', '여름', '뷰티', '브랜드', '가을', '...
# 1271  ['실루엣', 'LAURENT', '어깨', '모델', '스타일', '실루엣', '...
# 1272  ['브랜드', '모델', '모델', '전시', '디렉터', '모델', '모델', '...
# 1273  ['스타일', '클래식', '화이트', 'LAURENT', '속', '패션계', '...
#
# [1274 rows x 12 columns]

# %%
# magazine_sl.drop('why', axis=1, inplace=True)

# %%
magazine_sl.to_csv('./data/SL/magazine_sl.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_sl = pd.read_csv('./data/SL/magazine_sl.csv' , sep='|', encoding='utf-8')
magazine_sl
# Out:
#      magazine brand      category                    title  \
# 0           A   YSL     CELEBRITY         깊게 뿌리내리기 위하여, 수영
# 1           A   YSL       FASHION                    코트 체크
# 2           A   YSL       FASHION                데님이여 영원하라
# 3           A   YSL       FASHION                 안경 하세요?!
# 4           A   YSL       FASHION  가을의 정석, 트렌치 코트 입는 법 8가지
# ...       ...   ...           ...                      ...
# 1269        W   YSL  FASHION, 트렌드                   어깨로말해요
# 1270        W   YSL   FASHION, 뉴스                    W해시태그
# 1271        W   YSL   FASHION, 화보                  따로 또 같이
# 1272        W   YSL  FASHION, 트렌드                두려움 없는 반란
# 1273        W   YSL  FASHION, 트렌드                너도 나도 베트멍
#
#                                                    link        date  \
# 0     http://www.allurekorea.com/2020/11/20/%ea%b9%8...  2020-11-20
# 1     http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# 2     http://www.allurekorea.com/2020/11/06/%eb%8d%b...  2020-10-26
# 3     http://www.allurekorea.com/2020/10/29/%ec%95%8...  2020-10-23
# 4     http://www.allurekorea.com/2020/10/11/%ea%b0%8...  2020-09-27
# ...                                                 ...         ...
# 1269  http://www.wkorea.com/2016/09/05/%ec%96%b4%ea%...  2016-09-05
# 1270  http://www.wkorea.com/2016/09/02/w%ed%95%b4%ec...  2016-09-02
# 1271  http://www.wkorea.com/2016/09/02/%eb%94%b0%eb%...  2016-09-02
# 1272  http://www.wkorea.com/2016/09/01/%eb%91%90%eb%...  2016-09-01
# 1273  http://www.wkorea.com/2016/09/01/%eb%84%88%eb%...  2016-09-01
#
#                                                contents  title_brand  check  \
# 0     ['누구보다 본인에게 엄격하지만 수용할 줄 아는 너른 마음도 지녔다. 오늘도 부단히...            0      0
# 1     ['겨울이 오기 전 기억해야 할 코트의 면면.', '90’S STANDARD', '...            0      0
# 2     ['데님 팬츠를 선택할 때 가장 중요한 것은 자신의 체형에 맞는 핏을 고르는 것이다...            0      0
# 3     ['모든 게 익고 마는 금빛 가을에는 탐스러운 금테 안경을. 전체 메탈로 장식한 다...            0      0
# 4     ['정직하고 말끔하게, 혹은 자유롭고 분방하게. 변화무쌍한 계절처럼 다양한 모습을 ...            0      0
# ...                                                 ...          ...    ...
# 1269  '어깨 좀 쓴다 하는 여인들이 모두 모였다. 이 현상은 특히 젊은 디자이너들의 의상...            0      0
# 1270  '패션&뷰티 아이템, 핫 스폿, 영화, 전시 등 더블유 에디터의 날카롭고 감각적인 ...            0      0
# 1271  '새로운 시즌을 맞아 더 모호하고 더 자유로운 방식으로 진화하고 있는 젠더 블렌딩 ...            0      0
# 1272  '오늘날 패션엔 경계가 사라졌다. 패션계에 하이와 로 패션의 캐주얼한 조우가 무르익...            0      0
# 1273  '패션계에서 노바운더리 시대의 전후를 가르는 존재가 된 베트멍. 그 대표 아이템은 ...            0      0
#
#                                            word_laurent  \
# 0     ['빨간 더블 브레스티드 코트, 타이츠, 라텍스 소재 보디슈트와 사이하이 부츠는 모...
# 1     ['클래식한 캐멀 컬러 코트는 1백78만원, 우영미(Wooyoungmi). 버건디 ...
# 2     ['  짙은 그레이 컬러의 데님 팬츠는 95만5천원, 생로랑 바이 안토니 바카렐로(...
# 3     ['  YSL 모노그램을 새긴 블랙 에나멜 안경다리의 둥근 금테 안경은 40만원대,...
# 4     ['컬러블록 트렌치코트는 가격미정, 르쥬(Leje). 컵케이크 프린트 티셔츠는 27...
# ...                                                 ...
# 1269  ["'어깨 좀 쓴다 하는 여인들이 모두 모였다. 이 현상은 특히 젊은 디자이너들의 ...
# 1270  ['#W뷰티콕  (뷰티 디렉터 송시은)\\n조회 2,023회\\n너무나 뜨거운 여름...
# 1271  ['중성적인 스타일링을 위해선 실루엣을 활용하는 방법에 주목해야 한다. 생로랑 남성...
# 1272  ['이러한 맥락은 오늘날 브랜드의 모델 캐스팅에도 그대로 적용된다. 일례로 유명한 ...
# 1273  ['셀린 디옹\\n나이 만48세\\n직업 세계적인 디바\\n평소 스타일 얼마 전까진...
#
#                                           sentences_tag  \
# 0     [('[', 'SS'), ("'", 'SS'), ('빨갛', 'VA'), ('ㄴ',...
# 1     [('[', 'SS'), ("'", 'SS'), ('클래식', 'NNG'), ('하...
# 2     [('[', 'SS'), ("'", 'SS'), ('짙', 'VV'), ('은', ...
# 3     [('[', 'SS'), ("'", 'SS'), ('YSL', 'OL'), ('모노...
# 4     [('[', 'SS'), ("'", 'SS'), ('컬러', 'NNG'), ('블록...
# ...                                                 ...
# 1269  [('[', 'SS'), ('"', 'SS'), ("'", 'SS'), ('어깨',...
# 1270  [('[', 'SS'), ("'", 'SS'), ('#', 'SW'), ('W', ...
# 1271  [('[', 'SS'), ("'", 'SS'), ('중', 'NNG'), ('성적'...
# 1272  [('[', 'SS'), ("'", 'SS'), ('이러', 'XR'), ('하',...
# 1273  [('[', 'SS'), ("'", 'SS'), ('세', 'VA'), ('ㄹ', ...
#
#                                                    ADFN
# 0     ['코트', '소재', '슈트', '하이', '부츠', 'LAURENT', 'ANT...
# 1     ['클래식', '컬러', '코트', '컬러', '가죽', '셔츠', '스커트', '...
# 2     ['컬러', '데님', '팬츠', 'LAURENT', 'ANTHONY', 'LAUR...
# 3                          ['블랙', 'LAURENT', 'LAURENT']
# 4     ['컬러', '코트', '프린트', '데님', '팬츠', '슈즈', '선글라스', ...
# ...                                                 ...
# 1269  ['어깨', '디자이너', '의상', '어깨', '어깨', 'DESIGN', '데뷔...
# 1270  ['뷰티', '뷰티', '디렉터', '여름', '뷰티', '브랜드', '가을', '...
# 1271  ['실루엣', 'LAURENT', '어깨', '모델', '스타일', '실루엣', '...
# 1272  ['브랜드', '모델', '모델', '전시', '디렉터', '모델', '모델', '...
# 1273  ['스타일', '클래식', '화이트', 'LAURENT', '속', '패션계', '...
#
# [1274 rows x 12 columns]

# %%
magazine_sl['word_laurent'][0]
# Out:
# "['빨간 더블 브레스티드 코트, 타이츠, 라텍스 소재 보디슈트와 사이하이 부츠는 모두 생로랑 바이 안토니 바카렐로(Saint Laurent by Anthony Vaccarello). 골드 반지는 이에르 로르 (Hyeres Lor).']"

# %%
type(magazine_sl['word_laurent'][0])
# Out:
# str

# %%
# replace test
if '생 로랑' in magazine_sl.iloc[0,10] :
#     print('Yes')
    magazine_sl.iloc[0,10] = magazine_sl.iloc[0,10].replace('생 로랑' , '생로랑')
    print(magazine_sl.iloc[0,10])

# %%
# replace 전체 적용
replace = []
for i in range(len(magazine_sl)) :
    if '생 로랑' in magazine_sl.iloc[i,10] :
        magazine_sl.iloc[i,10] = magazine_sl.iloc[i,10].replace('생 로랑' , '생로랑')
        replace.append(i)
print(replace)
# Out:
# []

# %%
# 검토
for idx in replace :
    print(magazine_sl.iloc[idx,10])
    print('-'*100)

# %%
magazine_sl.to_csv('./data/SL/magazine_sl.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_sl = pd.read_csv('./data/SL/magazine_sl.csv' , sep='|', encoding='utf-8')

# %%
len(magazine_sl)
# Out:
# 1274

# %% [markdown]
# ## Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
slsl = []
for line in magazine_sl['word_laurent']:
    slsl.append(line)

# %%
type(slsl)
# Out:
# list

# %% [markdown]
# ### 외국어 안잘리게 영어로

# %%
for idx in range(len(slsl)) :
# for sentence in slsl :
    if '생로랑' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('생로랑' , 'SAINT_LAURENT')

# %%
for idx in range(len(slsl)) :
    if '이브 SAINT' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('이브 SAINT' , 'YVES_SAINT')

# %%
for idx in range(len(slsl)) :
    if '입SAINT' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('입SAINT' , 'YVES_SAINT')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '이브SAINT' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('이브SAINT' , 'YVES_SAINT')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '구찌' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('구찌' , 'GUCCI')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '안토니 바카렐로' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('안토니 바카렐로' , 'ANTHONY VACCARELLO')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '안토니바카렐로' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('안토니바카렐로' , 'ANTHONY VACCARELLO')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '안토니오' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('안토니오' , 'ANTHONY')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '안토니' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('안토니' , 'ANTHONY')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '디올' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('디올' , 'DIOR')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '오뜨 꾸띄르' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('오뜨 꾸띄르' , 'HAUTE COUTURE')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '에디 슬리먼' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('에디 슬리먼' , 'Hedi Slimane')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '쿠튀르' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('쿠튀르' , 'COUTURE')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '에디터' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('에디터' , 'EDITOR')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '마라케시' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('마라케시' , 'Marrakech')
#         print(idx, slsl[idx])

# %%
for idx in range(len(slsl)) :
    if '몽클레르' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('몽클레르' , 'MONCLER')
#         print(idx, slsl[idx])

# %%
FN = []
for idx in range(len(slsl)) :
    if '르 스모킹' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('르 스모킹' , 'LE_SMOKING')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 35

# %%
FN = []
for idx in range(len(slsl)) :
    if '에디션' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('에디션' , 'EDITION')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 13

# %%
FN = []
for idx in range(len(slsl)) :
    if '에디' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('에디' , 'HEDI')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 70

# %%
FN = []
for idx in range(len(slsl)) :
    if '바카렐로' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('바카렐로' , 'VACCARELLO')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 37

# %%
FN = []
for idx in range(len(slsl)) :
    if '바칼레로' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('바칼레로' , 'VACCARELLO')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(slsl)) :
    if '바칼렐로' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('바칼렐로' , 'VACCARELLO')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 1

# %%
FN = []
for idx in range(len(slsl)) :
    if '발렌시아가' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('발렌시아가' , 'BALENCIAGA')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 121

# %%
FN = []
for idx in range(len(slsl)) :
    if '꾸뛰르' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('꾸뛰르' , 'COUTURE')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 42

# %%
FN = []
for idx in range(len(slsl)) :
    if '베티 카트루스' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('베티 카트루스' , 'Betty Catroux')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(slsl)) :
    if '베티 카트루' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('베티 카트루' , 'Betty Catroux')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 8

# %%
FN = []
for idx in range(len(slsl)) :
    if '마리아 그라치아 치우리' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('마리아 그라치아 치우리' , 'Maria Grazia Chiuri')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 17

# %%
FN = []
for idx in range(len(slsl)) :
    if '치우리' in slsl[idx] :
#         slsl[idx] = slsl[idx].replace('마리아 그라치아 치우리' , 'Maria Grazia Chiuri')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 5

# %%
FN = []
for idx in range(len(slsl)) :
    if '스타일리시' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('스타일리시' , 'STYLISH')
        FN.append(i)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 10

# %%
FN = []
for idx in range(len(slsl)) :
    if '스포티' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('스포티' , 'SPORTY')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 16

# %%
FN = []
for idx in range(len(slsl)) :
    if '크리에이티브' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('크리에이티브' , 'CREATIVE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 99

# %%
FN = []
for idx in range(len(slsl)) :
    if '주얼리' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('주얼리' , 'JEWERLY')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 26

# %%
FN = []
for idx in range(len(slsl)) :
    if '마이클 코어스' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('마이클 코어스' , 'MICHAEL KORS')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 20

# %%
FN = []
for idx in range(len(slsl)) :
    if '메종' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('메종' , 'MAISON')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 25

# %%
FN = []
for idx in range(len(slsl)) :
    if '발렌티노' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('발렌티노' , 'VALENTINO')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 53

# %%
FN = []
for idx in range(len(slsl)) :
    if '베르사체' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('베르사체' , 'VERSACE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 36

# %%
FN = []
for idx in range(len(slsl)) :
    if '셀러브리티' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('셀러브리티' , 'CELEBRITY')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 15

# %%
FN = []
for idx in range(len(slsl)) :
    if '킴 존스' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('킴 존스' , 'KIM JONES')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 6

# %%
FN = []
for idx in range(len(slsl)) :
    if '살바토레 페라가모' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('살바토레 페라가모' , 'Salvatore Ferragamo')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 20

# %%
FN = []
for idx in range(len(slsl)) :
    if '칼 라거펠트' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('칼 라거펠트' , 'Karl Lagerfeld')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 33

# %%
FN = []
for idx in range(len(slsl)) :
    if '아카이브' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('아카이브' , 'ARCHIVE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 36

# %%
FN = []
for idx in range(len(slsl)) :
    if '에르메스' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('에르메스' , 'HERMES')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 31

# %%
FN = []
for idx in range(len(slsl)) :
    if '마리아' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('마리아' , 'MARIA')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 23

# %%
FN = []
for idx in range(len(slsl)) :
    if '레이디' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('레이디' , 'LADY')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 15

# %%
FN = []
for idx in range(len(slsl)) :
    if '케어링' in slsl[idx] :
#         slsl[idx] = slsl[idx].replace('케어링' , 'LADY')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 22

# %%
FN = []
for idx in range(len(slsl)) :
    if '캘빈 클라인' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('캘빈 클라인' , 'Calvin Klein')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 33

# %%
FN = []
for idx in range(len(slsl)) :
    if '스틸레토' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('스틸레토' , 'Stiletto')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 20

# %%
FN = []
for idx in range(len(slsl)) :
    if '펜디' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('펜디' , 'FENDI')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 39

# %%
FN = []
for idx in range(len(slsl)) :
    if '디자인' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('디자인' , 'DESIGN')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 160

# %%
FN = []
for idx in range(len(slsl)) :
    if '꾸띄르' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('꾸띄르' , 'COUTURE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 7

# %%
FN = []
for idx in range(len(slsl)) :
    if '알렉산더' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('알렉산더' , 'ALEXANDER')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 59

# %%
FN = []
for idx in range(len(slsl)) :
    if '벨라 하디드' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('벨라 하디드' , 'Bella Hadid')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 4

# %%
FN = []
for idx in range(len(slsl)) :
    if '시그니처' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('시그니처' , 'SIGNATURE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 12

# %%
FN = []
for idx in range(len(slsl)) :
    if '시그너처' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('시그너처' , 'SIGNATURE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 23

# %%
FN = []
for idx in range(len(slsl)) :
    if '존 갈리아노' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('존 갈리아노' , 'John Galliano')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 19

# %%
FN = []
for idx in range(len(slsl)) :
    if '캘빈클라인' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('캘빈클라인' , 'Calvin Klein')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 3

# %%
FN = []
for idx in range(len(slsl)) :
    if '셀린느' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('셀린느' , 'CELINE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 60

# %%
FN = []
for idx in range(len(slsl)) :
    if '인스타그램' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('인스타그램' , 'INSTAGRAM')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 41

# %%
FN = []
for idx in range(len(slsl)) :
    if '새들' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('새들' , 'SADDLE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 3

# %%
FN = []
for idx in range(len(slsl)) :
    if '아이코닉' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('아이코닉' , 'ICONIC')
        FN.append(idx)
#         print(idx, didi[idx])
print(len(FN))
# Out:
# 17

# %%
FN = []
for idx in range(len(slsl)) :
    if '부티크' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('부티크' , 'boutique')
        FN.append(idx)
#         print(idx, didi[idx])
print(len(FN))
# Out:
# 8

# %%
FN = []
for idx in range(len(slsl)) :
    if '인플루언서' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('인플루언서' , 'INFLUENCER')
        FN.append(idx)
#         print(idx, didi[idx])
print(len(FN))
# Out:
# 12

# %%
FN = []
for idx in range(len(slsl)) :
    if '블랙핑크' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('블랙핑크' , 'BLACKPINK')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 16

# %%
FN = []
for idx in range(len(slsl)) :
    if '셀린느' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('셀린느' , 'CELINE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(slsl)) :
    if '알렉산더' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('알렉산더' , 'Alexander McQueen')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(slsl)) :
    if '웨어러블' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('웨어러블' , 'WEARABLE')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 10

# %%
FN = []
for idx in range(len(slsl)) :
    if '앙리 피노' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('앙리 피노' , 'Henri Pinault')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 12

# %%
FN = []
for idx in range(len(slsl)) :
    if '컨템포러리' in slsl[idx] :
        slsl[idx] = slsl[idx].replace('컨템포러리' , 'contemporary')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(slsl)) :
    if '힐피거' in slsl[idx] :
#         slsl[idx] = slsl[idx].replace('웨어러블' , 'Henri Pinault')
        FN.append(idx)
#         print(idx, slsl[idx])
print(len(FN))
# Out:
# 6

# %% [markdown]
# ### 영문 다 대문자로 변환

# %%
for idx in range(len(slsl)) :
    slsl[idx] = slsl[idx].upper()
#     print(slsl[idx])

# %% [markdown]
# ### 각 문장별로 형태소 구분하기

# %%
sentences_tag = []
for i in range(len(slsl)) :
# for sentence in slsl:
#     print(i)
    morph = kkma.pos(slsl[i])
    sentences_tag.append(morph)
#     print(morph)
#     print('-'*30)

# %% [markdown]
# ### 형태소 구분 검토용으로 일부 진행

# %%
# sentences_tag[0]

# %%
# TEST
# 각 문장별로 형태소 구분하기
sentences_tagT = []
for i in range(200,1000) :
# for sentence in slsl:
    print(i)
    morph = kkma.pos(slsl[i])
    sentences_tagT.append(morph)
    print(morph)
    print('-'*30)
# Out:
# 200
# [('[', 'SS'), ("'", 'SS'), ('패션', 'NNG'), ('잡지', 'NNG'), ('를', 'JKO'), ('펼치', 'VV'), ('면', 'ECE'), ('가장', 'MAG'), ('먼저', 'MAG'), ('동시대', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('고', 'ECE'), ('파워', 'NNG'), ('푸', 'VV'), ('ㄹ', 'ETD'), ('한', 'NNG'), ('패션', 'NNG'), ('신과', 'NNG'), ('마주하', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('다', 'EFN'), ('.', 'SF'), ('바로', 'MAG'), ('현재', 'NNG'), ('의', 'JKG'), ('유행', 'NNG'), ('을', 'JKO'), ('점철', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETD'), ('패션', 'NNG'), ('하우스', 'NNG'), ('들', 'XSN'), ('의', 'JKG'), ('광고', 'NNG'), ('캠페인', 'NNG'), ('.', 'SF'), ('2019', 'NR'), ('S', 'OL'), ('/', 'SP'), ('S', 'OL'), ('시즌', 'NNG'), ('을', 'JKO'), ('시작하', 'VV'), ('며', 'ECE'), ('패션', 'NNG'), ('하우스', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('공개', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('광고', 'NNG'), ('비주얼', 'NNG'), ('의', 'JKG'), ('반', 'NNG'), ('이상', 'NNG'), ('이', 'JKS'), ('흑백', 'NNG'), ('사진', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('샤넬', 'UN'), (',', 'SP'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), (',', 'SP'), ('ALEXANDER', 'OL'), ('맥', 'NNG'), ('퀸', 'UN'), (',', 'SP'), ('프라다', 'NNG'), (',', 'SP'), ('MONCLER', 'OL'), ('등', 'NNB'), ('수많', 'VA'), ('은', 'ETD'), ('브랜드', 'NNG'), ('가', 'JKS'), ('블랙', 'NNG'), ('앤', 'NNG'), ('화이트', 'NNG'), ('의', 'JKG'), ('광고', 'NNG'), ('비주얼', 'NNG'), ('을', 'JKO'), ('선보이', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('지방시', 'NNG'), (',', 'SP'), ('에', 'JC'), ('르', 'NNG'), ('마노', 'NNG'), ('설비', 'NNG'), ('노', 'NNG'), (',', 'SP'), ('클로에', 'NNG'), (',', 'SP'), ('셀', 'NNG'), ('린', 'UN'), ('등', 'NNB'), ('도', 'JX'), ('마찬가지', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('셀린', 'UN'), ('의', 'JKG'), ('수장', 'NNG'), ('HEDI', 'OL'), ('SLIMANE', 'OL'), ('은', 'JX'), ('사진작가', 'NNG'), ('로', 'JKM'), ('도', 'JX'), ('활동', 'NNG'), ('하', 'XSV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('CREATIVE', 'OL'), ('디렉터', 'NNG'), ('시절', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('직접', 'NNG'), ('광고', 'NNG'), ('캠페인', 'NNG'), ('사진', 'NNG'), ('을', 'JKO'), ('촬영', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('던', 'EFQ'), ('HEDI', 'OL'), ('가', 'JKS'), ('자신', 'NNG'), ('의', 'JKG'), ('이름', 'NNG'), ('을', 'JKO'), ('내걸', 'VV'), ('ㄴ', 'ETD'), ('셀린', 'UN'), ('의', 'JKG'), ('첫', 'MDT'), ('번째', 'NNB'), ('광고', 'NNG'), ('비주얼', 'NNG'), ('을', 'JKO'), ('촬영', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('당', 'NNG'), ('연지', 'NNG'), ('사', 'VV'), ('아', 'ECS'), ('.', 'SF'), ('피사체', 'NNG'), ('에', 'JKM'), ('완전히', 'MAG'), ('몰두', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('HEDI', 'OL'), ('SLIMANE', 'OL'), ('의', 'JKG'), ('사진', 'NNG'), ('은', 'JX'), ('진지', 'XR'), ('하', 'XSA'), ('고', 'ECE'), ('도', 'JX'), ('섬세', 'XR'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('머리카락', 'NNG'), ('이', 'JKS'), ('흩어지', 'VV'), ('ㄴ', 'ETD'), ('모델', 'NNG'), ('이', 'JKS'), ('눈', 'NNG'), ('을', 'JKO'), ('지그시', 'MAG'), ('감', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('클로즈업', 'NNG'), ('사진', 'NNG'), ('이나', 'JC'), ('수트', 'NNG'), ('차림', 'NNG'), ('의', 'JKG'), ('남자', 'NNG'), ('모델', 'NNG'), ('이', 'JKS'), ('침대', 'NNG'), ('에', 'JKM'), ('기대어', 'NNG'), ('있', 'VV'), ('는', 'ETD'), ('사진', 'NNG'), ('은', 'JX'), ('대부분', 'NNG'), ('흑백', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('사진가', 'NNG'), ('피터', 'NNG'), ('린드버그', 'UN'), ('는', 'JX'), ('흑백', 'NNG'), ('을', 'JKO'), ('찍', 'VV'), ('는', 'ETD'), ('이유', 'NNG'), ('에', 'JKM'), ('대하', 'VV'), ('어', 'ECS'), ('컬러', 'NNG'), ('보다', 'JKM'), ('더', 'MAG'), ('깊', 'VA'), ('게', 'ECD'), ('사물', 'NNG'), ('의', 'JKG'), ('본질', 'NNG'), ('을', 'JKO'), ('느끼', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('기', 'ETN'), ('때문', 'NNB'), ('이', 'VCP'), ('라고', 'ECD'), ('하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('사람', 'NNG'), ('의', 'JKG'), ('얼굴', 'NNG'), ('은', 'JX'), ('각기', 'MAG'), ('다', 'MAG'), ('다른', 'MDT'), ('사연', 'NNG'), ('을', 'JKO'), ('지니', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('어', 'ECD'), ('얼굴', 'NNG'), ...
# ------------------------------
# 201
# [('[', 'SS'), ("'", 'SS'), ('물론', 'MAG'), ('베스트', 'NNG'), ('가', 'JKS'), ('지나', 'VV'), ('ㄴ', 'ETD'), ('세월', 'NNG'), ('동안', 'NNG'), ('전혀', 'MAG'), ('등장', 'NNG'), ('하', 'XSV'), ('지', 'ECD'), ('않', 'VXV'), ('았', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('아니', 'VCN'), ('다', 'EFN'), ('.', 'SF'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('CREATIVE', 'OL'), ('디렉터', 'NNG'), ('시절', 'NNG'), (',', 'SP'), ('스테', 'UN'), ('파', 'NNG'), ('노', 'NNG'), ('피', 'VV'), ('ㄹ라', 'ECD'), ('티', 'NNG'), ('는', 'JX'), ('LE', 'OL'), ('_', 'SW'), ('SMOKING', 'OL'), ('의', 'JKG'), ('대체재', 'NNG'), ('로', 'JKM'), ('베스트', 'NNG'), ('수트', 'NNG'), ('를', 'JKO'), ('제안', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('도', 'JX'), ('하', 'VV'), ('었', 'EPT'), ('고', 'ECE'), (',', 'SP'), ('미니멀', 'NNG'), ('리스트', 'NNG'), ('와', 'JKM'), ('실용성', 'NNG'), ('을', 'JKO'), ('추구', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('뉴욕', 'NNP'), ('디자이너', 'NNG'), ('들', 'XSN'), ('도', 'JX'), ('베스트', 'NNG'), ('를', 'JKO'), ('종종', 'MAG'), ('런웨이', 'UN'), ('에', 'JKM'), ('올리', 'VV'), ('곤', 'ECS'), ('하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('2000', 'NR'), ('년대', 'NNM'), ('중반', 'NNG'), (',', 'SP'), ('케이트', 'UN'), ('모스', 'NNG'), (',', 'SP'), ('샤를', 'UN'), ('로트', 'UN'), ('갱스', 'UN'), ('부', 'NNG'), ('르', 'NNG'), ('같', 'VA'), ('은', 'ETD'), ('패션', 'NNG'), ('아이콘', 'NNG'), ('과', 'JC'), ('할리우드', 'NNP'), ('의', 'JKG'), ('가십', 'NNG'), ('걸', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('즐기', 'VV'), ('어', 'ECS'), ('입', 'VV'), ('기', 'ETN'), ('도', 'JX'), ('하', 'VV'), ('었', 'EPT'), ('고', 'ECE'), ('.', 'SF'), ('하지만', 'MAC'), ('우리', 'NP'), ('가', 'JKS'), ('곧', 'MAG'), ('마주하', 'VV'), ('게', 'ECD'), ('되', 'VV'), ('ㄹ', 'ETD'), ('2019', 'NR'), ('년', 'NNM'), ('의', 'JKG'), ('수트', 'NNG'), ('베스트', 'NNG'), ('는', 'JX'), ('분명', 'MAG'), ('다르', 'VV'), ('며', 'ECE'), ('다양', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('스타일', 'NNG'), ('로', 'JKM'), ('런웨이', 'UN'), ('에서', 'JKM'), ('그', 'MDT'), ('존재', 'NNG'), ('감', 'NNG'), ('을', 'JKO'), ('발하', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 202
# [('[', 'SS'), ("'", 'SS'), ('DIOR', 'OL'), (',', 'SP'), ('GUCCI', 'OL'), (',', 'SP'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('등', 'NNG'), ('하우스', 'NNG'), ('브랜드', 'NNG'), ('의', 'JKG'), ('룩', 'UN'), ('을', 'JKO'), ('입', 'VV'), ('을', 'ETD'), ('거', 'NNB'), ('이', 'VCP'), ('라는', 'ETD'), ('예상', 'NNG'), ('을', 'JKO'), ('뒤', 'NNG'), ('업고', 'NNG'), ('제이', 'NNG'), ('백', 'NR'), ('COUTURE', 'OL'), (',', 'SP'), ('김', 'NNG'), ('서', 'JKM'), ('룡', 'UN'), ('옴', 'NNM'), ('므', 'UN'), ('등', 'NNB'), ('한국', 'NNG'), ('디자이너', 'NNG'), ('의', 'JKG'), ('수트', 'NNG'), ('를', 'JKO'), ('입', 'VV'), ('고', 'ECE'), ('레드', 'NNG'), ('카펫', 'NNG'), ('에', 'JKM'), ('오르', 'VV'), ('았', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('여기', 'NP'), ('에', 'JKM'), ('고급', 'NNG'), ('리무진', 'NNG'), ('이', 'JKS'), ('아니', 'VV'), ('ㄴ', 'ETD'), ('그', 'NP'), ('들', 'XSN'), ('이', 'JKS'), ('모델', 'NNG'), ('로', 'JKM'), ('활약', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('현대', 'NNG'), ('자동차', 'NNG'), ('의', 'JKG'), ('‘', 'SS'), ('펠', 'UN'), ('리', 'NNG'), ('세', 'MDN'), ('이드', 'NNG'), ('’', 'SS'), ('를', 'JKO'), ('타', 'VV'), ('고', 'ECE'), ('등장', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('도', 'JX'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 203
# [('[', 'SS'), ("'", 'SS'), ('BYBAZAAR', 'OL'), ('2018.12', 'NR'), ('.', 'SF'), ('26', 'NR'), ('"', 'SS'), (',', 'SP'), ('\\', 'SW'), ("'", 'SS'), ('"', 'SS'), ('흔히', 'MAG'), ('말하', 'VV'), ('는', 'ETD'), ('\\\\\\', 'SW'), ("'", 'SS'), ('아이', 'NNG'), ('돌', 'NNG'), ('\\\\\\', 'SW'), ("'", 'SS'), ('에게', 'JKM'), ('패션', 'NNG'), ('하우스', 'NNG'), ('브랜드', 'NNG'), ('협찬', 'NNG'), ('이', 'JKS'), ('힘들', 'VA'), ('다는', 'ETD'), ('것', 'NNB'), ('은', 'JKS'), ('과거', 'NNG'), ('이야기', 'NNG'), ('이', 'VCP'), ('ㄹ', 'ETD'), ('뿐', 'NNB'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('2018', 'NR'), ('년', 'NNM'), ('겨울', 'NNG'), ('을', 'JKO'), ('뜨겁', 'VA'), ('게', 'ECD'), ('달구', 'VV'), ('ㄴ', 'ETD'), ('방탄', 'NNG'), ('소년단', 'NNG'), (',', 'SP'), ('BTS', 'OL'), ('의', 'JKG'), ('시상식', 'NNG'), ('룩', 'UN'), ('에', 'JKM'), ('는', 'JX'), ('내로라', 'XR'), ('하', 'XSV'), ('는', 'ETD'), ('하우스', 'NNG'), ('브랜드', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('총', 'NNG'), ('출동', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('으니', 'ECD'), ('!', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('11', 'NR'), ('월', 'NNM'), ('28', 'NR'), ('일', 'NNM'), ('\\\\\\', 'SW'), ("'", 'SS'), ('아시아', 'NNG'), ('아티스트', 'NNG'), ('어', 'VV'), ('어', 'ECS'), ('워즈', 'UN'), ('(', 'SS'), ('AAA', 'OL'), (')', 'SS'), ('\\\\\\', 'SW'), ("'", 'SS'), ('에서', 'JKM'), ('2019', 'NR'), ('S', 'OL'), ('/', 'SP'), ('S', 'OL'), ('벨', 'NNG'), ('로', 'JKM'), ('티', 'NNG'), ('컬렉션', 'NNG'), ('을', 'JKO'), ('착용', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('방탄', 'NNG'), ('소년단', 'NNG'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\\\\\', 'SW'), ("'", 'SS'), ('2018', 'NR'), ('MAMA', 'OL'), ('JAPAN', 'OL'), ('\\\\\\', 'SW'), ("'", 'SS'), ('시상식', 'NNG'), ('에', 'JKM'), ('등장', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('방탄', 'NNG'), ('소년단', 'NNG'), ('!', 'SF'), ('CREATIVE', 'OL'), ('디렉터', 'NNG'), ('KIM', 'OL'), ('JONES', 'OL'), ('의', 'JKG'), ('첫', 'MDT'), ('번째', 'NNB'), ('2019', 'NR'), ('SPRING', 'OL'), ('DIOR', 'OL'), ('맨', 'MDT'), ('컬렉션', 'NNG'), ('을', 'JKO'), ('소화', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\\\\\', 'SW'), ("'", 'SS'), ('2018', 'NR'), ('MAMA', 'OL'), ('HONGKONG', 'OL'), ('\\\\\\', 'SW'), ("'", 'SS'), ('시상식', 'NNG'), ('에서', 'JKM'), ('#', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('소년단', 'NNG'), ('으로', 'JKM'), ('변신', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('BTS', 'OL'), ('.', 'SF'), ('빌', 'VV'), ('ㄹ', 'ETD'), ('보드', 'NNG'), ('시상식', 'NNG'), ('에서', 'JKM'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('수트', 'NNG'), ('를', 'JKO'), ('입', 'VV'), ('고', 'ECE'), ('등장', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('화제', 'NNG'), ('를', 'JKO'), ('모으', 'VV'), ('았', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('그', 'NP'), ('들', 'XSN'), ('은', 'JX'), ('이번', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('ANTHONY', 'OL'), ('VACCARELLO', 'OL'), ('의', 'JKG'), ('2019', 'NR'), ('SAINT', 'OL'), ('LAURENT', 'OL'), ('컬렉션', 'NNG'), ('을', 'JKO'), ('완벽', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('소화', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('그', 'MDT'), ('외', 'NNB'), ('에', 'JKM'), ('프라다', 'NNG'), (',', 'SP'), ('GUCCI', 'OL'), (',', 'SP'), ('VALENTINO', 'OL'), ('까', 'VV'), ('지', 'ECD'), ('.', 'SF'), ('레드', 'NNG'), ('카펫', 'NNG'), ('을', 'JKO'), ('런웨이', 'UN'), ('로', 'JKM'), ('만들', 'VV'), ('는', 'ETD'), ('그', 'NP'), ('들', 'XSN'), ('덕분', 'NNG'), ('에', 'JKM'), ('평소', 'NNG'), ('가요', 'NNG'), ('시상식', 'NNG'), ('을', 'JKO'), ('보', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('패션', 'NNG'), ('관계자', 'NNG'), ('들', 'XSN'), ('또한', 'MAG'), ('\\\\\\', 'SW'), ("'", 'SS'), ('이번', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('방탄', 'NNG'), ('소년단', 'NNG'), ('이', 'JKS'), ('어떤', 'MDT'), ('브랜드', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('\\\\\\', 'SW'), ("'", 'SS'), ('착', 'NNB'), ('장', 'NNG'), ('\\\\\\', 'SW'), ("'", 'SS'), ('하', 'VV'), ('었', 'EPT'), ('을지', 'ECS'), ('궁금하', 'VA'), ('어서', 'ECD'), ('\\\\\\', 'SW'), ("'", 'SS'), ('모니터링', 'NNG'), ('하', 'VV'), ('ㄴ다는', 'ETD'), ('후문', 'NNG'), ('!', ' ...
# ------------------------------
# 204
# [('[', 'SS'), ("'", 'SS'), ('그', 'MDT'), ('힘', 'NNG'), ('의', 'JKG'), ('상징', 'NNG'), ('은', 'JX'), ('(', 'SS'), ('적어도', 'MAG'), ('나', 'NP'), ('에', 'JKM'), ('겐', 'UN'), (')', 'SS'), ('‘', 'SS'), ('앞니', 'NNG'), ('가', 'JKS'), ('벌어지', 'VV'), ('ㄴ', 'ETD'), ('케이트', 'UN'), ('모스', 'NNG'), ('’', 'SS'), ('오', 'VV'), ('아', 'ECS'), ('‘', 'SS'), ('바지', 'NNG'), ('를', 'JKO'), ('내리', 'VV'), ('어', 'ECS'), ('입', 'NNG'), ('은', 'JX'), ('서태지', 'NNG'), ('’', 'SS'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('그', 'NP'), ('들', 'XSN'), ('은', 'JX'), ('파격', 'NNG'), (',', 'SP'), ('그리고', 'MAC'), ('새', 'NNG'), ('롭', 'XSA'), ('ㄴ', 'ETD'), ('시대', 'NNG'), ('를', 'JKO'), ('열', 'VV'), ('는', 'ETD'), ('아이콘', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('시', 'VV'), ('ㄴ', 'ETD'), ('디', 'NNG'), ('크로', 'UN'), ('퍼드', 'UN'), (',', 'SP'), ('린다', 'UN'), ('에', 'JKM'), ('반', 'NNG'), ('젤리', 'NNG'), ('스타', 'NNG'), ('처럼', 'JKM'), ('키', 'NNG'), ('크', 'VA'), ('고', 'ECE'), ('육감적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('글래머', 'NNG'), ('스타', 'NNG'), ('들', 'XSN'), ('의', 'JKG'), ('전성시대', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('던', 'EFQ'), ('1980', 'NR'), ('년대', 'NNM'), (',', 'SP'), ('마돈나', 'NNG'), ('의', 'JKG'), ('투', 'NNG'), ('머', 'MAG'), ('치', 'NNG'), ('룩', 'UN'), ('이', 'JKS'), ('각광', 'NNG'), ('받', 'VV'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('그', 'MDT'), ('80', 'NR'), ('년대', 'NNM'), ('의', 'JKG'), ('문턱', 'NNG'), ('을', 'JKO'), ('넘', 'VV'), ('고', 'ECE'), ('등장', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('당돌', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('소녀', 'NNG'), ('하', 'XSA'), ('게', 'ECD'), ('이트', 'UN'), ('모스', 'NNG'), ('.', 'SF'), ('하지만', 'MAC'), ('말', 'NNG'), ('도', 'JX'), ('안', 'MAG'), ('되', 'VV'), ('는', 'ETD'), ('얼굴', 'NNG'), ('(', 'SS'), ('앞니', 'NNG'), ('가', 'JKS'), ('벌어지', 'VV'), ('ㄴ', 'ETD'), (')', 'SS'), (',', 'SP'), ('말', 'NNG'), ('도', 'JX'), ('안', 'MAG'), ('되', 'VV'), ('는', 'ETD'), ('키', 'NNG'), ('(', 'SS'), ('167', 'NR'), ('CM', 'OL'), (')', 'SS'), (',', 'SP'), ('더', 'MAG'), ('말', 'NNG'), ('이', 'JKS'), ('안', 'MAG'), ('되', 'VV'), ('는', 'ETD'), ('몸집', 'NNG'), ('(', 'SS'), ('가슴', 'NNG'), ('이', 'JKS'), ('없', 'VA'), ('다', 'EFN'), ('!', 'SF'), (')', 'SS'), ('을', 'NNG'), ('지니', 'VV'), ('ㄴ', 'ETD'), ('그녀', 'NP'), ('는', 'JX'), ('90', 'NR'), ('년대', 'NNM'), ('의', 'JKG'), ('문', 'NNG'), ('을', 'JKO'), ('열', 'VV'), ('자마자', 'ECE'), ('전', 'MDT'), ('세계인', 'NNG'), ('의', 'JKG'), ('패션', 'NNG'), ('아이콘', 'NNG'), ('이', 'JKC'), ('되', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('슬립', 'NNG'), ('드레스', 'NNG'), ('한', 'MDN'), ('장', 'NNG'), (',', 'SP'), ('청바지', 'NNG'), ('하나', 'NR'), ('로', 'JKM'), ('완성', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('세련', 'NNG'), ('되', 'XSV'), ('ㅁ', 'ETN'), (',', 'SP'), ('무엇', 'NP'), ('보다', 'JKM'), ('당돌', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('눈빛', 'NNG'), ('과', 'JKM'), ('무심', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('말투', 'NNG'), ('까지', 'JX'), ('.', 'SF'), ('그녀', 'NP'), ('는', 'JX'), ('이번', 'NNG'), ('시즌', 'NNG'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('광고', 'NNG'), ('캠페인', 'NNG'), ('에서', 'JKM'), ('전성기', 'NNG'), ('못지않', 'VA'), ('은', 'ETD'), ('아름다움', 'NNG'), ('에', 'JKM'), ('카리스마', 'NNG'), ('를', 'JKO'), ('과시', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('도', 'JX'), ('하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 205
# [('[', 'SS'), ("'", 'SS'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('도', 'JX'), ('아웃', 'NNG'), ('포켓', 'NNG'), ('의', 'JKG'), ('웨스턴', 'NNG'), ('셔츠', 'NNG'), ('와', 'JKM'), ('챙', 'NNG'), ('이', 'JKS'), ('넓', 'VA'), ('은', 'ETD'), ('모자', 'NNG'), ('를', 'JKO'), ('쓰', 'VV'), ('ㄴ', 'ETD'), ('카', 'NNG'), ('우걸', 'NNG'), ('들', 'XSN'), ('을', 'JKO'), ('무대', 'NNG'), ('위', 'NNG'), ('에', 'JKM'), ('올리', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('클로에', 'NNG'), ('의', 'JKG'), ('나', 'NP'), ('타샤', 'UN'), ('램지', 'UN'), ('레비', 'NNG'), ('는', 'JX'), ('1970', 'NR'), ('년대', 'NNM'), ('빈티지', 'NNG'), ('영화', 'NNG'), ('의', 'JKG'), ('주인공', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('앤', 'NNG'), ('젤리', 'NNG'), ('카', 'NNG'), ('휴스턴', 'NNG'), (',', 'SP'), ('이자', 'NNG'), ('벨', 'NNG'), ('위', 'NNG'), ('페르', 'NNG'), ('등', 'NNB'), ('을', 'JKO'), ('떠올리', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('고', 'JKQ'), ('밝히', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('너무', 'MAG'), ('강하', 'VV'), ('어서', 'ECD'), ('차마', 'MAG'), ('닿', 'VV'), ('을', 'ETD'), ('수', 'NNB'), ('없', 'VA'), ('는', 'ETD'), ('존재', 'NNG'), ('로', 'JKM'), ('묘사', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('유연', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('화이트', 'NNG'), ('실크', 'NNG'), (',', 'SP'), ('레이스', 'NNG'), ('오간', 'NNG'), ('자', 'NNG'), ('블라우스', 'NNG'), ('에', 'JKM'), ('서부', 'NNG'), ('개척자', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('입', 'VV'), ('었', 'EPT'), ('을', 'ETD'), ('법', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('승마', 'NNG'), ('팬츠', 'NNG'), ('를', 'JKO'), ('매치', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('프린지', 'NNG'), ('가', 'JKS'), ('휘날리', 'VV'), ('는', 'ETD'), ('코트', 'NNG'), ('에', 'JKM'), ('레이스', 'NNG'), ('업', 'NNG'), ('부츠', 'NNG'), ('를', 'JKO'), ('신은', 'NNG'), ('모델', 'NNG'), ('들', 'XSN'), ('.', 'SF'), ('그', 'NP'), ('들', 'XSN'), ('의', 'JKG'), ('워킹', 'NNG'), ('은', 'JX'), ('왠지', 'MAG'), ('더', 'MAG'), ('당', 'NNG'), ('당하', 'XSV'), ('고', 'ECE'), ('힘차', 'VA'), ('게', 'ECD'), ('느껴지', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 206
# [('[', 'SS'), ("'", 'SS'), ('HEDI', 'OL'), ('는', 'JX'), ('DIOR', 'OL'), ('옴므', 'UN'), ('를', 'JKO'), ('떠나', 'VV'), ('면서', 'ECE'), ('자신', 'NNG'), ('의', 'JKG'), ('홈페이지', 'NNG'), ('에', 'JKM'), ('그', 'MDT'), ('이유', 'NNG'), ('를', 'JKO'), ('기고', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('그중', 'NNG'), ('LVMH', 'OL'), ('에서', 'JKM'), ('자신', 'NNG'), ('의', 'JKG'), ('SIGNATURE', 'OL'), ('레이블', 'NNG'), ('을', 'JKO'), ('만들', 'VV'), ('ㄹ라', 'ECD'), ('는', 'JX'), ('것', 'NNB'), ('을', 'JKO'), ('거절', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다는', 'ETD'), ('사실', 'NNG'), ('이', 'JKS'), ('떠오르', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('나', 'NP'), ('는', 'JX'), ('HEDI', 'OL'), ('의', 'JKG'), ('첫', 'MDT'), ('번째', 'NNB'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('과', 'JC'), ('셀', 'NNG'), ('린', 'UN'), ('쇼', 'NNG'), ('를', 'JKO'), ('직접', 'MAG'), ('목도', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('쇼', 'NNG'), ('장이', 'XSN'), ('시끄럽', 'VA'), ('었', 'EPT'), ('다면', 'ECE'), (',', 'SP'), ('지금', 'NNG'), ('은', 'JX'), ('소', 'NNG'), ('셜', 'UN'), ('네트워크', 'NNG'), ('가', 'JKS'), ('시끄럽', 'VA'), ('다', 'EFN'), ('.', 'SF'), ('쇼', 'NNG'), ('장', 'NNG'), ('은', 'JX'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('때', 'NNG'), ('에', 'JKM'), ('비하', 'VV'), ('어', 'ECS'), ('기대', 'NNG'), ('이상', 'NNG'), ('크', 'VA'), ('ㄴ', 'ETD'), ('박수', 'NNG'), ('가', 'JKS'), ('나오', 'VV'), ('았', 'EPT'), ('다', 'ECS'), ('(', 'SS'), ('고', 'NNG'), ('보', 'VV'), ('ㄴ다', 'ECS'), (')', 'SS'), ('.', 'SF'), ('LVMH', 'OL'), ('오', 'VV'), ('아', 'ECS'), ('케어', 'NNG'), ('링', 'NNG'), ('그룹', 'NNG'), ('을', 'JKO'), ('이토록', 'MAG'), ('자유', 'NNG'), ('롭', 'XSA'), ('게', 'ECD'), ('왕래', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETD'), ('자가', 'NNG'), ('또', 'MAG'), ('있', 'VV'), ('을까', 'EFQ'), ('?', 'SF'), ('자신', 'NNG'), ('의', 'JKG'), ('정체성', 'NNG'), ('을', 'JX'), ('고고', 'NNG'), ('히', 'NNG'), ('지키', 'VV'), ('면서', 'ECE'), ('.', 'SF'), ('대기업', 'NNG'), ('이', 'JKS'), ('사람', 'NNG'), ('을', 'JKO'), ('삼키', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('으려', 'ECD'), ('면', 'NNG'), (',', 'SP'), ('확고', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('수익', 'NNG'), ('을', 'JKO'), ('보장', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('브랜드', 'NNG'), ('가', 'JKC'), ('되', 'VV'), ('면', 'ECE'), ('되', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('열광', 'NNG'), ('하', 'XSV'), ('든', 'ECE'), ('반대', 'NNG'), ('하', 'XSV'), ('든', 'ECE'), ('팬', 'NNG'), ('이', 'JKS'), ('존재', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('한', 'NNG'), ('살', 'VV'), ('아', 'ECD'), ('있', 'VXV'), ('는', 'ETD'), ('전설', 'NNG'), ('이', 'JKC'), ('되', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('그러', 'VV'), ('ㄴ', 'ETD'), ('면', 'NNG'), ('에서', 'JKM'), ('통쾌', 'NNG'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('행여', 'MAG'), ('그', 'NP'), ('의', 'JKG'), ('옷', 'NNG'), ('이', 'JKS'), ('똑같', 'VA'), ('다고', 'EFN'), ('생각', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('가', 'VV'), ('아', 'ECS'), ('?', 'SF'), ('어느덧', 'MAG'), ('지천', 'NNG'), ('명이', 'NNG'), ('되', 'VV'), ('ㄴ', 'ETD'), ('그', 'NP'), ('의', 'JKG'), ('옷', 'NNG'), ('과', 'JC'), ('로큰롤', 'NNG'), ('정신', 'NNG'), ('의', 'JKG'), ('변화', 'NNG'), ('에', 'JKM'), ('관하', 'VV'), ('ㄴ', 'ETD'), ('이야기', 'NNG'), ('는', 'JX'), ('차고', 'NNG'), ('넘치', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('HEDI', 'OL'), ('는', 'JX'), ('HEDI', 'OL'), ('를', 'JKO'), ('만들', 'VV'), ('고', 'ECE'), ('(', 'SS'), ('DIOR', 'OL'), ('에서', 'JKM'), (')', 'SS'), (',', 'SP'), ('HEDI', 'OL'), ('를', 'JKO'), ('만들', 'VV'), ('고', 'ECE'), ('(', 'SS'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('에서', 'JKM'), (')', 'SS'), (',', 'SP'), ('HEDI', 'OL'), ('를', 'JKO'), ('만들', 'VV'), ('고', 'ECE'), ('(', 'SS'), ('셀', 'NNG'), ('린', 'UN'), ('에서', 'JKM'), (')', 'SS'), (',', 'SP'), ('HEDI', 'OL'), ('를', 'JKO'), ('만들', 'VV'), ('고', 'ECE'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('피비', 'NNG'), ('가', 'JKS'), ('몰', 'VV'), ('고', 'ECE'), ('다니', 'VV'), ('ㄴ', 'ETD'), ('셀린', 'UN'), ('의',  ...
# ------------------------------
# 207
# [('[', 'SS'), ("'", 'SS'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('에서', 'JKM'), ('그', 'NP'), ('가', 'JKS'), ('고수', 'NNG'), ('하', 'XSV'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('80', 'NR'), ('년대', 'NNM'), ('글', 'NNG'), ('램', 'NNG'), ('룩', 'UN'), ('의', 'JKG'), ('미니', 'NNG'), ('드레스', 'NNG'), (',', 'SP'), ('가죽', 'NNG'), ('과', 'JKM'), ('스팽글', 'NNG'), (',', 'SP'), ('80', 'NR'), ('년대', 'NNM'), ('과장', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('실루엣', 'NNG'), (',', 'SP'), ('처음', 'NNG'), ('으로', 'JKM'), ('공개', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('남성복', 'NNG'), ('까지', 'JX'), ('총', 'MDT'), ('96', 'NR'), ('벌', 'NNM'), ('의', 'JKG'), ('룩', 'UN'), ('이', 'JKS'), ('쏟아지', 'VV'), ('어', 'ECS'), ('나오', 'VV'), ('았', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('HTTPS', 'OL'), (':', 'SP'), ('//', 'SW'), ('TWITTER', 'OL'), ('.', 'SF'), ('COM', 'OL'), ('/', 'SP'), ('KALELAURENT', 'OL'), ('/', 'SP'), ('STATUS', 'OL'), ('/', 'SP'), ('1045769868979494912', 'NR'), ('?', 'SF'), ('REF', 'OL'), ('_', 'SW'), ('SRC', 'OL'), ('=', 'SW'), ('TWSRC', 'OL'), ('%', 'SW'), ('5', 'NR'), ('ETFW', 'OL'), ('%', 'SW'), ('7', 'NR'), ('CTWCAMP', 'OL'), ('%', 'SW'), ('5', 'NR'), ('ETWEETEMBED', 'OL'), ('%', 'SW'), ('7', 'NR'), ('CTWTERM', 'OL'), ('%', 'SW'), ('5', 'NR'), ('E', 'OL'), ('1045769868979494912', 'NR'), ('&', 'SW'), ('REF', 'OL'), ('_', 'SW'), ('URL', 'OL'), ('=', 'SW'), ('HTTPS', 'OL'), ('%', 'SW'), ('3', 'NR'), ('A', 'OL'), ('%', 'SW'), ('2', 'NR'), ('F', 'OL'), ('%', 'SW'), ('2', 'NR'), ('FWWW', 'OL'), ('.', 'SF'), ('HARPERSBAZAAR', 'OL'), ('.', 'SF'), ('COM', 'OL'), ('%', 'SW'), ('2', 'NR'), ('FFASHION', 'OL'), ('%', 'SW'), ('2FFASHION-WEEK', 'OL'), ('%', 'SW'), ('2', 'NR'), ('FA', 'OL'), ('23514923', 'NR'), ('%', 'SW'), ('2FHEDI-SLIMANE', 'OL'), ('-', 'SW'), ('CELINE-SPRING', 'OL'), ('-2019', 'NR'), ('%', 'SW'), ('2', 'NR'), ('F', 'OL'), ('"', 'SS'), (',', 'SP'), ('\\', 'SW'), ("'", 'SS'), ('"', 'SS'), ('피비', 'NNG'), ('필로', 'NNG'), ('가', 'JKS'), ('떠나', 'VV'), ('ㄴ', 'ETD'), ('셀린', 'UN'), ('의', 'JKG'), ('후임자', 'NNG'), ('가', 'JKS'), ('누', 'NNG'), ('가', 'JKC'), ('되', 'VV'), ('ㄹ지', 'ECD'), ('추측', 'NNG'), ('이', 'JKS'), ('난무', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('을', 'ETD'), ('때', 'NNG'), ('\\\\\\', 'SW'), ("'", 'SS'), ('HEDI', 'OL'), ('SLIMANE', 'OL'), ('의', 'JKG'), ('컴백', 'NNG'), ('\\\\\\', 'SW'), ("'", 'SS'), ('만', 'NNG'), ('으로', 'JKM'), ('모두', 'NNG'), ('가', 'JKS'), ('열광', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('그', 'NP'), ('가', 'JKS'), ('DIOR', 'OL'), ('옴', 'NNM'), ('므', 'UN'), (',', 'SP'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('에서', 'JKM'), ('보여주', 'VV'), ('었', 'EPT'), ('던', 'EFQ'), ('ICONIC', 'OL'), ('한', 'MDN'), ('룩들', 'UN'), ('과', 'JC'), ('행보', 'NNG'), ('는', 'JX'), ('그르', 'VV'), ('ㄹ', 'ETD'), ('\\\\\\', 'SW'), ("'", 'SS'), ('스타', 'NNG'), ('디자이너', 'NNG'), ('\\\\\\', 'SW'), ("'", 'SS'), ('로', 'NNG'), ('만들', 'VV'), ('었', 'EPT'), ('음', 'ETN'), ('에', 'JKM'), ('분명', 'NNG'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('그러', 'VV'), ('ㄴ', 'ETD'), ('그', 'NP'), ('가', 'JKS'), ('셀린', 'UN'), ('에서', 'JKM'), ('하우스', 'NNG'), ('고유', 'NNG'), ('의', 'JKG'), ('ARCHIVE', 'OL'), ('가', 'JKS'), ('아니', 'VV'), ('ㄴ', 'ETD'), (',', 'SP'), ('그', 'NP'), ('의', 'JKG'), ('ICONIC', 'OL'), ('한', 'MDN'), ('룩들', 'UN'), ('을', 'JKO'), ('등장', 'NNG'), ('시키', 'XSV'), ('었', 'EPT'), ('다고', 'EFN'), ('하', 'VV'), ('어서', 'ECD'), ('비난', 'NNG'), ('만', 'JX'), ('받', 'VV'), ('아야', 'ECD'), ('하', 'VV'), ('ㄹ까', 'EFQ'), ('?', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('이', 'NP'), ('는', 'JX'), ('패션', 'NNG'), ('하우스', 'NNG'), ('의', 'JKG'), ('DNA', 'OL'), ('보다', 'JKM'), ('스타', 'NNG'), (',', 'SP'), ('INFLUENCER', 'OL'), ('가', 'JKS'), ('중요', 'NNG'), ('해진', 'NNG'), ('지금', 'NNG'), ('시대', 'NNG'), ('의', 'JKG'), ('흐름', 'NNG'), ('과', 'JKM'), ('동일', 'NNG'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('LVMH', 'OL'), ('그룹', 'NNG'), ('이', 'JKS'), ('원하', 'VV'), ('는', 'ETD'), ('바', 'NNB'), ('이', 'VCP'), ('ㄹ까', 'EFQ'), ('?', 'SF'), ('좋', 'VA'), ('든' ...
# ------------------------------
# 208
# [('[', 'SS'), ("'", 'SS'), ('1980', 'NR'), ('년대', 'NNM'), ('의', 'JKG'), ('강렬', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('기운', 'NNG'), ('은', 'JX'), ('뉴욕', 'NNP'), ('에서', 'JKM'), ('가장', 'MAG'), ('먼저', 'MAG'), ('감지', 'NNG'), ('되', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('톰', 'UN'), ('포드', 'NNG'), ('의', 'JKG'), ('화려', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('섹슈얼', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('글', 'NNG'), ('램', 'NNG'), ('시크', 'NNG'), ('로', 'JKM'), ('시작', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('1980', 'NR'), ('년', 'NNM'), ('대', 'NNG'), ('무드', 'NNG'), ('는', 'JX'), ('마크', 'NNG'), ('제이콥스', 'UN'), ('의', 'JKG'), ('대담', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('커다랗', 'VA'), ('ㄴ', 'ETD'), ('어깨', 'NNG'), (',', 'SP'), ('과감', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('컬러', 'NNG'), ('블로킹', 'NNG'), ('으로', 'JKM'), ('정점', 'NNG'), ('을', 'JKO'), ('찍', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('각지', 'VV'), ('ㄴ', 'ETD'), ('패드로', 'NNG'), ('과장', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('어깨', 'NNG'), ('는', 'JX'), ('몸', 'NNG'), ('의', 'JKG'), ('일부', 'NNG'), ('같', 'VA'), ('았', 'EPT'), ('고', 'ECE'), (',', 'SP'), ('어깨', 'NNG'), ('를', 'JKO'), ('비롯', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('모든', 'NNP'), ('실루엣', 'NNG'), ('이', 'JKS'), ('크', 'VA'), ('ㄴ', 'ETD'), ('비율', 'NNG'), ('로', 'JKM'), ('팽창', 'NNG'), ('되', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('뿐', 'NNB'), ('만', 'JX'), ('이', 'JKC'), ('아니', 'VCN'), ('다', 'EFN'), ('.', 'SF'), ('그', 'VV'), ('ㄹ', 'ETD'), ('램', 'NNG'), ('과', 'JC'), ('섹슈얼', 'NNG'), ('리', 'XSN'), ('티', 'NNG'), ('의', 'JKG'), ('상징', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('브랜드', 'NNG'), ('의', 'JKG'), ('전성기', 'NNG'), ('1980', 'NR'), ('년대', 'NNM'), ('로', 'JKM'), ('돌아가', 'VV'), ('이를', 'UN'), ('새롭', 'VA'), ('게', 'ECD'), ('리', 'NNG'), ('바이', 'MAG'), ('벌', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('VERSACE', 'OL'), (',', 'SP'), ('1980', 'NR'), ('년대', 'NNM'), ('ARCHIVE', 'OL'), ('에서', 'JKM'), ('발췌', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('반짝이', 'VV'), ('ㅁ', 'ETN'), ('과', 'JKM'), ('화려', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('우아', 'XR'), ('하', 'XSA'), ('게', 'ECD'), ('표현', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('과', 'JKM'), ('발맹', 'UN'), (',', 'SP'), ('1980', 'NR'), ('년대', 'NNM'), ('특유', 'NNG'), ('의', 'JKG'), ('B', 'OL'), ('급', 'NNG'), ('감성', 'NNG'), ('과', 'JKM'), ('아찔', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), (',', 'SP'), ('속물', 'NNG'), ('주의', 'NNG'), ('같', 'VA'), ('은', 'ETD'), ('특징', 'NNG'), ('을', 'JKO'), ('긴장감', 'NNG'), ('넘치', 'VV'), ('는', 'ETD'), ('의상', 'NNG'), ('으로', 'JKM'), ('옮기', 'VV'), ('ㄴ', 'ETD'), ('지방시', 'NNG'), ('등', 'NNB'), ('일일이', 'MAG'), ('나열', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('어렵', 'VA'), ('ㄹ', 'ETD'), ('정도', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('\\', 'SW'), ("'", 'SS'), ('"', 'SS'), ('\\\\\\', 'SW'), ("'", 'SS'), ('80', 'NR'), ('S', 'OL'), ('"', 'SS'), (',', 'SP'), ('\\\\\\', 'SW'), ("'", 'SS'), ('FUTURISM', 'OL'), ('\\', 'SW'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 209
# [('[', 'SS'), ("'", 'SS'), ('아하', 'UN'), (',', 'SP'), ('칼', 'NNG'), ('의', 'JKG'), ('어머니', 'NNG'), ('엘리자베스', 'NNG'), ('가', 'JKS'), ('있', 'VV'), ('었', 'EPT'), ('지', 'EFN'), ('.', 'SF'), ('그', 'NP'), ('가', 'JKS'), ('어리', 'VA'), ('ㄴ', 'ETD'), ('시절', 'NNG'), ('에', 'JKM'), ('대하', 'VV'), ('ㄴ', 'ETD'), ('이야기', 'NNG'), ('를', 'JKO'), ('하', 'VV'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('이', 'VCP'), ('면', 'ECE'), ('유난히', 'MAG'), ('혐오감', 'NNG'), ('을', 'JKO'), ('드러내', 'VV'), ('는', 'ETD'), ('탓', 'NNG'), ('에', 'JKM'), ('그녀', 'NP'), ('는', 'JX'), ('내', 'VV'), ('게', 'ECD'), ('있', 'VXV'), ('어', 'ECD'), ('더', 'MAG'), ('알아보', 'VV'), ('고', 'ECE'), ('싶', 'VXA'), ('은', 'ETD'), ('흥미', 'NNG'), ('롭', 'XSA'), ('ㄴ', 'ETD'), ('여성', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('그러', 'VV'), ('ㄴ', 'ETD'), ('데', 'NNB'), ('오늘', 'NNG'), ('마주하', 'VV'), ('ㄴ', 'ETD'), ('그', 'NP'), ('는', 'JX'), ('평소', 'NNG'), ('보다', 'JKM'), ('는', 'JX'), ('살짝', 'MAG'), ('더', 'MAG'), ('말하', 'VV'), ('ㄹ', 'ETD'), ('준비', 'NNG'), ('가', 'JKC'), ('되', 'VV'), ('어', 'ECD'), ('있', 'VXV'), ('는', 'ETD'), ('듯하', 'VXA'), ('다', 'EFN'), ('.', 'SF'), ('오토', 'NNG'), ('라', 'NNG'), ('그', 'VV'), ('어', 'ECS'), ('펠트', 'NNG'), ('(', 'SS'), ('연', 'NNG'), ('유', 'NNG'), ('회사', 'NNG'), ('를', 'JKO'), ('운영', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('유복', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('독일', 'NNG'), ('출신', 'NNG'), ('비즈니스맨', 'NNG'), (')', 'SS'), ('의', 'NNG'), ('두', 'MDN'), ('번째', 'NNB'), ('부인', 'NNG'), ('인', 'NNG'), ('엘리자베스', 'NNG'), ('는', 'JX'), ('실제로', 'MAG'), ('자신', 'NNG'), ('의', 'JKG'), ('외동', 'NNP'), ('아들', 'NNG'), ('에게', 'JKM'), ('커다랗', 'VA'), ('ㄴ', 'ETD'), ('영향', 'NNG'), ('을', 'JKO'), ('끼치', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('칼', 'NNG'), ('은', 'JX'), ('그녀', 'NP'), ('에', 'JKM'), ('대하', 'VV'), ('어', 'ECS'), ('‘', 'SS'), ('완벽', 'NNG'), ('’', 'SS'), ('하', 'VV'), ('었', 'EPT'), ('다고', 'EFN'), ('말하', 'VV'), ('지만', 'ECE'), ('그', 'NP'), ('가', 'JKS'), ('그녀', 'NP'), ('의', 'JKG'), ('교육', 'NNG'), ('방식', 'NNG'), ('을', 'JKO'), ('설명', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('사실', 'NNG'), ('나', 'NP'), ('는', 'JX'), ('무섭', 'VA'), ('다고', 'EFN'), ('느끼', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('이를테면', 'MAG'), ('그녀', 'NP'), ('는', 'JX'), ('그', 'NP'), ('가', 'JKS'), ('피아노', 'NNG'), ('를', 'JKO'), ('연습', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('손가락', 'NNG'), ('위', 'NNG'), ('로', 'JKM'), ('피아노', 'NNG'), ('뚜껑', 'NNG'), ('을', 'JKO'), ('내리치', 'VV'), ('ㄴ다', 'ECS'), ('거나', 'JX'), (',', 'SP'), ('그림', 'NNG'), ('그리', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('을', 'JKO'), ('억지로', 'MAG'), ('시키', 'VV'), ('곤', 'ECS'), ('하', 'VV'), ('었', 'EPT'), ('고', 'ECE'), ('(', 'SS'), ('이유', 'NNG'), ('이', 'VCP'), ('ㄴ즉', 'ECE'), ('스', 'VV'), ('ㄴ', 'ETD'), (',', 'SP'), ('소음', 'NNG'), ('이', 'JKS'), ('작', 'VA'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKM'), (')', 'SS'), (',', 'SP'), ('손가락', 'NNG'), ('이', 'JKS'), ('못생기', 'VA'), ('었', 'EPT'), ('다는', 'ETD'), ('둥', 'NNB'), (',', 'SP'), ('콧구멍', 'NNG'), ('이', 'JKS'), ('너무', 'MAG'), ('넓', 'VA'), ('다는', 'ETD'), ('둥', 'NNB'), (',', 'SP'), ('헤어', 'NNG'), ('가', 'JKS'), ('우스꽝스럽', 'VA'), ('다는', 'ETD'), ('둥', 'NNB'), ('그', 'NP'), ('에', 'JKM'), ('관하', 'VV'), ('어', 'ECS'), ('가능', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('모든', 'MDT'), ('것', 'NNB'), ('을', 'JKO'), ('꼬투리', 'NNG'), ('잡', 'VV'), ('아', 'ECD'), ('비웃', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('그러하', 'VV'), ('ㄴ', 'ETD'), ('압박', 'NNG'), ('은', 'JX'), ('결국', 'NNG'), ('지금', 'NNG'), ('도', 'JX'), ('그', 'NP'), ('가', 'JKS'), ('대중', 'NNG'), ('앞', 'NNG'), ('에', 'JKM'), ('서', 'VV'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('자신', 'NNG'), ('의', 'JKG'), ('못나', 'VA'), ('ㄴ', 'ETD'), ('손', 'NNG'), ('을', 'JKO'), ('가리', 'VV'), ('기', 'ETN'), ('위하', 'VV'), ('어', 'ECS'), ('손가락', 'NNG'), ('이', 'JKS'), ('보이', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('는', 'ETD'), ('장갑', 'NNG'), ('을', 'JKO'), ('끼', 'VV'), ('게', 'ECD'), ('되', 'VV'), ('ㄴ', 'ETD'), ('계기', 'NNG'), ('가', 'JKC'), ('되', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('물론', 'MAG'), ('그러', 'VV' ...
# ------------------------------
# 210
# [('[', 'SS'), ("'", 'SS'), ('입', 'NNG'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('이', 'JKS'), ('처음', 'NNG'), ('으로', 'JKM'), ('LE', 'OL'), ('_', 'SW'), ('SMOKING', 'OL'), ('(', 'SS'), ('LE', 'OL'), ('SMOKING', 'OL'), (')', 'SS'), ('수트', 'NNG'), ('를', 'JKO'), ('DESIGN', 'OL'), ('하', 'VV'), ('었', 'EPT'), ('을', 'ETD'), ('때', 'NNG'), (',', 'SP'), ('그것', 'NP'), ('은', 'JX'), ('여성', 'NNG'), ('의', 'JKG'), ('패션', 'NNG'), ('에서', 'JKM'), ('혁명', 'NNG'), ('과', 'JKM'), ('도', 'JX'), ('같', 'VA'), ('은', 'ETD'), ('일', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('이전', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('여성', 'NNG'), ('이', 'JKS'), ('바지', 'NNG'), ('를', 'JKO'), ('착용', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('부적절하', 'VA'), ('고', 'ECE'), ('생각', 'NNG'), ('되', 'XSV'), ('었', 'EPT'), ('지만', 'ECE'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('이', 'MDT'), ('편견', 'NNG'), ('을', 'JKO'), ('깨트리', 'VV'), ('며', 'ECE'), ('패션', 'NNG'), ('의', 'JKG'), ('파워', 'NNG'), ('를', 'JKO'), ('보여주', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 211
# [('[', 'SS'), ("'", 'SS'), ('[', 'SS'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('스타일', 'NNG'), ('스마트', 'NNP'), ('하', 'XSV'), ('게', 'ECD'), ('쇼핑', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('남성', 'NNG'), ('성과', 'NNG'), ('여성성', 'NNG'), (',', 'SP'), ('파워', 'NNG'), ('풀', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('카리스마', 'NNG'), ('와', 'JC'), ('우', 'NNG'), ('아함', 'NNP'), ('이', 'JKS'), ('공존', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('블랙', 'NNG'), ('레더', 'NNG'), ('드레싱', 'NNG'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('BYBAZAAR', 'OL'), ('2018.08', 'NR'), ('.', 'SF'), ('18', 'NR'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('STYLING', 'OL'), ('TIP', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('매', 'VV'), ('니', 'ECD'), ('시한', 'NNG'), ('오버', 'NNG'), ('사이즈', 'NNG'), ('레더', 'NNG'), ('트', 'VV'), ('러', 'ECD'), ('커', 'VV'), ('어', 'ECS'), ('재킷', 'NNG'), ('에', 'JKM'), ('관능적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('레더', 'NNG'), ('쇼츠', 'UN'), ('를', 'JKO'), ('매치', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('카리스마', 'NNG'), ('넘치', 'VV'), ('는', 'ETD'), ('블랙', 'NNG'), ('레더', 'NNG'), ('룩', 'UN'), ('에', 'JKM'), ('울', 'VV'), ('ㄹ', 'ETD'), ('페도라', 'UN'), ('로', 'JKM'), ('시크', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('우', 'NNG'), ('아함', 'NNP'), ('을', 'JKO'), (',', 'SP'), ('볼드', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('그레이', 'NNG'), ('JEWERLY', 'OL'), ('로', 'JKM'), ('모던', 'NNG'), ('함', 'NNG'), ('을', 'JKO'), ('더하', 'VV'), ('ㄹ', 'ETD'), ('것', 'NNB'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('2', 'NR'), ('SHARE', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('KEYWORD', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('SMART', 'OL'), ('SHOPPING', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('블랙', 'NNG'), ('레더', 'NNG'), ('드레싱', 'NNG'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('CREDIT', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('EDITOR', 'OL'), ('|', 'SW'), ('이', 'MDT'), ('병', 'NNG'), ('호', 'XSN'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('사진', 'NNG'), ('|', 'SW'), ('KIM', 'OL'), ('DOOJONG', 'OL'), ('(', 'SS'), ('제품', 'NNG'), (')', 'SS'), ('&', 'SW'), ('FIRSTVIEW', 'OL'), ('KOREA', 'OL'), ('(', 'SS'), ('런', 'NNG'), ('웨이', 'UN'), (')', 'SS'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('WEEKLY', 'OL'), ('HOT', 'OL'), ('ISSUE', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('스웨트', 'UN'), ('셔츠', 'NNG'), ('하나', 'NR'), ('이', 'VCP'), ('면', 'ECE'), ('어디', 'NP'), ('든', 'JX'), ('갈', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('어', 'ECD'), ('#', 'SW'), ('원', 'NNG'), ('마일', 'NNG'), ('룩', 'UN'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('프라다', 'NNG'), ('에', 'JKM'), ('대하', 'VV'), ('ㄴ', 'ETD'), ('거', 'NNB'), ('의', 'JKG'), ('모든', 'MDT'), ('것', 'NNB'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('청', 'NNG'), ('정', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('연말', 'NNG'), ('모임', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('ㄴ', 'ETD'), ('#', 'SW'), ('프라이빗', 'NNG'), ('다', 'NNG'), ('이닝', 'NNG'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('막스', 'NNP'), ('마라', 'NNG'), (',', 'SP'), ('겨울철', 'NNG'), ('여성', 'NNG'), ('의', 'JKG'), ('제', 'NNG'), ('1', 'NR'), ('피난', 'NNG'), ('처', 'NNG'), ('코트', 'NNG'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('BAZAAR', 'OL'), ('BRAND', 'OL'), ('"', 'SS'), (',', 'SP'), ('"', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('BTS', 'OL'), ('컴백', 'NNG'), (',', 'SP'), ('이번', 'NNG'), ('앨범', 'NNG'), ('이', 'JKS'), ('더욱', 'MAG'), ('특별', 'NNG'), ('하', 'XSV ...
# ------------------------------
# 212
# [('[', 'SS'), ("'", 'SS'), ('패션', 'NNG'), ('사', 'NNG'), ('를', 'JKO'), ('통틀', 'VV'), ('어', 'ECD'), ('이', 'NP'), ('들', 'XSN'), ('만큼', 'JX'), ('완벽', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('고', 'ECE'), (',', 'SP'), ('또', 'MAG'), ('유명세', 'NNG'), ('를', 'JKO'), ('떨치', 'VV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('듀오', 'NNP'), ('가', 'JKS'), ('또', 'MAG'), ('있', 'VV'), ('을까', 'EFQ'), ('?', 'SF'), ('1982', 'NR'), ('년', 'NNM'), ('1', 'NR'), ('월', 'NNM'), (',', 'SP'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('하우스', 'NNG'), ('창립', 'NNG'), ('20', 'NR'), ('주년', 'NNM'), ('을', 'JKO'), ('기념', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('파티', 'NNG'), ('현장', 'NNG'), ('사진', 'NNG'), ('에서', 'JKM'), ('두', 'MDN'), ('사람', 'NNG'), ('의', 'JKG'), ('끈끈', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('우정', 'NNG'), ('과', 'JKM'), ('깊', 'VA'), ('은', 'ETD'), ('신뢰', 'NNG'), ('를', 'JKO'), ('느끼', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 213
# [('[', 'SS'), ("'", 'SS'), ('패션쇼', 'NNG'), ('초창기', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('사진', 'NNG'), ('작가', 'NNG'), ('들', 'XSN'), ('을', 'JKO'), ('위하', 'VV'), ('ㄴ', 'ETD'), ('포토', 'NNG'), ('존', 'NNP'), ('이', 'JKS'), ('없', 'VA'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('스스로', 'NNG'), ('촬영', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETD'), ('공간', 'NNG'), ('을', 'JKO'), ('만들', 'VV'), ('어야', 'ECD'), ('하', 'VV'), ('었', 'EPT'), ('는데', 'ECD'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('컬렉션', 'NNG'), ('에서', 'JKM'), ('크리스', 'NNG'), ('무어', 'NP'), ('는', 'JX'), ('살롱', 'NNG'), ('의', 'JKG'), ('창턱', 'NNG'), ('에', 'JKM'), ('앉', 'VV'), ('아', 'ECD'), ('촬영', 'NNG'), ('하', 'XSV'), ('어야', 'ECD'), ('하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('덕분', 'NNG'), ('에', 'JKM'), ('(', 'SS'), ('?', 'SF'), (')', 'SS'), ('오히려', 'MAG'), ('피날레', 'NNG'), ('에', 'JKM'), ('선', 'NNG'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('을', 'JKO'), ('포착', 'NNG'), ('하', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETD'), ('아주', 'MAG'), ('좋', 'VA'), ('은', 'ETD'), ('위치', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다고', 'EFN'), ('회상', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('지만', 'ECE'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('수', 'NNG'), ('십', 'NR'), ('년', 'NNM'), ('동안', 'NNG'), ('의', 'JKG'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('커리어', 'NNG'), ('를', 'JKO'), ('축하', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('엄청나', 'VA'), ('ㄴ', 'ETD'), ('경험', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('조', 'NNG'), ('르', 'NNG'), ('쥬', 'UN'), ('브라크', 'NNG'), ('(', 'SS'), ('GEORGES', 'OL'), ('BRAQUE', 'OL'), (')', 'SS'), ('의', 'NNG'), ('작품', 'NNG'), ('에서', 'JKM'), ('영감', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETD'), ('런웨이', 'UN'), ('를', 'JKO'), ('포착', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('순간', 'NNG'), ('또한', 'MAG'), ('그렇', 'VA'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 214
# [('[', 'SS'), ("'", 'SS'), ('“', 'SS'), ('너무', 'MAG'), ('많', 'VA'), ('은', 'ETD'), ('생각', 'NNG'), ('을', 'JKO'), ('하', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('고', 'ECE'), ('그냥', 'MAG'), ('그렇', 'VA'), ('게', 'ECD'), ('하', 'VV'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('그러', 'VV'), ('면', 'ECE'), ('사람', 'NNG'), ('들', 'XSN'), ('은', 'JX'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('이', 'JKS'), ('유색', 'NNG'), ('인종', 'NNG'), ('여성', 'NNG'), ('들', 'XSN'), ('을', 'JKO'), ('기용', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('첫', 'MDT'), ('번째', 'NNB'), ('하우스', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다는', 'ETD'), ('사실', 'NNG'), ('을', 'JKO'), ('떠올리', 'VV'), ('게', 'ECD'), ('되', 'VV'), ('죠', 'EFN'), ('.', 'SF'), ('저', 'NP'), ('는', 'JX'), ('사람', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('그것', 'NP'), ('을', 'JKO'), ('알아채', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('기쁘', 'VA'), ('어요', 'EFN'), ('.', 'SF'), ('하지만', 'MAC'), ('의도적', 'NNG'), ('으로', 'JKM'), ('그러', 'XR'), ('지', 'XSA'), ('ㄴ', 'ETD'), ('않', 'VXV'), ('습니다', 'EFN'), ('.', 'SF'), ('그냥', 'MAG'), ('그것', 'NP'), ('이', 'JKS'), ('중요', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKM'), ('그렇', 'VA'), ('게', 'ECD'), ('하', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('죠', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('자신', 'NNG'), ('의', 'JKG'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('데뷔', 'NNG'), ('쇼', 'NNG'), ('부터', 'JX'), ('다양', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('흑인', 'NNG'), ('모델', 'NNG'), ('들', 'XSN'), ('을', 'JKO'), ('기용', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('온', 'MDT'), ('ANTHONY', 'OL'), ('VACCARELLO', 'OL'), ('.', 'SF'), ('그', 'NP'), ('의', 'JKG'), ('태도', 'NNG'), ('야말로', 'JX'), ('지금', 'MAG'), ('우리', 'NP'), ('가', 'JKS'), ('이', 'MDT'), ('현상', 'NNG'), ('을', 'JKO'), ('바라보', 'VV'), ('는', 'ETD'), ('데', 'NNB'), ('필요', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('가장', 'MAG'), ('쿨하', 'VA'), ('ㄴ', 'ETD'), ('자세', 'NNG'), ('이', 'VCP'), ('ㄹ', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 215
# [('[', 'SS'), ("'", 'SS'), ('지중해', 'NNG'), ('를', 'JKO'), ('건느', 'VV'), ('어', 'ECS'), ('아프리카', 'NNG'), ('대륙', 'NNG'), ('에', 'JKM'), ('도착', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('디자이너', 'NNG'), ('들', 'XSN'), ('은', 'JX'), ('?', 'SF'), ('먼저', 'MAG'), ('스텔라', 'NNG'), ('매', 'NNG'), ('카트', 'NNG'), ('니', 'JC'), ('.', 'SF'), ('아프리카', 'NNG'), ('전통', 'NNG'), ('의상', 'NNG'), ('에서', 'JKM'), ('모티프', 'NNG'), ('를', 'JKO'), ('가져오', 'VV'), ('ㄴ', 'ETD'), ('화려', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('프린트', 'NNG'), ('드레스', 'NNG'), ('와', 'JKM'), ('오버사이즈', 'NNG'), ('의', 'JKG'), ('리넨', 'NNG'), ('사파리', 'NNG'), ('재킷', 'NNG'), ('등', 'NNB'), ('은', 'JX'), ('야생', 'NNG'), ('의', 'JKG'), ('대자연', 'NNG'), ('으로', 'JKM'), ('이끌', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('로베르', 'NNG'), ('토', 'NNG'), ('카', 'NNG'), ('발리', 'NNG'), ('역시', 'MAG'), ('아프리카', 'NNG'), ('초원', 'NNG'), ('으로', 'JKM'), ('떠나', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('카', 'MAG'), ('발리', 'NNG'), ('에서', 'JKM'), ('의', 'JKG'), ('첫', 'MDT'), ('번째', 'NNB'), ('컬렉션', 'NNG'), ('을', 'JKO'), ('선보이', 'VV'), ('ㄴ', 'ETD'), ('디자이너', 'NNG'), ('폴', 'NNG'), ('서리', 'VV'), ('지', 'ECD'), ('는', 'JX'), ('정제', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('이', 'JKS'), ('그', 'MDT'), ('조', 'NNG'), ('틱', 'UN'), ('룩', 'UN'), ('으로', 'JKM'), ('성공적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('데뷔', 'NNG'), ('를', 'JKO'), ('치러', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('지브', 'NNG'), ('러', 'NNP'), ('패턴', 'NNG'), ('과', 'JKM'), ('지브', 'NNG'), ('러', 'NNP'), ('를', 'JKO'), ('응용', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('스트라이프', 'NNG'), ('프린트', 'NNG'), ('의', 'JKG'), ('이브닝', 'NNG'), ('드레스', 'NNG'), ('는', 'JX'), ('물론', 'MAG'), ('아프리칸', 'NNG'), ('무드', 'NNG'), ('에', 'JKM'), ('어울리', 'VV'), ('는', 'ETD'), ('볼드', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('액세서리', 'NNG'), ('까지', 'JX'), ('관능', 'NNG'), ('미', 'NNG'), ('넘치', 'VV'), ('는', 'ETD'), ('아이템', 'NNG'), ('이', 'JKS'), ('시선', 'NNG'), ('을', 'JKO'), ('끌', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'JKG'), ('ANTHONY', 'OL'), ('VACCARELLO', 'OL'), ('는', 'JX'), ('이번', 'NNG'), ('시즌', 'NNG'), ('에펠', 'NNG'), ('탑', 'NNG'), ('이', 'JKS'), ('보이', 'VV'), ('는', 'ETD'), ('공간', 'NNG'), ('에서', 'JKM'), ('쇼', 'NNG'), ('를', 'JKO'), ('진행하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('브랜드', 'NNG'), ('의', 'JKG'), ('방대', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('ARCHIVE', 'OL'), ('를', 'JKO'), ('하', 'VV'), ('ㄴ', 'ETD'), ('편의', 'NNG'), ('드라마', 'NNG'), ('처럼', 'JKM'), ('펼치', 'VV'), ('었', 'EPT'), ('는데', 'ECD'), ('그중', 'NNG'), ('에서', 'JKM'), ('도', 'JX'), ('MARRAKECH', 'OL'), ('를', 'JKO'), ('연상', 'NNG'), ('시키', 'XSV'), ('는', 'ETD'), ('아이템', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('눈', 'NNG'), ('에', 'JKM'), ('띄', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('MARRAKECH', 'OL'), ('는', 'JX'), ('저', 'NP'), ('에게', 'JKM'), ('컬러', 'NNG'), ('를', 'JKO'), ('가르치', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('ㄴ', 'ETD'), ('도', 'VV'), ('시', 'EPH'), ('죠', 'EFN'), ('.', 'SF'), ('그곳', 'NP'), ('에', 'JKM'), ('가', 'VV'), ('기', 'ETN'), ('전', 'NNG'), ('저', 'NP'), ('에게', 'JKM'), ('는', 'JX'), ('블랙', 'NNG'), ('이', 'JKS'), ('전부', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('거든요', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('디자이너', 'NNG'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('이', 'JKS'), ('사랑', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('모코', 'NNG'), ('칸', 'NNG'), ('무드', 'NNG'), ('는', 'JX'), ('정통', 'NNG'), ('프렌치', 'NNG'), ('룩', 'UN'), ('에', 'JKM'), ('유쾌', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('가미', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('요소', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('한편', 'NNG'), (',', 'SP'), ('로', 'NNG'), ('에', 'JKM'), ('베', 'NNG'), ('의', 'JKG'), ('조', 'NNG'), ('너', 'NP'), ('서', 'JKM'), ('는', 'JX'), ('앤더슨', 'NNG'), ('은', 'JX'), ('인도', 'NNG'), ('와', 'JC'), ('발리', 'NNG'), ('로', 'JKM'), ('떠나', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('로', 'NNG'), ('에', 'JKM'), ('베', 'NNG'), ('의', 'JKG'), ('여인', 'NNG'), ('은', 'JX ...
# ------------------------------
# 216
# ...
# ------------------------------
# 994
# [('[', 'SS'), ("'", 'SS'), ('올해', 'NNG'), ('열리', 'VV'), ('ㄹ', 'ETD'), ('전시', 'NNG'), ('와', 'JKM'), ('멧', 'UN'), ('가르', 'VV'), ('아', 'ECS'), ('의', 'JKG'), ('주제', 'NNG'), ('는', 'JX'), ('꼬', 'VV'), ('ㅁ', 'ETN'), ('데', 'MAG'), ('가', 'VV'), ('아', 'ECS'), ('르', 'NNG'), ('송', 'NNG'), ('의', 'JKG'), ('디자이너', 'NNG'), ('‘', 'SS'), ('레이', 'NNG'), ('가', 'NNG'), ('와', 'JKM'), ('쿠보', 'UN'), ('’', 'SS'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('1983', 'NR'), ('년', 'NNM'), (',', 'SP'), ('디자이너', 'NNG'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('이후', 'NNG'), ('메트로', 'NNG'), ('폴리', 'NNG'), ('타', 'VV'), ('ㄴ', 'ETD'), ('미술관', 'NNG'), ('의', 'JKG'), ('의상', 'NNG'), ('연구소', 'NNG'), ('에서', 'JKM'), ('‘', 'SS'), ('현존', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('디자이너', 'NNG'), ('’', 'SS'), ('의', 'NNG'), ('전시', 'NNG'), ('를', 'JKO'), ('열', 'VV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('은', 'JKS'), ('처음', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('패션계', 'NNG'), ('의', 'JKG'), ('귀추', 'NNG'), ('가', 'JKS'), ('주목', 'NNG'), ('되', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('밖에', 'JX'), ('없', 'VA'), ('겠', 'EPT'), ('죠', 'EFN'), ('?', 'SF'), ('레이', 'NNG'), ('가', 'VV'), ('아', 'ECS'), ('와', 'VV'), ('쿠', 'ECE'), ('보', 'VXV'), ('는', 'ETD'), ('멧', 'UN'), ('가르', 'VV'), ('아', 'ECS'), ('가', 'JKS'), ('열리', 'VV'), ('는', 'ETD'), ('5', 'NR'), ('월', 'NNM'), ('1', 'NR'), ('일', 'NNM'), ('에', 'JKM'), ('명예', 'NNG'), ('의장', 'NNG'), ('으로서', 'JKM'), ('참석', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('예정', 'NNG'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 995
# [('[', 'SS'), ('"', 'SS'), ('게다가', 'MAG'), ('요즘', 'NNG'), ('거리', 'NNG'), ('의', 'JKG'), ('멋쟁이', 'NNG'), ('들', 'XSN'), ('은', 'JX'), ('구제', 'NNG'), ('청바지', 'NNG'), ('나', 'JC'), ('티셔츠', 'NNG'), ('와', 'JKM'), ('함께', 'MAG'), ('좀더', 'MAG'), ('합리적', 'NNG'), ('으로', 'JKM'), ('스타일링', 'NNG'), ('하', 'XSV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('가장', 'MAG'), ('손쉽', 'VA'), ('ㄴ', 'ETD'), ('접근', 'NNG'), ('은', 'JX'), ('디자이너', 'NNG'), ('들', 'XSN'), ('이나', 'JX'), ('레드', 'NNG'), ('카펫', 'NNG'), ('위의', 'NNG'), ('셀', 'NNG'), ('레', 'NNG'), ('브리', 'UN'), ('티', 'NNG'), ('가', 'JKS'), ('그러하', 'VA'), ('었', 'EPT'), ('듯이', 'ECD'), ('무릎', 'NNG'), ('길이', 'NNG'), ('의', 'JKG'), ('여성', 'NNG'), ('스럽', 'XSA'), ('ㄴ', 'ETD'), ('원피스', 'NNG'), ('를', 'JKO'), ('택하', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('.', 'SF'), ('오프', 'NNG'), ('화이트', 'NNG'), ('나', 'JC'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('처럼', 'JKM'), ('캐주얼', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('접근', 'NNG'), ('하', 'XSV'), ('려면', 'ECE'), ('통이', 'MAG'), ('넣', 'VV'), ('은', 'ETD'), ('와이드', 'NNG'), ('팬츠', 'NNG'), ('나', 'JC'), ('데님', 'NNG'), ('을', 'JKO'), ('매치', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('보', 'VV'), ('ㄹ', 'ETD'), ('것', 'NNB'), ('!', 'SF'), ('몬', 'MAG'), ('세', 'NNG'), ('톱', 'NNG'), ('처럼', 'JKM'), ('클래식', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('핀', 'NNG'), ('스트라이프', 'NNG'), ('셔츠', 'NNG'), ('이', 'VCP'), ('라면', 'ECD'), ('담백', 'XR'), ('하', 'XSA'), ('고', 'ECE'), ('시크', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('연출', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('다', 'EFN'), ('.', 'SF'), ('여기', 'NP'), ('에', 'JKM'), ('드러나', 'VV'), ('ㄴ', 'ETD'), ('한쪽', 'NNG'), ('어깨', 'NNG'), ('위', 'NNG'), ('로', 'JKM'), ('찰랑대', 'VV'), ('는', 'ETD'), ('기다랗', 'VA'), ('ㄴ', 'ETD'), ('귀고리', 'NNG'), ('나', 'JC'), ('볼드', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('뱅글', 'MAG'), ('같', 'VA'), ('은', 'ETD'), ('JEWERLY', 'OL'), ('는', 'JX'), ('원', 'NNG'), ('숄더', 'NNG'), ('룩', 'UN'), ('의', 'JKG'), ('매력', 'NNG'), ('을', 'JKO'), ('배가', 'NNG'), ('시키', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('ㄹ', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('노출', 'NNG'), ('의', 'JKG'), ('계절', 'NNG'), ('이', 'JKS'), ('다가오', 'VV'), ('는', 'ETD'), ('이때', 'NNG'), (',', 'SP'), ('원', 'NNG'), ('숄더', 'NNG'), ('아이템', 'NNG'), ('으로', 'JKM'), ('업그레이드', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('관능미', 'NNG'), ('를', 'JKO'), ('어필', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('보', 'VXV'), ('는', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('어떻', 'VA'), ('ㄹ까', 'EFQ'), ('?', 'SF'), ("'", 'SS'), (']', 'SS'), ('"', 'SS'), (']', 'SS')]
# ------------------------------
# 996
# [('[', 'SS'), ("'", 'SS'), ('“', 'SS'), ('전', 'NNG'), ('아주', 'MAG'), ('어리', 'VA'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('부터', 'JX'), ('COUTURE', 'OL'), ('를', 'JKO'), ('꿈꾸', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('브르', 'UN'), ('타', 'VV'), ('아', 'ECS'), ('뉴', 'NNG'), ('지방', 'NNG'), ('의', 'JKG'), ('작', 'VA'), ('은', 'ETD'), ('마을', 'NNG'), ('에서', 'JKM'), ('자란', 'NNG'), ('기용', 'NNG'), ('은', 'JX'), ('어리', 'VA'), ('ㄴ', 'ETD'), ('시절', 'NNG'), ('우연히', 'MAG'), ('접하', 'VV'), ('ㄴ', 'ETD'), ('<', 'SS'), ('보', 'VV'), ('고', 'ECS'), ('>', 'SS'), ('를', 'JKO'), ('보', 'VV'), ('며', 'ECE'), ('패션', 'NNG'), ('을', 'JKO'), ('상상', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('당시', 'NNG'), ('는', 'JX'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), (',', 'SP'), ('지방시', 'NNG'), (',', 'SP'), ('피에르', 'NNG'), ('발맹', 'UN'), (',', 'SP'), ('DIOR', 'OL'), ('등', 'NNB'), ('프랑스', 'NNG'), ('패션', 'NNG'), ('의', 'JKG'), ('전성기', 'NNG'), ('.', 'SF'), ('“', 'SS'), ('오뜨', 'UN'), ('COUTURE', 'OL'), ('가', 'JKS'), ('무엇', 'NNG'), ('을', 'JKO'), ('뜻하', 'VV'), ('는지', 'ECS'), ('는', 'JX'), ('정확히', 'MAG'), ('알', 'VV'), ('ㄹ지', 'ECD'), ('못하', 'VX'), ('었', 'EPT'), ('지만', 'ECE'), (',', 'SP'), ('그', 'MDT'), ('곳', 'NNG'), ('에', 'JKM'), ('특별', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('있', 'VV'), ('을', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('란', 'ETD'), ('짐작', 'NNG'), ('은', 'JX'), ('하', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('었', 'EPT'), ('죠', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('파리', 'NNG'), ('에서', 'JKM'), ('패션', 'NNG'), ('을', 'JKO'), ('공부', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('그', 'NP'), ('가', 'JKS'), ('처음', 'NNG'), ('으로', 'JKM'), ('COUTURE', 'OL'), ('세상', 'NNG'), ('을', 'JKO'), ('만나', 'VV'), ('ㄴ', 'ETD'), ('곳', 'NNG'), ('은', 'JX'), ('위', 'NNG'), ('베', 'NNG'), ('르', 'NNG'), ('들', 'VX'), ('지방', 'NNG'), ('시의', 'NNG'), ('하우스', 'NNG'), ('.', 'SF'), ('그', 'MDT'), ('곳', 'NNG'), ('에서', 'JKM'), ('좋', 'VA'), ('은', 'ETD'), ('소재', 'NNG'), ('가', 'JKS'), ('여성', 'NNG'), ('에게', 'JKM'), ('선사', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('따스', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('기운', 'NNG'), ('을', 'JKO'), (',', 'SP'), ('완벽', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('실루엣', 'NNG'), ('이', 'JKS'), ('줄', 'VV'), ('는', 'ETD'), ('자신감', 'NNG'), ('을', 'JKO'), ('배우', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('하루', 'NNG'), ('하루', 'NNG'), ('가', 'JKS'), ('모두', 'MAG'), ('위대', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('수업', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('패션', 'NNG'), ('이', 'JKS'), ('완성', 'NNG'), ('되', 'XSV'), ('는', 'ETD'), ('모든', 'MDT'), ('과정', 'NNG'), ('을', 'JKO'), ('처음', 'NNG'), ('부터', 'JX'), ('끝', 'NNG'), ('까지', 'JX'), ('지켜보', 'VV'), ('았', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('그', 'MDT'), ('후', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('그', 'NP'), ('는', 'JX'), ('라크르', 'UN'), ('와', 'JKM'), (',', 'SP'), ('VALENTINO', 'OL'), ('로', 'JKM'), ('옮겨가', 'VV'), ('며', 'ECE'), ('COUTURE', 'OL'), ('작업', 'NNG'), ('만', 'JX'), ('고집', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('COUTURE', 'OL'), ('에', 'JKM'), ('는', 'JX'), ('패션', 'NNG'), ('의', 'JKG'), ('가장', 'MAG'), ('순수', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('면', 'NNG'), ('이', 'JKS'), ('남', 'VV'), ('아', 'ECD'), ('있', 'VXV'), ('습니다', 'EFN'), ('.', 'SF'), ('”', 'SS'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 997
# [('[', 'SS'), ("'", 'SS'), ('이쯤', 'NNG'), ('에서', 'JKM'), ('눈치채', 'VV'), ('었', 'EPT'), ('을', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('오늘날', 'NNG'), ('여성', 'NNG'), ('옵션', 'NNG'), ('이란', 'JX'), ('편의', 'NNG'), ('와', 'JC'), ('안전', 'NNG'), ('을', 'JKO'), ('고려', 'NNP'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('최신', 'NNG'), ('기술', 'NNG'), ('을', 'JKO'), ('포장', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('새', 'NNG'), ('롭', 'XSA'), ('ㄴ', 'ETD'), ('이름', 'NNG'), ('이', 'VCP'), ('란', 'ETD'), ('것', 'NNB'), ('을', 'JKO'), ('.', 'SF'), ('어쩌', 'VV'), ('면', 'ECE'), ('‘', 'SS'), ('여성', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('ㄴ', 'ETD'), ('차', 'NNG'), ('’', 'SS'), ('이', 'VCP'), ('라는', 'ETD'), ('말', 'NNG'), ('이', 'JKS'), ('사라지', 'VV'), ('는', 'ETD'), ('때', 'NNG'), ('가', 'JKS'), ('바로', 'MAG'), ('인간', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('ㄴ', 'ETD'), ('자동차', 'NNG'), ('기술', 'NNG'), ('이', 'JKS'), ('절정', 'NNG'), ('에', 'JKM'), ('이르', 'VV'), ('ㄴ', 'ETD'), ('세상', 'NNG'), ('이', 'VCP'), ('리라', 'EFN'), ('.', 'SF'), ('YVES', 'OL'), ('_', 'SW'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('이', 'JKS'), ('LE', 'OL'), ('_', 'SW'), ('SMOKING', 'OL'), ('턱시도', 'NNG'), ('로', 'JKM'), ('여성', 'NNG'), ('에', 'JKM'), ('대하', 'VV'), ('ㄴ', 'ETD'), ('사회적', 'NNG'), ('편견', 'NNG'), ('과', 'JC'), ('수트', 'NNG'), ('의', 'JKG'), ('개념', 'NNG'), ('을', 'JKO'), ('뒤바꾸', 'VV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('처럼', 'JKM'), (',', 'SP'), ('또', 'MAG'), ('한', 'MDN'), ('번', 'NNB'), ('자동차', 'NNG'), ('의', 'JKG'), ('뜨겁', 'VA'), ('ㄴ', 'ETD'), ('프러포즈', 'UN'), ('를', 'JKO'), ('기대', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('이유', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 998
# [('[', 'SS'), ("'", 'SS'), ('한편', 'NNG'), ('알', 'NNG'), ('레', 'NNG'), ('산', 'NNG'), ('드로', 'NNG'), ('미켈레', 'UN'), ('는', 'JX'), ('GUCCI', 'OL'), ('리조트', 'NNG'), ('컬렉션', 'NNG'), ('을', 'JKO'), ('DESIGN', 'OL'), ('하', 'VV'), ('며', 'ECE'), ('이', 'MDT'), ('레이블', 'NNG'), ('의', 'JKG'), ('자료실', 'NNG'), ('을', 'JKO'), ('뒤지', 'VV'), ('었', 'EPT'), ('고', 'ECE'), ('뱀', 'NNG'), ('부', 'NNG'), ('키', 'NNG'), ('트', 'VV'), ('ㄴ', 'ETD'), ('힐', 'NNG'), ('(', 'SS'), ('본래', 'NNG'), ('톰', 'UN'), ('포드', 'NNG'), ('시절', 'NNG'), ('에', 'JKM'), ('DESIGN', 'OL'), ('한', 'NNG'), (')', 'SS'), ('을', 'NNG'), ('응용', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('슈즈', 'NNG'), ('를', 'JKO'), ('선보이', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('2017', 'NR'), ('년', 'NNM'), ('을', 'JKO'), ('위하', 'VV'), ('어', 'ECS'), ('선', 'NNG'), ('메탈', 'NNG'), ('릭', 'UN'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('녹색', 'NNG'), ('슬링', 'NNG'), ('백', 'NNG'), ('에', 'JKM'), ('키', 'NNG'), ('트', 'VV'), ('ㄴ', 'ETD'), ('힐', 'NNG'), ('을', 'JKO'), ('부착', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('금색', 'NNG'), ('스파이크', 'NNG'), ('로', 'JKM'), ('구멍', 'NNG'), ('을', 'JKO'), ('뚫', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('그리고', 'MAG'), ('섬세', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('DIOR', 'OL'), ('뿐', 'JX'), ('아니', 'VCN'), ('라', 'ECD'), ('셀린', 'UN'), ('의', 'JKG'), ('피비', 'NNG'), ('파일', 'NNG'), ('로', 'JKM'), ('역시', 'MAG'), ('여름', 'NNG'), ('용', 'XSN'), ('으로', 'JKM'), ('노란색', 'NNG'), ('키', 'NNG'), ('트', 'VV'), ('ㄴ', 'ETD'), ('힐', 'NNG'), ('뮬', 'UN'), ('(', 'SS'), ('역시', 'MAG'), ('내', 'NNG'), ('쇼핑', 'NNG'), ('리스트', 'NNG'), ('에', 'JKM'), ('올리', 'VV'), ('었', 'EPT'), ('다', 'ECS'), (')', 'SS'), ('을', 'NNG'), ('DESIGN', 'OL'), ('하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('그리고', 'MAG'), ('프라다', 'NNG'), ('에서', 'JKM'), ('는', 'JX'), ('키', 'NNG'), ('트', 'VV'), ('ㄴ', 'ETD'), ('힐', 'NNG'), ('에', 'JKM'), ('시', 'NNG'), ('퀸', 'UN'), (',', 'SP'), ('비즈', 'NNG'), (',', 'SP'), ('정교', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('깃털', 'NNG'), ('을', 'JKO'), ('장식', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('계속', 'MAG'), ('열거', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('지만', 'ECE'), ('(', 'SS'), ('로', 'NNG'), ('에', 'JKM'), ('베', 'NNG'), (',', 'SP'), ('3.1', 'NR'), ('필', 'NNB'), ('립', 'NNG'), ('림', 'NNM'), (',', 'SP'), ('그리고', 'MAC'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('등등', 'NNB'), (')', 'SS'), ('당신', 'NP'), ('은', 'JX'), ('메시지', 'NNG'), ('를', 'JKO'), ('이해', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('을', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('키', 'NNG'), ('트', 'VV'), ('ㄴ', 'ETD'), ('힐', 'NNG'), ('이', 'JKS'), ('확실히', 'MAG'), ('돌아오', 'VV'), ('았', 'EPT'), ('다는', 'ETD'), ('것', 'NNB'), ('을', 'JKO'), ('말', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('그러', 'VV'), ('나', 'ECE'), ('이번', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('약간', 'MAG'), ('과시', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('고', 'ECE'), ('스타일링', 'NNG'), ('은', 'JX'), ('훨씬', 'MAG'), ('덜', 'MAG'), ('고지식', 'XR'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('그렇', 'VV'), ('다', 'EFN'), ('.', 'SF'), ('그것', 'NP'), ('은', 'JX'), ('우아', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('슈즈', 'NNG'), ('지만', 'XR'), ('우리', 'NP'), ('는', 'JX'), ('그것', 'NP'), ('을', 'JKO'), ('트레이닝', 'NNG'), ('팬츠', 'NNG'), ('나', 'JC'), ('헐렁', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('스웨트셔츠', 'UN'), ('에', 'JKM'), ('매치', 'NNG'), ('하', 'XSV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 999
# [('[', 'SS'), ("'", 'SS'), ('대서양', 'NNG'), ('건너', 'NNG'), ('파리', 'NNG'), ('<', 'SS'), ('보', 'VV'), ('고', 'ECS'), ('>', 'SS'), ('의', 'NNG'), ('엠', 'NNG'), ('마', 'NNG'), ('뉴', 'NNG'), ('엘', 'NNG'), ('알', 'NNG'), ('트', 'VV'), ('는', 'ETD'), ('좀더', 'MAG'), ('파격적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('진보', 'NNG'), ('를', 'JKO'), ('꿈꾸', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('3', 'NR'), ('월', 'NNG'), ('호', 'NNG'), ('커버', 'NNG'), ('모델', 'NNG'), ('로', 'JKM'), ('브라질', 'NNG'), ('출신', 'NNG'), ('의', 'JKG'), ('트랜스', 'NNG'), ('젠더', 'NNG'), ('모델', 'NNG'), ('발', 'NNG'), ('렌티', 'NNG'), ('나', 'JC'), ('삼', 'NNG'), ('파이', 'NNG'), ('우', 'NNG'), ('를', 'JKO'), ('점찍', 'VV'), ('은', 'ETD'), ('것', 'NNB'), ('.', 'SF'), ('편집장', 'NNG'), ('의', 'JKG'), ('글', 'NNG'), ('속', 'NNG'), ('에서', 'JKM'), ('알', 'NNG'), ('트', 'VV'), ('는', 'ETD'), ('삼', 'NNG'), ('파이', 'NNG'), ('우가', 'NNG'), ('런던', 'NNG'), ('스튜디오', 'NNG'), ('에', 'JKM'), ('도착', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('을', 'ETD'), ('때', 'NNG'), ('의', 'JKG'), ('모습', 'NNG'), ('이', 'JKS'), ('프랑스', 'NNG'), ('<', 'SS'), ('보', 'VV'), ('고', 'ECS'), ('>', 'SS'), ('가', 'NNG'), ('지향', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('아름다움', 'NNG'), ('그대로', 'MAG'), ('이', 'VV'), ('었', 'EPT'), ('다고', 'EFN'), ('밝히', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('그녀', 'NP'), ('가', 'JKS'), ('지', 'NNG'), ('젤', 'NNG'), (',', 'SP'), ('다리아', 'NNG'), (',', 'SP'), ('HEDI', 'OL'), ('혹은', 'MAG'), ('안', 'MAG'), ('나오', 'VV'), ('아', 'ECS'), ('다른', 'MDT'), ('건', 'NNM'), ('없', 'VA'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('단', 'MAG'), ('하나', 'NNG'), ('그녀', 'NP'), ('가', 'JKS'), ('소년', 'NNG'), ('으로', 'JKM'), ('태어나', 'VV'), ('었', 'EPT'), ('다는', 'ETD'), ('점', 'NNG'), ('을', 'JKO'), ('제외', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('말', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('SAINT', 'OL'), ('_', 'SW'), ('LAURENT', 'OL'), ('의', 'NNG'), ('골드', 'NNG'), ('라', 'ECD'), ('메', 'NNG'), ('블라우스', 'NNG'), ('를', 'JKO'), ('입', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('삼', 'NNG'), ('파이', 'NNG'), ('우', 'NNG'), ('의', 'JKG'), ('모습', 'NNG'), ('은', 'JX'), ('톱', 'NNG'), ('모델', 'NNG'), ('과', 'JKM'), ('다르', 'VV'), ('ㄹ', 'ETD'), ('바', 'NNB'), ('없', 'VA'), ('다', 'EFN'), ('.', 'SF'), ('알', 'NNM'), ('트', 'VV'), ('는', 'ETD'), ('이러하', 'VA'), ('ㄴ', 'ETD'), ('시도', 'NNG'), ('가', 'JKS'), ('앞', 'NNG'), ('으로', 'JKM'), ('나아가', 'VV'), ('는', 'ETD'), ('발걸음', 'NNG'), ('중', 'NNB'), ('하나', 'NR'), ('일', 'NNM'), ('뿐', 'NNB'), ('이', 'VCP'), ('라', 'ECD'), ('덧붙이', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('“', 'SS'), ('트랜스', 'NNG'), ('젠더', 'NNG'), ('여성', 'NNG'), ('이', 'JKS'), ('잡지', 'NNG'), ('에', 'JKM'), ('등장', 'NNG'), ('하', 'XSV'), ('어도', 'ECD'), ('그것', 'NP'), ('에', 'JKM'), ('대하', 'VV'), ('어', 'ECS'), ('따로', 'MAG'), ('기사', 'NNG'), ('를', 'JKO'), ('적', 'VV'), ('을', 'ETD'), ('필요', 'NNG'), ('가', 'JKS'), ('없', 'VA'), ('을', 'ETD'), ('때', 'NNG'), (',', 'SP'), ('우리', 'NP'), ('는', 'JX'), ('전투', 'NNG'), ('에서', 'JKM'), ('승리', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('음', 'ETN'), ('을', 'JKO'), ('알', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('을', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('”', 'SS'), ("'", 'SS'), (']', 'SS')]
# ------------------------------

# %%
slsl[556]
# Out:
# '[\'"↑사진 = 프랑소아즈-HENRI PINAULT 케어링 그룹 회장이 피렌체 시장 다리오 나르델라로 부터 피렌체 시 최고 영예인 \\\'피오리노 도로\\\' 상를 받고 있다.", \\\'지난 1월 7일(현지시간) 피렌체남성복 박람회인 피티 워모 개막일에 뜻밖의 행사가 열렸다. 피렌체 중심부의 포르테자 다 바소에서 남성복 행사가 시작되는 동안, 프랑스 기업인 프랑소아즈-HENRI PINAULT 회장에게 경의를 표하는 작은 규모의 시상식이 피렌체 시청사에서 열렸다.\\\', "피렌체 시는 토스카나주 지역에 대한 케어링 그룹의 광범위한 투자에 대한 답례로 시에서 주는 가장 높은 영예인 \\\'피오리노 도로(FIORINO D\\\'ORO:플로린 금화)\\\'를 수여했다.", \\\'다리오 나르델라 피렌체 시장은 케어링 그룹과 피렌체와의 오랜 인연을 언급하며 "우리 지역과 공동체의 이익을 위해 실행된 성장 이니셔티브와 투자에 대해 케어링 그룹의 프랑소아즈-HENRI PINAULT 회장에게 특히 감사를 표했다"고 말했다. 현재 케어링그룹은 피렌체 지역에 여러 공장을 운영하고 있는데, 특히 GUCCI와 SAINT_LAURENT의 가죽 제품 전문 공장을 운영하고 있다.\', \'또한 다리오 나르델라 시장은 SAINT_LAURENT이 피렌체 외곽 지역 마을인 스칸디치에 대규모 부동산 개발을 시작할 것이라는 것을 강조했다. 이 곳에는 이미 브랜드가 공장을 가지고 있으며, 이전에 재무부 사무실이 입주했던 빌딩 안에 새로운 허브를 만들기 위해 모든 생산 시설을 한데 모을 계획이다.\']'

# %%
# len(slsl)

# %%
# print(morph)

# %%
# for i in range(len(slsl[0:5])) :
#     print(slsl[i])

# %%
# print(sentences_tag)
# print(len(sentences_tag))
# print('\n'*3)

# %%
# 명사 혹은 형용사인 품사만 선별해 리스트에 담기
noun_adj_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['NNG','NNP','VA', 'VV', 'OL']:
            noun_adj_list.append(word)

# %%
from collections import Counter

# %%
# noun_adj_list

# %%
# # 별된 품사별 빈도수 계산 & 상위 빈도 100위 까지 출력
# counts = Counter(noun_adj_list)
# print(counts.most_common(100))

# %%
# 명사만
noun_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['NNG','NNP', 'OL']:
            noun_list.append(word)
# noun_list

# %%
# counts_noun = Counter(noun_list)
# print(counts_noun.most_common(100))

# %% [markdown]
# ## Stopwords

# %%
stpwds = pd.read_csv('./stopwords.csv' , sep=',', encoding='utf-8', header=None)
# stpwds

# %%
print(type(stpwds))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 리스트로 변환
stpwds_l = stpwds[0].tolist()

# %%
# stpwds_l

# %%
type(stpwds_l)
# Out:
# list

# %%
# stpwds_l = []
add = ['위하', '선보이', '가격', '가격 미정', '미정', '지금', 'BY', 'N', '있', '없', '지나', '만들', '말하', '입', '보', 
       '되','선보이', '같', '대하', '등장', '사람', '받', '많', '더하', '최근', '보여주', '후', '르', '링', '리', '르', '라', 
      '레', '티', '크', '디', '통하', '전', '알', '슬', '대', '말', '잇', '타', '보이', '커', '베', 'S', '카', '키', '시', '주',
      '푸', '안', '그러', '늘', '비', '바', '위', '인', '이자', '노', '미', '테', '은', '마', '앤', '그렇', '부', '앞', '고', '코', 
       '장', '터', '쓰', '어떻', '사실', '사이', '길', '떠나', 
       'VACCARELLO', 'SLIMANE', 'SAINT', 'YVES']
for words in add :
    stpwds_l.append(words)
# stpwds_l

# %% [markdown]
# ### 불용어는 형태소분석 결과에서도 빼주기

# %%
# 불용어 제외 리스트
noun_adj_list_stp= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if word not in stpwds_l:
            if tag in ['NNG','NNP','VA', 'VV', 'OL']:
                noun_adj_list_stp.append(word)

# %%
# 블용어 제외 후 순위
counts_stp = Counter(noun_adj_list_stp)
print(counts_stp.most_common(100))
# Out:
# [('LAURENT', 2302), ('브랜드', 532), ('디자이너', 420), ('ANTHONY', 371), ('쇼', 370), ('HEDI', 348), ('DIOR', 343), ('드레스', 340), ('소재', 316), ('스타일', 316), ('모델', 298), ('여성', 288), ('파리', 284), ('팬츠', 269), ('장식', 254), ('GUCCI', 245), ('DESIGN', 244), ('재킷', 234), ('제품', 215), ('하우스', 214), ('컬러', 204), ('옷', 187), ('가죽', 186), ('부츠', 178), ('그룹', 176), ('디렉터', 176), ('CELINE', 164), ('새롭', 162), ('블랙', 154), ('아이템', 154), ('슈트', 153), ('BALENCIAGA', 150), ('프랑스', 144), ('럭셔리', 141), ('CREATIVE', 133), ('COUTURE', 131), ('코트', 130), ('생각', 130), ('데님', 129), ('로고', 128), ('셔츠', 124), ('여름', 122), ('영감', 121), ('슈즈', 119), ('봄', 118), ('좋', 116), ('선글라스', 114), ('세계', 114), ('캠페인', 114), ('실루엣', 113), ('영화', 109), ('새', 108), ('시대', 105), ('어깨', 104), ('전시', 104), ('사랑', 101), ('톱', 99), ('속', 97), ('시절', 97), ('라인', 96), ('광고', 96), ('수트', 96), ('미니', 95), ('패션계', 95), ('뷰티', 94), ('남성복', 94), ('즐기', 93), ('하이', 90), ('스커트', 90), ('이름', 90), ('완성', 90), ('트렌드', 90), ('시크', 90), ('패턴', 89), ('프라다', 88), ('의상', 88), ('자리', 86), ('열리', 86), ('숄더', 85), ('분위기', 85), ('클래식', 84), ('무드', 84), ('파워', 84), ('패션쇼', 84), ('화이트', 82), ('표현', 82), ('완벽', 82), ('작품', 81), ('이미지', 81), ('백', 79), ('다르', 78), ('뉴욕', 78), ('프린트', 77), ('선택', 77), ('위크', 77), ('피', 76), ('스타', 76), ('처음', 76), ('데뷔', 76), ('가을', 75)]

# %% [markdown]
# ## WordCloud

# %%
# https://khann.tistory.com/60

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = ' '.join(noun_adj_list)
# text

# %%
wordcloud = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-114-b6c22eaee40a> in <module>()
# ----> 1 wordcloud = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text)
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     612         """
#     613         words = self.process_text(text)
# --> 614         self.generate_from_frequencies(words)
#     615         return self
#     616
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     445             else:
#     446                 self.generate_from_frequencies(dict(frequencies[:2]),
# --> 447                                                max_font_size=self.height)
#     448                 # find font sizes
#     449                 sizes = [x[1] for x in self.layout_]
#
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
#     498                 transposed_font = ImageFont.TransposedFont(
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     834
#     835     try:
# --> 836         return freetype(font)
#     837     except OSError:
#     838         if not isPath(font):
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFont.py in freetype(font)
#     831
#     832     def freetype(font):
# --> 833         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     834
#     835     try:
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     192                     return
#     193             self.font = core.getfont(
# --> 194                 font, size, index, encoding, layout_engine=layout_engine
#     195             )
#     196         else:
#
# OSError: cannot open resource

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %%
# 블용어 제외 후 순위
counts_stp = Counter(noun_adj_list_stp)
print(counts_stp.most_common(100))

# %% [markdown]
# ### top100 wordcloud before deleting other brands

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top100 = counts_stp.most_common(100)
top100_word = []
for word, tag in top100 :
    top100_word.append(word)

# %%
text_b = ' '.join(top100_word)
text_b

# %%
wordcloud100 = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text_b)
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud100, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %% [markdown]
# ### top100 wordcloud after deleting other brands

# %%
stpwds_a = stpwds_l
brands = ['프라다', '샤넬', 'GUCCI', 'BALENCIAGA', 
          'DIOR', 'CELINE']
for words in brands :
    stpwds_a.append(words)
# stpwds_b

# %%
# 불용어 제외 리스트
noun_adj_list_stp= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if word not in stpwds_a:
            if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
                noun_adj_list_stp.append(word)
# noun_adj_list_stp

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top100 = counts_stp.most_common(100)
top100_word = []
for word, tag in top100 :
    top100_word.append(word)
# top100_word

# %%
text_a = ' '.join(top100_word)
text_a

# %%
wordcloud100 = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text_a)
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud100, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %%
top100_word

# %%
len(top100_word)

# %% [markdown]
# ### TOP50만 추출

# %%
common = ['패션', '컬렉션', '시즌', '사진', '연출', '모습', '매치', 
          '시작', '룩', '다양']

# %%
# 불용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top50 = counts_stp.most_common(50)
top50_word = []
for word, tag in top50 :
    top50_word.append(word)

# %%
top50_word
# Out:
# ['LAURENT',
#  '브랜드',
#  '디자이너',
#  'ANTHONY',
#  '쇼',
#  'HEDI',
#  'DIOR',
#  '드레스',
#  '소재',
#  '스타일',
#  '모델',
#  '여성',
#  '파리',
#  '팬츠',
#  '장식',
#  'GUCCI',
#  'DESIGN',
#  '재킷',
#  '제품',
#  '하우스',
#  '컬러',
#  '옷',
#  '가죽',
#  '부츠',
#  '그룹',
#  '디렉터',
#  'CELINE',
#  '새롭',
#  '블랙',
#  '아이템',
#  '슈트',
#  'BALENCIAGA',
#  '프랑스',
#  '럭셔리',
#  'CREATIVE',
#  'COUTURE',
#  '코트',
#  '생각',
#  '데님',
#  '로고',
#  '셔츠',
#  '여름',
#  '영감',
#  '슈즈',
#  '봄',
#  '좋',
#  '선글라스',
#  '세계',
#  '캠페인',
#  '실루엣']

# %% [markdown]
# ### magazine_sl에 tag 컬럼 생성하기

# %%
len(sentences_tag)

# %%
print(magazine_sl['word_laurent'][0])
print(sentences_tag[0])

# %%
# 불용어 제외 리스트
ADFN = []
for sentence1 in sentences_tag:
    ADFNT = [] 
    for word, tag in sentence1:
        
        if word in top100_word:
           
            if tag in ['NNG','NNP','VA', 'VV', 'OL']:
                ADFNT.append(word)
    ADFN.append(ADFNT)

# %%
len(ADFN)

# %%
len(sentences_tag)

# %%
type(sentences_tag)

# %%
magazine_sl['sentences_tag'] = sentences_tag
magazine_sl

# %%
magazine_sl['ADFN'] = ADFN
magazine_sl

# %%
magazine_sl.to_csv('./data/SL/magazine_sl.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_sl = pd.read_csv('./data/SL/magazine_sl.csv' , sep='|', encoding='utf-8')
