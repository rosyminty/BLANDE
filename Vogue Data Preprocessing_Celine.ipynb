# %%
import pandas as pd
import numpy as np

# %%
V_Ce = pd.read_csv('./data/Vogue_Celine_ccc.csv' , sep='|', encoding='utf-8')
V_Ce
# Out:
#                                                 title        date  \
# 0                            셀린느 글로벌 앰배서더가 된 블랙핑크 리사!  2020.09.23
# 1                     인 더 백 : Burberry’s DK88 메이킹 스토리  2017.08.09
# 2                                          삭발에 빠진 여자들  2017.03.12
# 3                                   오뜨 꾸뛰르 쇼에서 만난 스타들  2017.01.25
# 4                                  2017 S/S Trends 11  2017.01.09
# 5                      2017 S/S 밀란 패션위크 – Day 3, 4, 5  2016.09.27
# 6   수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 셀린느: 현대 여성을 위한 ...  2016.03.06
# 7       수지 멘키스가 품평한 2016 F/W 뉴욕 패션위크 프로엔자 스쿨러: 통제와 해방  2016.02.18
# 8                                   촛불을 켠 듯 환한 피부의 비밀  2016.01.29
# 9                                                상속녀들  2015.12.11
# 10                                       Silent Scent  2015.10.10
# 11                                 강인해 보이지만 여린 블랙 퍼퓸들  2015.09.21
# 12                               V&A 미술관의 <기쁨과 고통> 전시  2015.08.18
# ...

# %%
# magazine column 추가
V_Ce['magazine'] = 'V'
V_Ce
# Out:
#                                                 title        date  \
# 0                            셀린느 글로벌 앰배서더가 된 블랙핑크 리사!  2020.09.23
# 1                     인 더 백 : Burberry’s DK88 메이킹 스토리  2017.08.09
# 2                                          삭발에 빠진 여자들  2017.03.12
# 3                                   오뜨 꾸뛰르 쇼에서 만난 스타들  2017.01.25
# 4                                  2017 S/S Trends 11  2017.01.09
# 5                      2017 S/S 밀란 패션위크 – Day 3, 4, 5  2016.09.27
# 6   수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 셀린느: 현대 여성을 위한 ...  2016.03.06
# 7       수지 멘키스가 품평한 2016 F/W 뉴욕 패션위크 프로엔자 스쿨러: 통제와 해방  2016.02.18
# 8                                   촛불을 켠 듯 환한 피부의 비밀  2016.01.29
# 9                                                상속녀들  2015.12.11
# 10                                       Silent Scent  2015.10.10
# 11                                 강인해 보이지만 여린 블랙 퍼퓸들  2015.09.21
# 12                               V&A 미술관의 <기쁨과 고통> 전시  2015.08.18
# ...

# %%
# Brand -> brand
V_Ce = V_Ce.rename({'Brand' : 'brand'}, axis='columns')
V_Ce
# Out:
#                                                 title        date  \
# 0                            셀린느 글로벌 앰배서더가 된 블랙핑크 리사!  2020.09.23
# 1                     인 더 백 : Burberry’s DK88 메이킹 스토리  2017.08.09
# 2                                          삭발에 빠진 여자들  2017.03.12
# 3                                   오뜨 꾸뛰르 쇼에서 만난 스타들  2017.01.25
# 4                                  2017 S/S Trends 11  2017.01.09
# 5                      2017 S/S 밀란 패션위크 – Day 3, 4, 5  2016.09.27
# 6   수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 셀린느: 현대 여성을 위한 ...  2016.03.06
# 7       수지 멘키스가 품평한 2016 F/W 뉴욕 패션위크 프로엔자 스쿨러: 통제와 해방  2016.02.18
# 8                                   촛불을 켠 듯 환한 피부의 비밀  2016.01.29
# 9                                                상속녀들  2015.12.11
# 10                                       Silent Scent  2015.10.10
# 11                                 강인해 보이지만 여린 블랙 퍼퓸들  2015.09.21
# 12                               V&A 미술관의 <기쁨과 고통> 전시  2015.08.18
# ...

# %%
# column 순서
V_Ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
# Out:
#    magazine brand     category  \
# 0         V    Ce      Fashion
# 1         V    Ce  ADVERTORIAL
# 2         V    Ce       Beauty
# 3         V    Ce      Fashion
# 4         V    Ce      Fashion
# 5         V    Ce      Fashion
# 6         V    Ce      Fashion
# 7         V    Ce      Fashion
# 8         V    Ce       Beauty
# 9         V    Ce      Fashion
# 10        V    Ce       Beauty
# 11        V    Ce       Beauty
# 12        V    Ce      Fashion
# 13        V    Ce      Fashion
# 14        V    Ce      Fashion
# 15        V    Ce      Fashion
# 16        V    Ce      Fashion
#
#                                                 title  \
# 0                            셀린느 글로벌 앰배서더가 된 블랙핑크 리사!
# 1                     인 더 백 : Burberry’s DK88 메이킹 스토리
# 2                                          삭발에 빠진 여자들
# 3                                   오뜨 꾸뛰르 쇼에서 만난 스타들
# 4                                  2017 S/S Trends 11
# 5                      2017 S/S 밀란 패션위크 – Day 3, 4, 5
# ...

# %%
V_Ce.to_csv('./data/Vogue_Celine.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
V_Ce = pd.read_csv('./data/Vogue_Celine.csv' , sep='|', encoding='utf-8')
V_Ce
# Out:
#                                                 title        date  \
# 0                            셀린느 글로벌 앰배서더가 된 블랙핑크 리사!  2020.09.23
# 1                     인 더 백 : Burberry’s DK88 메이킹 스토리  2017.08.09
# 2                                          삭발에 빠진 여자들  2017.03.12
# 3                                   오뜨 꾸뛰르 쇼에서 만난 스타들  2017.01.25
# 4                                  2017 S/S Trends 11  2017.01.09
# 5                      2017 S/S 밀란 패션위크 – Day 3, 4, 5  2016.09.27
# 6   수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 셀린느: 현대 여성을 위한 ...  2016.03.06
# 7       수지 멘키스가 품평한 2016 F/W 뉴욕 패션위크 프로엔자 스쿨러: 통제와 해방  2016.02.18
# 8                                   촛불을 켠 듯 환한 피부의 비밀  2016.01.29
# 9                                                상속녀들  2015.12.11
# 10                                       Silent Scent  2015.10.10
# 11                                 강인해 보이지만 여린 블랙 퍼퓸들  2015.09.21
# 12                               V&A 미술관의 <기쁨과 고통> 전시  2015.08.18
# ...
