# %%
import pandas as pd
import numpy as np

# %%
magazine_r = pd.read_csv('./data/bp/magazine_r.csv' , sep='|', encoding='utf-8')
magazine_r
# Out:
#    magazine brand     category                                          title  \
# 0    Allure     R       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 1         B     R      FASHION                                잘 고른 여름 원피스 한 벌
# 2         B     R    CELEBRITY                            난리 난 블랙핑크의 네일아트, 왜?
# 3         B     R      FASHION                      방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 4         B     R      FASHION                            무더위엔 원피스 한 벌이면 충분해!
# ..      ...   ...          ...                                            ...
# 83        W     R  FASHION, 화보                      Je t’aime ROSE (로제) Vol.1
# 84        W     R  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 85        W     R  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 86        W     R  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
# 87        W     R  W HOT ISSUE                          K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                                  link         date  \
# 0   http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
# 1       https://www.harpersbazaar.co.kr/article/47843   2020.07.24
# 2       https://www.harpersbazaar.co.kr/article/47719   2020.07.17
# 3       https://www.harpersbazaar.co.kr/article/41976   2019.09.04
# 4       https://www.harpersbazaar.co.kr/article/40532   2019.08.09
# ..                                                ...          ...
# 83  http://www.wkorea.com/2020/03/15/je-taime-rose...   2020-03-15
# 84  http://www.wkorea.com/2020/08/24/%eb%b8%94%eb%...   2020-08-24
# 85  http://www.wkorea.com/2020/07/20/%eb%b8%94%eb%...   2020-07-20
# 86  http://www.wkorea.com/2020/06/26/%eb%b8%94%eb%...   2020-06-26
# 87  http://www.wkorea.com/2020/03/24/k%ed%8c%9d-%e...   2020-03-24
#
#                                              contents  title_brand  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...            0
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...            0
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...            0
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...            0
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...            0
# ..                                                ...          ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...            1
# 84                                                 []            1
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...            1
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...            1
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...            1
#
#                                             word_rose
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...
# ..                                                ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...
# 84                                                 []
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...
#
# [88 rows x 9 columns]

# %% [markdown]
# ## Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
roro = []
for line in magazine_r['word_rose']:
    roro.append(line)

# %%
type(roro)
# Out:
# list

# %% [markdown]
# ### 외국어 안잘리게 영어로

# %%
FN = []
for idx in range(len(roro)) :
    if '마리아 그라치아 치우리' in roro[idx] :
        roro[idx] = roro[idx].replace('마리아 그라치아 치우리' , 'Maria Grazia Chiuri')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(roro)) :
    if '블랙핑크' in roro[idx] :
        roro[idx] = roro[idx].replace('블랙핑크' , 'BLACKPINK')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 57

# %%
FN = []
for idx in range(len(roro)) :
    if '디올' in roro[idx] :
        roro[idx] = roro[idx].replace('디올' , 'DIOR')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 3

# %%
FN = []
for idx in range(len(roro)) :
    if '리사' in roro[idx] :
        roro[idx] = roro[idx].replace('리사' , 'LISA')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 32

# %%
FN = []
for idx in range(len(roro)) :
    if '엘르' in roro[idx] :
        roro[idx] = roro[idx].replace('엘르' , 'ELLE')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 7

# %%
FN = []
for idx in range(len(roro)) :
    if '아이코닉' in roro[idx] :
        roro[idx] = roro[idx].replace('아이코닉' , 'ICONIC')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 2

# %%
FN = []
for idx in range(len(roro)) :
    if '파샤 드 까르띠에' in roro[idx] :
        roro[idx] = roro[idx].replace('파샤 드 까르띠에' , 'Pasha de Cartier')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(roro)) :
    if '레오퍼드' in roro[idx] :
        roro[idx] = roro[idx].replace('레오퍼드' , 'Leopard')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(roro)) :
    if '스틸레토' in roro[idx] :
        roro[idx] = roro[idx].replace('스틸레토' , 'Stiletto')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(roro)) :
    if '레전드' in roro[idx] :
        roro[idx] = roro[idx].replace('레전드' , 'LEGEND')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(roro)) :
    if '까르띠에' in roro[idx] :
        roro[idx] = roro[idx].replace('까르띠에' , 'Cartier')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 0

# %%
FN = []
for idx in range(len(roro)) :
    if '엔도르핀' in roro[idx] :
        roro[idx] = roro[idx].replace('엔도르핀' , 'Endorphins')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 1

# %%
FN = []
for idx in range(len(roro)) :
    if '셀레나' in roro[idx] :
        roro[idx] = roro[idx].replace('셀레나' , 'Selena')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 3

# %%
FN = []
for idx in range(len(roro)) :
    if '코첼라' in roro[idx] :
        roro[idx] = roro[idx].replace('코첼라' , 'Coachella')
        FN.append(idx)
#         print(idx, roro[idx])
print(len(FN))
# Out:
# 2

# %% [markdown]
# ### 영문 다 대문자로 변환

# %%
for idx in range(len(roro)) :
    roro[idx] = roro[idx].upper()
#     print(slsl[idx])

# %% [markdown]
# ### 각 문장별로 형태소 구분하기

# %%
sentences_tag = []
for i in range(len(roro)) :
# for sentence in didi:
#     print(i)
    morph = kkma.pos(roro[i])
    sentences_tag.append(morph)
#     print(morph)
#     print('-'*30)

# %% [markdown]
# ### 형태소 구분 검토용으로 일부 진행

# %%
len(roro)
# Out:
# 88

# %%
# TEST
# 각 문장별로 형태소 구분하기
sentences_tagT = []
for i in range(len(roro)) :
# for sentence in didi:
    print(i)
    morph = kkma.pos(roro[i])
    sentences_tagT.append(morph)
    print(morph)
    print('-'*30)
# Out:
# 0
# [('[', 'SS'), ("'", 'SS'), ('32', 'NR'), ('시간', 'NNG'), ('만', 'JX'), ('에', 'JC'), ('1', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('돌파', 'NNG'), ('!', 'SF'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('‘', 'SS'), ('HOW', 'OL'), ('YOU', 'OL'), ('LIKE', 'OL'), ('THAT', 'OL'), ('’', 'SS'), ('뮤직비디오', 'NNG'), ('.', 'SF'), ('여기', 'NP'), ('에', 'JKM'), ('숨기', 'VV'), ('어', 'ECS'), ('지', 'VXV'), ('ㄴ', 'ETD'), ('메이크업', 'NNG'), ('디테일', 'NNG'), ('이', 'JKS'), ('가득', 'MAG'), ('하다', 'NNP'), ('는', 'JX'), ('사실', 'NNG'), ('!', 'SF'), ('알', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('나요', 'EFQ'), ('?', 'SF'), ('BLACKPINK', 'OL'), ('메이크업', 'NNG'), ('담당', 'NNG'), ('우선', 'NNG'), ('이명선', 'NNG'), ('원장', 'NNG'), ('이', 'JKS'), ('한', 'MDN'), ('프레임', 'NNG'), (',', 'SP'), ('한', 'MDN'), ('프레임', 'NNG'), ('놓치', 'VV'), ('기', 'ETN'), ('쉽', 'VA'), ('ㄴ', 'ETD'), ('디테일', 'NNG'), ('을', 'JKO'), ('모두', 'MAG'), ('알리', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('\\', 'SW'), ('NQ', 'OL'), ('.', 'SF'), ('이', 'NR'), ('번', 'NNM'), ('뮤직비디오', 'NNG'), ('메이크업', 'NNG'), ('룩', 'UN'), ('의', 'JKG'), ('메인', 'NNG'), ('컨셉', 'UN'), ('은', 'JX'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가요', 'EFQ'), ('?', 'SF'), ('\\', 'SW'), ('N', 'OL'), ('강렬', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), (',', 'SP'), ('오리엔탈', 'NNG'), ('적인', 'NNG'), (',', 'SP'), ('그리고', 'MAC'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('‘', 'SS'), ('블랙', 'NNG'), ('’', 'SS'), ('스', 'VV'), ('러', 'ECD'), ('움', 'NNG'), ('\\', 'SW'), ('N', 'OL'), ('의상', 'NNG'), ('이나', 'JC'), ('헤어', 'NNG'), ('그리', 'VV'), ('고', 'ECE'), ('무대', 'NNG'), ('세트', 'NNG'), ('에서', 'JKM'), ('컬러', 'NNG'), ('가', 'JKS'), ('많이', 'MAG'), ('들어가', 'VV'), ('고', 'ECE'), ('화려', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKM'), ('메이크업', 'NNG'), ('에서', 'JKM'), ('는', 'JX'), ('컬러', 'NNG'), ('포인트', 'NNG'), ('를', 'JKO'), ('최대한', 'NNG'), ('빼', 'VV'), ('고', 'ECE'), ('진행', 'NNG'), ('을', 'JKO'), ('하', 'VV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('그래서', 'MAG'), ('제니', 'MAG'), ('의', 'JKG'), ('눈물', 'NNG'), ('글리', 'MAG'), ('털', 'VV'), ('나', 'ECE'), ('커다랗', 'VA'), ('ㄴ', 'ETD'), ('비즈', 'NNG'), ('등', 'NNB'), ('크', 'VA'), ('고', 'ECE'), ('무겁', 'VA'), ('ㄴ', 'ETD'), ('포인트', 'NNG'), ('를', 'JKO'), ('하나', 'NR'), ('만', 'JX'), ('주고', 'NNG'), ('점', 'NNG'), ('이나', 'JC'), ('선', 'NNG'), (',', 'SP'), ('형태', 'NNG'), ('에', 'JKM'), ('집중', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('메이크업', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('완성', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('같', 'VA'), ('아요', 'EFN'), ('.', 'SF'), ('\\', 'SW'), ('NQ', 'OL'), ('.', 'SF'), ('화제', 'NNG'), ('의', 'JKG'), ('한복', 'NNG'), ('씬', 'NNG'), ('의', 'JKG'), ('지수', 'NNG'), ('점', 'NNG'), ('메이크업', 'NNG'), ('은', 'JX'), ('누', 'VV'), ('구', 'ECE'), ('아이디어', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('나요', 'EFQ'), ('?', 'SF'), ('\\', 'SW'), ('N', 'OL'), ('사실', 'NNG'), ('이건', 'NNP'), ('지수', 'NNG'), ('본인', 'NNG'), ('의', 'JKG'), ('아이디어', 'NNG'), ('이', 'VCP'), ('에요', 'EFN'), ('.', 'SF'), ('뮤직비디오', 'NNG'), ('메이크업', 'NNG'), ('아이디어', 'NNG'), ('라', 'NNG'), ('기', 'NNG'), ('보', 'NNG'), ('단', 'NNG'), ('티', 'NNG'), ('저', 'MDT'), ('촬영', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('하', 'VV'), ('ㄴ', 'ETD'), ('메이크업', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'ECE'), ('너무', 'MAG'), ('마음', 'NNG'), ('에', 'JKM'), ('듣', 'VV'), ('어', 'ECD'), ('하', 'VV'), ('어서', 'ECD'), ('이것', 'NP'), ('이', 'JKS'), ('꼭', 'MAG'), ('뮤직', 'NNG'), ('비디오', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('들어가', 'VV'), ('었', 'EPT'), ('으면', 'ECD'), ('좋', 'VA'), ('겠', 'EPT'), ('다고', 'EFN'), ('하', 'VV'), ('더', 'EPT'), ('라고요', 'EFN'), ('.', 'SF'), ('그래서', 'MAG'), ('어디', 'NP'), ('에', 'JKM'), ('넣', 'VV'), ('으면', 'ECD'), ('좋', 'VA'), ('을지', 'ECS'), ('찾', 'VV'), ('다가', 'ECD'), ('한복', 'NNG'), ('과', 'JC'), ('무드', 'NNG'), ('가', 'JKS'), ('맞', 'VV'), ('을', 'ETD'), ('거', 'NNB'), ('같', 'VA'), ('아', 'ECD'), ('적용', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('한복', 'NNG'), ('이', 'JKS'), ('워낙에', 'MAG'), ('화려', 'NNG'), ('하', 'XSV'), ('어서', 'ECD'), ('좀', 'MA ...
# ------------------------------
# 1
# [('[', 'SS'), ("'", 'SS'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('시폰', 'NNG'), ('드레스', 'NNG'), ('를', 'JKO'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('처럼', 'JKM'), ('쿨하', 'VA'), ('게', 'ECD'), ('연출', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('싶', 'VXA'), ('다면', 'ECE'), ('?', 'SF'), ('플라워', 'NNG'), ('패턴', 'NNG'), ('의', 'JKG'), ('미니', 'NNG'), ('드레스', 'NNG'), ('를', 'JKO'), ('선택', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('로제', 'NNG'), ('.', 'SF'), ('셔링', 'NNG'), ('디테일', 'NNG'), ('이', 'JKS'), ('더', 'MAG'), ('해진', 'NNG'), ('슬립', 'NNG'), ('드레스', 'NNG'), ('로', 'JKM'), ('여성', 'NNG'), ('스럽', 'XSA'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('더하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('여기', 'NP'), ('에', 'JKM'), ('조개', 'NNG'), ('디', 'NNG'), ('테', 'NNM'), ('일의', 'NNG'), ('스트랩', 'NNG'), ('샌들', 'NNG'), ('로', 'JKM'), ('바캉스', 'NNG'), ('룩', 'UN'), ('에', 'JKM'), ('포인트', 'NNG'), ('를', 'JKO'), ('주', 'VV'), ('었', 'EPT'), ('는데', 'ECD'), ('보', 'VV'), ('ㄹ', 'ETD'), ('캡', 'NNG'), ('을', 'JKO'), ('착용', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('페미닌', 'NNG'), ('한', 'MDN'), ('룩', 'UN'), ('을', 'JKO'), ('중화', 'NNG'), ('시키', 'XSV'), ('어', 'ECS'), ('주', 'VXV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('로제', 'NNG'), ('스타일', 'NNG'), ('!', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 2
# [('[', 'SS'), ("'", 'SS'), ('번지', 'VV'), ('ㅁ', 'ETN'), ('기법', 'NNG'), ('을', 'JKO'), ('활용', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('변형', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('레오파드', 'NNP'), ('패턴', 'NNG'), ('을', 'JKO'), ('선보이', 'VV'), ('ㄴ', 'ETD'), ('로제', 'NNG'), ('.', 'SF'), ('화이트', 'NNG'), ('베이스', 'NNG'), ('위', 'NNG'), ('에', 'JKM'), ('브라운', 'NNG'), ('컬러', 'NNG'), ('로', 'JKM'), ('포인트', 'NNG'), ('를', 'JKO'), ('주', 'VV'), ('ㄴ', 'ETD'), ('뒤', 'NNG'), (',', 'SP'), ('무', 'XPN'), ('광', 'NNG'), ('톱', 'NNG'), ('코트', 'NNG'), ('로', 'JKM'), ('마무리', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('색다르', 'VA'), ('ㄴ', 'ETD'), ('패턴', 'NNG'), ('을', 'JKO'), ('즐기', 'VV'), ('고', 'ECE'), ('싶', 'VXA'), ('다면', 'ECE'), ('로제', 'NNG'), ('의', 'JKG'), ('네', 'MDN'), ('일', 'NNG'), ('을', 'JKO'), ('기억', 'NNG'), ('하', 'XSV'), ('자', 'ECE'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('100', 'NR'), ('점', 'NNB'), ('만점', 'NNG'), ('에', 'JKM'), ('100', 'NR'), ('점', 'NNM'), ('!', 'SF'), ('쉬폰', 'NNG'), ('드레스', 'NNG'), (',', 'SP'), ('암', 'NNG'), ('워머', 'UN'), ('와', 'JC'), ('조화', 'NNG'), ('를', 'JKO'), ('이루', 'VV'), ('며', 'ECE'), ('고급', 'NNG'), ('스럽', 'XSA'), ('ㄴ', 'ETD'), ('분위기', 'NNG'), ('를', 'JKO'), ('자아내', 'VV'), ('ㄴ', 'ETD'), ('로제', 'NNG'), ('의', 'JKG'), ('네', 'MDN'), ('일은', 'NNG'), ('라운드', 'NNG'), ('쉐입으', 'UN'), ('로', 'JKM'), ('손톱', 'NNG'), ('모양', 'NNG'), ('을', 'JKO'), ('잡', 'VV'), ('은', 'ETD'), ('뒤', 'NNG'), (',', 'SP'), ('블랙', 'NNG'), ('컬러', 'NNG'), ('로', 'JKM'), ('매', 'VV'), ('니', 'ECD'), ('시한', 'NNG'), ('무드', 'NNG'), ('를', 'JKO'), ('완성', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('스타일', 'NNG'), ('.', 'SF'), ('손톱', 'NNG'), ('끝', 'NNG'), ('부터', 'JX'), ('거칠', 'VA'), ('ㄴ', 'ETD'), ('느낌', 'NNG'), ('으로', 'JKM'), ('표현', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('특징', 'NNG'), ('!', 'SF'), ('손톱', 'NNG'), ('이', 'JKS'), ('긷', 'VV'), ('어', 'ECD'), ('지', 'VXV'), ('거나', 'ECE'), (',', 'SP'), ('긁히', 'VV'), ('어도', 'ECD'), ('티', 'NNG'), ('가', 'JKS'), ('나', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('을', 'ETD'), ('로제', 'NNG'), ('의', 'JKG'), ('네', 'MDN'), ('일', 'NNG'), ('은', 'JX'), ('집', 'NNG'), ('에서', 'JKM'), ('도', 'JX'), ('쉽', 'VA'), ('게', 'ECD'), ('따르', 'VV'), ('아', 'ECS'), ('해보', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('을', 'ETD'), ('듯', 'NNB'), ('!', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 3
# [('[', 'SS'), ("'", 'SS'), ('폭', 'NNG'), ('이', 'JKS'), ('좁', 'VA'), ('고', 'ECE'), ('긷', 'VV'), ('어', 'ECD'), ('치렁치렁', 'MAG'), ('하', 'VV'), ('ㄴ', 'ETD'), ('느낌', 'NNG'), ('없이', 'MAG'), ('색다르', 'VA'), ('ㄴ', 'ETD'), ('변화', 'NNG'), ('를', 'JKO'), ('손쉽', 'VA'), ('게', 'ECD'), ('주', 'VXV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('으니까', 'ECD'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('가방', 'NNG'), ('의', 'JKG'), ('탑', 'NNG'), ('핸들', 'NNG'), ('에', 'JKM'), ('쁘', 'UN'), ('띠', 'NNG'), ('스카프', 'NNG'), ('를', 'JKO'), ('돌돌', 'MAG'), ('말', 'VV'), ('면', 'ECE'), ('전혀', 'MAG'), ('다른', 'MDT'), ('가방', 'NNG'), ('처럼', 'JKM'), ('사용', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('이', 'NNG'), ('보다', 'JKM'), ('더', 'MAG'), ('간편', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('방법', 'NNG'), ('은', 'JX'), ('가방', 'NNG'), ('에', 'JKM'), ('쁘', 'UN'), ('띠', 'NNG'), ('스카프', 'NNG'), ('를', 'JKO'), ('묶', 'VV'), ('어', 'ECD'), ('연출', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('!', 'SF'), ('베이지', 'NNG'), ('컬러', 'NNG'), ('의', 'JKG'), ('가방', 'NNG'), ('에', 'JKM'), ('강렬', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('레드', 'NNG'), ('나', 'JC'), ('블루', 'NNG'), ('컬러', 'NNG'), ('의', 'JKG'), ('쁘', 'UN'), ('띠', 'NNG'), ('스카프', 'NNG'), ('를', 'JKO'), ('묶', 'VV'), ('어', 'ECD'), ('연출', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('려원', 'UN'), ('과', 'JC'), ('BLACKPINK', 'OL'), ('로', 'JKM'), ('제의', 'NNG'), ('스타일링', 'NNG'), ('방법', 'NNG'), ('을', 'JKO'), ('참고', 'NNG'), ('해보', 'VV'), ('ㄹ', 'ETD'), ('것', 'NNB'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 4
# [('[', 'SS'), ("'", 'SS'), ('오버사이즈', 'NNG'), ('티셔츠', 'NNG'), ('를', 'JKO'), ('원', 'NNG'), ('피스', 'NNG'), ('처럼', 'JKM'), ('연출', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('타이', 'NNG'), ('다이', 'NNG'), ('패턴', 'NNG'), ('하나', 'NR'), ('로', 'JKM'), ('박시하', 'VV'), ('면서', 'ECE'), ('도', 'JX'), ('캐주얼', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('데일리', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('완성', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('여기', 'NP'), ('에', 'JKM'), ('스포', 'UN'), ('티', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('무드', 'NNG'), ('의', 'JKG'), ('스니커즈', 'NNG'), ('를', 'JKO'), ('매치', 'NNG'), ('하', 'XSV'), ('거나', 'ECE'), ('투박', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('워', 'UN'), ('커', 'VV'), ('어', 'ECS'), (',', 'SP'), ('부츠', 'NNG'), ('로', 'JKM'), ('시크', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('연출', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('보', 'VXV'), ('는', 'ETD'), ('것', 'NNB'), ('은', 'JKS'), ('어떻', 'VA'), ('ㄹ까', 'EFQ'), ('?', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 5
# [('[', 'SS'), ("'", 'SS'), ('통기타', 'NNG'), ('를', 'JKO'), ('연주', 'NNG'), ('하', 'XSV'), ('거나', 'ECE'), ('레저', 'NNG'), ('스포츠', 'NNG'), ('를', 'JKO'), ('즐기', 'VV'), ('는', 'ETD'), ('모습', 'NNG'), ('을', 'JKO'), ('담', 'VV'), ('은', 'ETD'), ('스타', 'NNG'), ('들', 'XSN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('휴양지', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('만큼', 'NNB'), ('시원', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('해변', 'NNG'), ('에서', 'JKM'), ('제트', 'NNG'), ('스키', 'NNG'), (',', 'SP'), ('서핑', 'NNG'), (',', 'SP'), ('돌고래', 'NNG'), ('와', 'JKM'), ('인증', 'NNG'), ('샷', 'NNG'), ('을', 'JKO'), ('남기', 'VV'), ('ㄴ', 'ETD'), ('BLACKPINK', 'OL'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('통기타', 'NNG'), ('를', 'JKO'), ('연주', 'NNG'), ('하', 'XSV'), ('며', 'ECE'), ('감성', 'NNG'), ('샷', 'NNG'), ('을', 'JKO'), ('연출', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('싶', 'VXA'), ('다면', 'ECE'), ('카', 'VV'), ('아', 'ECS'), ('이아', 'UN'), ('거버', 'UN'), ('와', 'JC'), ('BLACKPINK', 'OL'), ('로', 'JKM'), ('제의', 'NNG'), ('사진', 'NNG'), ('을', 'JKO'), ('참고', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('것', 'NNB'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 6
# [('[', 'SS'), ("'", 'SS'), ('넷플릭스', 'UN'), ('에서', 'JKM'), ('는', 'JX'), ('어제', 'NNG'), ('(', 'SS'), ('14', 'NR'), ('일', 'NNM'), (')', 'SS'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('속내', 'NNG'), ('를', 'JKO'), ('담', 'VV'), ('은', 'ETD'), ('다큐멘터리', 'NNG'), ('〈', 'SS'), ('BLACKPINK', 'OL'), (':', 'SP'), ('세상', 'NNG'), ('을', 'JKO'), ('밝히', 'VV'), ('어', 'ECS'), ('라', 'NNG'), ('〉', 'SS'), ('를', 'JKO'), ('공개', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('지수', 'NNG'), (',', 'SP'), ('제니', 'MAG'), (',', 'SP'), ('로제', 'NNG'), (',', 'SP'), ('LISA', 'OL'), ('의', 'JKG'), ('솔직', 'XR'), ('담백', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('모습', 'NNG'), ('이', 'JKS'), ('담기', 'VV'), ('ㄴ', 'ETD'), ('이번', 'NNG'), ('다큐멘터리', 'NNG'), ('에서', 'JKM'), ('는', 'JX'), ('BLACKPINK', 'OL'), ('가', 'JKS'), ('어떻', 'VA'), ('게', 'ECD'), ('세계적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('스타', 'NNG'), ('로', 'JKM'), ('거듭나', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('었', 'EPT'), ('는지', 'ECS'), ('그', 'MDT'), ('과정', 'NNG'), ('을', 'JKO'), ('고스란히', 'MAG'), ('보여주', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('각', 'VV'), ('자', 'ECE'), ('다른', 'MDT'), ('나라', 'NNG'), ('에서', 'JKM'), ('보내', 'VV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('유년', 'NNG'), ('시절', 'NNG'), ('부터', 'JX'), ('지금', 'NNG'), ('까지', 'JX'), (',', 'SP'), ('여태', 'MAG'), ('보', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('없', 'VA'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('미', 'NNG'), ('공개', 'NNG'), ('비', 'XPN'), ('하인드', 'NNG'), ('영상', 'NNG'), ('이', 'JKS'), ('가득', 'MAG'), ('하다', 'NNP'), ('이', 'VCP'), ('고', 'ECE'), ('!', 'SF'), ('흥미', 'NNG'), ('롭', 'XSA'), ('ㄴ', 'ETD'), ('건', 'NNM'), ('할리우드', 'NNP'), ('감독', 'NNG'), ('이', 'JKS'), ('제작', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다는', 'ETD'), ('점', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('한국인', 'NNG'), ('이', 'JKS'), ('아니', 'VV'), ('ㄴ', 'ETD'), ('할리우드', 'NNP'), ('감독', 'NNG'), ('이', 'JKS'), ('바라보', 'VV'), ('ㄴ', 'ETD'), ('BLACKPINK', 'OL'), ('와', 'JC'), ('K', 'OL'), ('팝', 'NNG'), ('문화', 'NNG'), ('는', 'JX'), ('어떻', 'VA'), ('ㄹ까', 'EFQ'), ('?', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 7
# [('[', 'SS'), ("'", 'SS'), ('한국계', 'NNG'), ('호주', 'NNG'), ('인인', 'NNG'), ('로제', 'NNG'), ('는', 'JX'), ('이번', 'NNG'), ('다큐', 'NNP'), ('에서', 'JKM'), ('상당', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('성장', 'NNG'), ('을', 'JKO'), ('보여주', 'VV'), ('는데', 'ECD'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('로제', 'NNG'), ('는', 'JX'), ('의욕', 'NNG'), ('이', 'JKS'), ('대단', 'XR'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('아티스트', 'NNG'), ('로서', 'JKM'), ('성장', 'NNG'), ('하', 'XSV'), ('고자', 'ECD'), ('하', 'VV'), ('는', 'ETD'), ('의지', 'NNG'), ('가', 'JKS'), ('강하', 'VV'), ('고', 'ECE'), ('자신', 'NNG'), ('을', 'JKO'), ('밀어붙이', 'VV'), ('는', 'ETD'), ('모습', 'NNG'), ('이', 'JKS'), ('대단', 'XR'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('녹음', 'NNG'), ('스튜디오', 'NNG'), ('에서', 'JKM'), ('촬영', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('부분', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('는데', 'ECD'), ('그것', 'NP'), ('을', 'JKO'), ('다시', 'MAG'), ('보', 'VV'), ('면서', 'ECE'), ('‘', 'SS'), ('오', 'VV'), ('아', 'ECS'), ('정말', 'MAG'), ('대단', 'XR'), ('하', 'XSA'), ('다', 'ECS'), ('’', 'SS'), ('소리', 'NNG'), ('가', 'JKS'), ('나오', 'VV'), ('았', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('우리', 'NNM'), ('가', 'JKS'), ('촬영', 'NNG'), ('중', 'NNB'), ('이', 'VCP'), ('었', 'EPT'), ('다는', 'ETD'), ('것', 'NNB'), ('을', 'JKO'), ('잊', 'VV'), ('고', 'ECE'), ('곡', 'NNG'), ('작업', 'NNG'), ('에', 'JKM'), ('완전히', 'MAG'), ('몰입', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('있', 'VXV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('로제', 'NNG'), ('가', 'JKS'), ('‘', 'SS'), ('항', 'NNG'), ('상', 'XSN'), ('음악', 'NNG'), ('에', 'JKM'), ('둘러싸이', 'VV'), ('어', 'ECS'), ('있', 'VXV'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('연습', 'NNG'), ('생', 'XSN'), ('시절', 'NNG'), ('이', 'JKS'), ('그립', 'VA'), ('다', 'ECS'), ('’', 'SS'), ('며', 'JC'), ('‘', 'SS'), ('이제', 'NNG'), ('는', 'JX'), ('다양', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('시도', 'NNG'), ('를', 'JKO'), ('해보', 'VV'), ('려면', 'ECE'), ('밤', 'NNG'), ('을', 'JKO'), ('새우', 'VV'), ('어야', 'ECS'), ('만', 'JX'), ('하', 'VV'), ('ㄴ다', 'ECS'), ('’', 'SS'), ('고', 'NNG'), ('말하', 'VV'), ('는', 'ETD'), ('부분', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('는데', 'ECD'), (',', 'SP'), ('그', 'MDT'), ('한마디', 'NNG'), ('가', 'JKS'), ('로제', 'NNG'), ('가', 'JKS'), ('어떤', 'MDT'), ('사람', 'NNG'), ('인지', 'NNG'), ('를', 'JKO'), ('보여주', 'VV'), ('ㄴ다고', 'ECE'), ('생각', 'NNG'), ('하', 'XSV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('음악', 'NNG'), ('을', 'JKO'), ('너무', 'MAG'), ('도', 'JX'), ('열렬히', 'MAG'), ('사랑', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('사람', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 8
# [('[', 'SS'), ('"', 'SS'), ('[[', 'SW'), ("'", 'SS'), ('「', 'SS'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('-', 'SW'), ('뉴', 'NNG'), ('질', 'XSN'), ('랜드', 'NNG'), ('&', 'SW'), ('한국', 'NNG'), ('」', 'SS'), ('"', 'SS'), (',', 'SP'), ("'", 'SS'), ('「', 'SS'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('-', 'SW'), ('뉴', 'NNG'), ('질', 'XSN'), ('랜드', 'NNG'), ('&', 'SW'), ('한국', 'NNG'), ('」', 'SS'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 9
# [('[', 'SS'), ("'", 'SS'), ('「', 'SS'), ('로제', 'NNG'), ('(', 'SS'), ('@', 'SW'), ('ROSES', 'OL'), ('_', 'SW'), ('ARE', 'OL'), ('_', 'SW'), ('ROSIE', 'OL'), (')', 'SS'), ('」', 'SS'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('「', 'SS'), ('로제', 'NNG'), ('(', 'SS'), ('@', 'SW'), ('ROSES', 'OL'), ('_', 'SW'), ('ARE', 'OL'), ('_', 'SW'), ('ROSIE', 'OL'), (')', 'SS'), ('」', 'SS'), ("'", 'SS'), (',', 'SP'), ('"', 'SS'), ('크롭', 'UN'), ('카디건', 'NNG'), ('의', 'JKG'), ('인기', 'NNG'), ('는', 'JX'), ('작년', 'NNG'), ('에', 'JKM'), ('잇', 'VV'), ('어', 'ECD'), ('올해', 'NNG'), ('도', 'JX'), ('이어지', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('로제', 'NNG'), ('는', 'JX'), ('크롭', 'UN'), ('카디건', 'NNG'), ('을', 'JKO'), ('가장', 'MAG'), ('힙', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('입', 'VV'), ('는', 'ETD'), ('정석', 'NNG'), ('스타일', 'NNG'), ('을', 'JKO'), ('보여주', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('바로', 'MAG'), ('핏', 'NNG'), ('되', 'XSV'), ('는', 'ETD'), ('크롭', 'UN'), ('카디건', 'NNG'), ('을', 'JKO'), ('입', 'VV'), ('고', 'ECE'), ('하의', 'NNG'), ('로', 'JKM'), ('는', 'JX'), ('와이드', 'NNG'), ('데님', 'NNG'), ('팬츠', 'NNG'), ('를', 'JKO'), ('매치', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('!', 'SF'), ("'", 'SS'), (']', 'SS'), (',', 'SP'), ('[', 'SS'), ("'", 'SS'), ('일교차', 'NNG'), ('크', 'VA'), ('ㄴ', 'ETD'), ('요즘', 'NNG'), ('카디건', 'NNG'), ('없이', 'MAG'), ('외출', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('란', 'JX'), ('불가능', 'NNG'), ('에', 'JKM'), ('가깝', 'VA'), ('다', 'EFN'), ('.', 'SF'), ('카디건', 'NNG'), ('매년', 'MAG'), ('살', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('같', 'VA'), ('은데', 'ECD'), (',', 'SP'), ('어떻', 'VA'), ('게', 'ECD'), ('활용', 'NNG'), ('하', 'XSV'), ('ㄹ지', 'ECD'), ('모르', 'VV'), ('겠', 'EPT'), ('다면', 'ECE'), ('?', 'SF'), ('여기', 'NP'), ('이', 'MDT'), ('6', 'NR'), ('명', 'NNM'), ('의', 'JKG'), ('셀럽에게', 'UN'), ('서', 'JKM'), ('스타일링', 'NNG'), ('팁', 'NNG'), ('을', 'JKO'), ('얻', 'VV'), ('어', 'ECD'), ('보', 'VV'), ('자', 'ECE'), ('.', 'SF'), ('"', 'SS'), (']', 'SS')]
# ------------------------------
# 10
# [('[', 'SS'), ("'", 'SS'), ('감상', 'NNG'), ('포인트', 'NNG'), ('언뜻', 'MAG'), ('단순', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('듯하', 'VXA'), ('ㄴ', 'ETD'), ('비트', 'NNG'), ('속', 'NNG'), ('에서', 'JKM'), ('인도', 'NNG'), ('전통', 'NNG'), ('악기', 'NNG'), ('시타르', 'NNG'), ('가', 'JKS'), ('깔리', 'VV'), ('고', 'ECE'), ('랩', 'NNG'), (',', 'SP'), ('멜로', 'NNG'), ('디', 'NNG'), (',', 'SP'), ('특히', 'MAG'), ('‘', 'SS'), ('하우', 'NNG'), ('유', 'NNG'), ('라이크', 'NNG'), ('댓', 'NR'), ('’', 'SS'), ('이', 'VCP'), ('란', 'ETD'), ('외침', 'NNG'), ('이', 'JKS'), ('반복', 'NNG'), ('적', 'XSN'), ('으로', 'JKM'), ('들리', 'VV'), ('다', 'ECS'), ('뚝', 'MAG'), ('끊기', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('〈', 'SS'), ('비', 'VV'), ('ㄹ', 'ETD'), ('보드', 'NNG'), ('〉', 'SS'), ('늘', 'VV'), ('ㄴ', 'ETD'), ('“', 'SS'), ('후크', 'UN'), ('가', 'JKS'), ('너무나', 'MAG'), ('즉각적', 'NNG'), ('이', 'VCP'), ('어서', 'ECD'), ('매력', 'NNG'), ('에', 'JKM'), ('빠지', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('을', 'ETD'), ('수', 'NNB'), ('없', 'VA'), ('다', 'EFN'), ('.', 'SF'), ('”', 'SS'), ('고', 'NNG'), ('평론', 'NNG'), ('.', 'SF'), ('팔색조', 'NNG'), ('같', 'VA'), ('은', 'ETD'), ('멤버', 'NNG'), ('한', 'MDN'), ('명', 'NNM'), (',', 'SP'), ('한', 'NNG'), ('명의', 'NNG'), ('치명적', 'NNG'), ('유혹', 'NNG'), ('속', 'NNG'), ('에', 'JKM'), ('허우적거리', 'VV'), ('다', 'ECS'), ('보', 'VXV'), ('면', 'ECE'), ('어느덧', 'MAG'), ('“', 'SS'), ('하우', 'NNG'), ('유', 'NNG'), ('라이크', 'NNG'), ('댓', 'NR'), ('?', 'SF'), ('”', 'SS'), ('을', 'NNG'), ('흥얼거리', 'VV'), ('게', 'ECD'), ('되', 'VV'), ('고', 'ECE'), ('절대', 'MAG'), ('잊히', 'VV'), ('어', 'ECS'), ('지', 'VXV'), ('지', 'ECD'), ('않', 'VXV'), ('는', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('패션', 'NNG'), ('면', 'NNG'), ('에서', 'JKM'), ('는', 'JX'), ('이제', 'MAG'), ('‘', 'SS'), ('인간', 'NNG'), ('OO', 'OL'), ('’', 'SS'), ('가', 'VV'), ('아', 'ECS'), ('아니', 'VV'), ('ㄴ', 'ETD'), ('디자이너', 'NNG'), ('브랜드', 'NNG'), ('가', 'JKS'), ('따라오', 'VV'), ('는', 'ETD'), ('스타일', 'NNG'), ('아이콘', 'NNG'), ('이', 'JKC'), ('되', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('제니', 'MAG'), ('는', 'JX'), ('샤넬', 'UN'), (',', 'SP'), ('지수', 'NNG'), ('는', 'JX'), ('DIOR', 'OL'), ('뷰티', 'NNG'), (',', 'SP'), ('LISA', 'OL'), ('늘', 'VV'), ('ㄴ', 'ETD'), ('셀', 'NNG'), ('린느', 'UN'), (',', 'SP'), ('로제', 'NNG'), ('는', 'JX'), ('생로', 'NNG'), ('랑', 'JC'), ('의', 'JKG'), ('앰', 'UN'), ('배서', 'NNG'), ('드', 'VV'), ('어', 'ECS'), ('.', 'SF'), ('미국', 'NNP'), ('NBC', 'OL'), ('〈', 'SS'), ('지미', 'NNG'), ('패', 'VV'), ('ㄹ', 'ETD'), ('런', 'NNG'), ('쇼', 'NNG'), ('〉', 'SS'), ('에서', 'JKM'), ('는', 'JX'), ('한복', 'NNG'), ('에서', 'JKM'), ('영감', 'NNG'), ('을', 'JKO'), ('얻', 'VV'), ('은', 'ETD'), ('의상', 'NNG'), ('을', 'JKO'), ('입', 'VV'), ('어', 'ECD'), ('‘', 'SS'), ('K', 'OL'), ('-', 'SW'), ('스타', 'NNG'), ('이', 'VCP'), ('ㄹ', 'ETD'), ('’', 'SS'), ('전파', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('공헌', 'NNG'), ('.', 'SF'), ('\\', 'SW'), ("'", 'SS'), (',', 'SP'), ('"', 'SS'), ('‘', 'SS'), ('여덕', 'NNG'), ('’', 'SS'), ('이', 'NNG'), ('유독', 'MAG'), ('많', 'VA'), ('은', 'ETD'), ('레드', 'NNG'), ('벨벳', 'NNG'), ('에서', 'JKM'), ('도', 'JX'), ('막강', 'NNG'), ('팬', 'NNG'), ('덤', 'NNG'), ('을', 'JKO'), ('자랑', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('아', 'VV'), ('아', 'ECS'), ('이리', 'VV'), ('ㄴ', 'ETD'), ('과', 'NNG'), ('슬기', 'NNG'), ('가', 'JKS'), ('첫', 'MDT'), ('유닛', 'NNG'), ('듀오', 'NNP'), ('로', 'JKM'), ('출범', 'NNG'), ('.', 'SF'), ('세계', 'NNG'), ('에서', 'JKM'), ('비명', 'NNG'), ('이', 'JKS'), ('터지', 'VV'), ('어', 'ECS'), ('나오', 'VV'), ('ㄴ', 'ETD'), ('웅장', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('공개', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('6', 'NR'), ('일', 'NNM'), ('발매', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('첫', 'MDT'), ('미니', 'NNG'), ('앨범', 'NNG'), ('\\', 'SW'), ("'", 'SS'), ('몬스터', 'NNG'), ('(', 'SS'), ('MONSTER', 'OL'), (')', 'SS'), ('\\', 'SW'), ("'", 'SS'), ('늘', 'VV'), ('ㄴ', 'ETD'), ('직후', 'NNG'), ('국내', 'NNG'), ('음반', 'NNG'), ('차트', 'NNG'), ('올', 'NNG'), ('키', 'VV'), ('ㄹ', 'ETD'), (',', 'SP'), ('동명', 'NNG'), ('타이틀', 'NNG'), ('곡', 'NNG'), ('역시', 'MAG'), ('음', 'NNG'), ('원', 'NNG'), ('차트', 'NNG'), ('1', 'NR'), ('위', 'NNM'), (',', 'SP'), ('아이', ' ...
# ------------------------------
# 11
# [('[', 'SS'), ("'", 'SS'), ('뮤직비디오', 'NNG'), ('속', 'NNG'), ('제니', 'MAG'), ('오', 'VV'), ('아', 'ECS'), ('로제', 'NNG'), ('가', 'JKS'), ('입', 'NNG'), ('은', 'JX'), ('한복', 'NNG'), ('은', 'JX'), ('‘', 'SS'), ('단하', 'NNG'), ('주단', 'NNG'), ('’', 'SS'), ('제품', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 12
# [('[', 'SS'), ("'", 'SS'), ('얼마', 'NNG'), ('전', 'NNG'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('가', 'JKS'), ('메', 'VV'), ('고', 'ECE'), ('나오', 'VV'), ('아', 'ECS'), ('와', 'VV'), ('ㄴ', 'ETD'), ('판', 'NNG'), ('을', 'JKO'), ('일으키', 'VV'), ('었', 'EPT'), ('던', 'EFQ'), ('카이', 'UN'), ('아', 'VV'), ('아', 'ECS'), ('사', 'VV'), ('아', 'ECS'), ('첼', 'UN'), ('백', 'NR'), ('.', 'SF'), ('언뜻', 'MAG'), ('투박', 'XR'), ('하', 'XSV'), ('어', 'ECS'), ('보이', 'VV'), ('어도', 'ECD'), ('생로', 'NNG'), ('랑', 'JC'), ('특유', 'NNG'), ('의', 'JKG'), ('시크', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('느낌', 'NNG'), ('이', 'JKS'), ('잘', 'MAG'), ('살', 'VV'), ('아', 'ECD'), ('있', 'VXV'), ('다', 'EFN'), ('.', 'SF'), ('평일', 'NNG'), ('과', 'JC'), ('주말', 'NNG'), ('모두', 'NNG'), ('커버', 'NNG'), ('가능', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('실용적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('디자인', 'NNG'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 13
# [('[', 'SS'), ("'", 'SS'), ('로제', 'NNG'), ('IN', 'OL'), ('생', 'NNG'), ('로', 'NNG'), ('랑', 'JC'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 14
# [('[', 'SS'), ("'", 'SS'), ('발리', 'NNG'), ('에서', 'JKM'), ('한', 'MDN'), ('줌', 'NNG'), ('허리', 'NNG'), ('를', 'JKO'), ('뽐내', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('BLACKPINK', 'OL'), ('#', 'SW'), ('로제', 'NNG'), ('.', 'SF'), ('테라스', 'NNG'), ('에', 'JKM'), ('있', 'VV'), ('는', 'ETD'), ('해먹', 'NNG'), ('에서', 'JKM'), ('여유', 'NNG'), ('롭', 'XSA'), ('ㄴ', 'ETD'), ('시간', 'NNG'), ('을', 'JKO'), ('보내', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('다', 'EFN'), ('.', 'SF'), ('블랙', 'NNG'), ('브라탑', 'UN'), ('에', 'JKM'), ('데님', 'NNG'), ('팬츠', 'NNG'), ('를', 'JKO'), ('매치', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('편안', 'NNG'), ('하', 'XSV'), ('면서', 'ECE'), ('세상', 'NNG'), ('힙', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('쓰', 'VV'), ('어', 'ECS'), ('머', 'NP'), ('스타일', 'NNG'), ('을', 'JKO'), ('보여주', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('다', 'EFN'), ('.', 'SF'), ('휴양지', 'NNG'), ('에서', 'JKM'), ('캡', 'NNG'), ('모자', 'NNG'), ('는', 'JX'), ('필수', 'NNG'), ('!', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 15
# [('[', 'SS'), ("'", 'SS'), ('1', 'NR'), ('번', 'NNB'), ('타자', 'NNG'), ('는', 'JX'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('.', 'SF'), ('허리', 'NNG'), ('까지', 'JX'), ('늘어뜨리', 'VV'), ('ㄴ', 'ETD'), ('길', 'VA'), ('ㄴ', 'ETD'), ('생머리', 'NNG'), ('에', 'JKM'), ('금발', 'NNG'), ('을', 'JKO'), ('가미', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('별다르', 'VA'), ('ㄴ', 'ETD'), ('액세서리', 'NNG'), ('없이', 'MAG'), ('도', 'JX'), ('신비', 'NNG'), ('롭', 'XSA'), ('ㄴ', 'ETD'), ('분위기', 'NNG'), ('가', 'JKS'), ('물씬', 'MAG'), ('풍기', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 16
# [('[', 'SS'), ("'", 'SS'), ('컴백', 'NNG'), ('하', 'XSV'), ('자마자', 'ECE'), ('1', 'NR'), ('위', 'NNG'), ('행진', 'NNG'), ('에', 'JKM'), ('미국', 'NNP'), ('빌', 'VV'), ('ㄹ', 'ETD'), ('보드', 'NNG'), ('차트', 'NNG'), ('에서', 'JKM'), ('K', 'OL'), ('팝', 'NNG'), ('걸', 'NNG'), ('그룹', 'NNG'), ('사상', 'NNG'), ('최고', 'NNG'), ('성적', 'NNG'), ('을', 'JKO'), ('거두', 'VV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('빌', 'VV'), ('ㄹ', 'ETD'), ('보드', 'NNG'), ('와', 'JKM'), ('함께', 'MAG'), ('세계', 'NNG'), ('3', 'NR'), ('대', 'NNM'), ('음악', 'NNG'), ('차트', 'NNG'), ('로', 'JKM'), ('꼽히', 'VV'), ('는', 'ETD'), ('영국', 'NNG'), ('의', 'JKG'), ('‘', 'SS'), ('오피셜', 'NNG'), ('차트', 'NNG'), ('’', 'SS'), (',', 'SP'), ('일본', 'NNG'), ('의', 'JKG'), ('‘', 'SS'), ('오리', 'NNG'), ('콘', 'NNG'), ('’', 'SS'), ('에', 'JKM'), ('이름', 'NNG'), ('을', 'JKO'), ('올리', 'VV'), ('기', 'ETN'), ('도', 'JX'), ('하', 'VV'), ('었', 'EPT'), ('고요', 'EFN'), ('.', 'SF'), ('데뷔', 'NNG'), ('3', 'NR'), ('년', 'NNM'), ('차', 'NNG'), ('에', 'JKM'), ('‘', 'SS'), ('최초', 'NNG'), ('’', 'SS'), ('오', 'VV'), ('아', 'ECS'), ('‘', 'SS'), ('최고', 'NNG'), ('’', 'SS'), ('이', 'VCP'), ('라는', 'ETD'), ('수식어', 'NNG'), ('가', 'JKS'), ('붙', 'VV'), ('는', 'ETD'), ('주인공', 'NNG'), ('이', 'JKC'), ('되', 'VV'), ('ㄴ', 'ETD'), ('기분', 'NNG'), ('은', 'JX'), ('어', 'VV'), ('어', 'ECS'), ('때', 'NNG'), ('이', 'VCP'), ('요', 'EFN'), ('?', 'SF'), ('로제', 'NNG'), ('굉장히', 'MAG'), ('과분', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('수식', 'NNG'), ('어', 'VV'), ('죠', 'EFN'), ('.', 'SF'), ('그러', 'VV'), ('ㄴ', 'ETD'), ('말', 'NNG'), ('은', 'JX'), ('쉽', 'VA'), ('게', 'ECD'), ('익숙', 'XR'), ('해지', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('을', 'ETD'), ('것', 'NNB'), ('같', 'VA'), ('아요', 'EFN'), ('.', 'SF'), ('제니', 'MAG'), ('일', 'NR'), ('년', 'NNB'), ('만', 'NNB'), ('의', 'JKG'), ('컴백', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('고', 'ECE'), (',', 'SP'), ('음', 'NNG'), ('원', 'NNG'), ('등', 'NNB'), ('순위', 'NNG'), ('를', 'JKO'), ('생각', 'NNG'), ('하', 'XSV'), ('면서', 'ECE'), ('준비', 'NNG'), ('하', 'XSV'), ('지', 'ECD'), ('는', 'JX'), ('않', 'VXV'), ('았', 'EPT'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKM'), ('영광', 'NNG'), ('스럽', 'XSA'), ('ㄴ', 'ETD'), ('마음', 'NNG'), ('이', 'JKS'), ('크', 'VA'), ('어요', 'EFN'), ('.', 'SF'), ('특히', 'MAG'), ('이번', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('저희', 'NP'), ('가', 'JKS'), ('여태껏', 'MAG'), ('안', 'MAG'), ('하', 'VV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), (',', 'SP'), ('좀', 'MAG'), ('더', 'MAG'), ('세', 'VV'), ('ㄴ', 'ETD'), ('콘셉트', 'NNG'), ('라', 'NNG'), ('걱정', 'NNG'), ('을', 'JKO'), ('많이', 'MAG'), ('하', 'VV'), ('었', 'EPT'), ('거든요', 'EFN'), ('.', 'SF'), ('다행히', 'MAG'), ('좋아하', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('시', 'EPH'), ('어서', 'ECD'), ('저희', 'NP'), ('도', 'JX'), ('즐겁', 'VA'), ('어요', 'EFN'), ('.', 'SF'), ('‘', 'SS'), ('다음', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('또', 'MAG'), ('새롭', 'VA'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('을', 'JKO'), ('해보', 'VV'), ('자', 'ECE'), ('’', 'SS'), ('이', 'VCP'), ('라는', 'ETD'), ('용기', 'NNG'), ('도', 'JX'), ('생기', 'VV'), ('고요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('예전', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('잘', 'MAG'), ('출연', 'NNG'), ('하', 'XSV'), ('지', 'ECD'), ('않', 'VXV'), ('았', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('예능', 'NNG'), ('프로그램', 'NNG'), ('에서', 'JKM'), ('도', 'JX'), ('요즘', 'NNG'), ('많이', 'MAG'), ('보이', 'VV'), ('더', 'EPT'), ('라고요', 'EFN'), ('.', 'SF'), ('제니', 'MAG'), ('이제', 'NNG'), ('는', 'JX'), ('저희', 'NP'), ('를', 'JKO'), ('있', 'VV'), ('는', 'ETD'), ('그대로', 'MAG'), ('보여드리', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('겁나', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('더', 'EPT'), ('라고요', 'EFN'), ('.', 'SF'), ('꾸밈없이', 'MAG'), ('솔직', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('모습', 'NNG'), ('이', 'JKS'), ('제일', 'MAG'), ('좋', 'VA'), ('다는', 'ETD'), ('것', 'NNB'), ('도', 'JX'), ('알', 'VV'), ('았', 'EPT'), ('고요', 'EFN'), ('.', 'SF'), ('로제', 'NNG'), ('시간', 'NNG'), ('이', 'JKS'), ('지나', 'VV'), ('ㄹ수록', 'ECD'), ('좀', 'MAG'), ('더', 'MAG'), ('즐기', 'VV'), ('려고', 'ECD'), ('하', 'VV'), ('는', 'ETD'), ('편', 'NNB'), ('이', 'VCP'), ('에요', 'EFN'), ('.', 'SF'), ('아직', 'MAG'), ('많이', 'MAG'), ...
# ------------------------------
# 17
# [('[', 'SS'), ("'", 'SS'), ('\\', 'SW'), ("'", 'SS'), (',', 'SP'), ('"', 'SS'), ('로제', 'NNG'), ('가', 'JKS'), ('‘', 'SS'), ('꾸안꾸', 'UN'), ('\\', 'SW'), ("'", 'SS'), ('데', 'NNB'), ('일', 'NR'), ('리', 'NNM'), ('룩', 'UN'), ('으로', 'JKM'), ('고르', 'VV'), ('ㄴ', 'ETD'), ('슈즈', 'NNG'), ('는', 'JX'), ('어', 'VV'), ('어', 'ECS'), ('그', 'MDT'), ('슬리퍼', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('발등', 'NNG'), ('을', 'JKO'), ('넓', 'VA'), ('게', 'ECD'), ('덮', 'VV'), ('은', 'ETD'), ('시어링', 'NNG'), ('디테일', 'NNG'), ('이', 'JKS'), ('귀엽', 'VA'), ('ㄴ', 'ETD'), ('인상', 'NNG'), ('을', 'JKO'), ('풍기', 'VV'), ('는데요', 'ECD'), (',', 'SP'), ('그녀', 'NP'), ('는', 'JX'), ('블랙', 'NNG'), (',', 'SP'), ('네이비', 'NNG'), ('처럼', 'JKM'), ('톤', 'NNG'), ('다운', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('룩', 'UN'), ('과', 'JC'), ('매치', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('슈즈', 'NNG'), ('의', 'JKG'), ('컬러', 'NNG'), ('와', 'JKM'), ('비슷', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('크로스', 'NNG'), ('보디', 'NNG'), ('백', 'NNG'), ('을', 'JKO'), ('짧', 'VA'), ('게', 'ECD'), ('메', 'NNG'), ('포인트', 'NNG'), ('있', 'VV'), ('는', 'ETD'), ('아웃', 'NNG'), ('핏', 'NNG'), ('을', 'JKO'), ('즐기', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('"', 'SS'), (',', 'SP'), ('\\', 'SW'), ("''", 'SW'), (']', 'SS')]
# ------------------------------
# 18
# [('[', 'SS'), ("'", 'SS'), ('로제', 'NNG'), ('에게', 'JKM'), ('배우', 'VV'), ('는', 'ETD'), ('베레', 'NNG'), ('쓰', 'VV'), ('는', 'ETD'), ('꿀', 'NNG'), ('팁', 'NNG'), ('!', 'SF'), ('헤어', 'NNG'), ('를', 'JKO'), ('모두', 'MAG'), ('뒤', 'NNG'), ('로', 'JKM'), ('넘기', 'VV'), ('어', 'ECS'), ('이마', 'NNG'), ('를', 'JKO'), ('온전히', 'MAG'), ('드러내', 'VV'), ('기', 'ETN'), ('보다', 'JKM'), ('는', 'JX'), ('한쪽', 'NNG'), ('옆', 'NNG'), ('머리', 'NNG'), ('로', 'JKM'), ('관자', 'NNG'), ('놀이', 'NNG'), ('를', 'JKO'), ('살짝', 'MAG'), ('덮', 'VV'), ('어', 'ECD'), ('주', 'VXV'), ('ㄴ', 'ETD'), ('뒤', 'NNG'), ('베레', 'NNG'), ('를', 'JKO'), ('쓰', 'VV'), ('면', 'ECE'), ('광대', 'NNG'), ('와', 'JKM'), ('턱', 'NNG'), ('선', 'NNG'), ('을', 'JKO'), ('절묘', 'XR'), ('하', 'XSA'), ('게', 'ECD'), ('감추', 'VV'), ('어', 'ECS'), ('얼굴', 'NNG'), ('이', 'JKS'), ('훨씬', 'MAG'), ('작', 'VA'), ('아', 'ECD'), ('보이', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('어요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 19
# [('[', 'SS'), ('"', 'SS'), ('[[', 'SW'), (']', 'SS'), (',', 'SP'), ('[', 'SS'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('블랙', 'NNG'), ('핑크', 'NNG'), ('로제', 'NNG'), ('는', 'JX'), ('색', 'NNG'), ('이', 'JKS'), ('살짝', 'MAG'), ('빠지', 'VV'), ('ㄴ', 'ETD'), ('핑크빛', 'NNG'), ('헤어', 'NNG'), ('를', 'JKO'), ('양', 'MDT'), ('갈래', 'NNG'), ('로', 'JKM'), ('묶', 'VV'), ('어', 'ECD'), ('귀엽', 'VA'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('발산', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('있', 'VXV'), ('어요', 'EFN'), ('.', 'SF'), ('여기', 'NP'), ('서', 'JKM'), ('앞머리', 'NNG'), ('두', 'MDN'), ('가닥', 'NNG'), ('을', 'JKO'), ('빼', 'VV'), ('내', 'EFN'), ('더듬이', 'NNG'), ('같', 'VA'), ('은', 'ETD'), ('포인트', 'NNG'), ('를', 'JKO'), ('주', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('도', 'JX'), ('잊', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('았', 'EPT'), ('죠', 'EFN'), ('.', 'SF'), ('헤어', 'NNG'), ('컬러', 'NNG'), ('와', 'JKM'), ('어울리', 'VV'), ('도록', 'ECD'), ('연', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('갈색', 'NNG'), ('으로', 'JKM'), ('눈썹', 'NNG'), ('을', 'JKO'), ('탈색', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('블', 'VV'), ('러', 'ECD'), ('시', 'VV'), ('어', 'ECS'), ('오', 'VV'), ('아', 'ECS'), ('립', 'NNG'), ('컬러', 'NNG'), ('를', 'JKO'), ('은은', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('핑크색', 'NNG'), ('으로', 'JKM'), ('맞추', 'VV'), ('어', 'ECD'), ('러', 'ECD'), ('블', 'VV'), ('ㄹ', 'ETD'), ('리', 'NNB'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('뷰티', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('완성', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('카', 'VV'), ('아', 'ECS'), ('이아', 'UN'), ('그', 'VV'), ('어', 'ECS'), ('벌', 'VV'), ('는', 'ETD'), ('사회적', 'NNG'), ('거리', 'NNG'), ('두', 'VV'), ('기', 'ETN'), ('를', 'JKO'), ('하', 'VV'), ('며', 'ECE'), ('집', 'NNG'), ('에서', 'JKM'), ('셀프', 'NNG'), ('로', 'JKM'), ('헤어', 'NNG'), ('스타일', 'NNG'), ('에', 'JKM'), ('변화', 'NNG'), ('를', 'JKO'), ('주', 'VV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('헤어', 'NNG'), ('스타일', 'NNG'), ('리스트', 'NNG'), ('귀도', 'NNG'), ('팔라우', 'NNG'), ('와', 'JC'), ('영상', 'NNG'), ('통화', 'NNG'), ('로', 'JKM'), ('조언', 'NNG'), ('을', 'JKO'), ('얻', 'VV'), ('으며', 'ECE'), ('원하', 'VV'), ('는', 'ETD'), ('핑크', 'NNG'), ('헤어', 'NNG'), ('로', 'JKM'), ('변신', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('데', 'NNB'), ('에', 'JKM'), ('성공', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('죠', 'EFN'), ('.', 'SF'), ('그녀', 'NP'), ('같', 'VA'), ('은', 'ETD'), ('헤어', 'NNG'), ('컬러', 'NNG'), ('에', 'JKM'), ('도전', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('싶', 'VXA'), ('다면', 'ECE'), ('먼저', 'MAG'), ('헤어', 'NNG'), ('끝', 'NNG'), ('만', 'JX'), ('탈색', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('주', 'VXV'), ('세요', 'EFN'), ('.', 'SF'), ('귀', 'NNG'), ('라인', 'NNG'), ('을', 'JKO'), ('중심', 'NNG'), ('으로', 'JKM'), ('브라운', 'NNG'), ('헤어', 'NNG'), ('와', 'JC'), ('핑크', 'NNG'), ('컬러', 'NNG'), ('가', 'JKS'), ('자연', 'NNG'), ('스럽', 'XSA'), ('게', 'ECD'), ('그', 'VV'), ('러', 'ECD'), ('데이', 'NNG'), ('션', 'UN'), ('되', 'VV'), ('도록', 'ECD'), ('염색', 'NNG'), ('하', 'XSV'), ('면', 'ECE'), ('꽤', 'MAG'), ('괜찮', 'VA'), ('은', 'ETD'), ('결과물', 'NNG'), ('이', 'JKS'), ('나오', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('을', 'ETD'), ('거', 'NNB'), ('이', 'VCP'), ('에요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('모델', 'NNG'), ('로', 'NNG'), ('티', 'NNG'), ('모스', 'NNG'), ('는', 'JX'), ('바', 'NNG'), ('비', 'NNG'), ('인형', 'NNG'), ('같', 'VA'), ('은', 'ETD'), ('독보적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('비주얼', 'NNG'), ('을', 'JKO'), ('선보이', 'VV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('헤어', 'NNG'), ('뿌리', 'NNG'), ('부터', 'JX'), ('빈틈없이', 'MAG'), ('연', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('핑크색', 'NNG'), ('으로', 'JKM'), ('염색', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('헤어', 'NNG'), ('스타일', 'NNG'), ('이', 'JKS'), ('우선', 'MAG'), ('눈길', 'NNG'), ('을', 'JKO'), ('사로잡', 'VV'), ('습니다', 'EFN'), ('.', 'SF'), ('광택', 'NNG'), ('이', 'JKS'), ('흐르', 'VV'), ('는', 'ETD'), ('머릿결', 'NNG'), ('을', 'JKO'), ('강조', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('전체적', 'NNG'), ('으로', 'JKM'), ('핑크', 'NNG'), ('컬러', 'NNG'), ('를', 'JKO'), ('사용', 'NNG'), ...
# ------------------------------
# 20
# [('[', 'SS'), ("'", 'SS'), ('로제', 'NNG'), ('나', 'JC'), ('유', 'NNG'), ('빌', 'VV'), ('ㄴ', 'ETD'), ('이', 'MDT'), ('선택', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('브이넥', 'NNG'), ('베스트', 'NNG'), ('는', 'JX'), ('올가을', 'NNG'), ('트렌드', 'NNG'), ('중', 'NNB'), ('하나', 'NR'), ('인', 'NNG'), ('프', 'UN'), ('레', 'NNG'), ('피', 'NNG'), ('룩', 'UN'), ('으로', 'JKM'), ('도', 'JX'), ('활용', 'NNG'), ('만점', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('밋밋', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('데일리', 'NNG'), ('룩', 'UN'), ('에', 'JKM'), ('포인트', 'NNG'), ('를', 'JKO'), ('주', 'VV'), ('고', 'ECE'), ('싶', 'VXA'), ('다면', 'ECE'), ('에밀', 'UN'), ('리', 'NNG'), ('신', 'XPN'), ('들레', 'NNG'), ('브처', 'UN'), ('럼', 'NNM'), ('비', 'XPN'), ('비드', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('컬러', 'NNG'), ('의', 'JKG'), ('니트', 'NNG'), ('베스트', 'NNG'), ('를', 'JKO'), ('추천', 'NNG'), ('하', 'XSV'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('F', 'OL'), ('/', 'SP'), ('W', 'OL'), ('시즌', 'NNG'), ('내내', 'MAG'), ('입', 'VV'), ('을', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETD'), ('두툼', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('울', 'NNG'), ('베스트', 'NNG'), ('이', 'VCP'), ('라면', 'ECD'), ('알', 'VV'), ('ㄹ', 'ETD'), ('렉', 'NNG'), ('사', 'VV'), ('아', 'ECS'), ('청', 'NNG'), ('처럼', 'JKM'), ('단독', 'NNG'), ('으로', 'JKM'), ('매치', 'NNG'), ('하', 'XSV'), ('어도', 'ECD'), ('좋', 'VA'), ('겠', 'EPT'), ('네요', 'EFN'), ('.', 'SF'), ('본격적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('가을', 'NNG'), ('쇼핑', 'NNG'), ('을', 'JKO'), ('준비', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('있', 'VXA'), ('다면', 'ECE'), ('니트', 'NNG'), ('베스트', 'NNG'), ('를', 'JKO'), ('잊', 'VV'), ('지', 'ECD'), ('마', 'VV'), ('세요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 21
# [('[', 'SS'), ('"', 'SS'), ('[[', 'SW'), ("''", 'SW'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("''", 'SW'), (']', 'SS'), (',', 'SP'), ('[', 'SS'), ("'", 'SS'), ('안토니', 'NNG'), ('바', 'NNG'), ('카', 'NNG'), ('렐', 'UN'), ('로', 'JKM'), ('의', 'JKG'), ('생', 'NNG'), ('로', 'NNG'), ('랑', 'JC'), ('캠페인', 'NNG'), ('YSL', 'OL'), ('32', 'NR'), ('주인공', 'NNG'), ('로제', 'NNG'), ('.', 'SF'), ('어떠', 'VV'), ('ㄴ', 'ETD'), ('색', 'NNG'), ('도', 'JX'), ('자신', 'NNG'), ('만', 'JX'), ('의', 'JKG'), ('것', 'NNB'), ('으로', 'JKM'), ('흡수', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('버리', 'VXV'), ('는', 'ETD'), ('로제', 'NNG'), ('에게', 'JKM'), ('컬러', 'NNG'), ('는', 'JX'), ('블랙', 'NNG'), ('하나', 'NR'), ('로', 'JKM'), ('충분', 'XR'), ('하', 'XSA'), ('다', 'EFN'), ('.', 'SF'), ('채도', 'NNG'), ('와', 'JC'), ('명도', 'NNG'), ('그리고', 'MAC'), ('로제', 'NNG'), ('만이', 'NNG'), ('존재', 'NNG'), ('하', 'XSV'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('몰입', 'NNG'), ('의', 'JKG'), ('순간', 'NNG'), ('.', 'SF'), ('그', 'MDT'), ('첫', 'MDT'), ('번째', 'NNB'), ('영상', 'NNG'), ('이', 'JKS'), ('펼쳐지', 'VV'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('RETRO', 'OL'), ('AND', 'OL'), ('MODERN', 'OL'), ('AT', 'OL'), ('THE', 'OL'), ('SAME', 'OL'), ('TIME', 'OL'), (',', 'SP'), ('THE', 'OL'), ('NEWLY', 'OL'), ('LAUNCHED', 'OL'), ('SAINT', 'OL'), ('LAURENT', 'OL'), ('BAG', 'OL'), (',', 'SP'), ('THE', 'OL'), ('SOLFERINO', 'OL'), (',', 'SP'), ('IS', 'OL'), ('PROPOSED', 'OL'), ('IN', 'OL'), ('A', 'OL'), ('TIMELESS', 'OL'), ('CHOICE', 'OL'), ('OF', 'OL'), ('MATERIALS', 'OL'), ('AND', 'OL'), ('COLORS', 'OL'), ('.', 'SF'), ('DISCOVER', 'OL'), ('THE', 'OL'), ('BAG', 'OL'), ('IN', 'OL'), ('THE', 'OL'), ('VIDEO', 'OL'), ('FEATURING', 'OL'), ('ROS', 'OL'), ('É', 'SW'), ('.', 'SF'), ("'", 'SS'), (']]', 'SW'), ('"', 'SS'), (']', 'SS')]
# ------------------------------
# 22
# [('[', 'SS'), ("'", 'SS'), ('목', 'NNG'), ('선과', 'NNG'), ('어깨', 'NNG'), (',', 'SP'), ('허리', 'NNG'), ('와', 'JC'), ('허벅지', 'NNG'), ('등', 'NNG'), ('스킨', 'NNG'), ('을', 'JKO'), ('적당히', 'MAG'), ('드러내', 'VV'), ('ㄴ', 'ETD'), ('스타일', 'NNG'), ('을', 'JKO'), ('선보이', 'VV'), ('ㄴ', 'ETD'), ('로제', 'NNG'), ('.', 'SF'), ('이번', 'NNG'), ('시즌', 'NNG'), ('‘', 'SS'), ('핫', 'MDT'), ('’', 'SS'), ('아이템', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('롱', 'UN'), ('글러브', 'NNG'), ('와', 'JC'), ('체인', 'NNG'), ('네', 'MDN'), ('크리스', 'NNG'), ('까지', 'JX'), ('섭렵', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 23
# [('[', 'SS'), ("'", 'SS'), ('이', 'NNG'), ('들', 'XSN'), ('의', 'JKG'), ('모습', 'NNG'), ('에', 'JKM'), ('심', 'NNG'), ('쿵', 'MAG'), ('하', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('을', 'ETD'), ('수', 'NNB'), ('없', 'VA'), ('죠', 'EFN'), ('!', 'SF'), ('핑크', 'NNG'), ('의', 'JKG'), ('해답', 'NNG'), ('은', 'JX'), ('이', 'NP'), ('들', 'XSN'), ('에게', 'JKM'), ('있', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('제니', 'MAG'), (',', 'SP'), ('로제', 'NNG'), (',', 'SP'), ('LISA', 'OL'), (',', 'SP'), ('지수', 'NNG'), ('그리고', 'MAC'), ('SELENA', 'OL'), ('고메즈', 'UN'), ('는', 'JX'), ('온통', 'MAG'), ('핑크빛', 'NNG'), ('으로', 'JKM'), ('채워진', 'NNG'), ('뮤직', 'NNG'), ('비디오', 'NNG'), ('를', 'JKO'), ('선보이', 'VV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 24
# [('[', 'SS'), ("'", 'SS'), ('‘', 'SS'), ('HOW', 'OL'), ('YOU', 'OL'), ('LIKE', 'OL'), ('THAT', 'OL'), ('’', 'SS'), ('으로', 'JKM'), ('20', 'NR'), ('년', 'NNM'), ('6', 'NR'), ('월', 'NNM'), ('26', 'NR'), ('일', 'NNM'), ('컴백', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('국내외', 'NNG'), ('음', 'NNG'), ('원', 'NNG'), ('차트', 'NNG'), ('와', 'JKM'), ('유', 'NNG'), ('튜브', 'NNG'), ('뷰', 'NNG'), (',', 'SP'), ('음악', 'NNG'), ('방송', 'NNG'), ('9', 'NR'), ('관', 'NNM'), ('왕', 'NNG'), ('등', 'NNB'), ('신기록', 'NNG'), ('을', 'JKO'), ('갈아치우', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('BLACKPINK', 'OL'), ('.', 'SF'), ('압도적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('인기', 'NNG'), ('로', 'JKM'), ('지금', 'NNG'), ('은', 'JX'), ('BLACKPINK', 'OL'), ('시대', 'NNG'), ('라', 'NNG'), ('명명', 'NNG'), ('하', 'XSV'), ('어도', 'ECD'), ('과언', 'NNG'), ('이', 'JKS'), ('아니', 'VV'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('이', 'NR'), ('를', 'JKO'), ('증명', 'NNG'), ('하', 'XSV'), ('듯', 'ECD'), ('‘', 'SS'), ('한국', 'NNG'), ('기업', 'NNG'), ('평판', 'NNG'), ('연구소', 'NNG'), ('’', 'SS'), ('에서', 'JKM'), ('내놓', 'VV'), ('은', 'ETD'), ('7', 'NR'), ('월', 'NNM'), ('의', 'JKG'), ('걸', 'NNG'), ('그룹', 'NNG'), ('개인', 'NNG'), ('브랜드', 'NNG'), ('평판', 'NNG'), ('랭킹', 'NNG'), ('에서', 'JKM'), ('1', 'NR'), ('위', 'NNM'), ('부터', 'JX'), ('3', 'NR'), ('위', 'NNM'), ('까지', 'JX'), ('모두', 'MAG'), ('BLACKPINK', 'OL'), ('멤버', 'NNG'), ('가', 'JKS'), ('차지', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('1', 'NR'), ('위', 'NNM'), ('제니', 'MAG'), (',', 'SP'), ('2', 'NR'), ('위', 'NNM'), ('LISA', 'OL'), (',', 'SP'), ('3', 'NR'), ('위', 'NNM'), ('지수', 'NNG'), ('이', 'VCP'), ('고', 'ECE'), (',', 'SP'), ('〈', 'SS'), ('ELLE', 'OL'), ('〉', 'SS'), ('7', 'NR'), ('월', 'NNM'), ('호', 'NNB'), ('의', 'JKG'), ('뮤즈', 'NNG'), ('로제', 'NNG'), ('는', 'JX'), ('6', 'NR'), ('위', 'NNM'), ('에', 'JKM'), ('랭크', 'NNG'), ('되', 'XSV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('그', 'NP'), ('들', 'XSN'), ('의', 'JKG'), ('영향력', 'NNG'), ('이', 'JKS'), ('얼마나', 'MAG'), ('강력', 'XR'), ('하', 'XSA'), ('ㄴ지', 'ECD'), ('새삼', 'MAG'), ('느끼', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETD'), ('뉴스', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('〉', 'SS'), ('로제', 'NNG'), (',', 'SP'), ('우', 'NNG'), ('멀', 'VA'), ('ㄴ', 'ETD'), ('인', 'NNG'), ('블랙', 'NNG'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 25
# [('[', 'SS'), ("'", 'SS'), ('크롭트', 'UN'), ('톱', 'NNG'), ('과', 'JC'), ('미니스커트', 'NNG'), (',', 'SP'), ('두툼', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('레그워머', 'UN'), ('까지', 'JX'), ('합세', 'NNG'), ('하', 'XSV'), ('니', 'ECD'), ('90', 'NR'), ('년대', 'NNM'), ('의', 'JKG'), ('우상', 'NNG'), (',', 'SP'), ('S', 'OL'), ('.', 'SF'), ('E', 'OL'), ('.', 'SF'), ('S', 'OL'), ('.', 'SF'), ('가', 'JKS'), ('돌아오', 'VV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('만', 'JX'), ('같', 'VA'), ('네요', 'EFN'), ('.', 'SF'), ('그때', 'NNG'), ('도', 'JX'), ('지금', 'NNG'), ('도', 'JX'), ('통하', 'VV'), ('는', 'ETD'), ('포니', 'NNG'), ('테일', 'NNM'), ('스타일', 'NNG'), ('은', 'JX'), ('이마', 'NNG'), ('가', 'JKS'), ('강조', 'NNG'), ('되', 'XSV'), ('기', 'ETN'), ('마련', 'NNB'), ('이', 'VCP'), ('죠', 'EFN'), ('.', 'SF'), ('이마', 'NNG'), ('에', 'JKM'), ('콤플렉스', 'NNG'), ('가', 'JKS'), ('있', 'VA'), ('다면', 'ECE'), ('로제', 'NNG'), ('의', 'JKG'), ('스타일', 'NNG'), ('을', 'JKO'), ('눈여겨보', 'VV'), ('세요', 'EFN'), ('.', 'SF'), ('헤어', 'NNG'), ('라인', 'NNG'), ('을', 'JKO'), ('따르', 'VV'), ('아', 'ECS'), ('앞머리', 'NNG'), ('를', 'JKO'), ('길', 'VA'), ('게', 'ECD'), ('늘어뜨리', 'VV'), ('면', 'ECE'), ('얼굴', 'NNG'), ('이', 'JKS'), ('한결', 'MAG'), ('작', 'VA'), ('고', 'ECE'), ('갸름', 'XR'), ('하', 'XSA'), ('게', 'ECD'), ('보이', 'VV'), ('어요', 'EFN'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 26
# ...
# ------------------------------
# 82
# [('[', 'SS'), ("'", 'SS'), ('생로', 'NNG'), ('랑', 'JC'), ('(', 'SS'), ('SAINT', 'OL'), ('LAURENT', 'OL'), (')', 'SS'), ('의', 'NNG'), ('수장', 'NNG'), ('안토니', 'NNG'), ('바', 'NNG'), ('카', 'NNG'), ('렐', 'UN'), ('로', 'JKM'), ('의', 'JKG'), ('열렬', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('사랑', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('는', 'ETD'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('가', 'JKS'), ('또', 'MAG'), ('한', 'MDN'), ('번', 'NNB'), ('그', 'NP'), ('의', 'JKG'), ('부름', 'NNG'), ('에', 'JKM'), ('응하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('2020', 'NR'), ('F', 'OL'), ('/', 'SP'), ('W', 'OL'), ('파리', 'NNG'), ('패션', 'NNG'), ('위크', 'NNG'), ('의', 'JKG'), ('둘째', 'NR'), ('낳', 'VV'), ('ㄹ', 'ETD'), ('가장', 'MAG'), ('긴장감', 'NNG'), ('넘치', 'VV'), ('는', 'ETD'), ('현장', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('쇼', 'NNG'), ('장', 'NNG'), ('으로', 'JKM'), ('가기', 'NNG'), ('직전', 'NNG'), (',', 'SP'), ('로제', 'NNG'), ('는', 'JX'), ('생로', 'NNG'), ('랑', 'JC'), ('의', 'JKG'), ('2020', 'NR'), ('S', 'OL'), ('/', 'SP'), ('S', 'OL'), ('컬렉션', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('입', 'VV'), ('고서', 'ECD'), ('더블유', 'NNG'), ('코리아', 'NNG'), ('를', 'JKO'), ('만나', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('파리', 'NNG'), ('와', 'JKM'), ('생로', 'NNG'), ('랑', 'JC'), (',', 'SP'), ('그리고', 'MAC'), ('로제', 'NNG'), ('의', 'JKG'), ('빛나', 'VV'), ('는', 'ETD'), ('앙상블', 'NNG'), ('.', 'SF'), ("'", 'SS'), (']', 'SS')]
# ------------------------------
# 83
# [('[', 'SS'), ("'", 'SS'), ('2020', 'NR'), ('F', 'OL'), ('/', 'SP'), ('W', 'OL'), ('생로', 'NNG'), ('랑', 'JC'), ('쇼', 'NNG'), ('에', 'JKM'), ('참석', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('화보', 'NNG'), ('선', 'NNG'), ('공개', 'NNG'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('생로', 'NNG'), ('랑', 'JC'), ('(', 'SS'), ('SAINT', 'OL'), ('LAURENT', 'OL'), (')', 'SS'), ('의', 'NNG'), ('수장', 'NNG'), ('안토니', 'NNG'), ('바', 'NNG'), ('카', 'NNG'), ('렐', 'UN'), ('로', 'JKM'), ('의', 'JKG'), ('열렬', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('사랑', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('는', 'ETD'), ('BLACKPINK', 'OL'), ('로제', 'NNG'), ('가', 'JKS'), ('또', 'MAG'), ('한번', 'NNG'), ('그', 'NP'), ('의', 'JKG'), ('부름', 'NNG'), ('에', 'JKM'), ('응하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('2020', 'NR'), ('F', 'OL'), ('/', 'SP'), ('W', 'OL'), ('파리', 'NNG'), ('패션', 'NNG'), ('위크', 'NNG'), ('의', 'JKG'), ('둘째', 'NR'), ('낳', 'VV'), ('ㄹ', 'ETD'), ('가장', 'MAG'), ('긴장감', 'NNG'), ('넘치', 'VV'), ('는', 'ETD'), ('현장', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('쇼', 'NNG'), ('장', 'NNG'), ('으로', 'JKM'), ('가기', 'NNG'), ('직전', 'NNG'), (',', 'SP'), ('로제', 'NNG'), ('는', 'JX'), ('2020', 'NR'), ('S', 'OL'), ('/', 'SP'), ('S', 'OL'), ('컬렉션', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('입', 'VV'), ('고서', 'ECD'), ('더블유', 'NNG'), ('코리아', 'NNG'), ('를', 'JKO'), ('만나', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('파리', 'NNG'), ('와', 'JKM'), ('생로', 'NNG'), ('랑', 'JC'), (',', 'SP'), ('그리고', 'MAC'), ('로제', 'NNG'), ('의', 'JKG'), ('빛나', 'VV'), ('는', 'ETD'), ('앙상블', 'NNG'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (']', 'SS')]
# ------------------------------
# 84
# [('[', 'SS'), (']', 'SS')]
# ------------------------------
# 85
# [('[', 'SS'), ("'", 'SS'), ('‘', 'SS'), ('내셔널', 'NNG'), ('아이스크림', 'NNG'), ('데이', 'NNG'), ('’', 'SS'), ('를', 'JKO'), ('기념', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('귀엽', 'VA'), ('ㄴ', 'ETD'), ('포스', 'NNG'), ('팅', 'UN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('제니', 'MAG'), ('오', 'VV'), ('아', 'ECS'), ('LISA', 'OL'), ('를', 'JKO'), ('시작', 'NNG'), ('으로', 'JKM'), ('BLACKPINK', 'OL'), ('멤버', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('아이스크림', 'NNG'), ('과', 'JKM'), ('함께', 'MAG'), ('한', 'MDN'), ('매력적', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('셀', 'NNG'), ('카', 'NNG'), ('를', 'JKO'), ('개인', 'NNG'), ('인', 'NNG'), ('스타', 'NNG'), ('그램', 'NNM'), ('에', 'JKM'), ('업', 'NNG'), ('로드', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('시작', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('양', 'MDT'), ('갈래', 'NNG'), ('머리', 'NNG'), ('를', 'JKO'), ('하', 'VV'), ('고', 'ECE'), ('소프트', 'NNG'), ('아이스크림', 'NNG'), ('을', 'JKO'), ('들', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('제니', 'MAG'), ('의', 'JKG'), ('모습', 'NNG'), ('은', 'JX'), ('귀엽', 'VA'), ('ㄴ', 'ETD'), ('소녀', 'NNG'), ('의', 'JKG'), ('이미지', 'NNG'), ('그', 'MDT'), ('자체', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('이', 'VCP'), ('어서', 'ECD'), ('LISA', 'OL'), ('도', 'JX'), ('같', 'VA'), ('은', 'ETD'), ('아이스크림', 'NNG'), ('을', 'JKO'), ('들', 'VV'), ('고', 'ECE'), ('찍', 'VV'), ('은', 'ETD'), ('셀', 'NNG'), ('카', 'NNG'), ('를', 'JKO'), ('공개', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('제니', 'MAG'), ('오', 'VV'), ('아', 'ECS'), ('는', 'JX'), ('사뭇', 'MAG'), ('다른', 'MDT'), ('시크', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('모습', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('이', 'VCP'), ('어서', 'ECD'), ('지수', 'NNG'), ('역시', 'MAG'), ('바', 'NNG'), ('형태', 'NNG'), ('의', 'JKG'), ('아이스크림', 'NNG'), ('을', 'JKO'), ('들', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('사진', 'NNG'), ('을', 'JKO'), ('연잇', 'VV'), ('어', 'ECD'), ('인', 'NNG'), ('스타', 'NNG'), ('그램', 'NNM'), ('에', 'JKM'), ('업', 'NNG'), ('로드', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('BLACKPINK', 'OL'), ('가', 'JKS'), ('갑자기', 'MAG'), ('연잇', 'VV'), ('어', 'ECD'), ('아이스크림', 'NNG'), ('셀', 'NNG'), ('카', 'NNG'), ('를', 'JKO'), ('공개', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('이유', 'NNG'), ('는', 'JX'), ('무엇', 'NNG'), ('을', 'JKO'), ('까', 'VV'), ('아', 'ECS'), ('?', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('그', 'MDT'), ('답', 'NNG'), ('이', 'JKS'), ('로제', 'NNG'), ('의', 'JKG'), ('인', 'NNG'), ('스타', 'NNG'), ('그램', 'NNG'), ('스토리', 'NNG'), ('에서', 'JKM'), ('밝혀지', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('로제', 'NNG'), ('는', 'JX'), ('제니', 'MAG'), (',', 'SP'), ('LISA', 'OL'), ('가', 'JKS'), ('업', 'NNG'), ('로드', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('동일', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('아이스크림', 'NNG'), ('을', 'JKO'), ('들', 'VV'), ('고', 'ECE'), ('‘', 'SS'), ('HAPPY', 'OL'), ('NATIONAL', 'OL'), ('ICE', 'OL'), ('CREAM', 'OL'), ('DAY', 'OL'), ('’', 'SS'), ('이', 'VCP'), ('라는', 'ETD'), ('메시지', 'NNG'), ('와', 'JKM'), ('함께', 'MAG'), ('세', 'VV'), ('ㄹ', 'ETD'), ('카', 'NNG'), ('를', 'JKO'), ('올리', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('‘', 'SS'), ('NATIONAL', 'OL'), ('ICE', 'OL'), ('CREAM', 'OL'), ('DAY', 'OL'), ('’', 'SS'), ('늘', 'VV'), ('ㄴ', 'ETD'), ('미국', 'NNP'), ('에서', 'JKM'), ('유래', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('기념일', 'NNG'), ('로', 'JKM'), (',', 'SP'), ('7', 'NR'), ('월', 'NNM'), ('셋째', 'NR'), ('주', 'NNG'), ('일요일', 'NNG'), ('이', 'JKS'), ('아이스크림', 'NNG'), ('의', 'JKG'), ('날', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('귀엽', 'VA'), ('ㄴ', 'ETD'), ('셀', 'NNG'), ('카', 'NNG'), ('는', 'JX'), ('팬', 'NNG'), ('들', 'XSN'), ('에게', 'JKM'), ('잠시', 'MAG'), ('나마', 'JX'), ('더위', 'NNG'), ('를', 'JKO'), ('잊', 'VV'), ('는', 'E ...
# ------------------------------
# 86
# [('[', 'SS'), ("'", 'SS'), ('한국', 'NNG'), ('신진', 'NNG'), ('디자이너', 'NNG'), ('부터', 'JX'), ('하이', 'NNG'), ('패션', 'NNG'), ('브랜드', 'NNG'), ('까지', 'JX'), ('섭렵', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('블', 'VV'), ('ㄹ', 'ETD'), ('핑', 'MAG'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('6', 'NR'), ('월', 'NNM'), ('26', 'NR'), ('일', 'NNM'), ('드디어', 'MAG'), ('BLACKPINK', 'OL'), ('가', 'VV'), ('아', 'ECS'), ('컴백', 'NNG'), ('을', 'JKO'), ('하', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('티', 'NNG'), ('징', 'NNG'), ('비주얼', 'NNG'), ('부터', 'JX'), ('기존', 'NNG'), ('의', 'JKG'), ('여자', 'NNG'), ('아이', 'NNG'), ('돌', 'NNG'), ('그룹', 'NNG'), ('이', 'JKS'), ('선보이', 'VV'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('비주얼', 'NNG'), ('과', 'JKM'), ('는', 'JX'), ('다르', 'VA'), ('ㄴ', 'ETD'), ('파격', 'NNG'), ('그', 'MDT'), ('자체', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('흡사', 'MAG'), ('여', 'NNG'), ('전사', 'NNG'), ('를', 'JKO'), ('떠올리', 'VV'), ('ㄹ', 'ETD'), ('정', 'NNG'), ('도로', 'NNG'), ('파워', 'NNG'), ('풀', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('이미지', 'NNG'), ('는', 'JX'), ('기존', 'NNG'), ('의', 'JKG'), ('틀', 'NNG'), ('을', 'JKO'), ('완전히', 'MAG'), ('깨', 'NNG'), ('버리', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('YG', 'OL'), ('의', 'JKG'), ('한', 'MDN'), ('관계자', 'NNG'), ('에', 'JKM'), ('따르', 'VV'), ('면', 'ECE'), ('특히', 'MAG'), ('이번', 'NNG'), ('앨범', 'NNG'), ('은', 'JX'), ('멤버', 'NNG'), ('들', 'XSN'), ('이', 'JKS'), ('더욱', 'MAG'), ('주도적', 'NNG'), ('으로', 'JKM'), ('나서', 'VV'), ('서', 'ECD'), ('의견', 'NNG'), ('개진', 'NNG'), ('을', 'JKO'), ('많이', 'MAG'), ('하', 'VV'), ('었', 'EPT'), ('다고', 'EFN'), ('하', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('티', 'NNG'), ('징', 'NNG'), ('이미지', 'NNG'), ('속', 'NNG'), ('그', 'NP'), ('들', 'XSN'), ('이', 'JKS'), ('입', 'NNG'), ('은', 'JX'), ('패션', 'NNG'), ('브랜드', 'NNG'), ('를', 'JKO'), ('자세히', 'MAG'), ('살펴보', 'VV'), ('면', 'ECE'), ('한국', 'NNG'), ('신진', 'NNG'), ('디자이너', 'NNG'), ('부터', 'JX'), ('하이', 'NNG'), ('패션', 'NNG'), ('브랜드', 'NNG'), ('까지', 'JX'), ('두루', 'MAG'), ('섭렵', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('스타일링', 'NNG'), ('에', 'JKM'), ('있', 'VV'), ('어서', 'ECD'), ('도', 'JX'), ('남다르', 'VA'), ('ㅁ', 'ETN'), ('을', 'JKO'), ('보여주', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('로제', 'NNG'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('로제', 'NNG'), ('는', 'JX'), ('한국', 'NNG'), ('디자이너', 'NNG'), ('제품', 'NNG'), ('으로', 'JKM'), ('스타일링', 'NNG'), ('을', 'JKO'), ('완성', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('혜인', 'NNG'), ('서의', 'NNG'), ('체인', 'NNG'), ('장식', 'NNG'), ('슬립', 'NNG'), ('드레스', 'NNG'), ('에', 'JKM'), (',', 'SP'), ('최근', 'NNG'), ('라이징', 'NNG'), ('하', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('는', 'ETD'), ('디자이너', 'NNG'), ('이', 'NNG'), ('경진', 'NNG'), ('이', 'JKS'), ('이끌', 'VV'), ('는', 'ETD'), ('진', 'NNG'), ('존', 'NNP'), ('잼', 'NNG'), ('의', 'JKG'), ('스카프', 'NNG'), ('톱', 'NNG'), ('을', 'JKO'), ('더하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('LISA', 'OL'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('LISA', 'OL'), ('가', 'JKS'), ('착용', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('크롭', 'UN'), ('셔츠', 'NNG'), ('역시', 'MAG'), ('한국', 'NNG'), ('디자이너', 'NNG'), ('브랜드', 'NNG'), ('제품', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('디자이너', 'NNG'), ('방혜령', 'UN'), ('의', 'JKG'), ('쏘', 'VV'), ('ㄴ', 'ETD'), ('지크', 'UN'), ('크롭', 'UN'), ('셔츠', 'NNG'), ('를', 'JKO'), ('착용', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('쏠', 'VV'), ('ㄴ지', 'ECD'), ('크', 'VA'), ('는', 'ETD'), ('2019', 'NR'), ('년', 'NNG'), ('론', 'NNG'), ('칭', 'NNM'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('신진', 'NNG'), ('브랜드', 'NNG'), ('로', 'JKM'), ('날렵', 'XR'), ('하', 'XSA'), ('고', 'ECE'), ('모던', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('분위기', 'NNG'), ('의', 'JKG'), ('옷', 'NNG'), ('들', 'XSN'), ('을', 'JKO'), ('만들', 'VV'), ('어', 'ECD'), ('내', 'VXV'), ('ㄴ다', 'EFN'), ('.', 'SF'), ('타이트', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('피트', 'NNM'), ('의', 'JKG'), ('셔 ...
# ------------------------------
# 87
# [('[', 'SS'), ("'", 'SS'), ('K', 'OL'), ('팝', 'NNG'), ('그룹', 'NNG'), ('최초', 'NNG'), ('!', 'SF'), ('BLACKPINK', 'OL'), ('<', 'SS'), ('뚜', 'MAG'), ('두', 'MDN'), ('뚜', 'MAG'), ('두', 'JX'), ('(', 'SS'), ('DDU-DU', 'OL'), ('DDU-DU', 'OL'), (')', 'SS'), ('>', 'SS'), ('뮤직비디오', 'NNG'), ('가', 'JKS'), ('유', 'NNG'), ('튜브', 'NNG'), ('조', 'NNG'), ('회수', 'NNG'), ('11', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('를', 'JKO'), ('기록하', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("''", 'SW'), (',', 'SP'), ("'", 'SS'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('K-POP', 'OL'), ('파워', 'NNG'), ('가', 'JKS'), ('한계', 'NNG'), ('를', 'JKO'), ('모르', 'VV'), ('고', 'ECE'), ('올라가', 'VV'), ('는', 'ETD'), ('중이', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF'), ('바로', 'MAG'), ('오늘', 'NNG'), ('24', 'NR'), ('일', 'NNM'), ('오후', 'NNG'), ('12', 'NR'), ('시경', 'NNG'), ('<', 'SS'), ('뚜', 'MAG'), ('두', 'MDN'), ('뚜', 'MAG'), ('두', 'JX'), ('(', 'SS'), ('DDU-DU', 'OL'), ('DDU-DU', 'OL'), (')', 'SS'), ('>', 'SS'), ('뮤직비디오', 'NNG'), ('가', 'JKS'), ('유', 'NNG'), ('튜브', 'NNG'), ('조', 'NNG'), ('회수', 'NNG'), ('11', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('를', 'JKO'), ('달성', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('이', 'NP'), ('는', 'JX'), ('K-POP', 'OL'), ('남녀', 'NNG'), ('그룹', 'NNG'), ('을', 'JKO'), ('통틀', 'VV'), ('어', 'ECD'), ('세운', 'NNG'), ('최초', 'NNG'), ('의', 'JKG'), ('대기록', 'NNG'), ('.', 'SF'), ('<', 'SS'), ('뚜', 'MAG'), ('두', 'MDN'), ('뚜', 'MAG'), ('두', 'JX'), ('(', 'SS'), ('DDU-DU', 'OL'), ('DDU-DU', 'OL'), (')', 'SS'), ('>', 'SS'), ('뮤직비디오', 'NNG'), ('가', 'JKS'), ('공개', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('지', 'NNB'), ('약', 'MDN'), ('1', 'NR'), ('년', 'NNM'), ('9', 'NR'), ('개월', 'NNM'), ('만', 'NNB'), ('에', 'JKM'), ('일', 'NNG'), ('이', 'VCP'), ('며', 'ECE'), ('10', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('를', 'JKO'), ('달성', 'NNG'), ('하', 'XSV'), ('지', 'ECD'), ('도', 'JX'), ('불과', 'MAG'), ('4', 'NR'), ('개월', 'NNM'), ('밖에', 'JX'), ('되', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('았', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('<', 'SS'), ('뚜', 'MAG'), ('두', 'MDN'), ('뚜', 'MAG'), ('두', 'JX'), ('(', 'SS'), ('DDU-DU', 'OL'), ('DDU-DU', 'OL'), (')', 'SS'), ('>', 'SS'), ('늘', 'VV'), ('ㄴ', 'ETD'), ('음', 'NNG'), ('원', 'NNG'), ('이', 'JKS'), ('발매되', 'VV'), ('자마자', 'ECE'), ('한국', 'NNG'), ('음', 'NNG'), ('원', 'NNG'), ('차트', 'NNG'), ('를', 'JKO'), ('올', 'NNG'), ('키', 'VV'), ('ㄹ', 'ETD'), ('하', 'VV'), ('고', 'ECE'), ('해외', 'NNG'), ('팬', 'NNG'), ('들', 'XSN'), ('도', 'JX'), ('단숨에', 'MAG'), ('사로잡', 'VV'), ('은', 'ETD'), ('메', 'NNG'), ('가', 'JKS'), ('히트', 'NNG'), ('곡', 'NNG'), ('.', 'SF'), ('특히', 'MAG'), ('비', 'VV'), ('ㄹ', 'ETD'), ('보드', 'NNG'), ('메인', 'NNG'), ('차트', 'NNG'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('비', 'VV'), ('ㄹ', 'ETD'), ('보드', 'NNG'), ('200', 'NR'), ('차트', 'NNG'), ('에서', 'JKM'), ('40', 'NR'), ('위', 'NNM'), (',', 'SP'), ('핫', 'NNG'), ('100', 'NR'), ('차트', 'NNG'), ('에서', 'JKM'), ('55', 'NR'), ('위', 'NNM'), ('를', 'JKO'), ('기록', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('등', 'NNB'), ('한국', 'NNG'), ('걸', 'NNG'), ('그룹', 'NNG'), ('으로서', 'JKM'), ('는', 'JX'), ('역대', 'NNG'), ('최고', 'NNG'), ('순위', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('도', 'JX'), ('하', 'VV'), ('었', 'EPT'), ('으며', 'ECE'), (',', 'SP'), ('미국', 'NNP'), ('레코드', 'NNG'), ('산업', 'NNG'), ('협회', 'NNG'), ('(', 'SS'), ('RIAA', 'OL'), (')', 'SS'), ('골드', 'NNG'), ('인증', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETD'), ('첫', 'MDT'), ('K-POP', 'OL'), ('걸', 'VV'), ('ㄹ', 'ETD'), ('그룹', 'NNG'), ('이', 'JKS'), ('기도', 'NNG'), ('하다', 'NNP'), ('.', 'SF'), ("'", 'SS'), (',', 'SP'), ("'", 'SS'), ('BLACKPINK', 'OL'), ('는', 'JX'), ('<', 'SS'), ('뚜', 'MAG'), ('두', 'MDN'), ('뚜', 'MAG'), ('두', 'JX'), ('>', 'SS'), ('뮤직비디오', 'NNG'), ('외', 'NNB'), ('에', 'JKM'), ('도', 'JX'), ('8', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('<', 'SS'), ('붐', 'NNG'), ('바', 'NNG'), ('야', 'JX'), ('>', 'SS'), (',', 'SP'), ('7', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('의', 'JKG'), ('<', 'SS'), ('마지막', 'NNG'), ('처럼' ...
# ------------------------------

# %%
roro[31]
# Out:
# "['패션계의 러브콜이 빗발치는 화제의 중심! BLACKPINK 로제가 파리에 나타났다. 생 로랑의 클래식한 벨벳 재킷과 마이크로 미니 쇼츠를 매치해 젊은 감각의 ‘프렌치 시크’를 보여줬다.']"

# %%
# 명사 혹은 형용사인 품사만 선별해 리스트에 담기
noun_adj_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
            noun_adj_list.append(word)

# %% [markdown]
# ## Stopwords

# %%
stpwds = pd.read_csv('./stopwords.csv' , sep=',', encoding='utf-8', header=None)
stpwds
# Out:
#        0
# 0      아
# 1      휴
# 2    아이구
# 3    아이쿠
# 4    아이고
# ..   ...
# 670   일곱
# 671   여덟
# 672   아홉
# 673    령
# 674    영
#
# [675 rows x 1 columns]

# %%
# 리스트로 변환
stpwds_l = stpwds[0].tolist()

# %%
# stpwds_l = []
add = ['위하', '선보이', '가격', '가격 미정', '미정', '지금', 'BY', '있', '없', '보', '같', '되', '좋', '입', '모습', 
       '보이', '많', '주', '듣', '통하', '전', '받', '공개', '더하', '따르', '선택', '어떻', '알', '맞', '사진', 
       '만들', '연출', '멤버', '크', '늘','그러', '앞', 'FASHIONN', 
      'BLACKPINK']
for words in add :
    stpwds_l.append(words)
# stpwds_l

# %% [markdown]
# ### 불용어는 형태소분석 결과에서도 빼주기

# %%
from collections import Counter

# %%
# 불용어 제외 리스트
noun_adj_list_stp= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if word not in stpwds_l:
            if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
                noun_adj_list_stp.append(word)

# %%
# 블용어 제외 순위
counts_stp = Counter(noun_adj_list_stp)
print(counts_stp.most_common(100))
# Out:
# [('로제', 202), ('생각', 48), ('컬러', 43), ('룩', 38), ('블랙', 38), ('사람', 38), ('스타일', 37), ('패션', 37), ('무대', 36), ('음악', 34), ('좋아하', 32), ('연습', 31), ('톱', 30), ('스타', 30), ('곡', 30), ('화보', 29), ('카디건', 28), ('보여주', 27), ('브랜드', 26), ('팬', 26), ('그룹', 26), ('헤어', 25), ('사랑', 25), ('걸', 25), ('즐기', 23), ('포인트', 22), ('마음', 22), ('영상', 22), ('한국', 22), ('노래', 22), ('매치', 21), ('데뷔', 21), ('디', 20), ('매력', 20), ('커버', 20), ('후', 19), ('촬영', 18), ('말', 18), ('차트', 18), ('배우', 18), ('춤', 18), ('메이크업', 17), ('드레스', 17), ('패턴', 17), ('위', 17), ('앨범', 17), ('컴백', 17), ('중요', 17), ('완성', 16), ('기억', 16), ('분위기', 16), ('요즘', 16), ('쇼', 16), ('시작', 16), ('모델', 16), ('인', 16), ('다르', 16), ('스커트', 16), ('뷰', 15), ('찾', 15), ('느낌', 15), ('표현', 15), ('스타일링', 15), ('잇', 15), ('살', 15), ('인터뷰', 15), ('가수', 15), ('시', 15), ('바', 15), ('아이템', 15), ('ELLE', 15), ('뮤직비디오', 14), ('라', 14), ('칭찬', 14), ('카', 14), ('K', 14), ('팝', 14), ('팬츠', 14), ('유', 14), ('쓰', 14), ('준비', 14), ('먹', 14), ('행복', 14), ('잘하', 14), ('얼', 14), ('처음', 14), ('웃음', 14), ('대하', 14), ('클래식', 14), ('재킷', 14), ('YG', 14), ('사실', 13), ('티', 13), ('리', 13), ('착용', 13), ('해보', 13), ('원', 13), ('보내', 13), ('고', 13), ('말하', 13)]

# %% [markdown]
# ## WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = ' '.join(noun_adj_list)
# text

# %%
# wordcloud = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text)
wordcloud = WordCloud(font_path='ows/Fonts/malgun.ttf', background_color='white', stopwords = stpwds_l).generate(text)

# %%
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %% [markdown]
# ### top100 wordcloud before deleting other brands

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top100 = counts_stp.most_common(100)
top100_word = []
for word, tag in top100 :
    top100_word.append(word)

# %%
text_b = ' '.join(top100_word)
text_b
# Out:
# '로제 생각 컬러 룩 블랙 사람 스타일 패션 무대 음악 좋아하 연습 톱 스타 곡 화보 카디건 보여주 브랜드 팬 그룹 헤어 사랑 걸 즐기 포인트 마음 영상 한국 노래 매치 데뷔 디 매력 커버 후 촬영 말 차트 배우 춤 메이크업 드레스 패턴 위 앨범 컴백 중요 완성 기억 분위기 요즘 쇼 시작 모델 인 다르 스커트 뷰 찾 느낌 표현 스타일링 잇 살 인터뷰 가수 시 바 아이템 ELLE 뮤직비디오 라 칭찬 카 K 팝 팬츠 유 쓰 준비 먹 행복 잘하 얼 처음 웃음 대하 클래식 재킷 YG 사실 티 리 착용 해보 원 보내 고 말하'

# %%
# wordcloud100 = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text_b)
# plt.figure(figsize=(22,22)) #이미지 사이즈 지정
# plt.imshow(wordcloud100, interpolation='lanczos') #이미지의 부드럽기 정도
# plt.axis('off') #x y 축 숫자 제거
# plt.show() 
# # plt.savefig()

# %% [markdown]
# ### top100 wordcloud after deleting other brands

# %%
stpwds_b = stpwds_l
brands = ['LISA', '지수']
for words in brands :
    stpwds_b.append(words)
# stpwds_b

# %%
# 불용어 제외 리스트
noun_adj_list_stp= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if word not in stpwds_b:
            if tag in ['NNG','NNP','VA', 'VV', 'OL', 'UN']:
                noun_adj_list_stp.append(word)

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top100 = counts_stp.most_common(100)
top100_word = []
for word, tag in top100 :
    top100_word.append(word)

# %%
text_a = ' '.join(top100_word)
text_a
# Out:
# '로제 생각 컬러 룩 블랙 사람 스타일 패션 무대 음악 좋아하 연습 톱 스타 곡 화보 카디건 보여주 브랜드 팬 그룹 헤어 사랑 걸 즐기 포인트 마음 영상 한국 노래 매치 데뷔 디 매력 커버 후 촬영 말 차트 배우 춤 메이크업 드레스 패턴 위 앨범 컴백 중요 완성 기억 분위기 요즘 쇼 시작 모델 인 다르 스커트 뷰 찾 느낌 표현 스타일링 잇 살 인터뷰 가수 시 바 아이템 ELLE 뮤직비디오 라 칭찬 카 K 팝 팬츠 유 쓰 준비 먹 행복 잘하 얼 처음 웃음 대하 클래식 재킷 YG 사실 티 리 착용 해보 원 보내 고 말하'

# %%
wordcloud100 = WordCloud(font_path='font/NanumGothic.ttf', background_color='white', stopwords = stpwds_l).generate(text_a)
plt.figure(figsize=(22,22)) #이미지 사이즈 지정
plt.imshow(wordcloud100, interpolation='lanczos') #이미지의 부드럽기 정도
plt.axis('off') #x y 축 숫자 제거
plt.show() 
# plt.savefig()

# %% [markdown]
# ### TOP50 따로 추출

# %%
common = ['패션', '컬렉션', '시즌', '사진', '연출', '모습', '매치',
          '시작', '룩', '다양', '브랜드', '쇼', '모델', '장식', '드레스', '파리', '여성', '스타일', '컬러', '디자이너', '블랙', '재킷',
          '아이템', '옷', '디렉터', '팬츠']

# %%
# 블용어 제외 순위 / 워드클라우드
counts_stp = Counter(noun_adj_list_stp)
top50 = counts_stp.most_common(50)
top50_word = []
for word, tag in top50 :
    if not word in common :
        if not word in brands :
            top50_word.append(word)

# %%
top50_word
# Out:
# ['로제',
#  '생각',
#  '사람',
#  '무대',
#  '음악',
#  '좋아하',
#  '연습',
#  '톱',
#  '스타',
#  '곡',
#  '화보',
#  '카디건',
#  '보여주',
#  '팬',
#  '그룹',
#  '헤어',
#  '사랑',
#  '걸',
#  '즐기',
#  '포인트',
#  '마음',
#  '영상',
#  '한국',
#  '노래',
#  '데뷔',
#  '디',
#  '매력',
#  '커버',
#  '후',
#  '촬영',
#  '말',
#  '차트',
#  '배우',
#  '춤',
#  '메이크업',
#  '패턴',
#  '위',
#  '앨범',
#  '컴백',
#  '중요',
#  '완성',
#  '기억']

# %% [markdown]
# ### magazine_di에 tag 컬럼 생성하기

# %%
len(sentences_tag)
# Out:
# 88

# %%
print(magazine_r['word_rose'][0])
print(sentences_tag[0])
# Out:
# ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비디오. 여기에 숨겨진 메이크업 디테일이 가득하다는 사실! 알고 있나요? 블랙핑크 메이크업 담당 우선 이명선 원장이 한프레임, 한 프레임 놓치기 쉬운 디테일을 모두 알려주었습니다.\nQ. 이번 뮤직비디오 메이크업 룩의 메인 컨셉은 무엇인가요?\n강렬함, 오리엔탈적인, 그리고 블랙핑크의 ‘블랙’스러움\n의상이나 헤어 그리고 무대 세트에서 컬러가 많이 들어가고 화려했기 때문에 메이크업에서는 컬러 포인트를 최대한 빼고 진행을 했어요. 그래서 제니의 눈물 글리터나 커다란 비즈 등 크고 무거운 포인트를 하나만 주고 점이나 선, 형태에 집중한 메이크업 룩을 완성했던 것 같아요.\nQ. 화제의 한복씬의 지수 점 메이크업은 누구 아이디어였나요?\n사실 이건 지수 본인의 아이디어예요. 뮤직비디오 메이크업 아이디어라기 보단 티저 촬영할 때 한 메이크업인데 너무 마음에 들어해서 이게 꼭 뮤직비디오에도 들어갔으면 좋겠다고 하더라고요. 그래서 어디에 넣으면 좋을지 찾다가 한복과 무드가 맞을 거 같아 적용했어요. 한복이 워낙에 화려해서 좀 밋밋해보이면 어쩌나 고민했는데 생각보다 더 예쁘고 포인트 있게 나왔어요.\nQ. 그 외 한복씬 메이크업의 디테일이 있다면?\n뮤비에서 잘 안보이긴 하는데, 로제씨 군무씬이나 살짝살짝 지나가는 모습을 보면 눈 밑에 오묘하게 빛나는 무언가 빛나요. 이게 눈 밑에 가느다란 실버 실 같은 걸로 속눈썹을 만들어서 붙인 건데 글리터를 붙이는 것보다 더 은은하고 묘하게 반짝여서 매우 마음에 들었습니다.\nQ. 제니의 눈 양 옆에 달린 큐빅 메이크업은 어떻게 연출했나요?\n원래 푸른 큐빅이 박힌 자리에 큐빅과 비슷한 컬러의 섀도우로 포인트를 주려 했었어요. 그런데 모니터링 하며 보니 크게 반짝이지 않아서 큰 포인트는 될 수 없겠더라고요. 그래서 커다란 푸른빛 큐빅을 얹었는데 일반 네일 글리터나 아이 글리터 보다 훨씬 시크하고 눈 길이가 연장되어 보여 날카로운 느낌을 주는 포인트가 되는 것 같아요.\nQ. 가장 마음에 들었던 메이크업 룩은?\n리사씨가 골목에서 등장하는 단독 랩파트! 현장에서도 굉장히 멋있단 반응이 많았고, 실제로 봤을 때도 너무 예뻤어요. 의상이 매우 화려한 편이라 원래 하려고 했던 시안은 적용하지 못했고 현장에서 입술 중앙 부분에 포인트를 주었어요. 입술산과 입술 형태를 살리고 싶어 나뭇잎같이 끝이 뾰족한 글리터를 입술 라인을 따라 붙여서 완성했습니다.\n로제에게 너무 예쁘다고 칭찬받은 메이크업 룩은? 영상에서 확인해보세요!']
# [('[', 'SS'), ("'", 'SS'), ('32', 'NR'), ('시간', 'NNG'), ('만', 'JX'), ('에', 'JC'), ('1', 'NR'), ('억', 'NR'), ('뷰', 'NNG'), ('돌파', 'NNG'), ('!', 'SF'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('‘', 'SS'), ('HOW', 'OL'), ('YOU', 'OL'), ('LIKE', 'OL'), ('THAT', 'OL'), ('’', 'SS'), ('뮤직비디오', 'NNG'), ('.', 'SF'), ('여기', 'NP'), ('에', 'JKM'), ('숨기', 'VV'), ('어', 'ECS'), ('지', 'VXV'), ('ㄴ', 'ETD'), ('메이크업', 'NNG'), ('디테일', 'NNG'), ('이', 'JKS'), ('가득', 'MAG'), ('하다', 'NNP'), ('는', 'JX'), ('사실', 'NNG'), ('!', 'SF'), ('알', 'VV'), ('고', 'ECE'), ('있', 'VXV'), ('나요', 'EFQ'), ('?', 'SF'), ('BLACKPINK', 'OL'), ('메이크업', 'NNG'), ('담당', 'NNG'), ('우선', 'NNG'), ('이명선', 'NNG'), ('원장', 'NNG'), ('이', 'JKS'), ('한', 'MDN'), ('프레임', 'NNG'), (',', 'SP'), ('한', 'MDN'), ('프레임', 'NNG'), ('놓치', 'VV'), ('기', 'ETN'), ('쉽', 'VA'), ('ㄴ', 'ETD'), ('디테일', 'NNG'), ('을', 'JKO'), ('모두', 'MAG'), ('알리', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('\\', 'SW'), ('NQ', 'OL'), ('.', 'SF'), ('이', 'NR'), ('번', 'NNM'), ('뮤직비디오', 'NNG'), ('메이크업', 'NNG'), ('룩', 'UN'), ('의', 'JKG'), ('메인', 'NNG'), ('컨셉', 'UN'), ('은', 'JX'), ('무엇', 'NP'), ('이', 'VCP'), ('ㄴ가요', 'EFQ'), ('?', 'SF'), ('\\', 'SW'), ('N', 'OL'), ('강렬', 'XR'), ('하', 'XSA'), ('ㅁ', 'ETN'), (',', 'SP'), ('오리엔탈', 'NNG'), ('적인', 'NNG'), (',', 'SP'), ('그리고', 'MAC'), ('BLACKPINK', 'OL'), ('의', 'JKG'), ('‘', 'SS'), ('블랙', 'NNG'), ('’', 'SS'), ('스', 'VV'), ('러', 'ECD'), ('움', 'NNG'), ('\\', 'SW'), ('N', 'OL'), ('의상', 'NNG'), ('이나', 'JC'), ('헤어', 'NNG'), ('그리', 'VV'), ('고', 'ECE'), ('무대', 'NNG'), ('세트', 'NNG'), ('에서', 'JKM'), ('컬러', 'NNG'), ('가', 'JKS'), ('많이', 'MAG'), ('들어가', 'VV'), ('고', 'ECE'), ('화려', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKM'), ('메이크업', 'NNG'), ('에서', 'JKM'), ('는', 'JX'), ('컬러', 'NNG'), ('포인트', 'NNG'), ('를', 'JKO'), ('최대한', 'NNG'), ('빼', 'VV'), ('고', 'ECE'), ('진행', 'NNG'), ('을', 'JKO'), ('하', 'VV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('그래서', 'MAG'), ('제니', 'MAG'), ('의', 'JKG'), ('눈물', 'NNG'), ('글리', 'MAG'), ('털', 'VV'), ('나', 'ECE'), ('커다랗', 'VA'), ('ㄴ', 'ETD'), ('비즈', 'NNG'), ('등', 'NNB'), ('크', 'VA'), ('고', 'ECE'), ('무겁', 'VA'), ('ㄴ', 'ETD'), ('포인트', 'NNG'), ('를', 'JKO'), ('하나', 'NR'), ('만', 'JX'), ('주고', 'NNG'), ('점', 'NNG'), ('이나', 'JC'), ('선', 'NNG'), (',', 'SP'), ('형태', 'NNG'), ('에', 'JKM'), ('집중', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('메이크업', 'NNG'), ('룩', 'UN'), ('을', 'JKO'), ('완성', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('더', 'EPT'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('같', 'VA'), ('아요', 'EFN'), ('.', 'SF'), ('\\', 'SW'), ('NQ', 'OL'), ('.', 'SF'), ('화제', 'NNG'), ('의', 'JKG'), ('한복', 'NNG'), ('씬', 'NNG'), ('의', 'JKG'), ('지수', 'NNG'), ('점', 'NNG'), ('메이크업', 'NNG'), ('은', 'JX'), ('누', 'VV'), ('구', 'ECE'), ('아이디어', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('나요', 'EFQ'), ('?', 'SF'), ('\\', 'SW'), ('N', 'OL'), ('사실', 'NNG'), ('이건', 'NNP'), ('지수', 'NNG'), ('본인', 'NNG'), ('의', 'JKG'), ('아이디어', 'NNG'), ('이', 'VCP'), ('에요', 'EFN'), ('.', 'SF'), ('뮤직비디오', 'NNG'), ('메이크업', 'NNG'), ('아이디어', 'NNG'), ('라', 'NNG'), ('기', 'NNG'), ('보', 'NNG'), ('단', 'NNG'), ('티', 'NNG'), ('저', 'MDT'), ('촬영', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETD'), ('때', 'NNG'), ('하', 'VV'), ('ㄴ', 'ETD'), ('메이크업', 'NNG'), ('이', 'VCP'), ('ㄴ데', 'ECE'), ('너무', 'MAG'), ('마음', 'NNG'), ('에', 'JKM'), ('듣', 'VV'), ('어', 'ECD'), ('하', 'VV'), ('어서', 'ECD'), ('이것', 'NP'), ('이', 'JKS'), ('꼭', 'MAG'), ('뮤직', 'NNG'), ('비디오', 'NNG'), ('에', 'JKM'), ('도', 'JX'), ('들어가', 'VV'), ('었', 'EPT'), ('으면', 'ECD'), ('좋', 'VA'), ('겠', 'EPT'), ('다고', 'EFN'), ('하', 'VV'), ('더', 'EPT'), ('라고요', 'EFN'), ('.', 'SF'), ('그래서', 'MAG'), ('어디', 'NP'), ('에', 'JKM'), ('넣', 'VV'), ('으면', 'ECD'), ('좋', 'VA'), ('을지', 'ECS'), ('찾', 'VV'), ('다가', 'ECD'), ('한복', 'NNG'), ('과', 'JC'), ('무드', 'NNG'), ('가', 'JKS'), ('맞', 'VV'), ('을', 'ETD'), ('거', 'NNB'), ('같', 'VA'), ('아', 'ECD'), ('적용', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('어요', 'EFN'), ('.', 'SF'), ('한복', 'NNG'), ('이', 'JKS'), ('워낙에', 'MAG'), ('화려', 'NNG'), ('하', 'XSV'), ('어서', 'ECD'), ('좀', 'MA ...

# %%
# 불용어 제외 리스트
ADFN= []
for sentence1 in sentences_tag:
    ADFNT = [] 
    for word, tag in sentence1:
        
        if word in top100_word:
           
            if tag in ['NNG','NNP','VA', 'VV', 'OL']:
                ADFNT.append(word)
    ADFN.append(ADFNT)

# %%
len(ADFN)
# Out:
# 88

# %%
len(sentences_tag)
# Out:
# 88

# %%
magazine_r['sentences_tag'] = sentences_tag
magazine_r
# Out:
#    magazine brand     category                                          title  \
# 0    Allure     R       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 1         B     R      FASHION                                잘 고른 여름 원피스 한 벌
# 2         B     R    CELEBRITY                            난리 난 블랙핑크의 네일아트, 왜?
# 3         B     R      FASHION                      방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 4         B     R      FASHION                            무더위엔 원피스 한 벌이면 충분해!
# ..      ...   ...          ...                                            ...
# 83        W     R  FASHION, 화보                      Je t’aime ROSE (로제) Vol.1
# 84        W     R  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 85        W     R  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 86        W     R  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
# 87        W     R  W HOT ISSUE                          K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                                  link         date  \
# 0   http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
# 1       https://www.harpersbazaar.co.kr/article/47843   2020.07.24
# 2       https://www.harpersbazaar.co.kr/article/47719   2020.07.17
# 3       https://www.harpersbazaar.co.kr/article/41976   2019.09.04
# 4       https://www.harpersbazaar.co.kr/article/40532   2019.08.09
# ..                                                ...          ...
# 83  http://www.wkorea.com/2020/03/15/je-taime-rose...   2020-03-15
# 84  http://www.wkorea.com/2020/08/24/%eb%b8%94%eb%...   2020-08-24
# 85  http://www.wkorea.com/2020/07/20/%eb%b8%94%eb%...   2020-07-20
# 86  http://www.wkorea.com/2020/06/26/%eb%b8%94%eb%...   2020-06-26
# 87  http://www.wkorea.com/2020/03/24/k%ed%8c%9d-%e...   2020-03-24
#
#                                              contents  title_brand  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...            0
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...            0
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...            0
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...            0
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...            0
# ..                                                ...          ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...            1
# 84                                                 []            1
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...            1
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...            1
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...            1
#
#                                             word_rose  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...
# ..                                                ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...
# 84                                                 []
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...
#
#                                         sentences_tag  \
# 0   [([, SS), (', SS), (32, NR), (시간, NNG), (만, JX...
# 1   [([, SS), (', SS), (BLACKPINK, OL), (로제, NNG),...
# 2   [([, SS), (', SS), (번지, VV), (ㅁ, ETN), (기법, NN...
# 3   [([, SS), (', SS), (폭, NNG), (이, JKS), (좁, VA)...
# 4   [([, SS), (', SS), (오버사이즈, NNG), (티셔츠, NNG), (...
# ..                                                ...
# 83  [([, SS), (', SS), (2020, NR), (F, OL), (/, SP...
# 84                                 [([, SS), (], SS)]
# 85  [([, SS), (', SS), (‘, SS), (내셔널, NNG), (아이스크림...
# 86  [([, SS), (', SS), (한국, NNG), (신진, NNG), (디자이너...
# 87  [([, SS), (', SS), (K, OL), (팝, NNG), (그룹, NNG...
#
#                                                  ADFN
# 0   ['뷰', '뮤직비디오', '메이크업', '사실', '메이크업', '뮤직비디오', ...
# 1   ['로제', '드레스', '로제', '패턴', '드레스', '로제', '드레스', ...
# 2   ['패턴', '로제', '위', '컬러', '포인트', '톱', '패턴', '즐기'...
# 3               ['느낌', '말', '컬러', '컬러', '스타일링', '해보']
# 4                  ['원', '로제', '패턴', '완성', '티', '매치']
# ..                                                ...
# 83  ['쇼', '로제', '화보', '바', '카', '사랑', '로제', '패션', ...
# 84                                                 []
# 85  ['시작', '카', '인', '스타', '시작', '카', '바', '인', '스...
# 86  ['한국', '패션', '브랜드', '컴백', '티', '그룹', '다르', 'YG...
# 87  ['K', '팝', '그룹', '뮤직비디오', '유', '뷰', '뮤직비디오', '...
#
# [88 rows x 11 columns]

# %%
magazine_r['ADFN'] = ADFN
magazine_r
# Out:
#    magazine brand     category                                          title  \
# 0    Allure     R       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 1         B     R      FASHION                                잘 고른 여름 원피스 한 벌
# 2         B     R    CELEBRITY                            난리 난 블랙핑크의 네일아트, 왜?
# 3         B     R      FASHION                      방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 4         B     R      FASHION                            무더위엔 원피스 한 벌이면 충분해!
# ..      ...   ...          ...                                            ...
# 83        W     R  FASHION, 화보                      Je t’aime ROSE (로제) Vol.1
# 84        W     R  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 85        W     R  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 86        W     R  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
# 87        W     R  W HOT ISSUE                          K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                                  link         date  \
# 0   http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
# 1       https://www.harpersbazaar.co.kr/article/47843   2020.07.24
# 2       https://www.harpersbazaar.co.kr/article/47719   2020.07.17
# 3       https://www.harpersbazaar.co.kr/article/41976   2019.09.04
# 4       https://www.harpersbazaar.co.kr/article/40532   2019.08.09
# ..                                                ...          ...
# 83  http://www.wkorea.com/2020/03/15/je-taime-rose...   2020-03-15
# 84  http://www.wkorea.com/2020/08/24/%eb%b8%94%eb%...   2020-08-24
# 85  http://www.wkorea.com/2020/07/20/%eb%b8%94%eb%...   2020-07-20
# 86  http://www.wkorea.com/2020/06/26/%eb%b8%94%eb%...   2020-06-26
# 87  http://www.wkorea.com/2020/03/24/k%ed%8c%9d-%e...   2020-03-24
#
#                                              contents  title_brand  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...            0
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...            0
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...            0
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...            0
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...            0
# ..                                                ...          ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...            1
# 84                                                 []            1
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...            1
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...            1
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...            1
#
#                                             word_rose  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...
# ..                                                ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...
# 84                                                 []
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...
#
#                                         sentences_tag  \
# 0   [([, SS), (', SS), (32, NR), (시간, NNG), (만, JX...
# 1   [([, SS), (', SS), (BLACKPINK, OL), (로제, NNG),...
# 2   [([, SS), (', SS), (번지, VV), (ㅁ, ETN), (기법, NN...
# 3   [([, SS), (', SS), (폭, NNG), (이, JKS), (좁, VA)...
# 4   [([, SS), (', SS), (오버사이즈, NNG), (티셔츠, NNG), (...
# ..                                                ...
# 83  [([, SS), (', SS), (2020, NR), (F, OL), (/, SP...
# 84                                 [([, SS), (], SS)]
# 85  [([, SS), (', SS), (‘, SS), (내셔널, NNG), (아이스크림...
# 86  [([, SS), (', SS), (한국, NNG), (신진, NNG), (디자이너...
# 87  [([, SS), (', SS), (K, OL), (팝, NNG), (그룹, NNG...
#
#                                                  ADFN
# 0   [뷰, 뮤직비디오, 메이크업, 사실, 메이크업, 뮤직비디오, 메이크업, 블랙, 헤어...
# 1   [로제, 드레스, 로제, 패턴, 드레스, 로제, 드레스, 디, 포인트, 착용, 로제...
# 2   [패턴, 로제, 위, 컬러, 포인트, 톱, 패턴, 즐기, 로제, 기억, 드레스, 분...
# 3                           [느낌, 말, 컬러, 컬러, 스타일링, 해보]
# 4                              [원, 로제, 패턴, 완성, 티, 매치]
# ..                                                ...
# 83           [쇼, 로제, 화보, 바, 카, 사랑, 로제, 패션, 쇼, 로제, 로제]
# 84                                                 []
# 85  [시작, 카, 인, 스타, 시작, 카, 바, 인, 스타, 카, 로제, 인, 스타, ...
# 86  [한국, 패션, 브랜드, 컴백, 티, 그룹, 다르, YG, 앨범, 티, 패션, 브랜...
# 87  [K, 팝, 그룹, 뮤직비디오, 유, 뷰, 뮤직비디오, 유, 뷰, 그룹, 뮤직비디오...
#
# [88 rows x 11 columns]

# %%
magazine_r.to_csv('./data/bp/magazine_r.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
magazine_r = pd.read_csv('./data/bp/magazine_r.csv' , sep='|', encoding='utf-8')
magazine_r
# Out:
#    magazine brand     category                                          title  \
# 0    Allure     R       BEAUTY  3억뷰 돌파 블랙핑크 뮤비 메이크업의 비밀은? 담당 메이크업 아티스트 직접 등판!
# 1         B     R      FASHION                                잘 고른 여름 원피스 한 벌
# 2         B     R    CELEBRITY                            난리 난 블랙핑크의 네일아트, 왜?
# 3         B     R      FASHION                      방탄소년단 뷔도 착용한 가을 액세서리는 무엇?
# 4         B     R      FASHION                            무더위엔 원피스 한 벌이면 충분해!
# ..      ...   ...          ...                                            ...
# 83        W     R  FASHION, 화보                      Je t’aime ROSE (로제) Vol.1
# 84        W     R  W HOT ISSUE                       블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 85        W     R  W HOT ISSUE                        블랙핑크가 아이스크림 셀카를 올린 이유는?
# 86        W     R  FASHION, 뉴스                           블랙핑크 컴백! 남다른 패션 스타일링
# 87        W     R  W HOT ISSUE                          K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                                  link         date  \
# 0   http://www.allurekorea.com/2020/07/19/3%ec%96%...  2020/07/19/
# 1       https://www.harpersbazaar.co.kr/article/47843   2020.07.24
# 2       https://www.harpersbazaar.co.kr/article/47719   2020.07.17
# 3       https://www.harpersbazaar.co.kr/article/41976   2019.09.04
# 4       https://www.harpersbazaar.co.kr/article/40532   2019.08.09
# ..                                                ...          ...
# 83  http://www.wkorea.com/2020/03/15/je-taime-rose...   2020-03-15
# 84  http://www.wkorea.com/2020/08/24/%eb%b8%94%eb%...   2020-08-24
# 85  http://www.wkorea.com/2020/07/20/%eb%b8%94%eb%...   2020-07-20
# 86  http://www.wkorea.com/2020/06/26/%eb%b8%94%eb%...   2020-06-26
# 87  http://www.wkorea.com/2020/03/24/k%ed%8c%9d-%e...   2020-03-24
#
#                                              contents  title_brand  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...            0
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...            0
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...            0
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...            0
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...            0
# ..                                                ...          ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...            1
# 84                                                 []            1
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...            1
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...            1
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...            1
#
#                                             word_rose  \
# 0   ['32시간만에 1억뷰 돌파! 블랙핑크의 ‘How you like that’ 뮤직비...
# 1   ['블랙핑크 로제', '시폰 드레스를 블랙핑크 로제처럼 쿨하게 연출하고 싶다면? 플...
# 2   ['번짐 기법을 활용한 변형된 레오파드 패턴을 선보인 로제. 화이트 베이스 위에 브...
# 3   ['폭이 좁고 길어 치렁치렁한 느낌 없이 색다른 변화를 손쉽게 줄 수 있으니까.',...
# 4   ['오버사이즈 티셔츠를 원피스처럼 연출한 블랙핑크 로제.', ' 타이다이 패턴 하나...
# ..                                                ...
# 83  ['2020 F/W 생로랑 쇼에 참석한 블랙핑크 로제 화보 선공개.', '생로랑(S...
# 84                                                 []
# 85  ['‘내셔널 아이스크림 데이’를 기념한 블랙핑크의 귀여운 포스팅.', '제니와 리사...
# 86  ['한국 신진 디자이너부터 하이 패션 브랜드까지 섭렵한 블핑', '6월 26일 드디...
# 87  ['K팝 그룹 최초! 블랙핑크 <뚜두뚜두(DDU-DU DDU-DU)> 뮤직비디오가 ...
#
#                                         sentences_tag  \
# 0   [('[', 'SS'), ("'", 'SS'), ('32', 'NR'), ('시간'...
# 1   [('[', 'SS'), ("'", 'SS'), ('BLACKPINK', 'OL')...
# 2   [('[', 'SS'), ("'", 'SS'), ('번지', 'VV'), ('ㅁ',...
# 3   [('[', 'SS'), ("'", 'SS'), ('폭', 'NNG'), ('이',...
# 4   [('[', 'SS'), ("'", 'SS'), ('오버사이즈', 'NNG'), (...
# ..                                                ...
# 83  [('[', 'SS'), ("'", 'SS'), ('2020', 'NR'), ('F...
# 84                         [('[', 'SS'), (']', 'SS')]
# 85  [('[', 'SS'), ("'", 'SS'), ('‘', 'SS'), ('내셔널'...
# 86  [('[', 'SS'), ("'", 'SS'), ('한국', 'NNG'), ('신진...
# 87  [('[', 'SS'), ("'", 'SS'), ('K', 'OL'), ('팝', ...
#
#                                                  ADFN
# 0   ['뷰', '뮤직비디오', '메이크업', '사실', '메이크업', '뮤직비디오', ...
# 1   ['로제', '드레스', '로제', '패턴', '드레스', '로제', '드레스', ...
# 2   ['패턴', '로제', '위', '컬러', '포인트', '톱', '패턴', '즐기'...
# 3               ['느낌', '말', '컬러', '컬러', '스타일링', '해보']
# 4                  ['원', '로제', '패턴', '완성', '티', '매치']
# ..                                                ...
# 83  ['쇼', '로제', '화보', '바', '카', '사랑', '로제', '패션', ...
# 84                                                 []
# 85  ['시작', '카', '인', '스타', '시작', '카', '바', '인', '스...
# 86  ['한국', '패션', '브랜드', '컴백', '티', '그룹', '다르', 'YG...
# 87  ['K', '팝', '그룹', '뮤직비디오', '유', '뷰', '뮤직비디오', '...
#
# [88 rows x 11 columns]
