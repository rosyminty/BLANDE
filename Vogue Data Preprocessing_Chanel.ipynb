# %%
import pandas as pd
import numpy as np

# %%
V_Ch = pd.read_csv('./data/Vogue_Chanel_ccc.csv' , sep='|', encoding='utf-8')
V_Ch
# Out:
#                               title        date  \
# 0                    보물 창고 같은 빈티지 숍  2020.11.09
# 1                         자유롭고 느긋하게  2020.11.05
# 2    샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬  2020.10.30
# 3           권지용, 지드래곤, GD, G-DRAGON  2020.10.21
# 4                            패션, 아멘  2020.10.21
# ..                              ...         ...
# 490            샤넬과 랑콤의 뮤즈 캐롤린 드 메그레  2014.10.01
# 491                  DDP에 상륙한 코코 샤넬  2014.08.20
# 492     바로크와 모더니즘이 뒤섞인 샤넬의 꾸뛰르 판타지!  2014.07.08
# 493               샤넬의 뮤즈, 블레이크 라이블리  2011.05.04
# 494      오드리 토투가 어떻게 레이디 샤넬로 성장했는가?  2009.08.26
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      0
# 1            http://www.vogue.co.kr/2020/11/05/232008/            0      0
# 2    http://www.vogue.co.kr/2020/10/30/%ec%83%a4%eb...            1      0
# 3    http://www.vogue.co.kr/2020/10/21/%ea%b6%8c%ec...            0      2
# ...

# %%
# magazine column 추가
V_Ch['magazine'] = 'V'
V_Ch
# Out:
#                               title        date  \
# 0                    보물 창고 같은 빈티지 숍  2020.11.09
# 1                         자유롭고 느긋하게  2020.11.05
# 2    샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬  2020.10.30
# 3           권지용, 지드래곤, GD, G-DRAGON  2020.10.21
# 4                            패션, 아멘  2020.10.21
# ..                              ...         ...
# 490            샤넬과 랑콤의 뮤즈 캐롤린 드 메그레  2014.10.01
# 491                  DDP에 상륙한 코코 샤넬  2014.08.20
# 492     바로크와 모더니즘이 뒤섞인 샤넬의 꾸뛰르 판타지!  2014.07.08
# 493               샤넬의 뮤즈, 블레이크 라이블리  2011.05.04
# 494      오드리 토투가 어떻게 레이디 샤넬로 성장했는가?  2009.08.26
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      0
# 1            http://www.vogue.co.kr/2020/11/05/232008/            0      0
# 2    http://www.vogue.co.kr/2020/10/30/%ec%83%a4%eb...            1      0
# 3    http://www.vogue.co.kr/2020/10/21/%ea%b6%8c%ec...            0      2
# ...

# %%
# Brand -> brand
V_Ch = V_Ch.rename({'Brand' : 'brand'}, axis='columns')
V_Ch
# Out:
#                               title        date  \
# 0                    보물 창고 같은 빈티지 숍  2020.11.09
# 1                         자유롭고 느긋하게  2020.11.05
# 2    샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬  2020.10.30
# 3           권지용, 지드래곤, GD, G-DRAGON  2020.10.21
# 4                            패션, 아멘  2020.10.21
# ..                              ...         ...
# 490            샤넬과 랑콤의 뮤즈 캐롤린 드 메그레  2014.10.01
# 491                  DDP에 상륙한 코코 샤넬  2014.08.20
# 492     바로크와 모더니즘이 뒤섞인 샤넬의 꾸뛰르 판타지!  2014.07.08
# 493               샤넬의 뮤즈, 블레이크 라이블리  2011.05.04
# 494      오드리 토투가 어떻게 레이디 샤넬로 성장했는가?  2009.08.26
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      0
# 1            http://www.vogue.co.kr/2020/11/05/232008/            0      0
# 2    http://www.vogue.co.kr/2020/10/30/%ec%83%a4%eb...            1      0
# 3    http://www.vogue.co.kr/2020/10/21/%ea%b6%8c%ec...            0      2
# ...

# %%
# column 순서
V_Ch = V_Ch[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
V_Ch
# Out:
#     magazine brand     category  \
# 0          V    Ch      Fashion
# 1          V    Ch      Fashion
# 2          V    Ch      Fashion
# 3          V    Ch      Fashion
# 4          V    Ch  daily issue
# ..       ...   ...          ...
# 465        V    Ch  ADVERTORIAL
# 466        V    Ch      Fashion
# 467        V    Ch      Fashion
# 468        V    Ch      Fashion
# 469        V    Ch      Fashion
#
#                                                 title  \
# 0                                      보물 창고 같은 빈티지 숍
# 1                                           자유롭고 느긋하게
# 2                      샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬
# 3                             권지용, 지드래곤, GD, G-DRAGON
# 4                                              패션, 아멘
# ..                                                ...
# 465                                민감한 피부가 기억해야 할 이야기
# 466                                   궁극의 여행템, 샤넬 러기지
# 467       #패션읽어주는언니 – 샤넬 공방에 숨겨졌던 스트리트 DNA, 코셰(Koché)
# ...

# %%
V_Ch.to_csv('./data/Vogue_Chanel.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
V_Ch = pd.read_csv('./data/Vogue_Chanel.csv' , sep='|', encoding='utf-8')
V_Ch
# Out:
#     magazine brand     category  \
# 0          V    Ch      Fashion
# 1          V    Ch      Fashion
# 2          V    Ch      Fashion
# 3          V    Ch      Fashion
# 4          V    Ch  daily issue
# ..       ...   ...          ...
# 465        V    Ch  ADVERTORIAL
# 466        V    Ch      Fashion
# 467        V    Ch      Fashion
# 468        V    Ch      Fashion
# 469        V    Ch      Fashion
#
#                                                 title  \
# 0                                      보물 창고 같은 빈티지 숍
# 1                                           자유롭고 느긋하게
# 2                      샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬
# 3                             권지용, 지드래곤, GD, G-DRAGON
# 4                                              패션, 아멘
# ..                                                ...
# 465                                민감한 피부가 기억해야 할 이야기
# 466                                   궁극의 여행템, 샤넬 러기지
# 467       #패션읽어주는언니 – 샤넬 공방에 숨겨졌던 스트리트 DNA, 코셰(Koché)
# ...

# %%
# 날짜 지난 거 빼기
d = list(range(470,495))
d
# Out:
# [470,
#  471,
#  472,
#  473,
#  474,
#  475,
#  476,
#  477,
#  478,
#  479,
#  480,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486,
#  487,
#  488,
#  489,
#  490,
#  491,
#  492,
#  493,
#  494]

# %%
V_Ch.drop(d, inplace = True)
V_Ch
# Out:
#                                                 title        date  \
# 0                                      보물 창고 같은 빈티지 숍  2020.11.09
# 1                                           자유롭고 느긋하게  2020.11.05
# 2                      샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬  2020.10.30
# 3                             권지용, 지드래곤, GD, G-DRAGON  2020.10.21
# 4                                              패션, 아멘  2020.10.21
# ..                                                ...         ...
# 465                                민감한 피부가 기억해야 할 이야기  2016.04.25
# 466                                   궁극의 여행템, 샤넬 러기지  2016.04.19
# 467       #패션읽어주는언니 – 샤넬 공방에 숨겨졌던 스트리트 DNA, 코셰(Koché)  2016.03.15
# 468  수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 샤넬: 인스타그램에 딱 좋겠어!  2016.03.08
# 469                          로마 치네치타 스튜디오에 펼쳐진 샤넬의 휴일  2016.01.18
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      0
# ...

# %%
V_Ch.to_csv('./data/Vogue_Chanel.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
V_Ch = pd.read_csv('./data/Vogue_Chanel.csv' , sep='|', encoding='utf-8')
V_Ch
# Out:
#                                                 title        date  \
# 0                                      보물 창고 같은 빈티지 숍  2020.11.09
# 1                                           자유롭고 느긋하게  2020.11.05
# 2                      샤넬 2020/21 크루즈 컬렉션 캠페인과 비하인드 씬  2020.10.30
# 3                             권지용, 지드래곤, GD, G-DRAGON  2020.10.21
# 4                                              패션, 아멘  2020.10.21
# ..                                                ...         ...
# 465                                민감한 피부가 기억해야 할 이야기  2016.04.25
# 466                                   궁극의 여행템, 샤넬 러기지  2016.04.19
# 467       #패션읽어주는언니 – 샤넬 공방에 숨겨졌던 스트리트 DNA, 코셰(Koché)  2016.03.15
# 468  수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 샤넬: 인스타그램에 딱 좋겠어!  2016.03.08
# 469                          로마 치네치타 스튜디오에 펼쳐진 샤넬의 휴일  2016.01.18
#
#                                                   link  title_brand  check  \
# 0    http://www.vogue.co.kr/2020/11/09/%eb%b3%b4%eb...            0      0
# ...
