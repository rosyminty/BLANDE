# %%
import pandas as pd
import numpy as np

# %%
V_Je = pd.read_csv('./data/Vogue_JENNIE_df.csv' , sep='|', encoding='utf-8')
V_Je
# Out:
#     magazine brand     category                         title  \
# 0          V    Je  daily issue  머라이어 캐리x아리아나 그란데 ‘Oh Santa!’
# 1          V    Je      Fashion                   머플러, 꺼내 둘러요
# 2          V    Je  daily issue        <프렌즈> 특별판, 내년 3월 촬영 시작
# 3          V    Je      Fashion                바스키아라는 소우주 앞에서
# 4          V    Je      Fashion            셀럽들이 꽂힌 커스텀 팬츠의 매력
# ..       ...   ...          ...                           ...
# 232        V    Je       Beauty                   Glow Recipe
# 233        V    Je       People              Shake That Booty
# 234        V    Je      Fashion       칸예 웨스트와 테일러 스위프트는 화해할까?
# 235        V    Je      Fashion             아이 앞에선 그저 엄마인 스타들
# 236        V    Je      Fashion                   #스타의옷장 #탱크톱
#
#                                                   link        date  \
# 0    http://www.vogue.co.kr/2020/12/04/%eb%a8%b8%eb...  2020.12.04
# 1    http://www.vogue.co.kr/2020/12/02/%eb%a8%b8%ed...  2020.12.02
# ...

# %% [markdown]
# ### 크롤링 부재한 아이들 채우기

# %%
# contents가 공백인 애들 다시 지정
cblank = []
for i in range(len(V_Je)) :
    if V_Je['contents'][i] == '[]' :    
        cblank.append(i)
print(cblank)
print(len(cblank))
# Out:
# [18, 19, 29]
# 3

# %%
print(V_Je.loc[29, 'link'])
# Out:
# http://www.vogue.co.kr/2020/03/30/%ec%9d%98-%ec%8a%88%ed%8d%bc%ed%9e%88%ec%96%b4%eb%a1%9c%eb%a1%9c-%eb%b3%80%ec%8b%a0%ed%95%9c-%ed%94%8c%eb%a1%9c%eb%a0%8c%ec%8a%a4-%ed%93%a8/

# %%
V_Je.loc[[18,19,29,189],'check'] = 2

# %% [markdown]
# ### 제니 외 다른 이름 지우기

# %%
for i in range(len(V_Je)) :
    if '제니퍼' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 한' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 홀저' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 류' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니시스' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '유제니디스' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 슬레이트' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 가스' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 험프리' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 미들턴' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 드레이퍼' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '유제니오' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니하우스' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '유제니' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 시미즈' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니 팩햄' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
for i in range(len(V_Je)) :
    if '제니시란' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2

# %%
V_Je[V_Je['check']==2]
# Out:
#     magazine brand     category                         title  \
# 0          V    Je  daily issue  머라이어 캐리x아리아나 그란데 ‘Oh Santa!’
# 2          V    Je  daily issue        <프렌즈> 특별판, 내년 3월 촬영 시작
# 3          V    Je      Fashion                바스키아라는 소우주 앞에서
# 5          V    Je  daily issue            디카프리오와 샬라메가 한 영화에?
# 7          V    Je      Fashion             내일이 궁금한 여자 뮤지션 3인
# ..       ...   ...          ...                           ...
# 232        V    Je       Beauty                   Glow Recipe
# 233        V    Je       People              Shake That Booty
# 234        V    Je      Fashion       칸예 웨스트와 테일러 스위프트는 화해할까?
# 235        V    Je      Fashion             아이 앞에선 그저 엄마인 스타들
# 236        V    Je      Fashion                   #스타의옷장 #탱크톱
#
#                                                   link        date  \
# 0    http://www.vogue.co.kr/2020/12/04/%eb%a8%b8%eb...  2020.12.04
# 2    http://www.vogue.co.kr/2020/11/13/%ed%94%84%eb...  2020.11.13
# ...

# %% [markdown]
# ### 본문에 제니 없으면 지우기

# %%
for i in range(len(V_Je)):
    if not '제니' in V_Je['contents'][i] :
        V_Je.loc[i, 'check'] = 2
        print(i)
# Out:
# 8
# 18
# 19
# 29
# 38
# 45
# 99
# 105
# 118
# 119
# 120
# 122
# 135
# 138
# 139
# 142
# 146
# 147
# 149
# 150
# 155
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 167
# 170
# 175
# 177
# 179
# 186
# 188
# 192
# 195
# 196
# 198
# 200
# 201
# 202
# 203
# 205
# 208
# 209
# 210
# 211
# 213
# 215
# 217
# 218
# 221
# 222
# 223
# 224
# 225
# 227
# 231
# 232
# 235
# 236

# %%
print(V_Je.loc[38, 'link'])
# Out:
# http://www.vogue.co.kr/2020/01/31/j-lox%ec%83%a4%ed%82%a4%eb%9d%bc-%ec%8a%88%ed%8d%bc%eb%b3%bc-%ed%95%98%ed%94%84%ed%83%80%ec%9e%84-%ec%87%bc-%ec%8a%a4%ed%8f%ac/

# %% [markdown]
# ### 카테고리로 확인

# %%
# category 종류
V_Je['category'].unique()
# Out:
# array(['daily issue', 'Fashion', 'Beauty', 'Living', 'People', 'Video'],
#       dtype=object)

# %%
# category별 개수
V_Je['category'].value_counts()
# Out:
# Fashion        100
# Beauty          46
# daily issue     40
# Living          37
# People          11
# Video            3
# Name: category, dtype: int64

# %%
V_Je[(V_Je['category'] == 'Video') & (V_Je['check'] != 2)]
# Out:
# Empty DataFrame
# Columns: [magazine, brand, category, title, link, date, contents, title_brand, check]
# Index: []

# %%
V_Je[(V_Je['category'] == 'People') & (V_Je['check'] != 2)]
# Out:
# Empty DataFrame
# Columns: [magazine, brand, category, title, link, date, contents, title_brand, check]
# Index: []

# %%
print(V_Je.loc[77, 'link'])
# Out:
# http://www.vogue.co.kr/2019/09/16/love-and-loss/

# %%
V_Je.loc[77,'check'] = 2

# %%
V_Je[(V_Je['category'] == 'Living') & (V_Je['check'] != 2)]
# Out:
#     magazine brand category                 title  \
# 35         V    Je   Living         LABOR OF LOVE
# 110        V    Je   Living           저의 친구가 맞습니다
# 123        V    Je   Living       그들만의 언어, ‘돌민정음’
# 176        V    Je   Living  Instinct of Painting
# 187        V    Je   Living         주말에 뭐 볼까? – ④
#
#                                                   link        date  \
# 35    http://www.vogue.co.kr/2020/02/11/labor-of-love/  2020.02.11
# 110  http://www.vogue.co.kr/2018/12/27/%ec%a0%80%ec...  2018.12.27
# 123  http://www.vogue.co.kr/2018/09/26/%ea%b7%b8%eb...  2018.09.26
# 176  http://www.vogue.co.kr/2017/09/28/instinct-of-...  2017.09.28
# 187  http://www.vogue.co.kr/2017/07/12/%ec%a3%bc%eb...  2017.07.12
#
#                                               contents  title_brand  check
# 35   ['그레타 거윅은 루이자 메이 알콧이 <작은 아씨들>을 출간한 36세에 영화 <작은...            0      0
# 110  ['의외의 인맥을 자랑하는 스타의 절친 라인업 7', '제시카의 크리스마스 스페셜 ...            0      0
# ...

# %%
print(V_Je.loc[187, 'link'])
# Out:
# http://www.vogue.co.kr/2017/07/12/%ec%a3%bc%eb%a7%90%ec%97%90-%eb%ad%90-%eb%b3%bc%ea%b9%8c-%e2%91%a3/

# %%
V_Je.loc[[35, 176, 187],'check'] = 2

# %%
V_Je[(V_Je['category'] == 'daily issue') & (V_Je['check'] == 0)]
# Out:
#     magazine brand     category                     title  \
# 26         V    Je  daily issue  ‘슈스스’ 한혜연 픽 패셔니스타 아이돌 5인
# 52         V    Je  daily issue      ‘텀블러’가 뽑은 올해의 인기 아이돌
# 73         V    Je  daily issue               스타들의 체크 활용법
# 76         V    Je  daily issue          필름 카메라에 푹 빠진 스타들
# 78         V    Je  daily issue             가을 드라마 여배우 격전
# 102        V    Je  daily issue     분위기 천재! 인스타그램 속 스타 5인
#
#                                                   link        date  \
# 26   http://www.vogue.co.kr/2020/04/17/%ec%8a%88%ec...  2020.04.17
# 52   http://www.vogue.co.kr/2019/12/03/%ed%85%80%eb...  2019.12.03
# 73   http://www.vogue.co.kr/2019/09/19/%ec%8a%a4%ed...  2019.09.19
# 76   http://www.vogue.co.kr/2019/09/16/%ed%95%84%eb...  2019.09.16
# 78   http://www.vogue.co.kr/2019/09/10/%ea%b0%80%ec...  2019.09.10
# 102  http://www.vogue.co.kr/2019/03/25/%eb%b6%84%ec...  2019.03.25
#
#                                               contents  title_brand  check
# ...

# %%
print(V_Je.loc[102, 'link'])
# Out:
# http://www.vogue.co.kr/2019/03/25/%eb%b6%84%ec%9c%84%ea%b8%b0-%ec%b2%9c%ec%9e%ac-%ec%9d%b8%ec%8a%a4%ed%83%80%ea%b7%b8%eb%9e%a8-%ec%86%8d-%ec%8a%a4%ed%83%80-5%ec%9d%b8/

# %%
V_Je.loc[[78],'check'] = 2

# %%
V_Je[(V_Je['category'] == 'Beauty') & (V_Je['check'] == 0)]
# Out:
#     magazine brand category                            title  \
# 6          V    Je   Beauty  My Skin But Glow. 헤라 글로우 래스팅 쿠션
# 54         V    Je   Beauty                        이렇게 잘라주세요
# 62         V    Je   Beauty                ‘인어 공주의 눈물’ 메이크업?
# 66         V    Je   Beauty                  가을엔 블루 스모키 메이크업
# 71         V    Je   Beauty                       앞머리 대신 잔머리
# 87         V    Je   Beauty               스마트폰에 저장! 내일의 메이크업
# 91         V    Je   Beauty                 스타의 그 운동 #운동스타그램
# 98         V    Je   Beauty                        부기 제거 대작전
# 117        V    Je   Beauty                   입술에 블러 처리 해주세요
# 129        V    Je   Beauty                           대세는 귀티
# 132        V    Je   Beauty      높이 높이! 얼굴이 작아 보이는 하이 반묶음 헤어
# 169        V    Je   Beauty          여자 연예인들의 셀카를 책임지는 카메라 앱
# 190        V    Je   Beauty                 올여름 주목해야 할 헤어 컬러
# 206        V    Je   Beauty                       Girl Crush
# ...

# %%
print(V_Je.loc[228, 'link'])
# Out:
# http://www.vogue.co.kr/2016/12/05/cold-play/

# %%
V_Je.loc[[91, 129, 206, 228],'check'] = 2

# %%
V_Je[(V_Je['category'] == 'Fashion') & (V_Je['check'] == 0)]
# Out:
#     magazine brand category  \
# 1          V    Je  Fashion
# 4          V    Je  Fashion
# 10         V    Je  Fashion
# 12         V    Je  Fashion
# 60         V    Je  Fashion
# 63         V    Je  Fashion
# 68         V    Je  Fashion
# 80         V    Je  Fashion
# 81         V    Je  Fashion
# 83         V    Je  Fashion
# 92         V    Je  Fashion
# 108        V    Je  Fashion
# 112        V    Je  Fashion
# 113        V    Je  Fashion
# 128        V    Je  Fashion
# 133        V    Je  Fashion
# 134        V    Je  Fashion
# 145        V    Je  Fashion
#
#                                                  title  \
# 1                                          머플러, 꺼내 둘러요
# 4                                   셀럽들이 꽂힌 커스텀 팬츠의 매력
# 10                           지금부터 가을까지 ‘만능템’! 베스트 모아보기
# 12                         지금 여자 아이돌들이 빠져 있는 #하이틴패션 탐구
# 60                               Comment te dire adieu
# 63                           카니예 웨스트 손에서 새롭게 태어난 일요 예배
# ...

# %%
print(V_Je.loc[145, 'link'])
# Out:
# http://www.vogue.co.kr/2018/03/19/%ed%94%bc%ec%97%90%eb%a5%b4-%ec%95%84%eb%a5%b4%eb%94%94-%eb%8d%94-%ed%81%ac%eb%a6%ac%ec%97%90%ec%9d%b4%ed%84%b0/

# %%
V_Je.loc[[68, 83, 108, 145],'check'] = 2

# %%
# 중간저장
V_Je.to_csv('./data/Vogue_JENNIE_df.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
