# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 데이터 전처리하면서 magazine_di 만들 준비

# %% [markdown]
# ### Allure

# %%
a_di = pd.read_csv('./data/d/Allure_Dior.csv' , sep='|', encoding='utf-8')
a_di
# Out:
#     magazine brand   category                         title  \
# 0          A     D  CELEBRITY      디올 뷰티 코리아의 앰배서더 이하늬를 만나다
# 1          A     D     BEAUTY  캔디 키스 선미 입술, 디올 립 뭐 발랐어? (6)
# 2          A     D     BEAUTY  캔디 키스 선미 입술, 디올 립 뭐 발랐어? (5)
# 3          A     D     BEAUTY  캔디 키스 선미 입술, 디올 립 뭐 발랐어? (4)
# 4          A     D     BEAUTY  캔디 키스 선미 입술, 디올 립 뭐 발랐어? (3)
# ..       ...   ...        ...                           ...
# 323        A     D    FASHION                     맨해튼의 낮과 밤
# 324        A     D    FEATURE              아만다 사이프리드를 닮은 향기
# 325        A     D     BEAUTY                 뷰티 쇼핑 리스트 <2>
# 326        A     D     BEAUTY                    립스틱 짙게 바르고
# 327        A     D    FASHION                    미래지향적 스포티즘
#
#                                                   link        date  \
# 0    http://www.allurekorea.com/2020/03/26/%eb%94%9...  2020-03-26
# 1    http://www.allurekorea.com/2019/01/09/%ec%ba%9...  2019-01-09
# ...

# %%
# date로 정렬
a_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
a_di
# Out:
#     magazine brand category                               title  \
# 8          A     D   BEAUTY         화장대에 올려두고 싶은 투명한 크리스털 아이템 4
# 10         A     D   BEAUTY                        AUTUMN TOUCH
# 9          A     D   BEAUTY  11월의 뷰티 신상 파헤치기 #잇츠온세일 #바디 #향수 #헤어
# 11         A     D   BEAUTY                        진짜 보습이 필요할 때
# 12         A     D   BEAUTY  단숨에 맑은 피부로! 뷰티 에디터가 고른 촉촉한 쿠션 추천 4
# ..       ...   ...      ...                                 ...
# 323        A     D  FASHION                           맨해튼의 낮과 밤
# 324        A     D  FEATURE                    아만다 사이프리드를 닮은 향기
# 325        A     D   BEAUTY                       뷰티 쇼핑 리스트 <2>
# 326        A     D   BEAUTY                          립스틱 짙게 바르고
# 327        A     D  FASHION                          미래지향적 스포티즘
#
#                                                   link        date  \
# 8    http://www.allurekorea.com/2020/11/18/%ed%99%9...  2020-11-18
# ...

# %%
a_di.to_csv('./data/d/a_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
a_di = pd.read_csv('./data/d/a_di.csv' , sep='|', encoding='utf-8')
a_di
# Out:
#     magazine brand category                               title  \
# 0          A     D   BEAUTY         화장대에 올려두고 싶은 투명한 크리스털 아이템 4
# 1          A     D   BEAUTY                        AUTUMN TOUCH
# 2          A     D   BEAUTY  11월의 뷰티 신상 파헤치기 #잇츠온세일 #바디 #향수 #헤어
# 3          A     D   BEAUTY                        진짜 보습이 필요할 때
# 4          A     D   BEAUTY  단숨에 맑은 피부로! 뷰티 에디터가 고른 촉촉한 쿠션 추천 4
# ..       ...   ...      ...                                 ...
# 323        A     D  FASHION                           맨해튼의 낮과 밤
# 324        A     D  FEATURE                    아만다 사이프리드를 닮은 향기
# 325        A     D   BEAUTY                       뷰티 쇼핑 리스트 <2>
# 326        A     D   BEAUTY                          립스틱 짙게 바르고
# 327        A     D  FASHION                          미래지향적 스포티즘
#
#                                                   link        date  \
# 0    http://www.allurekorea.com/2020/11/18/%ed%99%9...  2020-11-18
# ...

# %%
a_di_t = a_di[a_di['check'] != 2]
a_di_t
# Out:
#     magazine brand   category                                        title  \
# 5          A     D    FASHION                                   빈티지 쇼핑의 시대
# 7          A     D    FASHION                  주식을 시작한 패션 에디터의 이야기, 나는 주주다
# 9          A     D    FASHION                            거리로 나온 하이패션 슈즈들 4
# 16         A     D    FASHION  차정원부터 아이린까지. 옷 잘입는 셀럽들의 사복 패션에 등장한 뉴 백은 무엇?
# 23         A     D  CELEBRITY                    DON’T CATEGORIZE ME / 유태오
# ..       ...   ...        ...                                          ...
# 317        A     D    FASHION                                       동물의 왕국
# 318        A     D    FASHION                                        신고합니다
# 323        A     D    FASHION                                    맨해튼의 낮과 밤
# 324        A     D    FEATURE                             아만다 사이프리드를 닮은 향기
# 327        A     D    FASHION                                   미래지향적 스포티즘
#
# ...

# %% [markdown]
# ### BAZAAR

# %%
b_di = pd.read_csv('./data/d/Daum_BAZAAR_Dior.csv' , sep='|', encoding='utf-8')
b_di
# Out:
#      Unnamed: 0 magazine brand     category  \
# 0             0        B     D       BEAUTY
# 1             1        B     D       BEAUTY
# 2             2        B     D       BEAUTY
# 3             3        B     D       BEAUTY
# 4             4        B     D       BEAUTY
# ..          ...      ...   ...          ...
# 102         102        B     D       BEAUTY
# 103         103        B     D  ART&CULTURE
# 104         104        B     D      FASHION
# 105         105        B     D      FASHION
# 106         106        B     D       BEAUTY
#
#                                           title  \
# 0                          이하늬가 바른 립스틱 컬러는 몇 번?
# 1                           요즘 여배우 사이에서 핫한 스킨케어
# 2                     코로나19에도 불티나게 팔린 메이크업 제품은?
# 3    EXCLUSIVE! 톱 모델 지젤번천이 전해 온 환경 운동가로서의 신념...
# 4                       짧은 직모여도 괜찮아! 신상 마스카라 털기
# ..                                          ...
# 102                           여름에만 가능한 뷰티 #립티튜드
# ...

# %%
b_di.drop('Unnamed: 0', axis=1, inplace=True)
b_di
# Out:
#     magazine brand     category                                       title  \
# 0          B     D       BEAUTY                        이하늬가 바른 립스틱 컬러는 몇 번?
# 1          B     D       BEAUTY                         요즘 여배우 사이에서 핫한 스킨케어
# 2          B     D       BEAUTY                   코로나19에도 불티나게 팔린 메이크업 제품은?
# 3          B     D       BEAUTY  EXCLUSIVE! 톱 모델 지젤번천이 전해 온 환경 운동가로서의 신념...
# 4          B     D       BEAUTY                     짧은 직모여도 괜찮아! 신상 마스카라 털기
# ..       ...   ...          ...                                         ...
# 102        B     D       BEAUTY                           여름에만 가능한 뷰티 #립티튜드
# 103        B     D  ART&CULTURE                                  패션과 뷰티와 아트
# 104        B     D      FASHION                         결혼을 앞둔 당신의 워치 & 주얼리
# 105        B     D      FASHION                               드레스 한 벌이면 충분해
# 106        B     D       BEAUTY                              미세먼지엔 매트 파운데이션
#
# ...

# %%
# date로 정렬
b_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
b_di
# Out:
#     magazine brand     category                                       title  \
# 0          B     D       BEAUTY                        이하늬가 바른 립스틱 컬러는 몇 번?
# 1          B     D       BEAUTY                         요즘 여배우 사이에서 핫한 스킨케어
# 2          B     D       BEAUTY                   코로나19에도 불티나게 팔린 메이크업 제품은?
# 3          B     D       BEAUTY  EXCLUSIVE! 톱 모델 지젤번천이 전해 온 환경 운동가로서의 신념...
# 4          B     D       BEAUTY                     짧은 직모여도 괜찮아! 신상 마스카라 털기
# ..       ...   ...          ...                                         ...
# 102        B     D       BEAUTY                           여름에만 가능한 뷰티 #립티튜드
# 103        B     D  ART&CULTURE                                  패션과 뷰티와 아트
# 104        B     D      FASHION                         결혼을 앞둔 당신의 워치 & 주얼리
# 105        B     D      FASHION                               드레스 한 벌이면 충분해
# 106        B     D       BEAUTY                              미세먼지엔 매트 파운데이션
#
# ...

# %%
b_di.to_csv('./data/d/b_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
b_di = pd.read_csv('./data/d/b_di.csv' , sep='|', encoding='utf-8')
b_di
# Out:
#     magazine brand     category                                       title  \
# 0          B     D       BEAUTY                        이하늬가 바른 립스틱 컬러는 몇 번?
# 1          B     D       BEAUTY                         요즘 여배우 사이에서 핫한 스킨케어
# 2          B     D       BEAUTY                   코로나19에도 불티나게 팔린 메이크업 제품은?
# 3          B     D       BEAUTY  EXCLUSIVE! 톱 모델 지젤번천이 전해 온 환경 운동가로서의 신념...
# 4          B     D       BEAUTY                     짧은 직모여도 괜찮아! 신상 마스카라 털기
# ..       ...   ...          ...                                         ...
# 102        B     D       BEAUTY                           여름에만 가능한 뷰티 #립티튜드
# 103        B     D  ART&CULTURE                                  패션과 뷰티와 아트
# 104        B     D      FASHION                         결혼을 앞둔 당신의 워치 & 주얼리
# 105        B     D      FASHION                               드레스 한 벌이면 충분해
# 106        B     D       BEAUTY                              미세먼지엔 매트 파운데이션
#
# ...

# %%
b_di_t = b_di[b_di['check'] != 2]
b_di_t
# Out:
#     magazine brand     category                          title  \
# 5          B     D    CELEBRITY               명품도 싹쓰리 음원도 싹쓰리!
# 6          B     D      FASHION                 지금 가장 핫한 브랜드는?
# 7          B     D      FASHION             저장하고 싶은 2020 여름 풍경
# 8          B     D      FASHION          안방 1열에서 보는 디지털 오트 쿠튀르
# 10         B     D      FASHION    수지가 백상예술대상에서 특급 대우받은 그 드레스!
# 12         B     D      FASHION      위시리스트 VS 장바구니템 #담아(만)볼게요!
# 13         B     D      FASHION                    이 쇼츠엔 이 슈즈!
# 14         B     D    CELEBRITY                  이성경과 함께 날아올라!
# 15         B     D      FASHION               에디터들의 인생 가방은 무엇?
# 16         B     D      FASHION           이번 시즌 런웨이에서 뽑은 베스트 룩
# 19         B     D      FASHION         한 폭의 그림같은 아티스틱한 패션아이템들
# 20         B     D      FASHION       정주행하기 좋은 패션 다큐멘터리 BEST 4
# 21         B     D      FASHION      지금, 주목해야 할 주얼리의 네 가지 키워드!
# 22         B     D      FASHION  루이 비통부터 디올까지 품절각 신상 슈즈 BEST 3
# ...

# %% [markdown]
# ### Cosmopolitan

# %%
c_di = pd.read_csv('./data/d/c_d.csv' , sep='|', encoding='utf-8')
c_di
# Out:
#     magazine brand category                           title  \
# 0          C     D   BEAUTY                판매왕 길만 걷는 뷰티템 모음
# 1          C     D  FASHION                아이돌들의 '최애' 주얼리는?
# 2          C     D  FASHION                  가을 여자라면 역시 체크지
# 3          C     D   BEAUTY           뷰티터's Pick! 신상 뷰티템 14
# 4          C     D   BEAUTY                   시크한 벨벳 립스틱 추천
# ..       ...   ...      ...                             ...
# 419        C     D   BEAUTY                     신상크림 전격 분석!
# 420        C     D   CELEBS      루비 로즈가 말하는 걸 크러시한 여자가 되는 법
# 421        C     D   CELEBS                 자신만의 색을 간직한 고아라
# 422        C     D   CELEBS             원조 걸크러쉬, 김선아가 돌아왔다!
# 423        C     D   CELEBS  15명의 스타들, #여자 그리고 #나이 에 대해 말하다
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201112000053785  2020-11-12
# 1    http://v.media.daum.net/v/20201119121642288  2020-11-19
# ...

# %%
# date로 정렬
c_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
c_di
# Out:
#     magazine brand category                               title  \
# 1          C     D  FASHION                    아이돌들의 '최애' 주얼리는?
# 3          C     D   BEAUTY               뷰티터's Pick! 신상 뷰티템 14
# 0          C     D   BEAUTY                    판매왕 길만 걷는 뷰티템 모음
# 2          C     D  FASHION                      가을 여자라면 역시 체크지
# 5          C     D  FASHION                  카디건 이렇게도 입을 수 있어요!
# ..       ...   ...      ...                                 ...
# 309        C     D   CAREER                    가을 바람에 어울릴 헤어 퍼퓸
# 236        C     D   BEAUTY                      스타가 찜콩한 그 립스틱!
# 417        C     D   BEAUTY                       스테파니의 수분 메이크업
# 383        C     D  FASHION                    시크하게 들거나 손목에 감거나
# 327        C     D   BEAUTY  여자들은 닮고 싶고, 남자들은 만나고 싶은 궁극의 메이크업 룰
#
#                                             link        date  \
# 1    http://v.media.daum.net/v/20201119121642288  2020-11-19
# 3    http://v.media.daum.net/v/20201115001027008  2020-11-15
# ...

# %%
# Out:
#     magazine brand category                               title  \
# 1          C     D  FASHION                    아이돌들의 '최애' 주얼리는?
# 3          C     D   BEAUTY               뷰티터's Pick! 신상 뷰티템 14
# 0          C     D   BEAUTY                    판매왕 길만 걷는 뷰티템 모음
# 2          C     D  FASHION                      가을 여자라면 역시 체크지
# 5          C     D  FASHION                  카디건 이렇게도 입을 수 있어요!
# ..       ...   ...      ...                                 ...
# 309        C     D   CAREER                    가을 바람에 어울릴 헤어 퍼퓸
# 236        C     D   BEAUTY                      스타가 찜콩한 그 립스틱!
# 417        C     D   BEAUTY                       스테파니의 수분 메이크업
# 383        C     D  FASHION                    시크하게 들거나 손목에 감거나
# 327        C     D   BEAUTY  여자들은 닮고 싶고, 남자들은 만나고 싶은 궁극의 메이크업 룰
#
#                                             link        date  \
# 1    http://v.media.daum.net/v/20201119121642288  2020-11-19
# 3    http://v.media.daum.net/v/20201115001027008  2020-11-15
# ...

# %%
c_di.to_csv('./data/d/c_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
c_di = pd.read_csv('./data/d/c_di.csv' , sep='|', encoding='utf-8')
c_di
# Out:
#     magazine brand category                               title  \
# 0          C     D  FASHION                    아이돌들의 '최애' 주얼리는?
# 1          C     D   BEAUTY               뷰티터's Pick! 신상 뷰티템 14
# 2          C     D   BEAUTY                    판매왕 길만 걷는 뷰티템 모음
# 3          C     D  FASHION                      가을 여자라면 역시 체크지
# 4          C     D  FASHION                  카디건 이렇게도 입을 수 있어요!
# ..       ...   ...      ...                                 ...
# 419        C     D   CAREER                    가을 바람에 어울릴 헤어 퍼퓸
# 420        C     D   BEAUTY                      스타가 찜콩한 그 립스틱!
# 421        C     D   BEAUTY                       스테파니의 수분 메이크업
# 422        C     D  FASHION                    시크하게 들거나 손목에 감거나
# 423        C     D   BEAUTY  여자들은 닮고 싶고, 남자들은 만나고 싶은 궁극의 메이크업 룰
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201119121642288  2020-11-19
# 1    http://v.media.daum.net/v/20201115001027008  2020-11-15
# ...

# %%
for i in range(len(c_di)) :
    if '레디올낫' in c_di['contents'][i] :
        print(i, c_di['contents'][i])
# Out:
# 0 [['「 Layered Pearl 」', '「 Layered Pearl 」', '', '', '', '', '', '', '', '중년 이상 여자용으로 여겨졌던 진주가 여돌, 남돌 할 것 없이 초강세. 과거처럼 큰 해수 진주가 아니라 쌀알 같은 담수진주나 인조 진주를 다른 소재와 레이어링하는 스타일.', '「 Ethnic & Antique 」', '「 Ethnic & Antique 」', '', '', '', '', '', '', '', '', '', '「 Simple Silver 」', '「 Simple Silver 」', '', '', '', '', '', '', '', '', '', '남돌들이 일상에서 가장 자주 착용하는 심플한 실버 주얼리가 여돌들 사이에서도 유행. 스테이씨 윤의 볼드한 실버 초커는 뱅 헤어와 어울리며 마치 클레오파트라 같은 느낌. 태연이 한 레이어드 실버 목걸이는 그가 일상에서도 즐겨 하는 스타일. 하얗고 가는 목에 찰떡같이 어울린다. 방탄소년단 제이홉은 길이가 다른 펜던트 두 개만 심플하게 하고 반지까지 생략했다. 올 네이비 컬러 룩에 작지만 강력한 액센트. NCT 루카스의 볼드한 실버 체인 목걸이와 심플한 귀걸이는 데님 재킷을 더 거칠게 드러낸다. 17일 미니 2집 〈웁스(Woops!)〉로 컴배한 우즈는 언제나 빛나는 패션 감각에 맞게 주얼리는 최소화. 이날 무대의상의 복잡한 컬러와 패턴에 딱 할 일만 하는 단순한 펜던트 하나만 했다.', '「 80’s Vibe 」', '「 80’s Vibe 」', '', '', '', '', '', '', '', '', '', "지난 봄부터 꾸준히 유행인 강렬한 80년대 바이브가 겨울에도 쭉. 신곡 ‘마고(Mago)’로 컴백해 정상을 재확인한 여자친구 은하의 귀걸이는 디스코 룩 그 자체. 지난 달 컴백해 ‘스타(star)’로 활동을 이어 가는 이달의 소녀 희진의 드롭 이어링도 마치 그 위에 미러 볼이 반짝일 것 같은 ’80년대 감성이다. 스파게티 스트랩 톱과 찰떡. 지난 15일, 신곡 '이
# ...

# %%
c_di.iloc[0,8] = 2
c_di.iloc[0]
# Out:
# magazine                                                       C
# brand                                                          D
# category                                                 FASHION
# title                                           아이돌들의 '최애' 주얼리는?
# link                 http://v.media.daum.net/v/20201119121642288
# date                                                  2020-11-19
# contents       [['「 Layered Pearl 」', '「 Layered Pearl 」', ''...
# title_brand                                                    0
# check                                                          2
# why                                                          NaN
# Name: 0, dtype: object

# %%
c_di.to_csv('./data/d/c_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
c_di_t = c_di[c_di['check'] != 2]
c_di_t
# Out:
#     magazine brand category                title  \
# 0          C     D  FASHION     아이돌들의 '최애' 주얼리는?
# 4          C     D  FASHION   카디건 이렇게도 입을 수 있어요!
# 6          C     D   CELEBS   미국은 지금 투표가 패션 트렌드!
# 7          C     D  FASHION   소장각! 스마트 기기 액세서리 5
# 8          C     D  FASHION        세련된 필드룩을 보여줄게
# ..       ...   ...      ...                  ...
# 411        C     D  FASHION  소피아 리치의 에슬레저 룩 따라잡기
# 416        C     D  FASHION       화이트 룩 VS 컬러풀 룩
# 417        C     D  FASHION  2016 FW 트렌드, 로고 티셔츠
# 419        C     D   CAREER     가을 바람에 어울릴 헤어 퍼퓸
# 422        C     D  FASHION     시크하게 들거나 손목에 감거나
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201119121642288  2020-11-19
# 4    http://v.media.daum.net/v/20201108000047639  2020-11-08
# 6    http://v.media.daum.net/v/20201028112827008  2020-10-28
# 7    http://v.media.daum.net/v/20201026000029487  2020-10-26
# 8    http://v.media.daum.net/v/20201021001032087  2020-10-21
# ...

# %% [markdown]
# ### Elle

# %%
e_di = pd.read_csv('./data/d/elle_d.csv' , sep='|', encoding='utf-8')
e_di
# Out:
#     magazine brand category                    title  \
# 0          E     D  FASHION     애플 워치 말고 진짜 시계가 그리워서
# 1          E     D  FASHION    코로나 시대에도 패션위크 가능? 가능!
# 2          E     D  FASHION  어머 이건 사야 해! 보송보송 #시어링부츠
# 3          E     D  FASHION  응답하라, 1940! 할리우드 황금기 패션
# 4          E     D   BEAUTY    디올의 뮤즈 지수, 청량한 여름을 닮은
# ..       ...   ...      ...                      ...
# 439        E     D   BEAUTY            미세먼지, 어떡하지 너?
# 440        E     D   BEAUTY              내가 제일 잘 나가!
# 441        E     D  FASHION             심쿵, 프린세스 스토리
# 442        E     D   BEAUTY        K뷰티 아이콘, 24년의 변천사
# 443        E     D   BEAUTY         화장품, 어디서 사는게 이득?
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201120000103797  2020-11-20
# 1    http://v.media.daum.net/v/20201120000117805  2020-11-20
# 2    http://v.media.daum.net/v/20201119000038133  2020-11-19
# 3    http://v.media.daum.net/v/20201108000151657  2020-11-08
# ...

# %%
# date로 정렬
e_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
e_di
# Out:
#     magazine brand category                    title  \
# 0          E     D  FASHION     애플 워치 말고 진짜 시계가 그리워서
# 1          E     D  FASHION    코로나 시대에도 패션위크 가능? 가능!
# 2          E     D  FASHION  어머 이건 사야 해! 보송보송 #시어링부츠
# 3          E     D  FASHION  응답하라, 1940! 할리우드 황금기 패션
# 5          E     D   BEAUTY  -5살 가능? 탄력 올리는 스킨케어 추천템
# ..       ...   ...      ...                      ...
# 188        E     D   BEAUTY               예쁜 입술로 말해요
# 399        E     D  FASHION          블랙과 화이트는 언제나 옳다
# 368        E     D   BEAUTY           허니문을 위한 뷰티 파우치
# 441        E     D  FASHION             심쿵, 프린세스 스토리
# 414        E     D   BEAUTY                신상이 #하태핫태
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201120000103797  2020-11-20
# 1    http://v.media.daum.net/v/20201120000117805  2020-11-20
# 2    http://v.media.daum.net/v/20201119000038133  2020-11-19
# 3    http://v.media.daum.net/v/20201108000151657  2020-11-08
# ...

# %%
e_di.to_csv('./data/d/e_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
e_di = pd.read_csv('./data/d/e_di.csv' , sep='|', encoding='utf-8')
e_di
# Out:
#     magazine brand category                    title  \
# 0          E     D  FASHION     애플 워치 말고 진짜 시계가 그리워서
# 1          E     D  FASHION    코로나 시대에도 패션위크 가능? 가능!
# 2          E     D  FASHION  어머 이건 사야 해! 보송보송 #시어링부츠
# 3          E     D  FASHION  응답하라, 1940! 할리우드 황금기 패션
# 4          E     D   BEAUTY  -5살 가능? 탄력 올리는 스킨케어 추천템
# ..       ...   ...      ...                      ...
# 439        E     D   BEAUTY               예쁜 입술로 말해요
# 440        E     D  FASHION          블랙과 화이트는 언제나 옳다
# 441        E     D   BEAUTY           허니문을 위한 뷰티 파우치
# 442        E     D  FASHION             심쿵, 프린세스 스토리
# 443        E     D   BEAUTY                신상이 #하태핫태
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201120000103797  2020-11-20
# 1    http://v.media.daum.net/v/20201120000117805  2020-11-20
# 2    http://v.media.daum.net/v/20201119000038133  2020-11-19
# 3    http://v.media.daum.net/v/20201108000151657  2020-11-08
# ...

# %%
e_di_t = e_di[e_di['check'] != 2]
e_di_t
# Out:
#     magazine brand category                                    title  \
# 33         E     D   BEAUTY                    디올의 뮤즈 지수, 청량한 여름을 닮은
# 35         E     D  FASHION                    디올의 행운의 주얼리 #로즈드방 컬렉션
# 37         E     D        0    화사하고 로맨틱한 분위기를 낼 땐 디올 어딕트 스텔라 샤인 #536
# 39         E     D     STAR                     인간 미스 디올, 지수의 여름 이야기
# 73         E     D  FASHION         디올 2020 A/W 레디-투-웨어 컬렉션 라이브 스트리밍
# 76         E     D  FASHION                    리한나가 '픽'했다는 디올 북 토트 백
# 80         E     D  FASHION                 지속가능한 패션을 위하여, 디올의 뉴 컬렉션
# 86         E     D  FASHION          디올 오트 쿠튀르 2020 S/S 컬렉션 라이브 스트리밍
# 87         E     D  FASHION                디올의 첫 번째 여자, 마리아 그라치아 치우리
# 89         E     D   BEAUTY                        그라스 장미를 향한 디올의 찬가
# 90         E     D  FASHION                    레이디 디올, 지금 가장 예술적인 가방
# 97         E     D     STAR  디올 캡춰 토탈 스킨케어 뮤즈, 지젤 번천과 디올 뷰티가 함께한 ...
# 98         E     D   BEAUTY                            디올 파운데이션의 특별함
# ...

# %% [markdown]
# ### FashionBiz

# %%
fb_di = pd.read_csv('./data/d/FB_Dior.csv' , sep='|', encoding='utf-8')
fb_di
# Out:
#    magazine brand        category  \
# 0        FB     D  Life & Culture
# 1        FB     D    Today's News
# 2        FB     D  Premium Report
# 3        FB     D    Today's News
# 4        FB     D    Today's News
# 5        FB     D    Today's News
# 6        FB     D    Today's News
# 7        FB     D  Fashion Report
# 8        FB     D    Today's News
# 9        FB     D    Today's News
# 10       FB     D    Today's News
# 11       FB     D    Today's News
# 12       FB     D    Today's News
# 13       FB     D    Today's News
# 14       FB     D    Today's News
# 15       FB     D    Today's News
# 16       FB     D    Today's News
# 17       FB     D    Today's News
# 18       FB     D    Today's News
# 19       FB     D    Today's News
# 20       FB     D    Today's News
# 21       FB     D    Today's News
# 22       FB     D    Today's News
# 23       FB     D      World Wide
# 24       FB     D    Today's News
# 25       FB     D    Today's News
# ...

# %%
# date로 정렬
fb_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
fb_di
# Out:
#    magazine brand        category  \
# 0        FB     D  Life & Culture
# 1        FB     D    Today's News
# 2        FB     D  Premium Report
# 3        FB     D    Today's News
# 4        FB     D    Today's News
# 5        FB     D    Today's News
# 6        FB     D    Today's News
# 7        FB     D  Fashion Report
# 8        FB     D    Today's News
# 9        FB     D    Today's News
# 10       FB     D    Today's News
# 11       FB     D    Today's News
# 12       FB     D    Today's News
# 13       FB     D    Today's News
# 14       FB     D    Today's News
# 15       FB     D    Today's News
# 16       FB     D    Today's News
# 17       FB     D    Today's News
# 18       FB     D    Today's News
# 19       FB     D    Today's News
# 20       FB     D    Today's News
# 21       FB     D    Today's News
# 22       FB     D    Today's News
# 23       FB     D      World Wide
# 24       FB     D    Today's News
# 25       FB     D    Today's News
# ...

# %%
fb_di.to_csv('./data/d/fb_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
fb_di = pd.read_csv('./data/d/fb_di.csv' , sep='|', encoding='utf-8')
fb_di
# Out:
#    magazine brand        category  \
# 0        FB     D  Life & Culture
# 1        FB     D    Today's News
# 2        FB     D  Premium Report
# 3        FB     D    Today's News
# 4        FB     D    Today's News
# 5        FB     D    Today's News
# 6        FB     D    Today's News
# 7        FB     D  Fashion Report
# 8        FB     D    Today's News
# 9        FB     D    Today's News
# 10       FB     D    Today's News
# 11       FB     D    Today's News
# 12       FB     D    Today's News
# 13       FB     D    Today's News
# 14       FB     D    Today's News
# 15       FB     D    Today's News
# 16       FB     D    Today's News
# 17       FB     D    Today's News
# 18       FB     D    Today's News
# 19       FB     D    Today's News
# 20       FB     D    Today's News
# 21       FB     D    Today's News
# 22       FB     D    Today's News
# 23       FB     D      World Wide
# 24       FB     D    Today's News
# 25       FB     D    Today's News
# ...

# %%
fb_di_t = fb_di[fb_di['check'] != 2]
fb_di_t
# Out:
#    magazine brand        category  \
# 0        FB     D  Life & Culture
# 1        FB     D    Today's News
# 2        FB     D  Premium Report
# 3        FB     D    Today's News
# 4        FB     D    Today's News
# 5        FB     D    Today's News
# 6        FB     D    Today's News
# 7        FB     D  Fashion Report
# 8        FB     D    Today's News
# 9        FB     D    Today's News
# 10       FB     D    Today's News
# 11       FB     D    Today's News
# 12       FB     D    Today's News
# 13       FB     D    Today's News
# 14       FB     D    Today's News
# 15       FB     D    Today's News
# 16       FB     D    Today's News
# 17       FB     D    Today's News
# 18       FB     D    Today's News
# 19       FB     D    Today's News
# 20       FB     D    Today's News
# 21       FB     D    Today's News
# 22       FB     D    Today's News
# 23       FB     D      World Wide
# 24       FB     D    Today's News
# 25       FB     D    Today's News
# ...

# %% [markdown]
# ### FashionN

# %%
fn_di = pd.read_csv('./data/d/fashionn_D.csv' , sep='|', encoding='utf-8')
fn_di
# Out:
#     brand category                                 title        date  \
# 0       D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1       D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락  2020-10-30
# 2       D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7  2020-10-10
# 3       D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7  2020-10-10
# 4       D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션  2020-10-10
# ..    ...      ...                                   ...         ...
# 468     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션  2016-10-01
# 469     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’  2016-09-20
# 470     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신  2016-09-08
# 471     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보  2016-09-06
# 472     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다  2016-09-02
#
#                                                   link  title_brand  check  \
# ...

# %%
# date로 정렬
fn_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
fn_di
# Out:
#     brand category                                 title        date  \
# 0       D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1       D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락  2020-10-30
# 2       D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7  2020-10-10
# 3       D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7  2020-10-10
# 4       D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션  2020-10-10
# ..    ...      ...                                   ...         ...
# 468     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션  2016-10-01
# 469     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’  2016-09-20
# 470     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신  2016-09-08
# 471     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보  2016-09-06
# 472     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다  2016-09-02
#
#                                                   link  title_brand  check  \
# ...

# %%
fn_di['magazine'] = 'FN'
fn_di
# Out:
#     brand category                                 title        date  \
# 0       D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1       D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락  2020-10-30
# 2       D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7  2020-10-10
# 3       D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7  2020-10-10
# 4       D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션  2020-10-10
# ..    ...      ...                                   ...         ...
# 468     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션  2016-10-01
# 469     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’  2016-09-20
# 470     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신  2016-09-08
# 471     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보  2016-09-06
# 472     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다  2016-09-02
#
#                                                   link  title_brand  check  \
# ...

# %%
# content -> contents
fn_di = fn_di.rename({'content' : 'contents'}, axis='columns')
fn_di
# Out:
#     brand category                                 title        date  \
# 0       D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33  2020-11-09
# 1       D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락  2020-10-30
# 2       D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7  2020-10-10
# 3       D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7  2020-10-10
# 4       D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션  2020-10-10
# ..    ...      ...                                   ...         ...
# 468     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션  2016-10-01
# 469     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’  2016-09-20
# 470     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신  2016-09-08
# 471     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보  2016-09-06
# 472     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다  2016-09-02
#
#                                                   link  title_brand  check  \
# ...

# %%
fn_di = fn_di[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
fn_di
# Out:
#     magazine brand category                                 title  \
# 0         FN     D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN     D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락
# 2         FN     D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7
# 3         FN     D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7
# 4         FN     D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션
# ..       ...   ...      ...                                   ...
# 468       FN     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션
# 469       FN     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’
# 470       FN     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신
# 471       FN     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보
# 472       FN     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다
#
#                                                   link        date  \
# 0    https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
# ...

# %%
fn_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
fn_di
# Out:
#     magazine brand category                                 title  \
# 0         FN     D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN     D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락
# 2         FN     D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7
# 3         FN     D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7
# 4         FN     D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션
# ..       ...   ...      ...                                   ...
# 468       FN     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션
# 469       FN     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’
# 470       FN     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신
# 471       FN     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보
# 472       FN     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다
#
#                                                   link        date  \
# 0    https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
# ...

# %%
fn_di.to_csv('./data/d/fn_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
fn_di = pd.read_csv('./data/d/fn_di.csv' , sep='|', encoding='utf-8')
fn_di
# Out:
#     magazine brand category                                 title  \
# 0         FN     D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN     D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락
# 2         FN     D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7
# 3         FN     D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7
# 4         FN     D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션
# ..       ...   ...      ...                                   ...
# 468       FN     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션
# 469       FN     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’
# 470       FN     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신
# 471       FN     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보
# 472       FN     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다
#
#                                                   link        date  \
# 0    https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
# ...

# %%
fn_di_t = fn_di[fn_di['check'] != 2]
fn_di_t
# Out:
#     magazine brand category                                 title  \
# 0         FN     D      라이프   굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN     D     월드패션      구찌, 고속성장 시대 끝났나? 3분기 매출 -8.9% 추락
# 2         FN     D       리뷰      [종합] 2021 봄/여름 파리 패션위크 트렌드 키워드 7
# 3         FN     D       리뷰     [종합] 2021 봄/여름 밀라노 패션위크 트렌드 키워드 7
# 4         FN     D       리뷰     [리뷰] 페미니스트 보헤미안, 2021 봄/여름 디올 컬렉션
# ..       ...   ...      ...                                   ...
# 468       FN     D       리뷰   [리뷰]포스트 뉴룩 시대의 개막, 2017 봄/여름 디올 컬렉션
# 469       FN     D     스타패션   경매 큐레이터로 변신한 탑, 품격 있는 블랙 수트 ‘시선 강탈’
# 470       FN     D     월드패션        팜므 파탈 리한나, 담배 피우는 마리 앙뜨와네뜨로 변신
# 471       FN     D     월드패션  [포토] 전설적인 스타일리스트 그레이스 고딩턴의 베스트 패션 화보
# 472       FN     D     월드패션          하이더 아커만, 벨루티의 크리에이티브 디렉터로 간다
#
#                                                   link        date  \
# 0    https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
# ...

# %% [markdown]
# ### Marie Claire

# %%
m_di = pd.read_csv('./data/d/marie_d.csv' , sep='|', encoding='utf-8')
m_di
# Out:
#     magazine brand   category                 title  \
# 0          M     D    fashion     Scenery Of Autumn
# 1          M     D    fashion       <스타트업> 수지 패션 탐구
# 2          M     D     beauty  HAPPY EARLY HOLIDAY!
# 3          M     D  celebrity                이준의 고요
# 4          M     D     beauty                보습의 정석
# ..       ...   ...        ...                   ...
# 584        M     D     beauty         어머 이건 꼭 사야 해!
# 585        M     D     beauty              귀부인의 인생템
# 586        M     D    fashion   2016 브라이덜 주얼리 컬렉션 ②
# 587        M     D  celebrity               뜻밖의 윤소희
# 588        M     D    fashion         Modern Matter
#
#                                                   link     date  \
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020-11
# 1    http://www.marieclairekorea.com/fashion/2020/1...  2020-11
# 2    http://www.marieclairekorea.com/beauty/2020/11...  2020-11
# 3    http://www.marieclairekorea.com/celebrity/2020...  2020-10
# ...

# %%
# date로 정렬
m_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
m_di
# Out:
#     magazine brand category                                 title  \
# 0          M     D  fashion                     Scenery Of Autumn
# 2          M     D   beauty                  HAPPY EARLY HOLIDAY!
# 1          M     D  fashion                       <스타트업> 수지 패션 탐구
# 9          M     D   beauty                 NAIL IN AUTUMN CLOSET
# 15         M     D  fashion                           영원불변의 클래식 백
# ..       ...   ...      ...                                   ...
# 578        M     D  fashion  이런 ‘깔맞춤’이라면 대환영! 샤크스킨(Shark Skin) 컬러
# 577        M     D   beauty               간단하게 변신할 수 있는 4가지 헤어스타일
# 576        M     D   beauty                       가을을 위한 메이크업 팁 3
# 575        M     D  fashion                               나도 디자이너
# 588        M     D  fashion                         Modern Matter
#
#                                                   link     date  \
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020-11
# ...

# %%
m_di.to_csv('./data/d/m_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
m_di = pd.read_csv('./data/d/m_di.csv' , sep='|', encoding='utf-8')
m_di
# Out:
#     magazine brand   category                                 title  \
# 0          M     D    fashion                     Scenery Of Autumn
# 1          M     D    fashion                       <스타트업> 수지 패션 탐구
# 2          M     D     beauty                  HAPPY EARLY HOLIDAY!
# 3          M     D     beauty                      BACK TO THE 90’S
# 4          M     D  celebrity                                이준의 고요
# ..       ...   ...        ...                                   ...
# 584        M     D     beauty                              귀부인의 인생템
# 585        M     D    fashion                   2016 브라이덜 주얼리 컬렉션 ②
# 586        M     D  celebrity                               뜻밖의 윤소희
# 587        M     D    fashion  패션 에디터 최신영의 See It, Buy It, Love It!
# 588        M     D    fashion                         Modern Matter
#
#                                                   link     date  \
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020-11
# ...

# %%
m_di_t = m_di[m_di['check'] != 2]
m_di_t
# Out:
#     magazine brand category                                 title  \
# 1          M     D  fashion                       <스타트업> 수지 패션 탐구
# 6          M     D  fashion   2021 S/S FASHION WEEK REVIEW #PARIS
# 8          M     D  fashion                                니트의 계절
# 14         M     D  fashion                           영원불변의 클래식 백
# 20         M     D  fashion                             여전히 첼시 부츠
# ..       ...   ...      ...                                   ...
# 576        M     D  fashion                               나도 디자이너
# 579        M     D  fashion  이런 ‘깔맞춤’이라면 대환영! 샤크스킨(Shark Skin) 컬러
# 580        M     D  fashion                           이 얼굴을 기억하세요
# 585        M     D  fashion                   2016 브라이덜 주얼리 컬렉션 ②
# 587        M     D  fashion  패션 에디터 최신영의 See It, Buy It, Love It!
#
#                                                   link     date  \
# 1    http://www.marieclairekorea.com/fashion/2020/1...  2020-11
# ...

# %% [markdown]
# ### Vogue

# %%
v_di = pd.read_csv('./data/d/Vogue_Dior.csv' , sep='|', encoding='utf-8')
v_di
# Out:
#     magazine brand     category  \
# 0          V     D      Fashion
# 1          V     D      Fashion
# 2          V     D  daily issue
# 3          V     D       Living
# 4          V     D      Fashion
# ..       ...   ...          ...
# 474        V     D      Fashion
# 475        V     D      Fashion
# 476        V     D       Beauty
# 477        V     D       People
# 478        V     D      Fashion
#
#                                                  title  \
# 0                                       보물 창고 같은 빈티지 숍
# 1                                        패션계 F4를 소개합니다
# 2                                               패션, 아멘
# 3                                     송경아처럼 예쁜 집 꾸미는 법
# 4                                    스트레이 키즈의 후회 없는 순간
# ..                                                 ...
# 474                         #RESORT – Dior Cruise 2017
# 475                                 아시아 최초의 디올 온라인 부티크
# 476                          디올 ‘샤또 드 라 콜 누와르’의 새로운 탄생
# ...

# %%
# date로 정렬
v_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
v_di
# Out:
#     magazine brand     category  \
# 0          V     D      Fashion
# 1          V     D      Fashion
# 2          V     D  daily issue
# 3          V     D       Living
# 4          V     D      Fashion
# ..       ...   ...          ...
# 474        V     D      Fashion
# 475        V     D      Fashion
# 476        V     D       Beauty
# 477        V     D       People
# 478        V     D      Fashion
#
#                                                  title  \
# 0                                       보물 창고 같은 빈티지 숍
# 1                                        패션계 F4를 소개합니다
# 2                                               패션, 아멘
# 3                                     송경아처럼 예쁜 집 꾸미는 법
# 4                                    스트레이 키즈의 후회 없는 순간
# ..                                                 ...
# 474                         #RESORT – Dior Cruise 2017
# 475                                 아시아 최초의 디올 온라인 부티크
# 476                          디올 ‘샤또 드 라 콜 누와르’의 새로운 탄생
# ...

# %%
v_di.to_csv('./data/d/v_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
v_di = pd.read_csv('./data/d/v_di.csv' , sep='|', encoding='utf-8')
v_di
# Out:
#     magazine brand     category  \
# 0          V     D      Fashion
# 1          V     D      Fashion
# 2          V     D  daily issue
# 3          V     D       Living
# 4          V     D      Fashion
# ..       ...   ...          ...
# 474        V     D      Fashion
# 475        V     D      Fashion
# 476        V     D       Beauty
# 477        V     D       People
# 478        V     D      Fashion
#
#                                                  title  \
# 0                                       보물 창고 같은 빈티지 숍
# 1                                        패션계 F4를 소개합니다
# 2                                               패션, 아멘
# 3                                     송경아처럼 예쁜 집 꾸미는 법
# 4                                    스트레이 키즈의 후회 없는 순간
# ..                                                 ...
# 474                         #RESORT – Dior Cruise 2017
# 475                                 아시아 최초의 디올 온라인 부티크
# 476                          디올 ‘샤또 드 라 콜 누와르’의 새로운 탄생
# ...

# %%
v_di_t = v_di[v_di['check'] != 2]
v_di_t
# Out:
#     magazine brand category  \
# 1          V     D  Fashion
# 5          V     D  Fashion
# 6          V     D  Fashion
# 11         V     D  Fashion
# 14         V     D  Fashion
# ..       ...   ...      ...
# 471        V     D  Fashion
# 472        V     D  Fashion
# 475        V     D  Fashion
# 477        V     D   People
# 478        V     D  Fashion
#
#                                                  title  \
# 1                                        패션계 F4를 소개합니다
# 5                                         더보이즈는 지지 않는다
# 6                                    패션쇼가 온라인으로 간 까닭은?
# 11                                          우리 시대의 핸드백
# 14                                      코로나 시대의 오뜨 꾸뛰르
# ..                                                 ...
# 471        London Calling 2 – Cruise In United Kingdom
# 472              London Calling 1 – 디올과 구찌의 초특급 게스트 경쟁
# 475                                 아시아 최초의 디올 온라인 부티크
# 477                                   한국 아티스트들의 레이디 디올
# ...

# %% [markdown]
# ### W

# %%
w_di = pd.read_csv('./data/d/w_D.csv' , sep='|', encoding='utf-8')
w_di
# Out:
#     brand                        category  \
# 0       D  2021 S/S, COLLECTION TV, PARIS
# 1       D                      WHAT'S NEW
# 2       D                FASHION, 쇼핑, 트렌드
# 3       D                      WHAT'S NEW
# 4       D                     FASHION, W맨
# ..    ...                             ...
# 647     D                     FASHION, 뉴스
# 648     D                     FASHION, 뉴스
# 649     D                     FASHION, 화보
# 650     D        FASHION, FEATURE, 피플, 화보
# 651     D                    FASHION, 트렌드
#
#                                      title        date  \
# 0    Dior(디올) 2021 S/S Collection 라이브 스트리밍  2020-09-29
# 1                   니트 버전으로 다시 태어난 디올 바 재킷  2020-09-09
# 2                        디올 바비백, 누가누가 들었나?  2020-06-15
# 3                               디올 바비 백 출시  2020-06-11
# 4           디올X나이키 조던 ‘에어 디올’, 국내 발매일은 언제?  2020-05-20
# ..                                     ...         ...
# 647                                  W해시태그  2016-09-02
# ...

# %%
# date로 정렬
w_di.sort_values(by=['date'], axis=0, ascending=False, inplace=True)
w_di
# Out:
#     brand                  category          title        date  \
# 36      D           FASHION, 쇼핑, 화보            띵동!  2020-11-08
# 37      D          FASHION, 쇼핑, 트렌드          버블 버블  2020-11-06
# 38      D                BEAUTY, 쇼핑  Little Forest  2020-11-06
# 39      D               FASHION, 쇼핑         물드는 계절  2020-11-03
# 40      D          FASHION, 트렌드, 화보          가을 따라  2020-11-02
# ..    ...                       ...            ...         ...
# 647     D               FASHION, 뉴스          W해시태그  2016-09-02
# 648     D               FASHION, 뉴스          마법의 색  2016-09-02
# 649     D               FASHION, 화보        따로 또 같이  2016-09-02
# 650     D  FASHION, FEATURE, 피플, 화보   GET REAL 정일우  2016-09-01
# 651     D              FASHION, 트렌드      너도 나도 베트멍  2016-09-01
#
#                                                   link  title_brand  check  \
# 36   http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...            0      0
# ...

# %%
w_di['magazine'] = 'W'
w_di
# Out:
#     brand                  category          title        date  \
# 36      D           FASHION, 쇼핑, 화보            띵동!  2020-11-08
# 37      D          FASHION, 쇼핑, 트렌드          버블 버블  2020-11-06
# 38      D                BEAUTY, 쇼핑  Little Forest  2020-11-06
# 39      D               FASHION, 쇼핑         물드는 계절  2020-11-03
# 40      D          FASHION, 트렌드, 화보          가을 따라  2020-11-02
# ..    ...                       ...            ...         ...
# 647     D               FASHION, 뉴스          W해시태그  2016-09-02
# 648     D               FASHION, 뉴스          마법의 색  2016-09-02
# 649     D               FASHION, 화보        따로 또 같이  2016-09-02
# 650     D  FASHION, FEATURE, 피플, 화보   GET REAL 정일우  2016-09-01
# 651     D              FASHION, 트렌드      너도 나도 베트멍  2016-09-01
#
#                                                   link  title_brand  check  \
# 36   http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...            0      0
# ...

# %%
# content -> contents
w_di = w_di.rename({'content' : 'contents'}, axis='columns')
w_di
# Out:
#     brand                  category          title        date  \
# 36      D           FASHION, 쇼핑, 화보            띵동!  2020-11-08
# 37      D          FASHION, 쇼핑, 트렌드          버블 버블  2020-11-06
# 38      D                BEAUTY, 쇼핑  Little Forest  2020-11-06
# 39      D               FASHION, 쇼핑         물드는 계절  2020-11-03
# 40      D          FASHION, 트렌드, 화보          가을 따라  2020-11-02
# ..    ...                       ...            ...         ...
# 647     D               FASHION, 뉴스          W해시태그  2016-09-02
# 648     D               FASHION, 뉴스          마법의 색  2016-09-02
# 649     D               FASHION, 화보        따로 또 같이  2016-09-02
# 650     D  FASHION, FEATURE, 피플, 화보   GET REAL 정일우  2016-09-01
# 651     D              FASHION, 트렌드      너도 나도 베트멍  2016-09-01
#
#                                                   link  title_brand  check  \
# 36   http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...            0      0
# ...

# %%
w_di = w_di[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
w_di
# Out:
#     magazine brand                  category          title  \
# 36         W     D           FASHION, 쇼핑, 화보            띵동!
# 37         W     D          FASHION, 쇼핑, 트렌드          버블 버블
# 38         W     D                BEAUTY, 쇼핑  Little Forest
# 39         W     D               FASHION, 쇼핑         물드는 계절
# 40         W     D          FASHION, 트렌드, 화보          가을 따라
# ..       ...   ...                       ...            ...
# 647        W     D               FASHION, 뉴스          W해시태그
# 648        W     D               FASHION, 뉴스          마법의 색
# 649        W     D               FASHION, 화보        따로 또 같이
# 650        W     D  FASHION, FEATURE, 피플, 화보   GET REAL 정일우
# 651        W     D              FASHION, 트렌드      너도 나도 베트멍
#
#                                                   link        date  \
# 36   http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...  2020-11-08
# 37   http://www.wkorea.com/2020/11/06/%eb%b2%84%eb%...  2020-11-06
# ...

# %%
w_di.to_csv('./data/d/w_di.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
w_di = pd.read_csv('./data/d/w_di.csv' , sep='|', encoding='utf-8')
w_di
# Out:
#     magazine brand                  category          title  \
# 0          W     D           FASHION, 쇼핑, 화보            띵동!
# 1          W     D          FASHION, 쇼핑, 트렌드          버블 버블
# 2          W     D                BEAUTY, 쇼핑  Little Forest
# 3          W     D               FASHION, 쇼핑         물드는 계절
# 4          W     D          FASHION, 트렌드, 화보          가을 따라
# ..       ...   ...                       ...            ...
# 647        W     D               FASHION, 뉴스          W해시태그
# 648        W     D               FASHION, 뉴스          마법의 색
# 649        W     D               FASHION, 화보        따로 또 같이
# 650        W     D  FASHION, FEATURE, 피플, 화보   GET REAL 정일우
# 651        W     D              FASHION, 트렌드      너도 나도 베트멍
#
#                                                   link        date  \
# 0    http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...  2020-11-08
# 1    http://www.wkorea.com/2020/11/06/%eb%b2%84%eb%...  2020-11-06
# ...

# %%
w_di_t = w_di[w_di['check'] != 2]
w_di_t
# Out:
#     magazine brand          category      title  \
# 0          W     D   FASHION, 쇼핑, 화보        띵동!
# 1          W     D  FASHION, 쇼핑, 트렌드      버블 버블
# 3          W     D       FASHION, 쇼핑     물드는 계절
# 4          W     D  FASHION, 트렌드, 화보      가을 따라
# 5          W     D      FASHION, 트렌드  뉴 패션쇼 스케치
# ..       ...   ...               ...        ...
# 646        W     D  FASHION, 쇼핑, 트렌드    가을의 하이킹
# 647        W     D       FASHION, 뉴스      W해시태그
# 648        W     D       FASHION, 뉴스      마법의 색
# 649        W     D       FASHION, 화보    따로 또 같이
# 651        W     D      FASHION, 트렌드  너도 나도 베트멍
#
#                                                   link        date  \
# 0    http://www.wkorea.com/2020/11/08/%eb%9d%b5%eb%...  2020-11-08
# 1    http://www.wkorea.com/2020/11/06/%eb%b2%84%eb%...  2020-11-06
# 3    http://www.wkorea.com/2020/11/03/%eb%ac%bc%eb%...  2020-11-03
# 4    http://www.wkorea.com/2020/11/02/%ea%b0%80%ec%...  2020-11-02
# ...
