# %%
import pandas as pd
import numpy as np

# %%
FB_Ch = pd.read_csv('./data/FashionBiz_Chanel_contents.csv' , sep='|', encoding='utf-8')
FB_Ch
# Out:
#                                title        date  \
# 0     [월드] 가브리엘 샤넬, 파리 의상 박물관서 첫 회고전  2020/10/14
# 1           랩시리즈, 브랜드 새 얼굴에 '장기용' 발탁  2020/09/01
# 2     [월드] 에레스, 팬데믹에도 파리 뉴 콘셉트 매장 오픈  2020/08/20
# 3      [월요기획] 에르메스~나이키, 온라인 중심 수입 재편  2020/06/01
# 4    [월드] 코로나19, 명품·스포츠 등 극과 극 대처법은?  2020/04/10
# 5   [월드] 佛 에르메스·샤넬 등 코로나19로 매장 공장 휴업  2020/03/23
# 6    [월드] 루이비통 등 럭셔리 메종, 호텔·카페로 진화 중  2020/02/06
# 7          샤넬, 롯데백화점 본점서 샹스 향수 팝업 진행  2020/02/04
# 8       [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장  2020/01/23
# 9            김영일 발렌시아 대표, 두번째 에세이 출간  2020/01/16
# 10    [포토뉴스]샤넬 N°5, 코엑스 광장에 아이스링크 오픈  2019/12/13
# 11      세포라부터 디올까지, 쇼핑몰 지하로 온 글로벌 뷰티  2019/11/08
# 12       페루 패션 박람회 온다! 친환경 알파카 섬유 특화  2019/10/04
# 13         [월드] 패션계 거장 칼 라거펠트 별이 되다!  2019/02/21
# 14  '샤넬 아이콘' 칼 라거펠트 타계 ... 패션계 애도 물결  2019/02/20
# 15      [월드] 칼 라거펠트, 샤넬 오트쿠튀르 피날레 불참  2019/01/28
# 16    [월드] 샤넬, 럭셔리 최초 '특수피혁 사용중단' 선언  2018/12/12
# 17            샤넬, 남성만을 위한 뷰티 공간 어디에?  2018/12/03
# ...

# %%
# magazine column 추가
FB_Ch['magazine'] = 'FB'
FB_Ch
# Out:
#                                title        date  \
# 0     [월드] 가브리엘 샤넬, 파리 의상 박물관서 첫 회고전  2020/10/14
# 1           랩시리즈, 브랜드 새 얼굴에 '장기용' 발탁  2020/09/01
# 2     [월드] 에레스, 팬데믹에도 파리 뉴 콘셉트 매장 오픈  2020/08/20
# 3      [월요기획] 에르메스~나이키, 온라인 중심 수입 재편  2020/06/01
# 4    [월드] 코로나19, 명품·스포츠 등 극과 극 대처법은?  2020/04/10
# 5   [월드] 佛 에르메스·샤넬 등 코로나19로 매장 공장 휴업  2020/03/23
# 6    [월드] 루이비통 등 럭셔리 메종, 호텔·카페로 진화 중  2020/02/06
# 7          샤넬, 롯데백화점 본점서 샹스 향수 팝업 진행  2020/02/04
# 8       [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장  2020/01/23
# 9            김영일 발렌시아 대표, 두번째 에세이 출간  2020/01/16
# 10    [포토뉴스]샤넬 N°5, 코엑스 광장에 아이스링크 오픈  2019/12/13
# 11      세포라부터 디올까지, 쇼핑몰 지하로 온 글로벌 뷰티  2019/11/08
# 12       페루 패션 박람회 온다! 친환경 알파카 섬유 특화  2019/10/04
# 13         [월드] 패션계 거장 칼 라거펠트 별이 되다!  2019/02/21
# 14  '샤넬 아이콘' 칼 라거펠트 타계 ... 패션계 애도 물결  2019/02/20
# 15      [월드] 칼 라거펠트, 샤넬 오트쿠튀르 피날레 불참  2019/01/28
# 16    [월드] 샤넬, 럭셔리 최초 '특수피혁 사용중단' 선언  2018/12/12
# 17            샤넬, 남성만을 위한 뷰티 공간 어디에?  2018/12/03
# ...

# %%
# Brand -> brand
FB_Ch = FB_Ch.rename({'Brand' : 'brand'}, axis='columns')
FB_Ch
# Out:
#                                title        date  \
# 0     [월드] 가브리엘 샤넬, 파리 의상 박물관서 첫 회고전  2020/10/14
# 1           랩시리즈, 브랜드 새 얼굴에 '장기용' 발탁  2020/09/01
# 2     [월드] 에레스, 팬데믹에도 파리 뉴 콘셉트 매장 오픈  2020/08/20
# 3      [월요기획] 에르메스~나이키, 온라인 중심 수입 재편  2020/06/01
# 4    [월드] 코로나19, 명품·스포츠 등 극과 극 대처법은?  2020/04/10
# 5   [월드] 佛 에르메스·샤넬 등 코로나19로 매장 공장 휴업  2020/03/23
# 6    [월드] 루이비통 등 럭셔리 메종, 호텔·카페로 진화 중  2020/02/06
# 7          샤넬, 롯데백화점 본점서 샹스 향수 팝업 진행  2020/02/04
# 8       [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장  2020/01/23
# 9            김영일 발렌시아 대표, 두번째 에세이 출간  2020/01/16
# 10    [포토뉴스]샤넬 N°5, 코엑스 광장에 아이스링크 오픈  2019/12/13
# 11      세포라부터 디올까지, 쇼핑몰 지하로 온 글로벌 뷰티  2019/11/08
# 12       페루 패션 박람회 온다! 친환경 알파카 섬유 특화  2019/10/04
# 13         [월드] 패션계 거장 칼 라거펠트 별이 되다!  2019/02/21
# 14  '샤넬 아이콘' 칼 라거펠트 타계 ... 패션계 애도 물결  2019/02/20
# 15      [월드] 칼 라거펠트, 샤넬 오트쿠튀르 피날레 불참  2019/01/28
# 16    [월드] 샤넬, 럭셔리 최초 '특수피혁 사용중단' 선언  2018/12/12
# 17            샤넬, 남성만을 위한 뷰티 공간 어디에?  2018/12/03
# ...

# %%
# column 순서
FB_Ch = FB_Ch[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]
FB_Ch
# Out:
#    magazine brand      category                             title  \
# 0        FB    Ch  Today's News    [월드] 가브리엘 샤넬, 파리 의상 박물관서 첫 회고전
# 1        FB    Ch  Today's News          랩시리즈, 브랜드 새 얼굴에 '장기용' 발탁
# 2        FB    Ch  Today's News    [월드] 에레스, 팬데믹에도 파리 뉴 콘셉트 매장 오픈
# 3        FB    Ch  Today's News     [월요기획] 에르메스~나이키, 온라인 중심 수입 재편
# 4        FB    Ch  Today's News   [월드] 코로나19, 명품·스포츠 등 극과 극 대처법은?
# 5        FB    Ch  Today's News  [월드] 佛 에르메스·샤넬 등 코로나19로 매장 공장 휴업
# 6        FB    Ch  Today's News   [월드] 루이비통 등 럭셔리 메종, 호텔·카페로 진화 중
# 7        FB    Ch  Today's News         샤넬, 롯데백화점 본점서 샹스 향수 팝업 진행
# 8        FB    Ch  Today's News      [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장
# 9        FB    Ch  Today's News           김영일 발렌시아 대표, 두번째 에세이 출간
# 10       FB    Ch  Today's News    [포토뉴스]샤넬 N°5, 코엑스 광장에 아이스링크 오픈
# 11       FB    Ch  Today's News      세포라부터 디올까지, 쇼핑몰 지하로 온 글로벌 뷰티
# 12       FB    Ch  Today's News       페루 패션 박람회 온다! 친환경 알파카 섬유 특화
# ...

# %%
FB_Ch.to_csv('./data/FB_Chanel.csv' , sep='|', mode='w' , encoding='utf-8' , index=False)
print('success')
# Out:
# success

# %%
FB_Ch = pd.read_csv('./data/FB_Chanel.csv' , sep='|', encoding='utf-8')
FB_Ch
# Out:
#    magazine brand      category                             title  \
# 0        FB    Ch  Today's News    [월드] 가브리엘 샤넬, 파리 의상 박물관서 첫 회고전
# 1        FB    Ch  Today's News          랩시리즈, 브랜드 새 얼굴에 '장기용' 발탁
# 2        FB    Ch  Today's News    [월드] 에레스, 팬데믹에도 파리 뉴 콘셉트 매장 오픈
# 3        FB    Ch  Today's News     [월요기획] 에르메스~나이키, 온라인 중심 수입 재편
# 4        FB    Ch  Today's News   [월드] 코로나19, 명품·스포츠 등 극과 극 대처법은?
# 5        FB    Ch  Today's News  [월드] 佛 에르메스·샤넬 등 코로나19로 매장 공장 휴업
# 6        FB    Ch  Today's News   [월드] 루이비통 등 럭셔리 메종, 호텔·카페로 진화 중
# 7        FB    Ch  Today's News         샤넬, 롯데백화점 본점서 샹스 향수 팝업 진행
# 8        FB    Ch  Today's News      [포토뉴스]디올뷰티 롯데월드몰, 고급 살롱처럼 단장
# 9        FB    Ch  Today's News           김영일 발렌시아 대표, 두번째 에세이 출간
# 10       FB    Ch  Today's News    [포토뉴스]샤넬 N°5, 코엑스 광장에 아이스링크 오픈
# 11       FB    Ch  Today's News      세포라부터 디올까지, 쇼핑몰 지하로 온 글로벌 뷰티
# 12       FB    Ch  Today's News       페루 패션 박람회 온다! 친환경 알파카 섬유 특화
# ...
